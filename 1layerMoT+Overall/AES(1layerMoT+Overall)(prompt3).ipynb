# %%
prompt_id = 3
model_name = "1LayerMoTOverall"  # 1LayerOverall, 1LayerMoTOverall, 2LayerOverall

# %%
import os
import pprint
import tensorflow as tf

if 'COLAB_TPU_ADDR' not in os.environ:
  print('ERROR: Not connected to a TPU runtime')
else:
  tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
  print ('TPU address is', tpu_address)

  with tf.Session(tpu_address) as session:
    devices = session.list_devices()

  print('TPU devices:')
  pprint.pprint(devices)
# Out:
# TPU address is grpc://10.61.214.26:8470
# TPU devices:
# [_DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:CPU:0, CPU, -1, 5188902736519512469),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 7648522961505141753),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 11216303742004774514),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 6036689190546167151),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 466739836904683614),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 4745411700155189269),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 3920864059110025860),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 7079720630169887235),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 3371527435764460305),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 12056242569304908371),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 8589934592, 17708719673180569970)]

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/My Drive/AES謝"
os.chdir(path)
# os.listdir(path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import argparse
import nltk
import tensorflow as tf
from keras.models import Model
from keras import layers
from keras.layers import Input, concatenate, Embedding, LSTM, Dense, Lambda
from keras.engine.topology import Layer
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
import re
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
import keras.backend as K
from sklearn.model_selection import KFold
from sklearn.metrics import cohen_kappa_score
from sklearn.preprocessing import StandardScaler
from keras.preprocessing.sequence import pad_sequences
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')

nltk.download('stopwords')
nltk.download('punkt')
# stopwords, punkt,
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Mean Over Time
class TemporalMean(Layer):
  def __init__(self, **kwargs):
      self.supports_masking = True
      super(TemporalMean, self).__init__(**kwargs)

  def compute_mask(self, input, input_mask=None):
      # do not pass the mask to the next layers
      return None

  def call(self, x, mask=None):
      if mask is not None:
          # mask (batch, time)
          mask = K.cast(mask, K.floatx())
          # mask (batch, x_dim, time)
          mask = K.repeat(mask, x.shape[-1])
          # mask (batch, time, x_dim)
          mask = tf.transpose(mask, [0,2,1])
          x = x * mask
      return K.sum(x, axis=1) / K.sum(mask, axis=1)

  def compute_output_shape(self, input_shape):
      # remove temporal dimension
      return (input_shape[0], input_shape[2])

def essay_to_wordlist(essay_v, remove_stopwords):
    """Remove the tagged labels and word tokenize the sentence."""
    essay_v = re.sub("[^a-zA-Z]", " ", essay_v)
    words = essay_v.lower().split()
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    return (words)

def get_clean_essays(Text):
    clean_essays = []
    for essay in Text:
        clean_essays.append(essay_to_wordlist(essay, remove_stopwords=False))
    return clean_essays

def create_dict(text):
    print("create_dict")
    word_index = {}
    word_index['xieyikuan'] = 0
    for sentence in text:
        for word in sentence:
            if word not in word_index:
                word_index[word] = len(word_index)
    word_index['unk'] = len(word_index)
    return word_index

def essay_to_index(essays, word_index):
    Essays = []
    for essay in essays:
        sentence = []
        for sent in essay:
            words = []
            for word in sent:
                words.append(word_index[word])
            sentence.append(words)
        Essays.append(sentence)
    return Essays

def essay_to_index2(essays, word_index):
    Essays = []
    for essay in essays:
        words = []
        for word in essay:
            words.append(word_index[word])
        Essays.append(words)
    return Essays

def get_embeddings_index():
    embeddings_index = {}
    f = open('glove.6B.50d.txt', 'r', encoding='UTF-8')
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.array(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    f.close()
    return embeddings_index

def embeddings_matrix(embeddings_index, word_index, embedding_dim):
    nb_words = len(word_index)
    embedding_matrix = np.zeros((nb_words + 1, embedding_dim))
    for word, i in word_index.items():
        if i > nb_words:
            continue
        embeddings_vector = embeddings_index.get(word)
        if embeddings_vector is not None:
            embedding_matrix[i] = embeddings_vector
        if embeddings_vector is None:
            embedding_matrix[i] = embeddings_index.get('unk')
    return embedding_matrix

# %%
csv_input = pd.read_csv(filepath_or_buffer="data_feature/set"+str(prompt_id)+"_feature(26).tsv", delimiter="\t", engine="python", error_bad_lines=False)

Text = csv_input['essay']
Score = csv_input['domain1_score']
Label = Score

# --------
if prompt_id == 1:
    Score = (Score - 2) / 10      # set_1     范围 2-12
elif prompt_id == 2:
    Score = (Score - 1) / 5       # set_2     范围 1-6
elif prompt_id == 3 or prompt_id == 4:
    Score = Score / 3           # set_3,4   范围 0-3
elif prompt_id == 5 or prompt_id == 6:
    Score = Score / 4           # set_5,6   范围 0-4
elif prompt_id == 7:
    Score = Score / 30          # set_7     范围 0-30
elif prompt_id == 8:
    Score = Score / 60          # set_8     范围 0-60

# get Overall Feature
overall_feature = csv_input[['word_count', 'avg_word_len', 'sentence_count', 'avg_sentence_len', 'lemma_count', 'noun_count', 'adj_count', 'adv_count', 'verb_count', 'cc_count',
                             'syllable_count', 'flesch_reading_ease', 'smog_index', 'flesch_kincaid_grade', 'coleman_liau_index', 'automated_readability_index',
                             'dale_chall_readability_score', 'difficult_words', 'linsear_write_formula',
                             'gunning_fog', 'spelling_errors', 'exc_count', 'que_count', 'comma_count', 'stopwords_num']]
# overall_feature = np.array(np.sqrt(overall_feature))
overall_feature = np.array(overall_feature)
num_feature = 25
where_are_nan = np.isnan(overall_feature)
where_are_inf = np.isinf(overall_feature)
overall_feature[where_are_nan] = 0
overall_feature[where_are_inf] = 0
# standardized
stdsc = StandardScaler()
overall_feature = stdsc.fit_transform(overall_feature)

# 做字典
clean_essays = get_clean_essays(Text)
word_index = create_dict(clean_essays)

# 做分句
text = np.array(Text)
# print(text)
a = []
for essay in text:
    a.append(sent_tokenize(essay))
texts = np.array(a)

# 做分词
essays = []
for essay in Text:
  essay_idx = essay_to_wordlist(essay, remove_stopwords=False)
  essays.append(essay_idx)
essays = np.array(essays)

Essays = essay_to_index2(clean_essays, word_index)
Essays = np.array(Essays)

if prompt_id == 1:
    max_essay_length = 600
elif prompt_id == 2:
    max_essay_length = 700
elif prompt_id == 3:
    max_essay_length = 256
elif prompt_id == 4:
    max_essay_length = 200
elif prompt_id == 5:
    max_essay_length = 256
elif prompt_id == 6:
    max_essay_length = 256
elif prompt_id == 7:
    max_essay_length = 350
elif prompt_id == 8:
    max_essay_length = 870

essay_pad = pad_sequences(Essays, maxlen=max_essay_length)

embeddings_index = get_embeddings_index()
embeddings_matrix = embeddings_matrix(embeddings_index, word_index, embedding_dim=50)

# 记录成绩
results = []
score_predict_list = []
sssscore = []
llllabel = []
newresults = []
cv = KFold(n_splits=5, shuffle=True, random_state=10)
count = 0
for train, test in cv.split(essay_pad):
    text_train, text_test = essay_pad[train], essay_pad[test]
    label_train, label_test = Score.iloc[train], Score.iloc[test]
    score_train, score_test = Label.iloc[train], Label.iloc[test]
    overall_train, overall_test = overall_feature[train], overall_feature[test]

    print('Build model '+str(count)+'...')
    count += 1

    # -------
    text_input = Input(shape=(max_essay_length, ), name='text_input')
    overall_feature_input = Input(shape=(num_feature,), name='overall_feature_input')

    embedding_layer = Embedding(input_dim=len(word_index) + 1,
                                output_dim=50,
                                weights=[embeddings_matrix],
                                input_length=max_essay_length,
                                trainable=True,
                                mask_zero=True)
    x = embedding_layer(text_input)  
    if model_name == "2LayerOverall":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)
    elif model_name == "1LayerMoTOverall":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)
      x = TemporalMean()(x)
    elif model_name == "1LayerOverall":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)
    x = layers.Dropout(0.5)(x)
    concat_layer = Lambda(concatenate)([x, overall_feature_input])
    output = Dense(1, activation='sigmoid')(concat_layer)

    model = Model(inputs=[text_input, overall_feature_input], outputs=output)
    # -------

    model.summary()
    model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001, decay=1e-6), metrics=['mean_absolute_error'])
    model.fit([text_train, overall_train], label_train, batch_size=32, epochs=50, verbose=2)

    score_predict = model.predict([text_test, overall_test])
    if prompt_id == 1:
        score_predict = score_predict*10+2
    elif prompt_id == 2:
        score_predict = score_predict*5+1
    elif prompt_id == 3:
        score_predict = score_predict*3
    elif prompt_id == 4:
        score_predict = score_predict*3
    elif prompt_id == 5:
        score_predict = score_predict*4
    elif prompt_id == 6:
        score_predict = score_predict*4
    elif prompt_id == 7:
        score_predict = score_predict*30
    elif prompt_id == 8:
        score_predict = score_predict*60

    score_predict = np.around(score_predict)

    sssscore.append(score_predict)
    llllabel.append(score_test)

    result = cohen_kappa_score(score_test.values, score_predict, weights='quadratic')
    print("Kappa Score: {}".format(result))
    results.append(result)
    for i in results:
      if i != 0:
        newresults.append(i)

print("Average Kappa score after a 5-fold cross validation: ", np.around(np.array(newresults).mean(), decimals=5))

sssscore = np.array(sssscore)
res = []
for scores in sssscore:
  for score in scores:
    res.append(score)

ll = np.array(llllabel)
res_label = []
for labels in ll:
  for label in labels:
    res_label.append(label)
res_label = np.array(res_label)

QWK = cohen_kappa_score(res_label, res, weights='quadratic')
print("Kappa score after a 5-fold cross validation: ", QWK)
# Out:
# create_dict
# Build model 0...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3239: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 256)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 256, 50)      317500      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 256, 300)     421200      embedding_1[0][0]
# __________________________________________________________________________________________________
# temporal_mean_1 (TemporalMean)  (None, 300)          0           lstm_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 300)          0           temporal_mean_1[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 325)          0           dropout_1[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            326         lambda_1[0][0]
# ==================================================================================================
# Total params: 739,026
# Trainable params: 739,026
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/50
#  - 57s - loss: 0.0636 - mean_absolute_error: 0.2047
# Epoch 2/50
#  - 57s - loss: 0.0418 - mean_absolute_error: 0.1656
# Epoch 3/50
#  - 57s - loss: 0.0370 - mean_absolute_error: 0.1525
# Epoch 4/50
#  - 57s - loss: 0.0351 - mean_absolute_error: 0.1489
# Epoch 5/50
#  - 58s - loss: 0.0351 - mean_absolute_error: 0.1474
# Epoch 6/50
#  - 58s - loss: 0.0345 - mean_absolute_error: 0.1453
# Epoch 7/50
#  - 57s - loss: 0.0340 - mean_absolute_error: 0.1444
# Epoch 8/50
#  - 58s - loss: 0.0332 - mean_absolute_error: 0.1432
# Epoch 9/50
#  - 58s - loss: 0.0333 - mean_absolute_error: 0.1442
# Epoch 10/50
#  - 57s - loss: 0.0325 - mean_absolute_error: 0.1411
# Epoch 11/50
#  - 57s - loss: 0.0317 - mean_absolute_error: 0.1389
# Epoch 12/50
#  - 57s - loss: 0.0312 - mean_absolute_error: 0.1381
# Epoch 13/50
#  - 57s - loss: 0.0305 - mean_absolute_error: 0.1359
# Epoch 14/50
#  - 57s - loss: 0.0299 - mean_absolute_error: 0.1350
# Epoch 15/50
#  - 57s - loss: 0.0302 - mean_absolute_error: 0.1353
# Epoch 16/50
#  - 57s - loss: 0.0291 - mean_absolute_error: 0.1331
# Epoch 17/50
#  - 58s - loss: 0.0282 - mean_absolute_error: 0.1300
# Epoch 18/50
#  - 58s - loss: 0.0286 - mean_absolute_error: 0.1311
# Epoch 19/50
#  - 57s - loss: 0.0271 - mean_absolute_error: 0.1281
# Epoch 20/50
#  - 57s - loss: 0.0276 - mean_absolute_error: 0.1287
# Epoch 21/50
#  - 57s - loss: 0.0258 - mean_absolute_error: 0.1246
# Epoch 22/50
#  - 57s - loss: 0.0251 - mean_absolute_error: 0.1220
# Epoch 23/50
#  - 57s - loss: 0.0238 - mean_absolute_error: 0.1181
# Epoch 24/50
#  - 57s - loss: 0.0227 - mean_absolute_error: 0.1149
# Epoch 25/50
#  - 58s - loss: 0.0223 - mean_absolute_error: 0.1136
# Epoch 26/50
#  - 57s - loss: 0.0202 - mean_absolute_error: 0.1098
# Epoch 27/50
#  - 58s - loss: 0.0209 - mean_absolute_error: 0.1106
# Epoch 28/50
#  - 58s - loss: 0.0193 - mean_absolute_error: 0.1063
# Epoch 29/50
#  - 58s - loss: 0.0188 - mean_absolute_error: 0.1036
# Epoch 30/50
#  - 57s - loss: 0.0172 - mean_absolute_error: 0.0995
# Epoch 31/50
#  - 58s - loss: 0.0173 - mean_absolute_error: 0.1009
# Epoch 32/50
#  - 57s - loss: 0.0165 - mean_absolute_error: 0.0990
# Epoch 33/50
#  - 58s - loss: 0.0159 - mean_absolute_error: 0.0960
# Epoch 34/50
#  - 58s - loss: 0.0149 - mean_absolute_error: 0.0941
# Epoch 35/50
#  - 57s - loss: 0.0147 - mean_absolute_error: 0.0940
# Epoch 36/50
#  - 57s - loss: 0.0137 - mean_absolute_error: 0.0898
# Epoch 37/50
#  - 57s - loss: 0.0129 - mean_absolute_error: 0.0873
# Epoch 38/50
#  - 57s - loss: 0.0123 - mean_absolute_error: 0.0842
# Epoch 39/50
#  - 56s - loss: 0.0125 - mean_absolute_error: 0.0847
# Epoch 40/50
#  - 57s - loss: 0.0116 - mean_absolute_error: 0.0818
# Epoch 41/50
#  - 57s - loss: 0.0115 - mean_absolute_error: 0.0804
# Epoch 42/50
#  - 57s - loss: 0.0106 - mean_absolute_error: 0.0786
# Epoch 43/50
#  - 57s - loss: 0.0106 - mean_absolute_error: 0.0780
# Epoch 44/50
#  - 57s - loss: 0.0109 - mean_absolute_error: 0.0792
# Epoch 45/50
#  - 57s - loss: 0.0104 - mean_absolute_error: 0.0791
# Epoch 46/50
#  - 56s - loss: 0.0100 - mean_absolute_error: 0.0757
# Epoch 47/50
#  - 56s - loss: 0.0093 - mean_absolute_error: 0.0715
# Epoch 48/50
#  - 56s - loss: 0.0094 - mean_absolute_error: 0.0719
# Epoch 49/50
#  - 57s - loss: 0.0093 - mean_absolute_error: 0.0737
# Epoch 50/50
#  - 56s - loss: 0.0094 - mean_absolute_error: 0.0725
# Kappa Score: 0.5829744589799843
# Build model 1...
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 256)          0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 256, 50)      317500      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 256, 300)     421200      embedding_2[0][0]
# __________________________________________________________________________________________________
# temporal_mean_2 (TemporalMean)  (None, 300)          0           lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 300)          0           temporal_mean_2[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 325)          0           dropout_2[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            326         lambda_2[0][0]
# ==================================================================================================
# Total params: 739,026
# Trainable params: 739,026
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 58s - loss: 0.0683 - mean_absolute_error: 0.2163
# Epoch 2/50
#  - 56s - loss: 0.0439 - mean_absolute_error: 0.1704
# Epoch 3/50
#  - 57s - loss: 0.0370 - mean_absolute_error: 0.1512
# Epoch 4/50
#  - 57s - loss: 0.0369 - mean_absolute_error: 0.1512
# Epoch 5/50
#  - 57s - loss: 0.0360 - mean_absolute_error: 0.1483
# Epoch 6/50
#  - 58s - loss: 0.0345 - mean_absolute_error: 0.1444
# Epoch 7/50
#  - 57s - loss: 0.0342 - mean_absolute_error: 0.1425
# Epoch 8/50
#  - 57s - loss: 0.0332 - mean_absolute_error: 0.1411
# Epoch 9/50
#  - 57s - loss: 0.0334 - mean_absolute_error: 0.1422
# Epoch 10/50
#  - 57s - loss: 0.0335 - mean_absolute_error: 0.1433
# Epoch 11/50
#  - 57s - loss: 0.0321 - mean_absolute_error: 0.1384
# Epoch 12/50
#  - 57s - loss: 0.0319 - mean_absolute_error: 0.1376
# Epoch 13/50
#  - 57s - loss: 0.0317 - mean_absolute_error: 0.1376
# Epoch 14/50
#  - 57s - loss: 0.0314 - mean_absolute_error: 0.1378
# Epoch 15/50
#  - 57s - loss: 0.0305 - mean_absolute_error: 0.1348
# Epoch 16/50
#  - 57s - loss: 0.0300 - mean_absolute_error: 0.1346
# Epoch 17/50
#  - 58s - loss: 0.0306 - mean_absolute_error: 0.1356
# Epoch 18/50
#  - 58s - loss: 0.0299 - mean_absolute_error: 0.1337
# Epoch 19/50
#  - 58s - loss: 0.0281 - mean_absolute_error: 0.1291
# Epoch 20/50
#  - 58s - loss: 0.0280 - mean_absolute_error: 0.1283
# Epoch 21/50
#  - 58s - loss: 0.0269 - mean_absolute_error: 0.1265
# Epoch 22/50
#  - 58s - loss: 0.0267 - mean_absolute_error: 0.1254
# Epoch 23/50
#  - 57s - loss: 0.0255 - mean_absolute_error: 0.1232
# Epoch 24/50
#  - 57s - loss: 0.0243 - mean_absolute_error: 0.1203
# Epoch 25/50
#  - 57s - loss: 0.0247 - mean_absolute_error: 0.1219
# Epoch 26/50
#  - 58s - loss: 0.0217 - mean_absolute_error: 0.1136
# Epoch 27/50
#  - 58s - loss: 0.0210 - mean_absolute_error: 0.1117
# Epoch 28/50
#  - 57s - loss: 0.0205 - mean_absolute_error: 0.1089
# Epoch 29/50
#  - 57s - loss: 0.0203 - mean_absolute_error: 0.1099
# Epoch 30/50
#  - 57s - loss: 0.0189 - mean_absolute_error: 0.1074
# Epoch 31/50
#  - 57s - loss: 0.0185 - mean_absolute_error: 0.1030
# Epoch 32/50
#  - 57s - loss: 0.0169 - mean_absolute_error: 0.0985
# Epoch 33/50
#  - 57s - loss: 0.0158 - mean_absolute_error: 0.0964
# Epoch 34/50
#  - 57s - loss: 0.0156 - mean_absolute_error: 0.0957
# Epoch 35/50
#  - 57s - loss: 0.0148 - mean_absolute_error: 0.0938
# Epoch 36/50
#  - 57s - loss: 0.0147 - mean_absolute_error: 0.0932
# Epoch 37/50
#  - 58s - loss: 0.0144 - mean_absolute_error: 0.0924
# Epoch 38/50
#  - 58s - loss: 0.0142 - mean_absolute_error: 0.0904
# Epoch 39/50
#  - 58s - loss: 0.0135 - mean_absolute_error: 0.0894
# Epoch 40/50
#  - 57s - loss: 0.0131 - mean_absolute_error: 0.0870
# Epoch 41/50
#  - 58s - loss: 0.0121 - mean_absolute_error: 0.0845
# Epoch 42/50
#  - 58s - loss: 0.0120 - mean_absolute_error: 0.0851
# Epoch 43/50
#  - 58s - loss: 0.0113 - mean_absolute_error: 0.0814
# Epoch 44/50
#  - 57s - loss: 0.0107 - mean_absolute_error: 0.0789
# Epoch 45/50
#  - 57s - loss: 0.0100 - mean_absolute_error: 0.0757
# Epoch 46/50
#  - 57s - loss: 0.0101 - mean_absolute_error: 0.0764
# Epoch 47/50
#  - 57s - loss: 0.0102 - mean_absolute_error: 0.0779
# Epoch 48/50
#  - 58s - loss: 0.0095 - mean_absolute_error: 0.0749
# Epoch 49/50
#  - 58s - loss: 0.0094 - mean_absolute_error: 0.0727
# Epoch 50/50
#  - 58s - loss: 0.0100 - mean_absolute_error: 0.0744
# Kappa Score: 0.5942009163646311
# Build model 2...
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 256)          0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 256, 50)      317500      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 256, 300)     421200      embedding_3[0][0]
# __________________________________________________________________________________________________
# temporal_mean_3 (TemporalMean)  (None, 300)          0           lstm_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 300)          0           temporal_mean_3[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 325)          0           dropout_3[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            326         lambda_3[0][0]
# ==================================================================================================
# Total params: 739,026
# Trainable params: 739,026
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 59s - loss: 0.0805 - mean_absolute_error: 0.2354
# Epoch 2/50
#  - 58s - loss: 0.0490 - mean_absolute_error: 0.1817
# Epoch 3/50
#  - 59s - loss: 0.0417 - mean_absolute_error: 0.1649
# Epoch 4/50
#  - 59s - loss: 0.0387 - mean_absolute_error: 0.1559
# Epoch 5/50
#  - 59s - loss: 0.0374 - mean_absolute_error: 0.1519
# Epoch 6/50
#  - 59s - loss: 0.0363 - mean_absolute_error: 0.1501
# Epoch 7/50
#  - 59s - loss: 0.0362 - mean_absolute_error: 0.1490
# Epoch 8/50
#  - 58s - loss: 0.0349 - mean_absolute_error: 0.1455
# Epoch 9/50
#  - 58s - loss: 0.0348 - mean_absolute_error: 0.1451
# Epoch 10/50
#  - 58s - loss: 0.0348 - mean_absolute_error: 0.1447
# Epoch 11/50
#  - 58s - loss: 0.0339 - mean_absolute_error: 0.1439
# Epoch 12/50
#  - 59s - loss: 0.0333 - mean_absolute_error: 0.1425
# Epoch 13/50
#  - 58s - loss: 0.0334 - mean_absolute_error: 0.1435
# Epoch 14/50
#  - 59s - loss: 0.0331 - mean_absolute_error: 0.1415
# Epoch 15/50
#  - 59s - loss: 0.0323 - mean_absolute_error: 0.1399
# Epoch 16/50
#  - 59s - loss: 0.0318 - mean_absolute_error: 0.1380
# Epoch 17/50
#  - 58s - loss: 0.0307 - mean_absolute_error: 0.1357
# Epoch 18/50
#  - 59s - loss: 0.0307 - mean_absolute_error: 0.1353
# Epoch 19/50
#  - 59s - loss: 0.0303 - mean_absolute_error: 0.1357
# Epoch 20/50
#  - 59s - loss: 0.0288 - mean_absolute_error: 0.1316
# Epoch 21/50
#  - 60s - loss: 0.0287 - mean_absolute_error: 0.1321
# Epoch 22/50
#  - 58s - loss: 0.0273 - mean_absolute_error: 0.1276
# Epoch 23/50
#  - 58s - loss: 0.0271 - mean_absolute_error: 0.1267
# Epoch 24/50
#  - 58s - loss: 0.0256 - mean_absolute_error: 0.1237
# Epoch 25/50
#  - 57s - loss: 0.0259 - mean_absolute_error: 0.1248
# Epoch 26/50
#  - 56s - loss: 0.0238 - mean_absolute_error: 0.1190
# Epoch 27/50
#  - 56s - loss: 0.0224 - mean_absolute_error: 0.1158
# Epoch 28/50
#  - 57s - loss: 0.0227 - mean_absolute_error: 0.1165
# Epoch 29/50
#  - 57s - loss: 0.0215 - mean_absolute_error: 0.1122
# Epoch 30/50
#  - 57s - loss: 0.0211 - mean_absolute_error: 0.1128
# Epoch 31/50
#  - 57s - loss: 0.0194 - mean_absolute_error: 0.1085
# Epoch 32/50
#  - 57s - loss: 0.0183 - mean_absolute_error: 0.1036
# Epoch 33/50
#  - 57s - loss: 0.0181 - mean_absolute_error: 0.1033
# Epoch 34/50
#  - 57s - loss: 0.0169 - mean_absolute_error: 0.0995
# Epoch 35/50
#  - 56s - loss: 0.0152 - mean_absolute_error: 0.0948
# Epoch 36/50
#  - 57s - loss: 0.0154 - mean_absolute_error: 0.0940
# Epoch 37/50
#  - 57s - loss: 0.0151 - mean_absolute_error: 0.0931
# Epoch 38/50
#  - 57s - loss: 0.0143 - mean_absolute_error: 0.0922
# Epoch 39/50
#  - 57s - loss: 0.0135 - mean_absolute_error: 0.0886
# Epoch 40/50
#  - 56s - loss: 0.0130 - mean_absolute_error: 0.0878
# Epoch 41/50
#  - 58s - loss: 0.0122 - mean_absolute_error: 0.0829
# Epoch 42/50
#  - 57s - loss: 0.0115 - mean_absolute_error: 0.0807
# Epoch 43/50
#  - 57s - loss: 0.0119 - mean_absolute_error: 0.0826
# Epoch 44/50
#  - 57s - loss: 0.0102 - mean_absolute_error: 0.0769
# Epoch 45/50
#  - 57s - loss: 0.0108 - mean_absolute_error: 0.0787
# Epoch 46/50
#  - 57s - loss: 0.0097 - mean_absolute_error: 0.0743
# Epoch 47/50
#  - 57s - loss: 0.0092 - mean_absolute_error: 0.0711
# Epoch 48/50
#  - 57s - loss: 0.0094 - mean_absolute_error: 0.0710
# Epoch 49/50
#  - 58s - loss: 0.0086 - mean_absolute_error: 0.0697
# Epoch 50/50
#  - 58s - loss: 0.0085 - mean_absolute_error: 0.0683
# Kappa Score: 0.5315201335391178
# Build model 3...
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 256)          0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 256, 50)      317500      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 256, 300)     421200      embedding_4[0][0]
# __________________________________________________________________________________________________
# temporal_mean_4 (TemporalMean)  (None, 300)          0           lstm_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 300)          0           temporal_mean_4[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 325)          0           dropout_4[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            326         lambda_4[0][0]
# ==================================================================================================
# Total params: 739,026
# Trainable params: 739,026
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 59s - loss: 0.1080 - mean_absolute_error: 0.2705
# Epoch 2/50
#  - 58s - loss: 0.0614 - mean_absolute_error: 0.2042
# Epoch 3/50
#  - 58s - loss: 0.0469 - mean_absolute_error: 0.1758
# Epoch 4/50
#  - 58s - loss: 0.0418 - mean_absolute_error: 0.1648
# Epoch 5/50
#  - 58s - loss: 0.0392 - mean_absolute_error: 0.1572
# Epoch 6/50
#  - 57s - loss: 0.0387 - mean_absolute_error: 0.1549
# Epoch 7/50
#  - 57s - loss: 0.0372 - mean_absolute_error: 0.1524
# Epoch 8/50
#  - 57s - loss: 0.0365 - mean_absolute_error: 0.1492
# Epoch 9/50
#  - 57s - loss: 0.0359 - mean_absolute_error: 0.1483
# Epoch 10/50
#  - 58s - loss: 0.0355 - mean_absolute_error: 0.1469
# Epoch 11/50
#  - 58s - loss: 0.0352 - mean_absolute_error: 0.1464
# Epoch 12/50
#  - 57s - loss: 0.0349 - mean_absolute_error: 0.1454
# Epoch 13/50
#  - 58s - loss: 0.0345 - mean_absolute_error: 0.1448
# Epoch 14/50
#  - 58s - loss: 0.0344 - mean_absolute_error: 0.1438
# Epoch 15/50
#  - 58s - loss: 0.0330 - mean_absolute_error: 0.1406
# Epoch 16/50
#  - 58s - loss: 0.0336 - mean_absolute_error: 0.1432
# Epoch 17/50
#  - 58s - loss: 0.0328 - mean_absolute_error: 0.1409
# Epoch 18/50
#  - 58s - loss: 0.0321 - mean_absolute_error: 0.1388
# Epoch 19/50
#  - 57s - loss: 0.0311 - mean_absolute_error: 0.1369
# Epoch 20/50
#  - 58s - loss: 0.0309 - mean_absolute_error: 0.1368
# Epoch 21/50
#  - 58s - loss: 0.0306 - mean_absolute_error: 0.1356
# Epoch 22/50
#  - 58s - loss: 0.0301 - mean_absolute_error: 0.1330
# Epoch 23/50
#  - 58s - loss: 0.0294 - mean_absolute_error: 0.1323
# Epoch 24/50
#  - 58s - loss: 0.0283 - mean_absolute_error: 0.1300
# Epoch 25/50
#  - 58s - loss: 0.0275 - mean_absolute_error: 0.1283
# Epoch 26/50
#  - 58s - loss: 0.0265 - mean_absolute_error: 0.1248
# Epoch 27/50
#  - 58s - loss: 0.0253 - mean_absolute_error: 0.1229
# Epoch 28/50
#  - 58s - loss: 0.0246 - mean_absolute_error: 0.1202
# Epoch 29/50
#  - 58s - loss: 0.0238 - mean_absolute_error: 0.1182
# Epoch 30/50
#  - 58s - loss: 0.0227 - mean_absolute_error: 0.1155
# Epoch 31/50
#  - 58s - loss: 0.0211 - mean_absolute_error: 0.1107
# Epoch 32/50
#  - 58s - loss: 0.0206 - mean_absolute_error: 0.1114
# Epoch 33/50
#  - 58s - loss: 0.0195 - mean_absolute_error: 0.1085
# Epoch 34/50
#  - 59s - loss: 0.0192 - mean_absolute_error: 0.1064
# Epoch 35/50
#  - 58s - loss: 0.0184 - mean_absolute_error: 0.1031
# Epoch 36/50
#  - 58s - loss: 0.0166 - mean_absolute_error: 0.0976
# Epoch 37/50
#  - 58s - loss: 0.0157 - mean_absolute_error: 0.0959
# Epoch 38/50
#  - 58s - loss: 0.0160 - mean_absolute_error: 0.0965
# Epoch 39/50
#  - 58s - loss: 0.0154 - mean_absolute_error: 0.0942
# Epoch 40/50
#  - 57s - loss: 0.0151 - mean_absolute_error: 0.0939
# Epoch 41/50
#  - 57s - loss: 0.0128 - mean_absolute_error: 0.0844
# Epoch 42/50
#  - 57s - loss: 0.0133 - mean_absolute_error: 0.0875
# Epoch 43/50
#  - 57s - loss: 0.0122 - mean_absolute_error: 0.0825
# Epoch 44/50
#  - 57s - loss: 0.0117 - mean_absolute_error: 0.0802
# Epoch 45/50
#  - 58s - loss: 0.0121 - mean_absolute_error: 0.0829
# Epoch 46/50
#  - 57s - loss: 0.0110 - mean_absolute_error: 0.0780
# Epoch 47/50
#  - 57s - loss: 0.0114 - mean_absolute_error: 0.0790
# Epoch 48/50
#  - 57s - loss: 0.0109 - mean_absolute_error: 0.0771
# Epoch 49/50
#  - 56s - loss: 0.0104 - mean_absolute_error: 0.0750
# Epoch 50/50
#  - 57s - loss: 0.0094 - mean_absolute_error: 0.0716
# Kappa Score: 0.6104663980919167
# Build model 4...
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 256)          0
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 256, 50)      317500      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 256, 300)     421200      embedding_5[0][0]
# __________________________________________________________________________________________________
# temporal_mean_5 (TemporalMean)  (None, 300)          0           lstm_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 300)          0           temporal_mean_5[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 325)          0           dropout_5[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            326         lambda_5[0][0]
# ==================================================================================================
# Total params: 739,026
# Trainable params: 739,026
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 60s - loss: 0.0616 - mean_absolute_error: 0.2017
# Epoch 2/50
#  - 57s - loss: 0.0433 - mean_absolute_error: 0.1678
# Epoch 3/50
#  - 58s - loss: 0.0384 - mean_absolute_error: 0.1552
# Epoch 4/50
#  - 58s - loss: 0.0371 - mean_absolute_error: 0.1522
# Epoch 5/50
#  - 58s - loss: 0.0355 - mean_absolute_error: 0.1483
# Epoch 6/50
#  - 58s - loss: 0.0361 - mean_absolute_error: 0.1502
# Epoch 7/50
#  - 57s - loss: 0.0351 - mean_absolute_error: 0.1472
# Epoch 8/50
#  - 57s - loss: 0.0344 - mean_absolute_error: 0.1446
# Epoch 9/50
#  - 57s - loss: 0.0335 - mean_absolute_error: 0.1432
# Epoch 10/50
#  - 57s - loss: 0.0330 - mean_absolute_error: 0.1413
# Epoch 11/50
#  - 58s - loss: 0.0332 - mean_absolute_error: 0.1422
# Epoch 12/50
#  - 57s - loss: 0.0329 - mean_absolute_error: 0.1420
# Epoch 13/50
#  - 57s - loss: 0.0313 - mean_absolute_error: 0.1381
# Epoch 14/50
#  - 57s - loss: 0.0321 - mean_absolute_error: 0.1390
# Epoch 15/50
#  - 58s - loss: 0.0309 - mean_absolute_error: 0.1366
# Epoch 16/50
#  - 57s - loss: 0.0309 - mean_absolute_error: 0.1367
# Epoch 17/50
#  - 57s - loss: 0.0306 - mean_absolute_error: 0.1367
# Epoch 18/50
#  - 57s - loss: 0.0300 - mean_absolute_error: 0.1345
# Epoch 19/50
#  - 57s - loss: 0.0289 - mean_absolute_error: 0.1317
# Epoch 20/50
#  - 57s - loss: 0.0286 - mean_absolute_error: 0.1309
# Epoch 21/50
#  - 57s - loss: 0.0276 - mean_absolute_error: 0.1291
# Epoch 22/50
#  - 57s - loss: 0.0264 - mean_absolute_error: 0.1274
# Epoch 23/50
#  - 58s - loss: 0.0261 - mean_absolute_error: 0.1250
# Epoch 24/50
#  - 57s - loss: 0.0242 - mean_absolute_error: 0.1201
# Epoch 25/50
#  - 57s - loss: 0.0239 - mean_absolute_error: 0.1192
# Epoch 26/50
#  - 57s - loss: 0.0224 - mean_absolute_error: 0.1139
# Epoch 27/50
#  - 58s - loss: 0.0218 - mean_absolute_error: 0.1150
# Epoch 28/50
#  - 57s - loss: 0.0208 - mean_absolute_error: 0.1103
# Epoch 29/50
#  - 57s - loss: 0.0203 - mean_absolute_error: 0.1084
# Epoch 30/50
#  - 57s - loss: 0.0200 - mean_absolute_error: 0.1086
# Epoch 31/50
#  - 57s - loss: 0.0187 - mean_absolute_error: 0.1049
# Epoch 32/50
#  - 57s - loss: 0.0181 - mean_absolute_error: 0.1025
# Epoch 33/50
#  - 57s - loss: 0.0175 - mean_absolute_error: 0.1027
# Epoch 34/50
#  - 57s - loss: 0.0159 - mean_absolute_error: 0.0971
# Epoch 35/50
#  - 58s - loss: 0.0158 - mean_absolute_error: 0.0964
# Epoch 36/50
#  - 57s - loss: 0.0161 - mean_absolute_error: 0.0975
# Epoch 37/50
#  - 58s - loss: 0.0144 - mean_absolute_error: 0.0924
# Epoch 38/50
#  - 58s - loss: 0.0136 - mean_absolute_error: 0.0894
# Epoch 39/50
#  - 58s - loss: 0.0133 - mean_absolute_error: 0.0891
# Epoch 40/50
#  - 58s - loss: 0.0137 - mean_absolute_error: 0.0891
# Epoch 41/50
#  - 58s - loss: 0.0137 - mean_absolute_error: 0.0891
# Epoch 42/50
#  - 58s - loss: 0.0122 - mean_absolute_error: 0.0842
# Epoch 43/50
#  - 58s - loss: 0.0119 - mean_absolute_error: 0.0825
# Epoch 44/50
#  - 58s - loss: 0.0117 - mean_absolute_error: 0.0827
# Epoch 45/50
#  - 58s - loss: 0.0106 - mean_absolute_error: 0.0785
# Epoch 46/50
#  - 57s - loss: 0.0101 - mean_absolute_error: 0.0780
# Epoch 47/50
#  - 57s - loss: 0.0101 - mean_absolute_error: 0.0772
# Epoch 48/50
#  - 57s - loss: 0.0101 - mean_absolute_error: 0.0756
# Epoch 49/50
#  - 57s - loss: 0.0096 - mean_absolute_error: 0.0743
# Epoch 50/50
#  - 57s - loss: 0.0093 - mean_absolute_error: 0.0735
# Kappa Score: 0.5558918693247052
# Average Kappa score after a 5-fold cross validation:  0.57754
# Kappa score after a 5-fold cross validation:  0.5760222239637239
