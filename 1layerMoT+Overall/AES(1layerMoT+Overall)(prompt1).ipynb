# %%
prompt_id = 1
model_name = "1LayerMoTOverall"  # 1LayerOverall, 1LayerMoTOverall, 2LayerOverall

# %%
import os
import pprint
import tensorflow as tf

if 'COLAB_TPU_ADDR' not in os.environ:
  print('ERROR: Not connected to a TPU runtime')
else:
  tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
  print ('TPU address is', tpu_address)

  with tf.Session(tpu_address) as session:
    devices = session.list_devices()

  print('TPU devices:')
  pprint.pprint(devices)
# Out:
# TPU address is grpc://10.5.172.18:8470
# TPU devices:
# [_DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:CPU:0, CPU, -1, 4295876481795311470),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 1694995363269778353),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 2084255927067201339),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 8640067302282788703),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 1073024262031169085),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 8411144035076786602),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 15163641742281376252),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 4218694136559636458),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 8329201818026106070),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 12643805402512987423),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 8589934592, 12371743432196137978)]

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/My Drive/AES謝"
os.chdir(path)
# os.listdir(path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import argparse
import nltk
import tensorflow as tf
from keras.models import Model
from keras import layers
from keras.layers import Input, concatenate, Embedding, LSTM, Dense, Lambda
from keras.engine.topology import Layer
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
import re
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
import keras.backend as K
from sklearn.model_selection import KFold
from sklearn.metrics import cohen_kappa_score
from sklearn.preprocessing import StandardScaler
from keras.preprocessing.sequence import pad_sequences
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')

nltk.download('stopwords')
nltk.download('punkt')
# stopwords, punkt,
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Mean Over Time
class TemporalMean(Layer):
  def __init__(self, **kwargs):
      self.supports_masking = True
      super(TemporalMean, self).__init__(**kwargs)

  def compute_mask(self, input, input_mask=None):
      # do not pass the mask to the next layers
      return None

  def call(self, x, mask=None):
      if mask is not None:
          # mask (batch, time)
          mask = K.cast(mask, K.floatx())
          # mask (batch, x_dim, time)
          mask = K.repeat(mask, x.shape[-1])
          # mask (batch, time, x_dim)
          mask = tf.transpose(mask, [0,2,1])
          x = x * mask
      return K.sum(x, axis=1) / K.sum(mask, axis=1)

  def compute_output_shape(self, input_shape):
      # remove temporal dimension
      return (input_shape[0], input_shape[2])

def essay_to_wordlist(essay_v, remove_stopwords):
    """Remove the tagged labels and word tokenize the sentence."""
    essay_v = re.sub("[^a-zA-Z]", " ", essay_v)
    words = essay_v.lower().split()
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    return (words)

def get_clean_essays(Text):
    clean_essays = []
    for essay in Text:
        clean_essays.append(essay_to_wordlist(essay, remove_stopwords=False))
    return clean_essays

def create_dict(text):
    print("create_dict")
    word_index = {}
    word_index['xieyikuan'] = 0
    for sentence in text:
        for word in sentence:
            if word not in word_index:
                word_index[word] = len(word_index)
    word_index['unk'] = len(word_index)
    return word_index

def essay_to_index(essays, word_index):
    Essays = []
    for essay in essays:
        sentence = []
        for sent in essay:
            words = []
            for word in sent:
                words.append(word_index[word])
            sentence.append(words)
        Essays.append(sentence)
    return Essays

def essay_to_index2(essays, word_index):
    Essays = []
    for essay in essays:
        words = []
        for word in essay:
            words.append(word_index[word])
        Essays.append(words)
    return Essays

def get_embeddings_index():
    embeddings_index = {}
    f = open('glove.6B.50d.txt', 'r', encoding='UTF-8')
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.array(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    f.close()
    return embeddings_index

def embeddings_matrix(embeddings_index, word_index, embedding_dim):
    nb_words = len(word_index)
    embedding_matrix = np.zeros((nb_words + 1, embedding_dim))
    for word, i in word_index.items():
        if i > nb_words:
            continue
        embeddings_vector = embeddings_index.get(word)
        if embeddings_vector is not None:
            embedding_matrix[i] = embeddings_vector
        if embeddings_vector is None:
            embedding_matrix[i] = embeddings_index.get('unk')
    return embedding_matrix

# %%
csv_input = pd.read_csv(filepath_or_buffer="data_feature/set"+str(prompt_id)+"_feature(26).tsv", delimiter="\t", engine="python", error_bad_lines=False)

Text = csv_input['essay']
Score = csv_input['domain1_score']
Label = Score

# --------
if prompt_id == 1:
    Score = (Score - 2) / 10      # set_1     范围 2-12
elif prompt_id == 2:
    Score = (Score - 1) / 5       # set_2     范围 1-6
elif prompt_id == 3 or prompt_id == 4:
    Score = Score / 3           # set_3,4   范围 0-3
elif prompt_id == 5 or prompt_id == 6:
    Score = Score / 4           # set_5,6   范围 0-4
elif prompt_id == 7:
    Score = Score / 30          # set_7     范围 0-30
elif prompt_id == 8:
    Score = Score / 60          # set_8     范围 0-60

# get Overall Feature
overall_feature = csv_input[['word_count', 'avg_word_len', 'sentence_count', 'avg_sentence_len', 'lemma_count', 'noun_count', 'adj_count', 'adv_count', 'verb_count', 'cc_count',
                             'syllable_count', 'flesch_reading_ease', 'smog_index', 'flesch_kincaid_grade', 'coleman_liau_index', 'automated_readability_index',
                             'dale_chall_readability_score', 'difficult_words', 'linsear_write_formula',
                             'gunning_fog', 'spelling_errors', 'exc_count', 'que_count', 'comma_count', 'stopwords_num']]
# overall_feature = np.array(np.sqrt(overall_feature))
overall_feature = np.array(overall_feature)
num_feature = 25
where_are_nan = np.isnan(overall_feature)
where_are_inf = np.isinf(overall_feature)
overall_feature[where_are_nan] = 0
overall_feature[where_are_inf] = 0
# standardized
stdsc = StandardScaler()
overall_feature = stdsc.fit_transform(overall_feature)

# 做字典
clean_essays = get_clean_essays(Text)
word_index = create_dict(clean_essays)

# 做分句
text = np.array(Text)
# print(text)
a = []
for essay in text:
    a.append(sent_tokenize(essay))
texts = np.array(a)

# 做分词
essays = []
for essay in Text:
  essay_idx = essay_to_wordlist(essay, remove_stopwords=False)
  essays.append(essay_idx)
essays = np.array(essays)

Essays = essay_to_index2(clean_essays, word_index)
Essays = np.array(Essays)

if prompt_id == 1:
    max_essay_length = 600
elif prompt_id == 2:
    max_essay_length = 700
elif prompt_id == 3:
    max_essay_length = 256
elif prompt_id == 4:
    max_essay_length = 200
elif prompt_id == 5:
    max_essay_length = 256
elif prompt_id == 6:
    max_essay_length = 256
elif prompt_id == 7:
    max_essay_length = 350
elif prompt_id == 8:
    max_essay_length = 870

essay_pad = pad_sequences(Essays, maxlen=max_essay_length)

embeddings_index = get_embeddings_index()
embeddings_matrix = embeddings_matrix(embeddings_index, word_index, embedding_dim=50)

# 记录成绩
results = []
score_predict_list = []
sssscore = []
llllabel = []
newresults = []
cv = KFold(n_splits=5, shuffle=True, random_state=10)
count = 0
for train, test in cv.split(essay_pad):
    text_train, text_test = essay_pad[train], essay_pad[test]
    label_train, label_test = Score.iloc[train], Score.iloc[test]
    score_train, score_test = Label.iloc[train], Label.iloc[test]
    overall_train, overall_test = overall_feature[train], overall_feature[test]

    # print('Build model '+str(count)+'...')
    # count += 1

    # -------
    text_input = Input(shape=(max_essay_length, ), name='text_input')
    overall_feature_input = Input(shape=(num_feature,), name='overall_feature_input')

    embedding_layer = Embedding(input_dim=len(word_index) + 1,
                                output_dim=50,
                                weights=[embeddings_matrix],
                                input_length=max_essay_length,
                                trainable=True,
                                mask_zero=True)
    x = embedding_layer(text_input)  
    if model_name == "2LayerOverall":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)
    elif model_name == "1LayerMoTOverall":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)
      x = TemporalMean()(x)
    elif model_name == "1LayerOverall":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)
    x = layers.Dropout(0.5)(x)
    concat_layer = Lambda(concatenate)([x, overall_feature_input])
    output = Dense(1, activation='sigmoid')(concat_layer)

    model = Model(inputs=[text_input, overall_feature_input], outputs=output)
    # -------

    model.summary()
    model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001, decay=1e-6), metrics=['mean_absolute_error'])
    model.fit([text_train, overall_train], label_train, batch_size=32, epochs=50, verbose=2)

    score_predict = model.predict([text_test, overall_test])
    if prompt_id == 1:
        score_predict = score_predict*10+2
    elif prompt_id == 2:
        score_predict = score_predict*5+1
    elif prompt_id == 3:
        score_predict = score_predict*3
    elif prompt_id == 4:
        score_predict = score_predict*3
    elif prompt_id == 5:
        score_predict = score_predict*4
    elif prompt_id == 6:
        score_predict = score_predict*4
    elif prompt_id == 7:
        score_predict = score_predict*30
    elif prompt_id == 8:
        score_predict = score_predict*60

    score_predict = np.around(score_predict)

    sssscore.append(score_predict)
    llllabel.append(score_test)

    result = cohen_kappa_score(score_test.values, score_predict, weights='quadratic')
    print("Kappa Score: {}".format(result))
    results.append(result)
    for i in results:
      if i != 0:
        newresults.append(i)

print("Average Kappa score after a 5-fold cross validation: ", np.around(np.array(newresults).mean(), decimals=5))

sssscore = np.array(sssscore)
res = []
for scores in sssscore:
  for score in scores:
    res.append(score)

ll = np.array(llllabel)
res_label = []
for labels in ll:
  for label in labels:
    res_label.append(label)
res_label = np.array(res_label)

QWK = cohen_kappa_score(res_label, res, weights='quadratic')
print("Kappa score after a 5-fold cross validation: ", QWK)
# Out:
# create_dict
# Build model 0...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3239: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 600)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 600, 50)      783100      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 600, 300)     421200      embedding_1[0][0]
# __________________________________________________________________________________________________
# temporal_mean_1 (TemporalMean)  (None, 300)          0           lstm_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 300)          0           temporal_mean_1[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 325)          0           dropout_1[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            326         lambda_1[0][0]
# ==================================================================================================
# Total params: 1,204,626
# Trainable params: 1,204,626
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/50
#  - 143s - loss: 0.0223 - mean_absolute_error: 0.1148
# Epoch 2/50
#  - 142s - loss: 0.0119 - mean_absolute_error: 0.0845
# Epoch 3/50
#  - 143s - loss: 0.0097 - mean_absolute_error: 0.0781
# Epoch 4/50
#  - 145s - loss: 0.0090 - mean_absolute_error: 0.0747
# Epoch 5/50
#  - 145s - loss: 0.0083 - mean_absolute_error: 0.0723
# Epoch 6/50
#  - 145s - loss: 0.0081 - mean_absolute_error: 0.0706
# Epoch 7/50
#  - 151s - loss: 0.0076 - mean_absolute_error: 0.0685
# Epoch 8/50
#  - 148s - loss: 0.0074 - mean_absolute_error: 0.0673
# Epoch 9/50
#  - 142s - loss: 0.0070 - mean_absolute_error: 0.0657
# Epoch 10/50
#  - 141s - loss: 0.0070 - mean_absolute_error: 0.0659
# Epoch 11/50
#  - 136s - loss: 0.0067 - mean_absolute_error: 0.0648
# Epoch 12/50
#  - 136s - loss: 0.0067 - mean_absolute_error: 0.0640
# Epoch 13/50
#  - 137s - loss: 0.0066 - mean_absolute_error: 0.0641
# Epoch 14/50
#  - 136s - loss: 0.0066 - mean_absolute_error: 0.0640
# Epoch 15/50
#  - 135s - loss: 0.0064 - mean_absolute_error: 0.0636
# Epoch 16/50
#  - 134s - loss: 0.0064 - mean_absolute_error: 0.0633
# Epoch 17/50
#  - 136s - loss: 0.0065 - mean_absolute_error: 0.0638
# Epoch 18/50
#  - 133s - loss: 0.0063 - mean_absolute_error: 0.0626
# Epoch 19/50
#  - 134s - loss: 0.0062 - mean_absolute_error: 0.0620
# Epoch 20/50
#  - 134s - loss: 0.0062 - mean_absolute_error: 0.0622
# Epoch 21/50
#  - 134s - loss: 0.0061 - mean_absolute_error: 0.0618
# Epoch 22/50
#  - 134s - loss: 0.0062 - mean_absolute_error: 0.0616
# Epoch 23/50
#  - 136s - loss: 0.0060 - mean_absolute_error: 0.0611
# Epoch 24/50
#  - 136s - loss: 0.0058 - mean_absolute_error: 0.0605
# Epoch 25/50
#  - 137s - loss: 0.0058 - mean_absolute_error: 0.0598
# Epoch 26/50
#  - 137s - loss: 0.0056 - mean_absolute_error: 0.0588
# Epoch 27/50
#  - 136s - loss: 0.0054 - mean_absolute_error: 0.0570
# Epoch 28/50
#  - 136s - loss: 0.0053 - mean_absolute_error: 0.0571
# Epoch 29/50
#  - 136s - loss: 0.0052 - mean_absolute_error: 0.0565
# Epoch 30/50
#  - 135s - loss: 0.0051 - mean_absolute_error: 0.0563
# Epoch 31/50
#  - 136s - loss: 0.0049 - mean_absolute_error: 0.0540
# Epoch 32/50
#  - 136s - loss: 0.0046 - mean_absolute_error: 0.0525
# Epoch 33/50
#  - 136s - loss: 0.0047 - mean_absolute_error: 0.0533
# Epoch 34/50
#  - 136s - loss: 0.0043 - mean_absolute_error: 0.0507
# Epoch 35/50
#  - 137s - loss: 0.0041 - mean_absolute_error: 0.0501
# Epoch 36/50
#  - 137s - loss: 0.0040 - mean_absolute_error: 0.0488
# Epoch 37/50
#  - 137s - loss: 0.0042 - mean_absolute_error: 0.0494
# Epoch 38/50
#  - 138s - loss: 0.0039 - mean_absolute_error: 0.0483
# Epoch 39/50
#  - 137s - loss: 0.0036 - mean_absolute_error: 0.0458
# Epoch 40/50
#  - 137s - loss: 0.0032 - mean_absolute_error: 0.0441
# Epoch 41/50
#  - 137s - loss: 0.0030 - mean_absolute_error: 0.0424
# Epoch 42/50
#  - 136s - loss: 0.0028 - mean_absolute_error: 0.0404
# Epoch 43/50
#  - 135s - loss: 0.0028 - mean_absolute_error: 0.0407
# Epoch 44/50
#  - 134s - loss: 0.0027 - mean_absolute_error: 0.0393
# Epoch 45/50
#  - 134s - loss: 0.0026 - mean_absolute_error: 0.0392
# Epoch 46/50
#  - 135s - loss: 0.0023 - mean_absolute_error: 0.0362
# Epoch 47/50
#  - 135s - loss: 0.0023 - mean_absolute_error: 0.0361
# Epoch 48/50
#  - 135s - loss: 0.0023 - mean_absolute_error: 0.0363
# Epoch 49/50
#  - 134s - loss: 0.0021 - mean_absolute_error: 0.0344
# Epoch 50/50
#  - 134s - loss: 0.0020 - mean_absolute_error: 0.0336
# Kappa Score: 0.7977084962431578
# Build model 1...
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 600)          0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 600, 50)      783100      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 600, 300)     421200      embedding_2[0][0]
# __________________________________________________________________________________________________
# temporal_mean_2 (TemporalMean)  (None, 300)          0           lstm_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 300)          0           temporal_mean_2[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 325)          0           dropout_2[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            326         lambda_2[0][0]
# ==================================================================================================
# Total params: 1,204,626
# Trainable params: 1,204,626
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 133s - loss: 0.0375 - mean_absolute_error: 0.1471
# Epoch 2/50
#  - 133s - loss: 0.0150 - mean_absolute_error: 0.0923
# Epoch 3/50
#  - 132s - loss: 0.0100 - mean_absolute_error: 0.0769
# Epoch 4/50
#  - 132s - loss: 0.0092 - mean_absolute_error: 0.0748
# Epoch 5/50
#  - 132s - loss: 0.0087 - mean_absolute_error: 0.0733
# Epoch 6/50
#  - 132s - loss: 0.0082 - mean_absolute_error: 0.0708
# Epoch 7/50
#  - 132s - loss: 0.0078 - mean_absolute_error: 0.0688
# Epoch 8/50
#  - 132s - loss: 0.0074 - mean_absolute_error: 0.0673
# Epoch 9/50
#  - 132s - loss: 0.0072 - mean_absolute_error: 0.0666
# Epoch 10/50
#  - 132s - loss: 0.0071 - mean_absolute_error: 0.0660
# Epoch 11/50
#  - 132s - loss: 0.0069 - mean_absolute_error: 0.0650
# Epoch 12/50
#  - 132s - loss: 0.0069 - mean_absolute_error: 0.0655
# Epoch 13/50
#  - 134s - loss: 0.0066 - mean_absolute_error: 0.0637
# Epoch 14/50
#  - 135s - loss: 0.0066 - mean_absolute_error: 0.0637
# Epoch 15/50
#  - 135s - loss: 0.0066 - mean_absolute_error: 0.0633
# Epoch 16/50
#  - 135s - loss: 0.0065 - mean_absolute_error: 0.0632
# Epoch 17/50
#  - 134s - loss: 0.0062 - mean_absolute_error: 0.0622
# Epoch 18/50
#  - 133s - loss: 0.0062 - mean_absolute_error: 0.0621
# Epoch 19/50
#  - 137s - loss: 0.0061 - mean_absolute_error: 0.0610
# Epoch 20/50
#  - 136s - loss: 0.0061 - mean_absolute_error: 0.0618
# Epoch 21/50
#  - 136s - loss: 0.0058 - mean_absolute_error: 0.0600
# Epoch 22/50
#  - 137s - loss: 0.0058 - mean_absolute_error: 0.0597
# Epoch 23/50
#  - 139s - loss: 0.0056 - mean_absolute_error: 0.0588
# Epoch 24/50
#  - 146s - loss: 0.0057 - mean_absolute_error: 0.0589
# Epoch 25/50
#  - 148s - loss: 0.0053 - mean_absolute_error: 0.0572
# Epoch 26/50
#  - 148s - loss: 0.0053 - mean_absolute_error: 0.0568
# Epoch 27/50
#  - 147s - loss: 0.0053 - mean_absolute_error: 0.0566
# Epoch 28/50
#  - 147s - loss: 0.0050 - mean_absolute_error: 0.0549
# Epoch 29/50
#  - 149s - loss: 0.0050 - mean_absolute_error: 0.0542
# Epoch 30/50
#  - 150s - loss: 0.0047 - mean_absolute_error: 0.0533
# Epoch 31/50
#  - 149s - loss: 0.0045 - mean_absolute_error: 0.0525
# Epoch 32/50
#  - 150s - loss: 0.0046 - mean_absolute_error: 0.0529
# Epoch 33/50
#  - 149s - loss: 0.0046 - mean_absolute_error: 0.0525
# Epoch 34/50
#  - 149s - loss: 0.0040 - mean_absolute_error: 0.0484
# Epoch 35/50
#  - 149s - loss: 0.0039 - mean_absolute_error: 0.0482
# Epoch 36/50
#  - 148s - loss: 0.0038 - mean_absolute_error: 0.0469
# Epoch 37/50
#  - 148s - loss: 0.0038 - mean_absolute_error: 0.0471
# Epoch 38/50
#  - 148s - loss: 0.0034 - mean_absolute_error: 0.0447
# Epoch 39/50
#  - 148s - loss: 0.0034 - mean_absolute_error: 0.0446
# Epoch 40/50
#  - 148s - loss: 0.0032 - mean_absolute_error: 0.0425
# Epoch 41/50
#  - 147s - loss: 0.0029 - mean_absolute_error: 0.0410
# Epoch 42/50
#  - 148s - loss: 0.0028 - mean_absolute_error: 0.0403
# Epoch 43/50
#  - 148s - loss: 0.0028 - mean_absolute_error: 0.0398
# Epoch 44/50
#  - 148s - loss: 0.0025 - mean_absolute_error: 0.0385
# Epoch 45/50
#  - 149s - loss: 0.0025 - mean_absolute_error: 0.0379
# Epoch 46/50
#  - 149s - loss: 0.0023 - mean_absolute_error: 0.0363
# Epoch 47/50
#  - 147s - loss: 0.0022 - mean_absolute_error: 0.0353
# Epoch 48/50
#  - 140s - loss: 0.0022 - mean_absolute_error: 0.0353
# Epoch 49/50
#  - 138s - loss: 0.0020 - mean_absolute_error: 0.0340
# Epoch 50/50
#  - 146s - loss: 0.0021 - mean_absolute_error: 0.0351
# Kappa Score: 0.8186830890665191
# Build model 2...
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 600)          0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 600, 50)      783100      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 600, 300)     421200      embedding_3[0][0]
# __________________________________________________________________________________________________
# temporal_mean_3 (TemporalMean)  (None, 300)          0           lstm_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 300)          0           temporal_mean_3[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 325)          0           dropout_3[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            326         lambda_3[0][0]
# ==================================================================================================
# Total params: 1,204,626
# Trainable params: 1,204,626
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 153s - loss: 0.0167 - mean_absolute_error: 0.0978
# Epoch 2/50
#  - 151s - loss: 0.0090 - mean_absolute_error: 0.0754
# Epoch 3/50
#  - 151s - loss: 0.0083 - mean_absolute_error: 0.0721
# Epoch 4/50
#  - 151s - loss: 0.0081 - mean_absolute_error: 0.0712
# Epoch 5/50
#  - 150s - loss: 0.0079 - mean_absolute_error: 0.0699
# Epoch 6/50
#  - 150s - loss: 0.0074 - mean_absolute_error: 0.0676
# Epoch 7/50
#  - 149s - loss: 0.0074 - mean_absolute_error: 0.0679
# Epoch 8/50
#  - 149s - loss: 0.0071 - mean_absolute_error: 0.0669
# Epoch 9/50
#  - 149s - loss: 0.0072 - mean_absolute_error: 0.0669
# Epoch 10/50
#  - 148s - loss: 0.0067 - mean_absolute_error: 0.0649
# Epoch 11/50
#  - 148s - loss: 0.0069 - mean_absolute_error: 0.0651
# Epoch 12/50
#  - 148s - loss: 0.0067 - mean_absolute_error: 0.0643
# Epoch 13/50
#  - 148s - loss: 0.0067 - mean_absolute_error: 0.0644
# Epoch 14/50
#  - 148s - loss: 0.0065 - mean_absolute_error: 0.0638
# Epoch 15/50
#  - 145s - loss: 0.0065 - mean_absolute_error: 0.0635
# Epoch 16/50
#  - 148s - loss: 0.0064 - mean_absolute_error: 0.0625
# Epoch 17/50
#  - 148s - loss: 0.0066 - mean_absolute_error: 0.0638
# Epoch 18/50
#  - 147s - loss: 0.0064 - mean_absolute_error: 0.0629
# Epoch 19/50
#  - 148s - loss: 0.0061 - mean_absolute_error: 0.0615
# Epoch 20/50
#  - 147s - loss: 0.0061 - mean_absolute_error: 0.0616
# Epoch 21/50
#  - 137s - loss: 0.0060 - mean_absolute_error: 0.0603
# Epoch 22/50
#  - 135s - loss: 0.0059 - mean_absolute_error: 0.0605
# Epoch 23/50
#  - 135s - loss: 0.0059 - mean_absolute_error: 0.0601
# Epoch 24/50
#  - 135s - loss: 0.0056 - mean_absolute_error: 0.0595
# Epoch 25/50
#  - 135s - loss: 0.0056 - mean_absolute_error: 0.0579
# Epoch 26/50
#  - 137s - loss: 0.0055 - mean_absolute_error: 0.0577
# Epoch 27/50
#  - 146s - loss: 0.0052 - mean_absolute_error: 0.0567
# Epoch 28/50
#  - 146s - loss: 0.0050 - mean_absolute_error: 0.0552
# Epoch 29/50
#  - 146s - loss: 0.0051 - mean_absolute_error: 0.0557
# Epoch 30/50
#  - 146s - loss: 0.0051 - mean_absolute_error: 0.0548
# Epoch 31/50
#  - 145s - loss: 0.0048 - mean_absolute_error: 0.0538
# Epoch 32/50
#  - 145s - loss: 0.0044 - mean_absolute_error: 0.0512
# Epoch 33/50
#  - 146s - loss: 0.0044 - mean_absolute_error: 0.0507
# Epoch 34/50
#  - 147s - loss: 0.0041 - mean_absolute_error: 0.0493
# Epoch 35/50
#  - 147s - loss: 0.0038 - mean_absolute_error: 0.0480
# Epoch 36/50
#  - 147s - loss: 0.0036 - mean_absolute_error: 0.0459
# Epoch 37/50
#  - 143s - loss: 0.0036 - mean_absolute_error: 0.0463
# Epoch 38/50
#  - 134s - loss: 0.0034 - mean_absolute_error: 0.0444
# Epoch 39/50
#  - 135s - loss: 0.0033 - mean_absolute_error: 0.0439
# Epoch 40/50
#  - 134s - loss: 0.0031 - mean_absolute_error: 0.0426
# Epoch 41/50
#  - 136s - loss: 0.0030 - mean_absolute_error: 0.0418
# Epoch 42/50
#  - 139s - loss: 0.0029 - mean_absolute_error: 0.0405
# Epoch 43/50
#  - 146s - loss: 0.0027 - mean_absolute_error: 0.0392
# Epoch 44/50
#  - 146s - loss: 0.0026 - mean_absolute_error: 0.0386
# Epoch 45/50
#  - 146s - loss: 0.0027 - mean_absolute_error: 0.0396
# Epoch 46/50
#  - 146s - loss: 0.0024 - mean_absolute_error: 0.0376
# Epoch 47/50
#  - 146s - loss: 0.0023 - mean_absolute_error: 0.0359
# Epoch 48/50
#  - 146s - loss: 0.0023 - mean_absolute_error: 0.0365
# Epoch 49/50
#  - 146s - loss: 0.0020 - mean_absolute_error: 0.0338
# Epoch 50/50
#  - 147s - loss: 0.0021 - mean_absolute_error: 0.0347
# Kappa Score: 0.81147607184349
# Build model 3...
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 600)          0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 600, 50)      783100      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 600, 300)     421200      embedding_4[0][0]
# __________________________________________________________________________________________________
# temporal_mean_4 (TemporalMean)  (None, 300)          0           lstm_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 300)          0           temporal_mean_4[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 325)          0           dropout_4[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            326         lambda_4[0][0]
# ==================================================================================================
# Total params: 1,204,626
# Trainable params: 1,204,626
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 147s - loss: 0.0172 - mean_absolute_error: 0.1002
# Epoch 2/50
#  - 146s - loss: 0.0105 - mean_absolute_error: 0.0805
# Epoch 3/50
#  - 142s - loss: 0.0100 - mean_absolute_error: 0.0775
# Epoch 4/50
#  - 135s - loss: 0.0089 - mean_absolute_error: 0.0738
# Epoch 5/50
#  - 135s - loss: 0.0083 - mean_absolute_error: 0.0708
# Epoch 6/50
#  - 135s - loss: 0.0080 - mean_absolute_error: 0.0692
# Epoch 7/50
#  - 135s - loss: 0.0076 - mean_absolute_error: 0.0683
# Epoch 8/50
#  - 140s - loss: 0.0074 - mean_absolute_error: 0.0675
# Epoch 9/50
#  - 145s - loss: 0.0075 - mean_absolute_error: 0.0678
# Epoch 10/50
#  - 146s - loss: 0.0070 - mean_absolute_error: 0.0648
# Epoch 11/50
#  - 146s - loss: 0.0069 - mean_absolute_error: 0.0653
# Epoch 12/50
#  - 146s - loss: 0.0070 - mean_absolute_error: 0.0657
# Epoch 13/50
#  - 145s - loss: 0.0069 - mean_absolute_error: 0.0652
# Epoch 14/50
#  - 145s - loss: 0.0068 - mean_absolute_error: 0.0653
# Epoch 15/50
#  - 145s - loss: 0.0066 - mean_absolute_error: 0.0631
# Epoch 16/50
#  - 146s - loss: 0.0067 - mean_absolute_error: 0.0638
# Epoch 17/50
#  - 145s - loss: 0.0065 - mean_absolute_error: 0.0637
# Epoch 18/50
#  - 145s - loss: 0.0062 - mean_absolute_error: 0.0622
# Epoch 19/50
#  - 139s - loss: 0.0064 - mean_absolute_error: 0.0627
# Epoch 20/50
#  - 136s - loss: 0.0062 - mean_absolute_error: 0.0617
# Epoch 21/50
#  - 139s - loss: 0.0060 - mean_absolute_error: 0.0608
# Epoch 22/50
#  - 137s - loss: 0.0061 - mean_absolute_error: 0.0609
# Epoch 23/50
#  - 139s - loss: 0.0058 - mean_absolute_error: 0.0596
# Epoch 24/50
#  - 145s - loss: 0.0059 - mean_absolute_error: 0.0606
# Epoch 25/50
#  - 139s - loss: 0.0058 - mean_absolute_error: 0.0597
# Epoch 26/50
#  - 139s - loss: 0.0057 - mean_absolute_error: 0.0586
# Epoch 27/50
#  - 137s - loss: 0.0056 - mean_absolute_error: 0.0590
# Epoch 28/50
#  - 137s - loss: 0.0054 - mean_absolute_error: 0.0574
# Epoch 29/50
#  - 138s - loss: 0.0050 - mean_absolute_error: 0.0554
# Epoch 30/50
#  - 137s - loss: 0.0051 - mean_absolute_error: 0.0556
# Epoch 31/50
#  - 136s - loss: 0.0048 - mean_absolute_error: 0.0539
# Epoch 32/50
#  - 137s - loss: 0.0045 - mean_absolute_error: 0.0522
# Epoch 33/50
#  - 136s - loss: 0.0047 - mean_absolute_error: 0.0528
# Epoch 34/50
#  - 137s - loss: 0.0045 - mean_absolute_error: 0.0524
# Epoch 35/50
#  - 138s - loss: 0.0041 - mean_absolute_error: 0.0492
# Epoch 36/50
#  - 137s - loss: 0.0038 - mean_absolute_error: 0.0476
# Epoch 37/50
#  - 137s - loss: 0.0039 - mean_absolute_error: 0.0478
# Epoch 38/50
#  - 137s - loss: 0.0035 - mean_absolute_error: 0.0457
# Epoch 39/50
#  - 137s - loss: 0.0032 - mean_absolute_error: 0.0434
# Epoch 40/50
#  - 137s - loss: 0.0033 - mean_absolute_error: 0.0441
# Epoch 41/50
#  - 137s - loss: 0.0031 - mean_absolute_error: 0.0426
# Epoch 42/50
#  - 138s - loss: 0.0030 - mean_absolute_error: 0.0413
# Epoch 43/50
#  - 137s - loss: 0.0029 - mean_absolute_error: 0.0406
# Epoch 44/50
#  - 135s - loss: 0.0026 - mean_absolute_error: 0.0389
# Epoch 45/50
#  - 133s - loss: 0.0025 - mean_absolute_error: 0.0379
# Epoch 46/50
#  - 134s - loss: 0.0026 - mean_absolute_error: 0.0387
# Epoch 47/50
#  - 134s - loss: 0.0024 - mean_absolute_error: 0.0376
# Epoch 48/50
#  - 133s - loss: 0.0022 - mean_absolute_error: 0.0359
# Epoch 49/50
#  - 133s - loss: 0.0022 - mean_absolute_error: 0.0354
# Epoch 50/50
#  - 134s - loss: 0.0022 - mean_absolute_error: 0.0356
# Kappa Score: 0.7894402200231408
# Build model 4...
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 600)          0
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 600, 50)      783100      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 600, 300)     421200      embedding_5[0][0]
# __________________________________________________________________________________________________
# temporal_mean_5 (TemporalMean)  (None, 300)          0           lstm_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 300)          0           temporal_mean_5[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 325)          0           dropout_5[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            326         lambda_5[0][0]
# ==================================================================================================
# Total params: 1,204,626
# Trainable params: 1,204,626
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 134s - loss: 0.0182 - mean_absolute_error: 0.1021
# Epoch 2/50
#  - 132s - loss: 0.0097 - mean_absolute_error: 0.0771
# Epoch 3/50
#  - 133s - loss: 0.0084 - mean_absolute_error: 0.0729
# Epoch 4/50
#  - 132s - loss: 0.0077 - mean_absolute_error: 0.0693
# Epoch 5/50
#  - 133s - loss: 0.0076 - mean_absolute_error: 0.0683
# Epoch 6/50
#  - 132s - loss: 0.0073 - mean_absolute_error: 0.0671
# Epoch 7/50
#  - 132s - loss: 0.0071 - mean_absolute_error: 0.0662
# Epoch 8/50
#  - 133s - loss: 0.0070 - mean_absolute_error: 0.0660
# Epoch 9/50
#  - 133s - loss: 0.0070 - mean_absolute_error: 0.0662
# Epoch 10/50
#  - 135s - loss: 0.0069 - mean_absolute_error: 0.0654
# Epoch 11/50
#  - 134s - loss: 0.0068 - mean_absolute_error: 0.0651
# Epoch 12/50
#  - 133s - loss: 0.0067 - mean_absolute_error: 0.0645
# Epoch 13/50
#  - 135s - loss: 0.0064 - mean_absolute_error: 0.0628
# Epoch 14/50
#  - 134s - loss: 0.0065 - mean_absolute_error: 0.0635
# Epoch 15/50
#  - 135s - loss: 0.0064 - mean_absolute_error: 0.0636
# Epoch 16/50
#  - 135s - loss: 0.0062 - mean_absolute_error: 0.0622
# Epoch 17/50
#  - 134s - loss: 0.0063 - mean_absolute_error: 0.0623
# Epoch 18/50
#  - 134s - loss: 0.0062 - mean_absolute_error: 0.0625
# Epoch 19/50
#  - 134s - loss: 0.0062 - mean_absolute_error: 0.0622
# Epoch 20/50
#  - 135s - loss: 0.0060 - mean_absolute_error: 0.0612
# Epoch 21/50
#  - 136s - loss: 0.0059 - mean_absolute_error: 0.0607
# Epoch 22/50
#  - 138s - loss: 0.0061 - mean_absolute_error: 0.0612
# Epoch 23/50
#  - 136s - loss: 0.0057 - mean_absolute_error: 0.0596
# Epoch 24/50
#  - 138s - loss: 0.0059 - mean_absolute_error: 0.0602
# Epoch 25/50
#  - 136s - loss: 0.0057 - mean_absolute_error: 0.0593
# Epoch 26/50
#  - 135s - loss: 0.0056 - mean_absolute_error: 0.0583
# Epoch 27/50
#  - 136s - loss: 0.0052 - mean_absolute_error: 0.0567
# Epoch 28/50
#  - 136s - loss: 0.0051 - mean_absolute_error: 0.0558
# Epoch 29/50
#  - 137s - loss: 0.0049 - mean_absolute_error: 0.0541
# Epoch 30/50
#  - 137s - loss: 0.0045 - mean_absolute_error: 0.0525
# Epoch 31/50
#  - 139s - loss: 0.0044 - mean_absolute_error: 0.0519
# Epoch 32/50
#  - 138s - loss: 0.0042 - mean_absolute_error: 0.0495
# Epoch 33/50
#  - 140s - loss: 0.0040 - mean_absolute_error: 0.0485
# Epoch 34/50
#  - 139s - loss: 0.0040 - mean_absolute_error: 0.0479
# Epoch 35/50
#  - 139s - loss: 0.0035 - mean_absolute_error: 0.0458
# Epoch 36/50
#  - 138s - loss: 0.0035 - mean_absolute_error: 0.0452
# Epoch 37/50
#  - 137s - loss: 0.0032 - mean_absolute_error: 0.0438
# Epoch 38/50
#  - 136s - loss: 0.0030 - mean_absolute_error: 0.0418
# Epoch 39/50
#  - 136s - loss: 0.0029 - mean_absolute_error: 0.0413
# Epoch 40/50
#  - 137s - loss: 0.0027 - mean_absolute_error: 0.0393
# Epoch 41/50
#  - 135s - loss: 0.0026 - mean_absolute_error: 0.0382
# Epoch 42/50
#  - 137s - loss: 0.0026 - mean_absolute_error: 0.0385
# Epoch 43/50
#  - 137s - loss: 0.0024 - mean_absolute_error: 0.0376
# Epoch 44/50
#  - 138s - loss: 0.0024 - mean_absolute_error: 0.0370
# Epoch 45/50
#  - 138s - loss: 0.0022 - mean_absolute_error: 0.0356
# Epoch 46/50
#  - 137s - loss: 0.0022 - mean_absolute_error: 0.0356
# Epoch 47/50
#  - 136s - loss: 0.0020 - mean_absolute_error: 0.0341
# Epoch 48/50
#  - 137s - loss: 0.0020 - mean_absolute_error: 0.0330
# Epoch 49/50
#  - 139s - loss: 0.0019 - mean_absolute_error: 0.0322
# Epoch 50/50
#  - 136s - loss: 0.0018 - mean_absolute_error: 0.0316
# Kappa Score: 0.8100496186742581
# Average Kappa score after a 5-fold cross validation:  0.80578
# Kappa score after a 5-fold cross validation:  0.8065785985167627
