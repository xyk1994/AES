# %%
prompt_id = 8
model_name = "1layer"  # 1layer, 1layer_MoT, 2layer, 2layer_MoT

# %%
import os
import pprint
import tensorflow as tf

if 'COLAB_TPU_ADDR' not in os.environ:
  print('ERROR: Not connected to a TPU runtime')
else:
  tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
  print ('TPU address is', tpu_address)

  with tf.Session(tpu_address) as session:
    devices = session.list_devices()

  print('TPU devices:')
  pprint.pprint(devices)
# Out:
# TPU address is grpc://10.69.17.170:8470
# TPU devices:
# [_DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:CPU:0, CPU, -1, 17974135609030738401),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 11977150996864783473),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 17515601049455076774),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 8183764271570732082),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 321012705400197514),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 13548947830347560054),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 16812601246473094501),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 91313716069725851),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 15240954295566946036),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 12168689984657974960),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 8589934592, 8286777231156054078)]

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/My Drive/AES謝"
os.chdir(path)
# os.listdir(path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import argparse
import nltk
import tensorflow as tf
from keras.models import Model
from keras import layers
from keras.layers import Input, Embedding, LSTM, Dense
from keras.engine.topology import Layer
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
import keras.backend as K
from sklearn.model_selection import KFold
from sklearn.metrics import cohen_kappa_score
from keras.preprocessing.sequence import pad_sequences
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')

nltk.download('stopwords')
nltk.download('punkt')

# stopwords, punkt,
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Mean Over Time
class TemporalMean(Layer):
  def __init__(self, **kwargs):
      self.supports_masking = True
      super(TemporalMean, self).__init__(**kwargs)

  def compute_mask(self, input, input_mask=None):
      # do not pass the mask to the next layers
      return None

  def call(self, x, mask=None):
      if mask is not None:
          # mask (batch, time)
          mask = K.cast(mask, K.floatx())
          # mask (batch, x_dim, time)
          mask = K.repeat(mask, x.shape[-1])
          # mask (batch, time, x_dim)
          mask = tf.transpose(mask, [0,2,1])
          x = x * mask
      return K.sum(x, axis=1) / K.sum(mask, axis=1)

  def compute_output_shape(self, input_shape):
      # remove temporal dimension
      return (input_shape[0], input_shape[2])

def essay_to_wordlist(essay_v, remove_stopwords):
    """Remove the tagged labels and word tokenize the sentence."""
    essay_v = re.sub("[^a-zA-Z]", " ", essay_v)
    words = essay_v.lower().split()
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    return (words)

def get_clean_essays(Text):
    clean_essays = []
    for essay in Text:
        clean_essays.append(essay_to_wordlist(essay, remove_stopwords=False))
    return clean_essays

def create_dict(text):
    print("create_dict")
    word_index = {}
    word_index['xieyikuan'] = 0
    for sentence in text:
        for word in sentence:
            if word not in word_index:
                word_index[word] = len(word_index)
    word_index['unk'] = len(word_index)
    return word_index

def essay_to_index(essays, word_index):
    Essays = []
    for essay in essays:
        sentence = []
        for sent in essay:
            words = []
            for word in sent:
                words.append(word_index[word])
            sentence.append(words)
        Essays.append(sentence)
    return Essays

def essay_to_index2(essays, word_index):
    Essays = []
    for essay in essays:
        words = []
        for word in essay:
            words.append(word_index[word])
        Essays.append(words)
    return Essays

def get_embeddings_index():
    embeddings_index = {}
    f = open('glove.6B.50d.txt', 'r', encoding='UTF-8')
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.array(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    f.close()
    return embeddings_index

def embeddings_matrix(embeddings_index, word_index, embedding_dim):
    nb_words = len(word_index)
    embedding_matrix = np.zeros((nb_words + 1, embedding_dim))
    for word, i in word_index.items():
        if i > nb_words:
            continue
        embeddings_vector = embeddings_index.get(word)
        if embeddings_vector is not None:
            embedding_matrix[i] = embeddings_vector
        if embeddings_vector is None:
            embedding_matrix[i] = embeddings_index.get('unk')
    return embedding_matrix

# %%
csv_input = pd.read_csv(filepath_or_buffer="data_feature/set"+str(prompt_id)+"_feature(26).tsv", delimiter="\t", engine="python", error_bad_lines=False)

Text = csv_input['essay']
Score = csv_input['domain1_score']
Label = Score

# --------
if prompt_id == 1:
    Score = (Score - 2) / 10      # set_1     范围 2-12
elif prompt_id == 2:
    Score = (Score - 1) / 5       # set_2     范围 1-6
elif prompt_id == 3 or prompt_id == 4:
    Score = Score / 3           # set_3,4   范围 0-3
elif prompt_id == 5 or prompt_id == 6:
    Score = Score / 4           # set_5,6   范围 0-4
elif prompt_id == 7:
    Score = Score / 30          # set_7     范围 0-30
elif prompt_id == 8:
    Score = Score / 60          # set_8     范围 0-60
#print(Score)

# 做字典
clean_essays = get_clean_essays(Text)
word_index = create_dict(clean_essays)

# 做分句
text = np.array(Text)
# print(text)
a = []
for essay in text:
    a.append(sent_tokenize(essay))
texts = np.array(a)

# 做分词
essays = []
for essay in Text:
  essay_idx = essay_to_wordlist(essay, remove_stopwords=False)
  # sent = np.array(sent)
  essays.append(essay_idx)
essays = np.array(essays)

Essays = essay_to_index2(clean_essays, word_index)
Essays = np.array(Essays)

if prompt_id == 1:
    max_essay_length = 600
elif prompt_id == 2:
    max_essay_length = 700
elif prompt_id == 3:
    max_essay_length = 256
elif prompt_id == 4:
    max_essay_length = 200
elif prompt_id == 5:
    max_essay_length = 256
elif prompt_id == 6:
    max_essay_length = 256
elif prompt_id == 7:
    max_essay_length = 350
elif prompt_id == 8:
    max_essay_length = 870

essay_pad = pad_sequences(Essays, maxlen=max_essay_length)

embeddings_index = get_embeddings_index()
embeddings_matrix = embeddings_matrix(embeddings_index, word_index, embedding_dim=50)

# 记录成绩
results = []
score_predict_list = []
sssscore = []
llllabel = []
newresults = []
cv = KFold(n_splits=5, shuffle=True, random_state=10)

for train, test in cv.split(essay_pad):
    text_train, text_test = essay_pad[train], essay_pad[test]
    label_train, label_test = Score.iloc[train], Score.iloc[test]
    score_train, score_test = Label.iloc[train], Label.iloc[test]

    # -------
    print('Build model ...')
    text_input = Input(shape=(max_essay_length, ), name='text_input')

    embedding_layer = Embedding(input_dim=len(word_index) + 1,
                                output_dim=50,
                                weights=[embeddings_matrix],
                                input_length=max_essay_length,
                                trainable=True,
                                mask_zero=True)
    x = embedding_layer(text_input)  
    if model_name == "2layer_MoT":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)  
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)  
      x = TemporalMean()(x)
    elif model_name == "2layer":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)  
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)  
    elif model_name == "1layer_MoT":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)  
      x = TemporalMean()(x)
    elif model_name == "1layer":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)  
    x = layers.Dropout(0.5)(x)
    output = Dense(1, activation='sigmoid')(x)

    model = Model(inputs=text_input, outputs=output)
    # -------

    model.summary()
    model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001, decay=1e-6), metrics=['mean_absolute_error'])
    model.fit(text_train, label_train, batch_size=32, epochs=50, verbose=2)

    score_predict = model.predict(text_test)
    if prompt_id == 1:
        score_predict = score_predict*10+2
    elif prompt_id == 2:
        score_predict = score_predict*5+1
    elif prompt_id == 3:
        score_predict = score_predict*3
    elif prompt_id == 4:
        score_predict = score_predict*3
    elif prompt_id == 5:
        score_predict = score_predict*4
    elif prompt_id == 6:
        score_predict = score_predict*4
    elif prompt_id == 7:
        score_predict = score_predict*30
    elif prompt_id == 8:
        score_predict = score_predict*60

    score_predict = np.around(score_predict)

    sssscore.append(score_predict)
    llllabel.append(score_test)

    result = cohen_kappa_score(score_test.values, score_predict, weights='quadratic')
    print("Kappa Score: {}".format(result))
    results.append(result)
    for i in results:
      if i != 0:
        newresults.append(i)

print("Average Kappa score after a 5-fold cross validation: ", np.around(np.array(newresults).mean(), decimals=5))

sssscore = np.array(sssscore)
res = []
for scores in sssscore:
  for score in scores:
    res.append(score)

ll = np.array(llllabel)
res_label = []
for labels in ll:
  for label in labels:
    res_label.append(label)
res_label = np.array(res_label)

QWK = cohen_kappa_score(res_label, res, weights='quadratic')
print("Kappa score after a 5-fold cross validation: ", QWK)
# Out:
# create_dict
# Build model ...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3239: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 870)               0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 870, 50)           595750
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 300)               421200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 1,017,251
# Trainable params: 1,017,251
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/50
#  - 78s - loss: 0.0175 - mean_absolute_error: 0.1027
# Epoch 2/50
#  - 77s - loss: 0.0110 - mean_absolute_error: 0.0831
# Epoch 3/50
#  - 78s - loss: 0.0111 - mean_absolute_error: 0.0825
# Epoch 4/50
#  - 79s - loss: 0.0106 - mean_absolute_error: 0.0812
# Epoch 5/50
#  - 78s - loss: 0.0100 - mean_absolute_error: 0.0799
# Epoch 6/50
#  - 77s - loss: 0.0098 - mean_absolute_error: 0.0805
# Epoch 7/50
#  - 77s - loss: 0.0096 - mean_absolute_error: 0.0788
# Epoch 8/50
#  - 78s - loss: 0.0089 - mean_absolute_error: 0.0749
# Epoch 9/50
#  - 79s - loss: 0.0088 - mean_absolute_error: 0.0735
# Epoch 10/50
#  - 77s - loss: 0.0089 - mean_absolute_error: 0.0752
# Epoch 11/50
#  - 77s - loss: 0.0092 - mean_absolute_error: 0.0755
# Epoch 12/50
#  - 78s - loss: 0.0081 - mean_absolute_error: 0.0711
# Epoch 13/50
#  - 78s - loss: 0.0084 - mean_absolute_error: 0.0724
# Epoch 14/50
#  - 77s - loss: 0.0082 - mean_absolute_error: 0.0713
# Epoch 15/50
#  - 77s - loss: 0.0089 - mean_absolute_error: 0.0756
# Epoch 16/50
#  - 79s - loss: 0.0086 - mean_absolute_error: 0.0735
# Epoch 17/50
#  - 81s - loss: 0.0080 - mean_absolute_error: 0.0700
# Epoch 18/50
#  - 79s - loss: 0.0079 - mean_absolute_error: 0.0696
# Epoch 19/50
#  - 79s - loss: 0.0072 - mean_absolute_error: 0.0677
# Epoch 20/50
#  - 80s - loss: 0.0076 - mean_absolute_error: 0.0683
# Epoch 21/50
#  - 81s - loss: 0.0074 - mean_absolute_error: 0.0670
# Epoch 22/50
#  - 81s - loss: 0.0067 - mean_absolute_error: 0.0639
# Epoch 23/50
#  - 81s - loss: 0.0068 - mean_absolute_error: 0.0636
# Epoch 24/50
#  - 82s - loss: 0.0067 - mean_absolute_error: 0.0650
# Epoch 25/50
#  - 80s - loss: 0.0069 - mean_absolute_error: 0.0652
# Epoch 26/50
#  - 80s - loss: 0.0065 - mean_absolute_error: 0.0631
# Epoch 27/50
#  - 80s - loss: 0.0066 - mean_absolute_error: 0.0630
# Epoch 28/50
#  - 80s - loss: 0.0064 - mean_absolute_error: 0.0632
# Epoch 29/50
#  - 79s - loss: 0.0057 - mean_absolute_error: 0.0597
# Epoch 30/50
#  - 79s - loss: 0.0061 - mean_absolute_error: 0.0606
# Epoch 31/50
#  - 80s - loss: 0.0058 - mean_absolute_error: 0.0587
# Epoch 32/50
#  - 81s - loss: 0.0056 - mean_absolute_error: 0.0589
# Epoch 33/50
#  - 82s - loss: 0.0053 - mean_absolute_error: 0.0567
# Epoch 34/50
#  - 86s - loss: 0.0054 - mean_absolute_error: 0.0563
# Epoch 35/50
#  - 86s - loss: 0.0051 - mean_absolute_error: 0.0562
# Epoch 36/50
#  - 86s - loss: 0.0055 - mean_absolute_error: 0.0580
# Epoch 37/50
#  - 86s - loss: 0.0047 - mean_absolute_error: 0.0526
# Epoch 38/50
#  - 86s - loss: 0.0052 - mean_absolute_error: 0.0556
# Epoch 39/50
#  - 87s - loss: 0.0048 - mean_absolute_error: 0.0528
# Epoch 40/50
#  - 87s - loss: 0.0049 - mean_absolute_error: 0.0548
# Epoch 41/50
#  - 88s - loss: 0.0046 - mean_absolute_error: 0.0519
# Epoch 42/50
#  - 87s - loss: 0.0041 - mean_absolute_error: 0.0490
# Epoch 43/50
#  - 87s - loss: 0.0043 - mean_absolute_error: 0.0519
# Epoch 44/50
#  - 86s - loss: 0.0044 - mean_absolute_error: 0.0524
# Epoch 45/50
#  - 86s - loss: 0.0040 - mean_absolute_error: 0.0490
# Epoch 46/50
#  - 85s - loss: 0.0038 - mean_absolute_error: 0.0464
# Epoch 47/50
#  - 85s - loss: 0.0037 - mean_absolute_error: 0.0478
# Epoch 48/50
#  - 85s - loss: 0.0046 - mean_absolute_error: 0.0518
# Epoch 49/50
#  - 85s - loss: 0.0034 - mean_absolute_error: 0.0455
# Epoch 50/50
#  - 85s - loss: 0.0031 - mean_absolute_error: 0.0431
# Kappa Score: 0.17393026280219248
# Build model ...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 870)               0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 870, 50)           595750
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 300)               421200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 1,017,251
# Trainable params: 1,017,251
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 85s - loss: 0.0161 - mean_absolute_error: 0.1010
# Epoch 2/50
#  - 85s - loss: 0.0124 - mean_absolute_error: 0.0869
# Epoch 3/50
#  - 84s - loss: 0.0116 - mean_absolute_error: 0.0870
# Epoch 4/50
#  - 83s - loss: 0.0110 - mean_absolute_error: 0.0823
# Epoch 5/50
#  - 86s - loss: 0.0104 - mean_absolute_error: 0.0818
# Epoch 6/50
#  - 84s - loss: 0.0111 - mean_absolute_error: 0.0828
# Epoch 7/50
#  - 83s - loss: 0.0113 - mean_absolute_error: 0.0843
# Epoch 8/50
#  - 81s - loss: 0.0106 - mean_absolute_error: 0.0803
# Epoch 9/50
#  - 80s - loss: 0.0099 - mean_absolute_error: 0.0779
# Epoch 10/50
#  - 80s - loss: 0.0092 - mean_absolute_error: 0.0751
# Epoch 11/50
#  - 80s - loss: 0.0095 - mean_absolute_error: 0.0757
# Epoch 12/50
#  - 80s - loss: 0.0094 - mean_absolute_error: 0.0767
# Epoch 13/50
#  - 80s - loss: 0.0088 - mean_absolute_error: 0.0734
# Epoch 14/50
#  - 80s - loss: 0.0089 - mean_absolute_error: 0.0749
# Epoch 15/50
#  - 79s - loss: 0.0083 - mean_absolute_error: 0.0719
# Epoch 16/50
#  - 80s - loss: 0.0084 - mean_absolute_error: 0.0723
# Epoch 17/50
#  - 79s - loss: 0.0088 - mean_absolute_error: 0.0745
# Epoch 18/50
#  - 79s - loss: 0.0083 - mean_absolute_error: 0.0711
# Epoch 19/50
#  - 79s - loss: 0.0083 - mean_absolute_error: 0.0715
# Epoch 20/50
#  - 79s - loss: 0.0075 - mean_absolute_error: 0.0682
# Epoch 21/50
#  - 80s - loss: 0.0076 - mean_absolute_error: 0.0697
# Epoch 22/50
#  - 79s - loss: 0.0075 - mean_absolute_error: 0.0670
# Epoch 23/50
#  - 80s - loss: 0.0075 - mean_absolute_error: 0.0680
# Epoch 24/50
#  - 79s - loss: 0.0071 - mean_absolute_error: 0.0656
# Epoch 25/50
#  - 79s - loss: 0.0072 - mean_absolute_error: 0.0668
# Epoch 26/50
#  - 79s - loss: 0.0069 - mean_absolute_error: 0.0664
# Epoch 27/50
#  - 80s - loss: 0.0067 - mean_absolute_error: 0.0641
# Epoch 28/50
#  - 81s - loss: 0.0064 - mean_absolute_error: 0.0621
# Epoch 29/50
#  - 81s - loss: 0.0066 - mean_absolute_error: 0.0625
# Epoch 30/50
#  - 80s - loss: 0.0063 - mean_absolute_error: 0.0621
# Epoch 31/50
#  - 81s - loss: 0.0055 - mean_absolute_error: 0.0594
# Epoch 32/50
#  - 80s - loss: 0.0061 - mean_absolute_error: 0.0611
# Epoch 33/50
#  - 80s - loss: 0.0057 - mean_absolute_error: 0.0583
# Epoch 34/50
#  - 83s - loss: 0.0058 - mean_absolute_error: 0.0577
# Epoch 35/50
#  - 83s - loss: 0.0059 - mean_absolute_error: 0.0610
# Epoch 36/50
#  - 84s - loss: 0.0054 - mean_absolute_error: 0.0570
# Epoch 37/50
#  - 84s - loss: 0.0053 - mean_absolute_error: 0.0569
# Epoch 38/50
#  - 83s - loss: 0.0049 - mean_absolute_error: 0.0552
# Epoch 39/50
#  - 83s - loss: 0.0049 - mean_absolute_error: 0.0535
# Epoch 40/50
#  - 82s - loss: 0.0048 - mean_absolute_error: 0.0535
# Epoch 41/50
#  - 81s - loss: 0.0043 - mean_absolute_error: 0.0517
# Epoch 42/50
#  - 81s - loss: 0.0042 - mean_absolute_error: 0.0500
# Epoch 43/50
#  - 81s - loss: 0.0042 - mean_absolute_error: 0.0501
# Epoch 44/50
#  - 81s - loss: 0.0039 - mean_absolute_error: 0.0489
# Epoch 45/50
#  - 82s - loss: 0.0044 - mean_absolute_error: 0.0509
# Epoch 46/50
#  - 82s - loss: 0.0039 - mean_absolute_error: 0.0488
# Epoch 47/50
#  - 81s - loss: 0.0038 - mean_absolute_error: 0.0483
# Epoch 48/50
#  - 80s - loss: 0.0041 - mean_absolute_error: 0.0490
# Epoch 49/50
#  - 79s - loss: 0.0037 - mean_absolute_error: 0.0465
# Epoch 50/50
#  - 80s - loss: 0.0034 - mean_absolute_error: 0.0458
# Kappa Score: 0.13040448987879505
# Build model ...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 870)               0
# _________________________________________________________________
# embedding_3 (Embedding)      (None, 870, 50)           595750
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 300)               421200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 1,017,251
# Trainable params: 1,017,251
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 81s - loss: 0.0181 - mean_absolute_error: 0.1057
# Epoch 2/50
#  - 82s - loss: 0.0117 - mean_absolute_error: 0.0839
# Epoch 3/50
#  - 81s - loss: 0.0115 - mean_absolute_error: 0.0840
# Epoch 4/50
#  - 82s - loss: 0.0112 - mean_absolute_error: 0.0842
# Epoch 5/50
#  - 83s - loss: 0.0104 - mean_absolute_error: 0.0805
# Epoch 6/50
#  - 83s - loss: 0.0096 - mean_absolute_error: 0.0777
# Epoch 7/50
#  - 84s - loss: 0.0100 - mean_absolute_error: 0.0780
# Epoch 8/50
#  - 85s - loss: 0.0095 - mean_absolute_error: 0.0772
# Epoch 9/50
#  - 84s - loss: 0.0091 - mean_absolute_error: 0.0758
# Epoch 10/50
#  - 82s - loss: 0.0096 - mean_absolute_error: 0.0773
# Epoch 11/50
#  - 84s - loss: 0.0088 - mean_absolute_error: 0.0729
# Epoch 12/50
#  - 84s - loss: 0.0090 - mean_absolute_error: 0.0750
# Epoch 13/50
#  - 85s - loss: 0.0097 - mean_absolute_error: 0.0791
# Epoch 14/50
#  - 85s - loss: 0.0089 - mean_absolute_error: 0.0748
# Epoch 15/50
#  - 85s - loss: 0.0086 - mean_absolute_error: 0.0725
# Epoch 16/50
#  - 84s - loss: 0.0081 - mean_absolute_error: 0.0700
# Epoch 17/50
#  - 83s - loss: 0.0079 - mean_absolute_error: 0.0687
# Epoch 18/50
#  - 82s - loss: 0.0073 - mean_absolute_error: 0.0672
# Epoch 19/50
#  - 83s - loss: 0.0075 - mean_absolute_error: 0.0672
# Epoch 20/50
#  - 84s - loss: 0.0076 - mean_absolute_error: 0.0685
# Epoch 21/50
#  - 84s - loss: 0.0077 - mean_absolute_error: 0.0685
# Epoch 22/50
#  - 85s - loss: 0.0071 - mean_absolute_error: 0.0652
# Epoch 23/50
#  - 81s - loss: 0.0068 - mean_absolute_error: 0.0652
# Epoch 24/50
#  - 81s - loss: 0.0062 - mean_absolute_error: 0.0606
# Epoch 25/50
#  - 80s - loss: 0.0067 - mean_absolute_error: 0.0637
# Epoch 26/50
#  - 81s - loss: 0.0066 - mean_absolute_error: 0.0638
# Epoch 27/50
#  - 83s - loss: 0.0067 - mean_absolute_error: 0.0632
# Epoch 28/50
#  - 83s - loss: 0.0064 - mean_absolute_error: 0.0621
# Epoch 29/50
#  - 82s - loss: 0.0062 - mean_absolute_error: 0.0615
# Epoch 30/50
#  - 82s - loss: 0.0060 - mean_absolute_error: 0.0598
# Epoch 31/50
#  - 82s - loss: 0.0057 - mean_absolute_error: 0.0586
# Epoch 32/50
#  - 81s - loss: 0.0057 - mean_absolute_error: 0.0589
# Epoch 33/50
#  - 81s - loss: 0.0051 - mean_absolute_error: 0.0559
# Epoch 34/50
#  - 81s - loss: 0.0053 - mean_absolute_error: 0.0566
# Epoch 35/50
#  - 82s - loss: 0.0051 - mean_absolute_error: 0.0562
# Epoch 36/50
#  - 82s - loss: 0.0048 - mean_absolute_error: 0.0537
# Epoch 37/50
#  - 82s - loss: 0.0047 - mean_absolute_error: 0.0534
# Epoch 38/50
#  - 82s - loss: 0.0046 - mean_absolute_error: 0.0523
# Epoch 39/50
#  - 82s - loss: 0.0045 - mean_absolute_error: 0.0513
# Epoch 40/50
#  - 81s - loss: 0.0046 - mean_absolute_error: 0.0518
# Epoch 41/50
#  - 81s - loss: 0.0043 - mean_absolute_error: 0.0508
# Epoch 42/50
#  - 82s - loss: 0.0044 - mean_absolute_error: 0.0515
# Epoch 43/50
#  - 81s - loss: 0.0040 - mean_absolute_error: 0.0487
# Epoch 44/50
#  - 80s - loss: 0.0046 - mean_absolute_error: 0.0534
# Epoch 45/50
#  - 81s - loss: 0.0040 - mean_absolute_error: 0.0489
# Epoch 46/50
#  - 83s - loss: 0.0040 - mean_absolute_error: 0.0487
# Epoch 47/50
#  - 82s - loss: 0.0041 - mean_absolute_error: 0.0496
# Epoch 48/50
#  - 82s - loss: 0.0037 - mean_absolute_error: 0.0458
# Epoch 49/50
#  - 81s - loss: 0.0036 - mean_absolute_error: 0.0456
# Epoch 50/50
#  - 82s - loss: 0.0033 - mean_absolute_error: 0.0454
# Kappa Score: 0.08295796261597188
# Build model ...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 870)               0
# _________________________________________________________________
# embedding_4 (Embedding)      (None, 870, 50)           595750
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 300)               421200
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 1,017,251
# Trainable params: 1,017,251
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 83s - loss: 0.0169 - mean_absolute_error: 0.1005
# Epoch 2/50
#  - 81s - loss: 0.0116 - mean_absolute_error: 0.0851
# Epoch 3/50
#  - 80s - loss: 0.0106 - mean_absolute_error: 0.0809
# Epoch 4/50
#  - 81s - loss: 0.0105 - mean_absolute_error: 0.0817
# Epoch 5/50
#  - 80s - loss: 0.0108 - mean_absolute_error: 0.0810
# Epoch 6/50
#  - 80s - loss: 0.0097 - mean_absolute_error: 0.0760
# Epoch 7/50
#  - 81s - loss: 0.0105 - mean_absolute_error: 0.0814
# Epoch 8/50
#  - 81s - loss: 0.0099 - mean_absolute_error: 0.0785
# Epoch 9/50
#  - 81s - loss: 0.0094 - mean_absolute_error: 0.0756
# Epoch 10/50
#  - 81s - loss: 0.0090 - mean_absolute_error: 0.0734
# Epoch 11/50
#  - 83s - loss: 0.0099 - mean_absolute_error: 0.0789
# Epoch 12/50
#  - 83s - loss: 0.0081 - mean_absolute_error: 0.0702
# Epoch 13/50
#  - 81s - loss: 0.0088 - mean_absolute_error: 0.0738
# Epoch 14/50
#  - 82s - loss: 0.0082 - mean_absolute_error: 0.0703
# Epoch 15/50
#  - 81s - loss: 0.0083 - mean_absolute_error: 0.0716
# Epoch 16/50
#  - 81s - loss: 0.0083 - mean_absolute_error: 0.0720
# Epoch 17/50
#  - 81s - loss: 0.0082 - mean_absolute_error: 0.0714
# Epoch 18/50
#  - 82s - loss: 0.0076 - mean_absolute_error: 0.0678
# Epoch 19/50
#  - 82s - loss: 0.0075 - mean_absolute_error: 0.0690
# Epoch 20/50
#  - 82s - loss: 0.0076 - mean_absolute_error: 0.0687
# Epoch 21/50
#  - 83s - loss: 0.0072 - mean_absolute_error: 0.0669
# Epoch 22/50
#  - 82s - loss: 0.0076 - mean_absolute_error: 0.0684
# Epoch 23/50
#  - 82s - loss: 0.0073 - mean_absolute_error: 0.0668
# Epoch 24/50
#  - 83s - loss: 0.0068 - mean_absolute_error: 0.0646
# Epoch 25/50
#  - 82s - loss: 0.0070 - mean_absolute_error: 0.0649
# Epoch 26/50
#  - 82s - loss: 0.0070 - mean_absolute_error: 0.0658
# Epoch 27/50
#  - 82s - loss: 0.0066 - mean_absolute_error: 0.0640
# Epoch 28/50
#  - 82s - loss: 0.0058 - mean_absolute_error: 0.0594
# Epoch 29/50
#  - 81s - loss: 0.0064 - mean_absolute_error: 0.0614
# Epoch 30/50
#  - 82s - loss: 0.0059 - mean_absolute_error: 0.0596
# Epoch 31/50
#  - 82s - loss: 0.0060 - mean_absolute_error: 0.0613
# Epoch 32/50
#  - 81s - loss: 0.0058 - mean_absolute_error: 0.0577
# Epoch 33/50
#  - 83s - loss: 0.0058 - mean_absolute_error: 0.0594
# Epoch 34/50
#  - 85s - loss: 0.0055 - mean_absolute_error: 0.0573
# Epoch 35/50
#  - 84s - loss: 0.0051 - mean_absolute_error: 0.0551
# Epoch 36/50
#  - 82s - loss: 0.0052 - mean_absolute_error: 0.0552
# Epoch 37/50
#  - 80s - loss: 0.0049 - mean_absolute_error: 0.0541
# Epoch 38/50
#  - 80s - loss: 0.0048 - mean_absolute_error: 0.0534
# Epoch 39/50
#  - 80s - loss: 0.0045 - mean_absolute_error: 0.0520
# Epoch 40/50
#  - 80s - loss: 0.0045 - mean_absolute_error: 0.0522
# Epoch 41/50
#  - 80s - loss: 0.0048 - mean_absolute_error: 0.0544
# Epoch 42/50
#  - 80s - loss: 0.0045 - mean_absolute_error: 0.0513
# Epoch 43/50
#  - 79s - loss: 0.0043 - mean_absolute_error: 0.0507
# Epoch 44/50
#  - 79s - loss: 0.0039 - mean_absolute_error: 0.0481
# Epoch 45/50
#  - 80s - loss: 0.0042 - mean_absolute_error: 0.0509
# Epoch 46/50
#  - 80s - loss: 0.0039 - mean_absolute_error: 0.0478
# Epoch 47/50
#  - 79s - loss: 0.0039 - mean_absolute_error: 0.0478
# Epoch 48/50
#  - 79s - loss: 0.0035 - mean_absolute_error: 0.0457
# Epoch 49/50
#  - 79s - loss: 0.0034 - mean_absolute_error: 0.0449
# Epoch 50/50
#  - 79s - loss: 0.0032 - mean_absolute_error: 0.0442
# Kappa Score: 0.2575453508047063
# Build model ...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 870)               0
# _________________________________________________________________
# embedding_5 (Embedding)      (None, 870, 50)           595750
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 300)               421200
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 1,017,251
# Trainable params: 1,017,251
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 78s - loss: 0.0151 - mean_absolute_error: 0.0974
# Epoch 2/50
#  - 77s - loss: 0.0123 - mean_absolute_error: 0.0886
# Epoch 3/50
#  - 79s - loss: 0.0104 - mean_absolute_error: 0.0802
# Epoch 4/50
#  - 79s - loss: 0.0099 - mean_absolute_error: 0.0797
# Epoch 5/50
#  - 79s - loss: 0.0100 - mean_absolute_error: 0.0797
# Epoch 6/50
#  - 79s - loss: 0.0091 - mean_absolute_error: 0.0758
# Epoch 7/50
#  - 80s - loss: 0.0090 - mean_absolute_error: 0.0768
# Epoch 8/50
#  - 79s - loss: 0.0088 - mean_absolute_error: 0.0745
# Epoch 9/50
#  - 81s - loss: 0.0090 - mean_absolute_error: 0.0744
# Epoch 10/50
#  - 81s - loss: 0.0085 - mean_absolute_error: 0.0727
# Epoch 11/50
#  - 81s - loss: 0.0082 - mean_absolute_error: 0.0716
# Epoch 12/50
#  - 80s - loss: 0.0077 - mean_absolute_error: 0.0690
# Epoch 13/50
#  - 80s - loss: 0.0079 - mean_absolute_error: 0.0690
# Epoch 14/50
#  - 78s - loss: 0.0072 - mean_absolute_error: 0.0681
# Epoch 15/50
#  - 79s - loss: 0.0081 - mean_absolute_error: 0.0709
# Epoch 16/50
#  - 78s - loss: 0.0077 - mean_absolute_error: 0.0704
# Epoch 17/50
#  - 78s - loss: 0.0078 - mean_absolute_error: 0.0696
# Epoch 18/50
#  - 78s - loss: 0.0074 - mean_absolute_error: 0.0681
# Epoch 19/50
#  - 78s - loss: 0.0071 - mean_absolute_error: 0.0660
# Epoch 20/50
#  - 78s - loss: 0.0069 - mean_absolute_error: 0.0654
# Epoch 21/50
#  - 79s - loss: 0.0068 - mean_absolute_error: 0.0644
# Epoch 22/50
#  - 79s - loss: 0.0067 - mean_absolute_error: 0.0648
# Epoch 23/50
#  - 79s - loss: 0.0070 - mean_absolute_error: 0.0666
# Epoch 24/50
#  - 80s - loss: 0.0066 - mean_absolute_error: 0.0642
# Epoch 25/50
#  - 79s - loss: 0.0066 - mean_absolute_error: 0.0631
# Epoch 26/50
#  - 78s - loss: 0.0059 - mean_absolute_error: 0.0593
# Epoch 27/50
#  - 79s - loss: 0.0059 - mean_absolute_error: 0.0612
# Epoch 28/50
#  - 79s - loss: 0.0061 - mean_absolute_error: 0.0610
# Epoch 29/50
#  - 78s - loss: 0.0062 - mean_absolute_error: 0.0626
# Epoch 30/50
#  - 78s - loss: 0.0057 - mean_absolute_error: 0.0599
# Epoch 31/50
#  - 79s - loss: 0.0057 - mean_absolute_error: 0.0573
# Epoch 32/50
#  - 79s - loss: 0.0053 - mean_absolute_error: 0.0570
# Epoch 33/50
#  - 78s - loss: 0.0050 - mean_absolute_error: 0.0550
# Epoch 34/50
#  - 79s - loss: 0.0047 - mean_absolute_error: 0.0539
# Epoch 35/50
#  - 79s - loss: 0.0048 - mean_absolute_error: 0.0534
# Epoch 36/50
#  - 79s - loss: 0.0049 - mean_absolute_error: 0.0539
# Epoch 37/50
#  - 79s - loss: 0.0045 - mean_absolute_error: 0.0533
# Epoch 38/50
#  - 79s - loss: 0.0047 - mean_absolute_error: 0.0533
# Epoch 39/50
#  - 78s - loss: 0.0046 - mean_absolute_error: 0.0525
# Epoch 40/50
#  - 79s - loss: 0.0046 - mean_absolute_error: 0.0536
# Epoch 41/50
#  - 79s - loss: 0.0043 - mean_absolute_error: 0.0507
# Epoch 42/50
#  - 79s - loss: 0.0039 - mean_absolute_error: 0.0486
# Epoch 43/50
#  - 79s - loss: 0.0041 - mean_absolute_error: 0.0510
# Epoch 44/50
#  - 79s - loss: 0.0039 - mean_absolute_error: 0.0500
# Epoch 45/50
#  - 79s - loss: 0.0037 - mean_absolute_error: 0.0475
# Epoch 46/50
#  - 79s - loss: 0.0036 - mean_absolute_error: 0.0475
# Epoch 47/50
#  - 78s - loss: 0.0034 - mean_absolute_error: 0.0456
# Epoch 48/50
#  - 78s - loss: 0.0034 - mean_absolute_error: 0.0460
# Epoch 49/50
#  - 78s - loss: 0.0032 - mean_absolute_error: 0.0449
# Epoch 50/50
#  - 79s - loss: 0.0034 - mean_absolute_error: 0.0455
# Kappa Score: 0.24796398066609282
# Average Kappa score after a 5-fold cross validation:  0.16021
# Kappa score after a 5-fold cross validation:  0.17406560786077074
