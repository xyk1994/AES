# %%
prompt_id = 7
model_name = "1layer"  # 1layer, 1layer_MoT, 2layer, 2layer_MoT

# %%
import os
import pprint
import tensorflow as tf

if 'COLAB_TPU_ADDR' not in os.environ:
  print('ERROR: Not connected to a TPU runtime')
else:
  tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
  print ('TPU address is', tpu_address)

  with tf.Session(tpu_address) as session:
    devices = session.list_devices()

  print('TPU devices:')
  pprint.pprint(devices)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# ERROR: Not connected to a TPU runtime

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/My Drive/AES謝"
os.chdir(path)
# os.listdir(path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# ['glove.6B.50d.txt',
#  'data_feature',
#  'sent_feature',
#  'fine_tuning_out',
#  '1layer',
#  'AES(1layer)(prompt1).ipynb のコピー',
#  '1layerMoT',
#  '2layer',
#  '1layer+Overall',
#  '1layerMoT+Overall',
#  '2layer+Overall',
#  '実験結果.gsheet']

# %%
import argparse
import nltk
import tensorflow as tf
from keras.models import Model
from keras import layers
from keras.layers import Input, Embedding, LSTM, Dense
from keras.engine.topology import Layer
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
import keras.backend as K
from sklearn.model_selection import KFold
from sklearn.metrics import cohen_kappa_score
from keras.preprocessing.sequence import pad_sequences
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')

nltk.download('stopwords')
nltk.download('punkt')

# stopwords, punkt,
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Mean Over Time
class TemporalMean(Layer):
  def __init__(self, **kwargs):
      self.supports_masking = True
      super(TemporalMean, self).__init__(**kwargs)

  def compute_mask(self, input, input_mask=None):
      # do not pass the mask to the next layers
      return None

  def call(self, x, mask=None):
      if mask is not None:
          # mask (batch, time)
          mask = K.cast(mask, K.floatx())
          # mask (batch, x_dim, time)
          mask = K.repeat(mask, x.shape[-1])
          # mask (batch, time, x_dim)
          mask = tf.transpose(mask, [0,2,1])
          x = x * mask
      return K.sum(x, axis=1) / K.sum(mask, axis=1)

  def compute_output_shape(self, input_shape):
      # remove temporal dimension
      return (input_shape[0], input_shape[2])

def essay_to_wordlist(essay_v, remove_stopwords):
    """Remove the tagged labels and word tokenize the sentence."""
    essay_v = re.sub("[^a-zA-Z]", " ", essay_v)
    words = essay_v.lower().split()
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    return (words)

def get_clean_essays(Text):
    clean_essays = []
    for essay in Text:
        clean_essays.append(essay_to_wordlist(essay, remove_stopwords=False))
    return clean_essays

def create_dict(text):
    print("create_dict")
    word_index = {}
    word_index['xieyikuan'] = 0
    for sentence in text:
        for word in sentence:
            if word not in word_index:
                word_index[word] = len(word_index)
    word_index['unk'] = len(word_index)
    return word_index

def essay_to_index(essays, word_index):
    Essays = []
    for essay in essays:
        sentence = []
        for sent in essay:
            words = []
            for word in sent:
                words.append(word_index[word])
            sentence.append(words)
        Essays.append(sentence)
    return Essays

def essay_to_index2(essays, word_index):
    Essays = []
    for essay in essays:
        words = []
        for word in essay:
            words.append(word_index[word])
        Essays.append(words)
    return Essays

def get_embeddings_index():
    embeddings_index = {}
    f = open('glove.6B.50d.txt', 'r', encoding='UTF-8')
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.array(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    f.close()
    return embeddings_index

def embeddings_matrix(embeddings_index, word_index, embedding_dim):
    nb_words = len(word_index)
    embedding_matrix = np.zeros((nb_words + 1, embedding_dim))
    for word, i in word_index.items():
        if i > nb_words:
            continue
        embeddings_vector = embeddings_index.get(word)
        if embeddings_vector is not None:
            embedding_matrix[i] = embeddings_vector
        if embeddings_vector is None:
            embedding_matrix[i] = embeddings_index.get('unk')
    return embedding_matrix

# %%
csv_input = pd.read_csv(filepath_or_buffer="data_feature/set"+str(prompt_id)+"_feature(26).tsv", delimiter="\t", engine="python", error_bad_lines=False)

Text = csv_input['essay']
Score = csv_input['domain1_score']
Label = Score

# --------
if prompt_id == 1:
    Score = (Score - 2) / 10      # set_1     范围 2-12
elif prompt_id == 2:
    Score = (Score - 1) / 5       # set_2     范围 1-6
elif prompt_id == 3 or prompt_id == 4:
    Score = Score / 3           # set_3,4   范围 0-3
elif prompt_id == 5 or prompt_id == 6:
    Score = Score / 4           # set_5,6   范围 0-4
elif prompt_id == 7:
    Score = Score / 30          # set_7     范围 0-30
elif prompt_id == 8:
    Score = Score / 60          # set_8     范围 0-60
#print(Score)

# 做字典
clean_essays = get_clean_essays(Text)
word_index = create_dict(clean_essays)

# 做分句
text = np.array(Text)
# print(text)
a = []
for essay in text:
    a.append(sent_tokenize(essay))
texts = np.array(a)

# 做分词
essays = []
for essay in Text:
  essay_idx = essay_to_wordlist(essay, remove_stopwords=False)
  # sent = np.array(sent)
  essays.append(essay_idx)
essays = np.array(essays)

Essays = essay_to_index2(clean_essays, word_index)
Essays = np.array(Essays)

if prompt_id == 1:
    max_essay_length = 600
elif prompt_id == 2:
    max_essay_length = 700
elif prompt_id == 3:
    max_essay_length = 256
elif prompt_id == 4:
    max_essay_length = 200
elif prompt_id == 5:
    max_essay_length = 256
elif prompt_id == 6:
    max_essay_length = 256
elif prompt_id == 7:
    max_essay_length = 350
elif prompt_id == 8:
    max_essay_length = 870

essay_pad = pad_sequences(Essays, maxlen=max_essay_length)

embeddings_index = get_embeddings_index()
embeddings_matrix = embeddings_matrix(embeddings_index, word_index, embedding_dim=50)

# 记录成绩
results = []
score_predict_list = []
sssscore = []
llllabel = []
newresults = []
cv = KFold(n_splits=5, shuffle=True, random_state=10)

for train, test in cv.split(essay_pad):
    text_train, text_test = essay_pad[train], essay_pad[test]
    label_train, label_test = Score.iloc[train], Score.iloc[test]
    score_train, score_test = Label.iloc[train], Label.iloc[test]

    # -------
    print('Build model ...')
    text_input = Input(shape=(max_essay_length, ), name='text_input')

    embedding_layer = Embedding(input_dim=len(word_index) + 1,
                                output_dim=50,
                                weights=[embeddings_matrix],
                                input_length=max_essay_length,
                                trainable=True,
                                mask_zero=True)
    x = embedding_layer(text_input)  
    if model_name == "2layer_MoT":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)  
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)  
      x = TemporalMean()(x)
    elif model_name == "2layer":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)  
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)  
    elif model_name == "1layer_MoT":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)  
      x = TemporalMean()(x)
    elif model_name == "1layer":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)  
    x = layers.Dropout(0.5)(x)
    output = Dense(1, activation='sigmoid')(x)

    model = Model(inputs=text_input, outputs=output)
    # -------

    model.summary()
    model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001, decay=1e-6), metrics=['mean_absolute_error'])
    model.fit(text_train, label_train, batch_size=32, epochs=50, verbose=2)

    score_predict = model.predict(text_test)
    if prompt_id == 1:
        score_predict = score_predict*10+2
    elif prompt_id == 2:
        score_predict = score_predict*5+1
    elif prompt_id == 3:
        score_predict = score_predict*3
    elif prompt_id == 4:
        score_predict = score_predict*3
    elif prompt_id == 5:
        score_predict = score_predict*4
    elif prompt_id == 6:
        score_predict = score_predict*4
    elif prompt_id == 7:
        score_predict = score_predict*30
    elif prompt_id == 8:
        score_predict = score_predict*60

    score_predict = np.around(score_predict)

    sssscore.append(score_predict)
    llllabel.append(score_test)

    result = cohen_kappa_score(score_test.values, score_predict, weights='quadratic')
    print("Kappa Score: {}".format(result))
    results.append(result)
    for i in results:
      if i != 0:
        newresults.append(i)

print("Average Kappa score after a 5-fold cross validation: ", np.around(np.array(newresults).mean(), decimals=5))

sssscore = np.array(sssscore)
res = []
for scores in sssscore:
  for score in scores:
    res.append(score)

ll = np.array(llllabel)
res_label = []
for labels in ll:
  for label in labels:
    res_label.append(label)
res_label = np.array(res_label)

QWK = cohen_kappa_score(res_label, res, weights='quadratic')
print("Kappa score after a 5-fold cross validation: ", QWK)
# Out:
# create_dict
# Build model ...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3239: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 350)               0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 350, 50)           510050
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 300)               421200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 931,551
# Trainable params: 931,551
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/50
#  - 34s - loss: 0.0293 - mean_absolute_error: 0.1373
# Epoch 2/50
#  - 32s - loss: 0.0255 - mean_absolute_error: 0.1281
# Epoch 3/50
#  - 32s - loss: 0.0242 - mean_absolute_error: 0.1247
# Epoch 4/50
#  - 35s - loss: 0.0252 - mean_absolute_error: 0.1275
# Epoch 5/50
#  - 34s - loss: 0.0236 - mean_absolute_error: 0.1238
# Epoch 6/50
#  - 35s - loss: 0.0232 - mean_absolute_error: 0.1220
# Epoch 7/50
#  - 32s - loss: 0.0224 - mean_absolute_error: 0.1209
# Epoch 8/50
#  - 33s - loss: 0.0225 - mean_absolute_error: 0.1205
# Epoch 9/50
#  - 32s - loss: 0.0215 - mean_absolute_error: 0.1182
# Epoch 10/50
#  - 32s - loss: 0.0208 - mean_absolute_error: 0.1168
# Epoch 11/50
#  - 32s - loss: 0.0209 - mean_absolute_error: 0.1145
# Epoch 12/50
#  - 32s - loss: 0.0213 - mean_absolute_error: 0.1158
# Epoch 13/50
#  - 33s - loss: 0.0196 - mean_absolute_error: 0.1128
# Epoch 14/50
#  - 31s - loss: 0.0187 - mean_absolute_error: 0.1090
# Epoch 15/50
#  - 31s - loss: 0.0183 - mean_absolute_error: 0.1089
# Epoch 16/50
#  - 31s - loss: 0.0167 - mean_absolute_error: 0.1028
# Epoch 17/50
#  - 31s - loss: 0.0159 - mean_absolute_error: 0.1001
# Epoch 18/50
#  - 31s - loss: 0.0143 - mean_absolute_error: 0.0944
# Epoch 19/50
#  - 31s - loss: 0.0142 - mean_absolute_error: 0.0940
# Epoch 20/50
#  - 31s - loss: 0.0125 - mean_absolute_error: 0.0887
# Epoch 21/50
#  - 31s - loss: 0.0123 - mean_absolute_error: 0.0877
# Epoch 22/50
#  - 31s - loss: 0.0112 - mean_absolute_error: 0.0836
# Epoch 23/50
#  - 31s - loss: 0.0101 - mean_absolute_error: 0.0790
# Epoch 24/50
#  - 31s - loss: 0.0095 - mean_absolute_error: 0.0773
# Epoch 25/50
#  - 31s - loss: 0.0086 - mean_absolute_error: 0.0743
# Epoch 26/50
#  - 31s - loss: 0.0084 - mean_absolute_error: 0.0732
# Epoch 27/50
#  - 31s - loss: 0.0074 - mean_absolute_error: 0.0686
# Epoch 28/50
#  - 31s - loss: 0.0071 - mean_absolute_error: 0.0668
# Epoch 29/50
#  - 30s - loss: 0.0070 - mean_absolute_error: 0.0661
# Epoch 30/50
#  - 31s - loss: 0.0064 - mean_absolute_error: 0.0628
# Epoch 31/50
#  - 31s - loss: 0.0059 - mean_absolute_error: 0.0607
# Epoch 32/50
#  - 31s - loss: 0.0053 - mean_absolute_error: 0.0577
# Epoch 33/50
#  - 31s - loss: 0.0052 - mean_absolute_error: 0.0569
# Epoch 34/50
#  - 31s - loss: 0.0051 - mean_absolute_error: 0.0565
# Epoch 35/50
#  - 31s - loss: 0.0052 - mean_absolute_error: 0.0561
# Epoch 36/50
#  - 30s - loss: 0.0046 - mean_absolute_error: 0.0531
# Epoch 37/50
#  - 31s - loss: 0.0043 - mean_absolute_error: 0.0520
# Epoch 38/50
#  - 31s - loss: 0.0039 - mean_absolute_error: 0.0497
# Epoch 39/50
#  - 31s - loss: 0.0038 - mean_absolute_error: 0.0491
# Epoch 40/50
#  - 31s - loss: 0.0038 - mean_absolute_error: 0.0483
# Epoch 41/50
#  - 31s - loss: 0.0039 - mean_absolute_error: 0.0496
# Epoch 42/50
#  - 31s - loss: 0.0036 - mean_absolute_error: 0.0473
# Epoch 43/50
#  - 31s - loss: 0.0035 - mean_absolute_error: 0.0469
# Epoch 44/50
#  - 31s - loss: 0.0032 - mean_absolute_error: 0.0443
# Epoch 45/50
#  - 31s - loss: 0.0030 - mean_absolute_error: 0.0434
# Epoch 46/50
#  - 30s - loss: 0.0032 - mean_absolute_error: 0.0444
# Epoch 47/50
#  - 30s - loss: 0.0030 - mean_absolute_error: 0.0432
# Epoch 48/50
#  - 31s - loss: 0.0028 - mean_absolute_error: 0.0418
# Epoch 49/50
#  - 31s - loss: 0.0028 - mean_absolute_error: 0.0413
# Epoch 50/50
#  - 30s - loss: 0.0028 - mean_absolute_error: 0.0412
# Kappa Score: 0.6548286927294545
# Build model ...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 350)               0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 350, 50)           510050
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 300)               421200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 931,551
# Trainable params: 931,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 31s - loss: 0.0290 - mean_absolute_error: 0.1378
# Epoch 2/50
#  - 31s - loss: 0.0245 - mean_absolute_error: 0.1273
# Epoch 3/50
#  - 31s - loss: 0.0257 - mean_absolute_error: 0.1280
# Epoch 4/50
#  - 31s - loss: 0.0238 - mean_absolute_error: 0.1241
# Epoch 5/50
#  - 31s - loss: 0.0235 - mean_absolute_error: 0.1235
# Epoch 6/50
#  - 31s - loss: 0.0227 - mean_absolute_error: 0.1223
# Epoch 7/50
#  - 31s - loss: 0.0228 - mean_absolute_error: 0.1214
# Epoch 8/50
#  - 31s - loss: 0.0220 - mean_absolute_error: 0.1197
# Epoch 9/50
#  - 31s - loss: 0.0219 - mean_absolute_error: 0.1179
# Epoch 10/50
#  - 31s - loss: 0.0210 - mean_absolute_error: 0.1160
# Epoch 11/50
#  - 31s - loss: 0.0204 - mean_absolute_error: 0.1148
# Epoch 12/50
#  - 31s - loss: 0.0214 - mean_absolute_error: 0.1176
# Epoch 13/50
#  - 31s - loss: 0.0194 - mean_absolute_error: 0.1114
# Epoch 14/50
#  - 31s - loss: 0.0195 - mean_absolute_error: 0.1119
# Epoch 15/50
#  - 31s - loss: 0.0181 - mean_absolute_error: 0.1073
# Epoch 16/50
#  - 31s - loss: 0.0177 - mean_absolute_error: 0.1074
# Epoch 17/50
#  - 31s - loss: 0.0157 - mean_absolute_error: 0.1001
# Epoch 18/50
#  - 31s - loss: 0.0139 - mean_absolute_error: 0.0937
# Epoch 19/50
#  - 31s - loss: 0.0142 - mean_absolute_error: 0.0946
# Epoch 20/50
#  - 31s - loss: 0.0128 - mean_absolute_error: 0.0902
# Epoch 21/50
#  - 31s - loss: 0.0113 - mean_absolute_error: 0.0832
# Epoch 22/50
#  - 31s - loss: 0.0104 - mean_absolute_error: 0.0820
# Epoch 23/50
#  - 31s - loss: 0.0103 - mean_absolute_error: 0.0799
# Epoch 24/50
#  - 31s - loss: 0.0095 - mean_absolute_error: 0.0771
# Epoch 25/50
#  - 31s - loss: 0.0087 - mean_absolute_error: 0.0748
# Epoch 26/50
#  - 31s - loss: 0.0080 - mean_absolute_error: 0.0696
# Epoch 27/50
#  - 31s - loss: 0.0075 - mean_absolute_error: 0.0688
# Epoch 28/50
#  - 31s - loss: 0.0072 - mean_absolute_error: 0.0673
# Epoch 29/50
#  - 31s - loss: 0.0065 - mean_absolute_error: 0.0650
# Epoch 30/50
#  - 31s - loss: 0.0060 - mean_absolute_error: 0.0606
# Epoch 31/50
#  - 31s - loss: 0.0062 - mean_absolute_error: 0.0624
# Epoch 32/50
#  - 31s - loss: 0.0056 - mean_absolute_error: 0.0588
# Epoch 33/50
#  - 31s - loss: 0.0051 - mean_absolute_error: 0.0568
# Epoch 34/50
#  - 31s - loss: 0.0051 - mean_absolute_error: 0.0560
# Epoch 35/50
#  - 31s - loss: 0.0052 - mean_absolute_error: 0.0567
# Epoch 36/50
#  - 31s - loss: 0.0049 - mean_absolute_error: 0.0556
# Epoch 37/50
#  - 31s - loss: 0.0046 - mean_absolute_error: 0.0529
# Epoch 38/50
#  - 31s - loss: 0.0043 - mean_absolute_error: 0.0519
# Epoch 39/50
#  - 31s - loss: 0.0042 - mean_absolute_error: 0.0520
# Epoch 40/50
#  - 31s - loss: 0.0041 - mean_absolute_error: 0.0508
# Epoch 41/50
#  - 31s - loss: 0.0039 - mean_absolute_error: 0.0490
# Epoch 42/50
#  - 31s - loss: 0.0035 - mean_absolute_error: 0.0470
# Epoch 43/50
#  - 31s - loss: 0.0035 - mean_absolute_error: 0.0472
# Epoch 44/50
#  - 31s - loss: 0.0039 - mean_absolute_error: 0.0481
# Epoch 45/50
#  - 31s - loss: 0.0035 - mean_absolute_error: 0.0463
# Epoch 46/50
#  - 31s - loss: 0.0036 - mean_absolute_error: 0.0472
# Epoch 47/50
#  - 31s - loss: 0.0031 - mean_absolute_error: 0.0442
# Epoch 48/50
#  - 31s - loss: 0.0029 - mean_absolute_error: 0.0424
# Epoch 49/50
#  - 31s - loss: 0.0028 - mean_absolute_error: 0.0409
# Epoch 50/50
#  - 31s - loss: 0.0028 - mean_absolute_error: 0.0417
# Kappa Score: 0.6391233295828623
# Build model ...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 350)               0
# _________________________________________________________________
# embedding_3 (Embedding)      (None, 350, 50)           510050
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 300)               421200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 931,551
# Trainable params: 931,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 31s - loss: 0.0297 - mean_absolute_error: 0.1391
# Epoch 2/50
#  - 30s - loss: 0.0257 - mean_absolute_error: 0.1288
# Epoch 3/50
#  - 31s - loss: 0.0241 - mean_absolute_error: 0.1254
# Epoch 4/50
#  - 30s - loss: 0.0234 - mean_absolute_error: 0.1237
# Epoch 5/50
#  - 30s - loss: 0.0233 - mean_absolute_error: 0.1213
# Epoch 6/50
#  - 30s - loss: 0.0229 - mean_absolute_error: 0.1222
# Epoch 7/50
#  - 30s - loss: 0.0219 - mean_absolute_error: 0.1189
# Epoch 8/50
#  - 30s - loss: 0.0211 - mean_absolute_error: 0.1158
# Epoch 9/50
#  - 32s - loss: 0.0208 - mean_absolute_error: 0.1154
# Epoch 10/50
#  - 31s - loss: 0.0212 - mean_absolute_error: 0.1165
# Epoch 11/50
#  - 31s - loss: 0.0194 - mean_absolute_error: 0.1105
# Epoch 12/50
#  - 31s - loss: 0.0198 - mean_absolute_error: 0.1134
# Epoch 13/50
#  - 31s - loss: 0.0189 - mean_absolute_error: 0.1092
# Epoch 14/50
#  - 30s - loss: 0.0177 - mean_absolute_error: 0.1068
# Epoch 15/50
#  - 30s - loss: 0.0177 - mean_absolute_error: 0.1062
# Epoch 16/50
#  - 30s - loss: 0.0171 - mean_absolute_error: 0.1038
# Epoch 17/50
#  - 31s - loss: 0.0156 - mean_absolute_error: 0.0993
# Epoch 18/50
#  - 31s - loss: 0.0144 - mean_absolute_error: 0.0957
# Epoch 19/50
#  - 31s - loss: 0.0137 - mean_absolute_error: 0.0934
# Epoch 20/50
#  - 31s - loss: 0.0133 - mean_absolute_error: 0.0915
# Epoch 21/50
#  - 31s - loss: 0.0120 - mean_absolute_error: 0.0874
# Epoch 22/50
#  - 31s - loss: 0.0110 - mean_absolute_error: 0.0831
# Epoch 23/50
#  - 32s - loss: 0.0110 - mean_absolute_error: 0.0833
# Epoch 24/50
#  - 31s - loss: 0.0098 - mean_absolute_error: 0.0788
# Epoch 25/50
#  - 31s - loss: 0.0098 - mean_absolute_error: 0.0787
# Epoch 26/50
#  - 31s - loss: 0.0098 - mean_absolute_error: 0.0786
# Epoch 27/50
#  - 31s - loss: 0.0086 - mean_absolute_error: 0.0749
# Epoch 28/50
#  - 31s - loss: 0.0082 - mean_absolute_error: 0.0709
# Epoch 29/50
#  - 31s - loss: 0.0077 - mean_absolute_error: 0.0689
# Epoch 30/50
#  - 31s - loss: 0.0069 - mean_absolute_error: 0.0657
# Epoch 31/50
#  - 31s - loss: 0.0064 - mean_absolute_error: 0.0637
# Epoch 32/50
#  - 31s - loss: 0.0066 - mean_absolute_error: 0.0632
# Epoch 33/50
#  - 32s - loss: 0.0060 - mean_absolute_error: 0.0613
# Epoch 34/50
#  - 31s - loss: 0.0057 - mean_absolute_error: 0.0601
# Epoch 35/50
#  - 31s - loss: 0.0057 - mean_absolute_error: 0.0599
# Epoch 36/50
#  - 31s - loss: 0.0053 - mean_absolute_error: 0.0565
# Epoch 37/50
#  - 31s - loss: 0.0044 - mean_absolute_error: 0.0524
# Epoch 38/50
#  - 31s - loss: 0.0044 - mean_absolute_error: 0.0518
# Epoch 39/50
#  - 31s - loss: 0.0044 - mean_absolute_error: 0.0523
# Epoch 40/50
#  - 31s - loss: 0.0047 - mean_absolute_error: 0.0541
# Epoch 41/50
#  - 31s - loss: 0.0045 - mean_absolute_error: 0.0524
# Epoch 42/50
#  - 31s - loss: 0.0039 - mean_absolute_error: 0.0483
# Epoch 43/50
#  - 32s - loss: 0.0038 - mean_absolute_error: 0.0481
# Epoch 44/50
#  - 31s - loss: 0.0035 - mean_absolute_error: 0.0464
# Epoch 45/50
#  - 31s - loss: 0.0035 - mean_absolute_error: 0.0463
# Epoch 46/50
#  - 31s - loss: 0.0032 - mean_absolute_error: 0.0442
# Epoch 47/50
#  - 31s - loss: 0.0032 - mean_absolute_error: 0.0437
# Epoch 48/50
#  - 31s - loss: 0.0031 - mean_absolute_error: 0.0441
# Epoch 49/50
#  - 31s - loss: 0.0029 - mean_absolute_error: 0.0423
# Epoch 50/50
#  - 30s - loss: 0.0031 - mean_absolute_error: 0.0429
# Kappa Score: 0.5885369782930029
# Build model ...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 350)               0
# _________________________________________________________________
# embedding_4 (Embedding)      (None, 350, 50)           510050
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 300)               421200
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 931,551
# Trainable params: 931,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 32s - loss: 0.0284 - mean_absolute_error: 0.1354
# Epoch 2/50
#  - 31s - loss: 0.0260 - mean_absolute_error: 0.1304
# Epoch 3/50
#  - 31s - loss: 0.0249 - mean_absolute_error: 0.1266
# Epoch 4/50
#  - 31s - loss: 0.0245 - mean_absolute_error: 0.1260
# Epoch 5/50
#  - 31s - loss: 0.0239 - mean_absolute_error: 0.1249
# Epoch 6/50
#  - 31s - loss: 0.0235 - mean_absolute_error: 0.1231
# Epoch 7/50
#  - 31s - loss: 0.0225 - mean_absolute_error: 0.1211
# Epoch 8/50
#  - 31s - loss: 0.0225 - mean_absolute_error: 0.1214
# Epoch 9/50
#  - 31s - loss: 0.0226 - mean_absolute_error: 0.1218
# Epoch 10/50
#  - 31s - loss: 0.0217 - mean_absolute_error: 0.1179
# Epoch 11/50
#  - 31s - loss: 0.0216 - mean_absolute_error: 0.1183
# Epoch 12/50
#  - 31s - loss: 0.0210 - mean_absolute_error: 0.1155
# Epoch 13/50
#  - 31s - loss: 0.0199 - mean_absolute_error: 0.1134
# Epoch 14/50
#  - 31s - loss: 0.0192 - mean_absolute_error: 0.1111
# Epoch 15/50
#  - 30s - loss: 0.0192 - mean_absolute_error: 0.1111
# Epoch 16/50
#  - 31s - loss: 0.0181 - mean_absolute_error: 0.1072
# Epoch 17/50
#  - 31s - loss: 0.0169 - mean_absolute_error: 0.1029
# Epoch 18/50
#  - 31s - loss: 0.0164 - mean_absolute_error: 0.1018
# Epoch 19/50
#  - 30s - loss: 0.0170 - mean_absolute_error: 0.1046
# Epoch 20/50
#  - 30s - loss: 0.0150 - mean_absolute_error: 0.0973
# Epoch 21/50
#  - 30s - loss: 0.0146 - mean_absolute_error: 0.0960
# Epoch 22/50
#  - 31s - loss: 0.0132 - mean_absolute_error: 0.0914
# Epoch 23/50
#  - 31s - loss: 0.0123 - mean_absolute_error: 0.0874
# Epoch 24/50
#  - 31s - loss: 0.0120 - mean_absolute_error: 0.0868
# Epoch 25/50
#  - 31s - loss: 0.0103 - mean_absolute_error: 0.0807
# Epoch 26/50
#  - 31s - loss: 0.0094 - mean_absolute_error: 0.0766
# Epoch 27/50
#  - 31s - loss: 0.0091 - mean_absolute_error: 0.0744
# Epoch 28/50
#  - 31s - loss: 0.0096 - mean_absolute_error: 0.0771
# Epoch 29/50
#  - 31s - loss: 0.0078 - mean_absolute_error: 0.0698
# Epoch 30/50
#  - 31s - loss: 0.0077 - mean_absolute_error: 0.0685
# Epoch 31/50
#  - 30s - loss: 0.0068 - mean_absolute_error: 0.0650
# Epoch 32/50
#  - 31s - loss: 0.0069 - mean_absolute_error: 0.0655
# Epoch 33/50
#  - 31s - loss: 0.0059 - mean_absolute_error: 0.0607
# Epoch 34/50
#  - 31s - loss: 0.0065 - mean_absolute_error: 0.0632
# Epoch 35/50
#  - 31s - loss: 0.0056 - mean_absolute_error: 0.0588
# Epoch 36/50
#  - 31s - loss: 0.0053 - mean_absolute_error: 0.0578
# Epoch 37/50
#  - 30s - loss: 0.0051 - mean_absolute_error: 0.0566
# Epoch 38/50
#  - 31s - loss: 0.0048 - mean_absolute_error: 0.0554
# Epoch 39/50
#  - 31s - loss: 0.0044 - mean_absolute_error: 0.0524
# Epoch 40/50
#  - 31s - loss: 0.0045 - mean_absolute_error: 0.0529
# Epoch 41/50
#  - 31s - loss: 0.0048 - mean_absolute_error: 0.0550
# Epoch 42/50
#  - 31s - loss: 0.0044 - mean_absolute_error: 0.0526
# Epoch 43/50
#  - 31s - loss: 0.0041 - mean_absolute_error: 0.0500
# Epoch 44/50
#  - 31s - loss: 0.0039 - mean_absolute_error: 0.0483
# Epoch 45/50
#  - 31s - loss: 0.0039 - mean_absolute_error: 0.0489
# Epoch 46/50
#  - 30s - loss: 0.0038 - mean_absolute_error: 0.0489
# Epoch 47/50
#  - 30s - loss: 0.0037 - mean_absolute_error: 0.0475
# Epoch 48/50
#  - 31s - loss: 0.0033 - mean_absolute_error: 0.0457
# Epoch 49/50
#  - 30s - loss: 0.0032 - mean_absolute_error: 0.0443
# Epoch 50/50
#  - 30s - loss: 0.0030 - mean_absolute_error: 0.0427
# Kappa Score: 0.6199544879365337
# Build model ...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 350)               0
# _________________________________________________________________
# embedding_5 (Embedding)      (None, 350, 50)           510050
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 300)               421200
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 931,551
# Trainable params: 931,551
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 32s - loss: 0.0269 - mean_absolute_error: 0.1316
# Epoch 2/50
#  - 30s - loss: 0.0260 - mean_absolute_error: 0.1303
# Epoch 3/50
#  - 31s - loss: 0.0244 - mean_absolute_error: 0.1253
# Epoch 4/50
#  - 31s - loss: 0.0236 - mean_absolute_error: 0.1231
# Epoch 5/50
#  - 30s - loss: 0.0222 - mean_absolute_error: 0.1199
# Epoch 6/50
#  - 31s - loss: 0.0233 - mean_absolute_error: 0.1226
# Epoch 7/50
#  - 30s - loss: 0.0219 - mean_absolute_error: 0.1187
# Epoch 8/50
#  - 31s - loss: 0.0219 - mean_absolute_error: 0.1188
# Epoch 9/50
#  - 30s - loss: 0.0218 - mean_absolute_error: 0.1180
# Epoch 10/50
#  - 30s - loss: 0.0206 - mean_absolute_error: 0.1148
# Epoch 11/50
#  - 30s - loss: 0.0197 - mean_absolute_error: 0.1125
# Epoch 12/50
#  - 30s - loss: 0.0194 - mean_absolute_error: 0.1110
# Epoch 13/50
#  - 31s - loss: 0.0182 - mean_absolute_error: 0.1072
# Epoch 14/50
#  - 31s - loss: 0.0180 - mean_absolute_error: 0.1067
# Epoch 15/50
#  - 31s - loss: 0.0174 - mean_absolute_error: 0.1044
# Epoch 16/50
#  - 31s - loss: 0.0160 - mean_absolute_error: 0.1005
# Epoch 17/50
#  - 30s - loss: 0.0170 - mean_absolute_error: 0.1033
# Epoch 18/50
#  - 31s - loss: 0.0143 - mean_absolute_error: 0.0953
# Epoch 19/50
#  - 30s - loss: 0.0131 - mean_absolute_error: 0.0911
# Epoch 20/50
#  - 30s - loss: 0.0129 - mean_absolute_error: 0.0901
# Epoch 21/50
#  - 30s - loss: 0.0127 - mean_absolute_error: 0.0889
# Epoch 22/50
#  - 30s - loss: 0.0113 - mean_absolute_error: 0.0853
# Epoch 23/50
#  - 30s - loss: 0.0106 - mean_absolute_error: 0.0813
# Epoch 24/50
#  - 31s - loss: 0.0095 - mean_absolute_error: 0.0779
# Epoch 25/50
#  - 30s - loss: 0.0090 - mean_absolute_error: 0.0741
# Epoch 26/50
#  - 30s - loss: 0.0089 - mean_absolute_error: 0.0737
# Epoch 27/50
#  - 31s - loss: 0.0081 - mean_absolute_error: 0.0715
# Epoch 28/50
#  - 30s - loss: 0.0076 - mean_absolute_error: 0.0690
# Epoch 29/50
#  - 30s - loss: 0.0068 - mean_absolute_error: 0.0654
# Epoch 30/50
#  - 30s - loss: 0.0067 - mean_absolute_error: 0.0644
# Epoch 31/50
#  - 30s - loss: 0.0063 - mean_absolute_error: 0.0625
# Epoch 32/50
#  - 30s - loss: 0.0059 - mean_absolute_error: 0.0604
# Epoch 33/50
#  - 30s - loss: 0.0058 - mean_absolute_error: 0.0604
# Epoch 34/50
#  - 31s - loss: 0.0052 - mean_absolute_error: 0.0565
# Epoch 35/50
#  - 30s - loss: 0.0052 - mean_absolute_error: 0.0566
# Epoch 36/50
#  - 30s - loss: 0.0047 - mean_absolute_error: 0.0544
# Epoch 37/50
#  - 30s - loss: 0.0046 - mean_absolute_error: 0.0531
# Epoch 38/50
#  - 30s - loss: 0.0047 - mean_absolute_error: 0.0533
# Epoch 39/50
#  - 30s - loss: 0.0046 - mean_absolute_error: 0.0529
# Epoch 40/50
#  - 30s - loss: 0.0039 - mean_absolute_error: 0.0483
# Epoch 41/50
#  - 30s - loss: 0.0037 - mean_absolute_error: 0.0476
# Epoch 42/50
#  - 30s - loss: 0.0037 - mean_absolute_error: 0.0479
# Epoch 43/50
#  - 30s - loss: 0.0039 - mean_absolute_error: 0.0486
# Epoch 44/50
#  - 30s - loss: 0.0034 - mean_absolute_error: 0.0456
# Epoch 45/50
#  - 31s - loss: 0.0033 - mean_absolute_error: 0.0453
# Epoch 46/50
#  - 30s - loss: 0.0033 - mean_absolute_error: 0.0453
# Epoch 47/50
#  - 31s - loss: 0.0032 - mean_absolute_error: 0.0444
# Epoch 48/50
#  - 31s - loss: 0.0028 - mean_absolute_error: 0.0419
# Epoch 49/50
#  - 30s - loss: 0.0029 - mean_absolute_error: 0.0421
# Epoch 50/50
#  - 30s - loss: 0.0029 - mean_absolute_error: 0.0423
# Kappa Score: 0.666266322293943
# Average Kappa score after a 5-fold cross validation:  0.63349
# Kappa score after a 5-fold cross validation:  0.6349391476301377
