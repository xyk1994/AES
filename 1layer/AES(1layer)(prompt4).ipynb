# %%
prompt_id = 4
model_name = "1layer"  # 1layer, 1layer_MoT, 2layer, 2layer_MoT

# %%
import os
import pprint
import tensorflow as tf

if 'COLAB_TPU_ADDR' not in os.environ:
  print('ERROR: Not connected to a TPU runtime')
else:
  tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
  print ('TPU address is', tpu_address)

  with tf.Session(tpu_address) as session:
    devices = session.list_devices()

  print('TPU devices:')
  pprint.pprint(devices)
# Out:
# TPU address is grpc://10.39.83.178:8470
# TPU devices:
# [_DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:CPU:0, CPU, -1, 11276952791068559539),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 6865887657021376904),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 11393651410442866333),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 5178794294111159345),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 12233387216367422832),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 156044706801198837),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 8488169598936076956),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 9404618227954871634),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 2186815730960762860),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 968581818856148886),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 8589934592, 2826813910562043181)]

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/My Drive/AES謝"
os.chdir(path)
os.listdir(path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['glove.6B.50d.txt',
#  'data_feature',
#  'sent_feature',
#  'fine_tuning_out',
#  '1layer',
#  'AES(1layer)(prompt1).ipynb のコピー',
#  '1layerMoT',
#  '2layer',
#  '1layer+Overall',
#  '1layerMoT+Overall',
#  '2layer+Overall',
#  '実験結果.gsheet']

# %%
import argparse
import nltk
import tensorflow as tf
from keras.models import Model
from keras import layers
from keras.layers import Input, Embedding, LSTM, Dense
from keras.engine.topology import Layer
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
import keras.backend as K
from sklearn.model_selection import KFold
from sklearn.metrics import cohen_kappa_score
from keras.preprocessing.sequence import pad_sequences
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')

nltk.download('stopwords')
nltk.download('punkt')

# stopwords, punkt,
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Mean Over Time
class TemporalMean(Layer):
  def __init__(self, **kwargs):
      self.supports_masking = True
      super(TemporalMean, self).__init__(**kwargs)

  def compute_mask(self, input, input_mask=None):
      # do not pass the mask to the next layers
      return None

  def call(self, x, mask=None):
      if mask is not None:
          # mask (batch, time)
          mask = K.cast(mask, K.floatx())
          # mask (batch, x_dim, time)
          mask = K.repeat(mask, x.shape[-1])
          # mask (batch, time, x_dim)
          mask = tf.transpose(mask, [0,2,1])
          x = x * mask
      return K.sum(x, axis=1) / K.sum(mask, axis=1)

  def compute_output_shape(self, input_shape):
      # remove temporal dimension
      return (input_shape[0], input_shape[2])

def essay_to_wordlist(essay_v, remove_stopwords):
    """Remove the tagged labels and word tokenize the sentence."""
    essay_v = re.sub("[^a-zA-Z]", " ", essay_v)
    words = essay_v.lower().split()
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    return (words)

def get_clean_essays(Text):
    clean_essays = []
    for essay in Text:
        clean_essays.append(essay_to_wordlist(essay, remove_stopwords=False))
    return clean_essays

def create_dict(text):
    print("create_dict")
    word_index = {}
    word_index['xieyikuan'] = 0
    for sentence in text:
        for word in sentence:
            if word not in word_index:
                word_index[word] = len(word_index)
    word_index['unk'] = len(word_index)
    return word_index

def essay_to_index(essays, word_index):
    Essays = []
    for essay in essays:
        sentence = []
        for sent in essay:
            words = []
            for word in sent:
                words.append(word_index[word])
            sentence.append(words)
        Essays.append(sentence)
    return Essays

def essay_to_index2(essays, word_index):
    Essays = []
    for essay in essays:
        words = []
        for word in essay:
            words.append(word_index[word])
        Essays.append(words)
    return Essays

def get_embeddings_index():
    embeddings_index = {}
    f = open('glove.6B.50d.txt', 'r', encoding='UTF-8')
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.array(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    f.close()
    return embeddings_index

def embeddings_matrix(embeddings_index, word_index, embedding_dim):
    nb_words = len(word_index)
    embedding_matrix = np.zeros((nb_words + 1, embedding_dim))
    for word, i in word_index.items():
        if i > nb_words:
            continue
        embeddings_vector = embeddings_index.get(word)
        if embeddings_vector is not None:
            embedding_matrix[i] = embeddings_vector
        if embeddings_vector is None:
            embedding_matrix[i] = embeddings_index.get('unk')
    return embedding_matrix

# %%
csv_input = pd.read_csv(filepath_or_buffer="data_feature/set"+str(prompt_id)+"_feature(26).tsv", delimiter="\t", engine="python", error_bad_lines=False)

Text = csv_input['essay']
Score = csv_input['domain1_score']
Label = Score

# --------
if prompt_id == 1:
    Score = (Score - 2) / 10      # set_1     范围 2-12
elif prompt_id == 2:
    Score = (Score - 1) / 5       # set_2     范围 1-6
elif prompt_id == 3 or prompt_id == 4:
    Score = Score / 3           # set_3,4   范围 0-3
elif prompt_id == 5 or prompt_id == 6:
    Score = Score / 4           # set_5,6   范围 0-4
elif prompt_id == 7:
    Score = Score / 30          # set_7     范围 0-30
elif prompt_id == 8:
    Score = Score / 60          # set_8     范围 0-60
#print(Score)

# 做字典
clean_essays = get_clean_essays(Text)
word_index = create_dict(clean_essays)

# 做分句
text = np.array(Text)
# print(text)
a = []
for essay in text:
    a.append(sent_tokenize(essay))
texts = np.array(a)

# 做分词
essays = []
for essay in Text:
  essay_idx = essay_to_wordlist(essay, remove_stopwords=False)
  # sent = np.array(sent)
  essays.append(essay_idx)
essays = np.array(essays)

Essays = essay_to_index2(clean_essays, word_index)
Essays = np.array(Essays)

if prompt_id == 1:
    max_essay_length = 600
elif prompt_id == 2:
    max_essay_length = 700
elif prompt_id == 3:
    max_essay_length = 256
elif prompt_id == 4:
    max_essay_length = 200
elif prompt_id == 5:
    max_essay_length = 256
elif prompt_id == 6:
    max_essay_length = 256
elif prompt_id == 7:
    max_essay_length = 350
elif prompt_id == 8:
    max_essay_length = 870

essay_pad = pad_sequences(Essays, maxlen=max_essay_length)

embeddings_index = get_embeddings_index()
embeddings_matrix = embeddings_matrix(embeddings_index, word_index, embedding_dim=50)

# 记录成绩
results = []
score_predict_list = []
sssscore = []
llllabel = []
newresults = []
cv = KFold(n_splits=5, shuffle=True, random_state=10)

for train, test in cv.split(essay_pad):
    text_train, text_test = essay_pad[train], essay_pad[test]
    label_train, label_test = Score.iloc[train], Score.iloc[test]
    score_train, score_test = Label.iloc[train], Label.iloc[test]

    # -------
    print('Build model ...')
    text_input = Input(shape=(max_essay_length, ), name='text_input')

    embedding_layer = Embedding(input_dim=len(word_index) + 1,
                                output_dim=50,
                                weights=[embeddings_matrix],
                                input_length=max_essay_length,
                                trainable=True,
                                mask_zero=True)
    x = embedding_layer(text_input)  
    if model_name == "2layer_MoT":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)  
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)  
      x = TemporalMean()(x)
    elif model_name == "2layer":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)  
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)  
    elif model_name == "1layer_MoT":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)  
      x = TemporalMean()(x)
    elif model_name == "1layer":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)  
    x = layers.Dropout(0.5)(x)
    output = Dense(1, activation='sigmoid')(x)

    model = Model(inputs=text_input, outputs=output)
    # -------

    model.summary()
    model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001, decay=1e-6), metrics=['mean_absolute_error'])
    model.fit(text_train, label_train, batch_size=32, epochs=50, verbose=2)

    score_predict = model.predict(text_test)
    if prompt_id == 1:
        score_predict = score_predict*10+2
    elif prompt_id == 2:
        score_predict = score_predict*5+1
    elif prompt_id == 3:
        score_predict = score_predict*3
    elif prompt_id == 4:
        score_predict = score_predict*3
    elif prompt_id == 5:
        score_predict = score_predict*4
    elif prompt_id == 6:
        score_predict = score_predict*4
    elif prompt_id == 7:
        score_predict = score_predict*30
    elif prompt_id == 8:
        score_predict = score_predict*60

    score_predict = np.around(score_predict)

    sssscore.append(score_predict)
    llllabel.append(score_test)

    result = cohen_kappa_score(score_test.values, score_predict, weights='quadratic')
    print("Kappa Score: {}".format(result))
    results.append(result)
    for i in results:
      if i != 0:
        newresults.append(i)

print("Average Kappa score after a 5-fold cross validation: ", np.around(np.array(newresults).mean(), decimals=5))

sssscore = np.array(sssscore)
res = []
for scores in sssscore:
  for score in scores:
    res.append(score)

ll = np.array(llllabel)
res_label = []
for labels in ll:
  for label in labels:
    res_label.append(label)
res_label = np.array(res_label)

QWK = cohen_kappa_score(res_label, res, weights='quadratic')
print("Kappa score after a 5-fold cross validation: ", QWK)
# Out:
# create_dict
# Build model ...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 200)               0
# _________________________________________________________________
# embedding_3 (Embedding)      (None, 200, 50)           247500
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 300)               421200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 669,001
# Trainable params: 669,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 50s - loss: 0.1024 - mean_absolute_error: 0.2658
# Epoch 2/50
#  - 48s - loss: 0.0959 - mean_absolute_error: 0.2579
# Epoch 3/50
#  - 49s - loss: 0.0914 - mean_absolute_error: 0.2463
# Epoch 4/50
#  - 48s - loss: 0.0815 - mean_absolute_error: 0.2276
# Epoch 5/50
#  - 48s - loss: 0.0764 - mean_absolute_error: 0.2226
# Epoch 6/50
#  - 47s - loss: 0.0706 - mean_absolute_error: 0.2101
# Epoch 7/50
#  - 48s - loss: 0.0594 - mean_absolute_error: 0.1911
# Epoch 8/50
#  - 47s - loss: 0.0472 - mean_absolute_error: 0.1747
# Epoch 9/50
#  - 46s - loss: 0.0421 - mean_absolute_error: 0.1661
# Epoch 10/50
#  - 46s - loss: 0.0449 - mean_absolute_error: 0.1705
# Epoch 11/50
#  - 46s - loss: 0.0435 - mean_absolute_error: 0.1660
# Epoch 12/50
#  - 47s - loss: 0.0362 - mean_absolute_error: 0.1539
# Epoch 13/50
#  - 47s - loss: 0.0392 - mean_absolute_error: 0.1585
# Epoch 14/50
#  - 47s - loss: 0.0358 - mean_absolute_error: 0.1520
# Epoch 15/50
#  - 47s - loss: 0.0324 - mean_absolute_error: 0.1455
# Epoch 16/50
#  - 47s - loss: 0.0325 - mean_absolute_error: 0.1466
# Epoch 17/50
#  - 47s - loss: 0.0444 - mean_absolute_error: 0.1605
# Epoch 18/50
#  - 47s - loss: 0.0315 - mean_absolute_error: 0.1445
# Epoch 19/50
#  - 46s - loss: 0.0302 - mean_absolute_error: 0.1415
# Epoch 20/50
#  - 46s - loss: 0.0287 - mean_absolute_error: 0.1357
# Epoch 21/50
#  - 45s - loss: 0.0267 - mean_absolute_error: 0.1317
# Epoch 22/50
#  - 45s - loss: 0.0262 - mean_absolute_error: 0.1303
# Epoch 23/50
#  - 45s - loss: 0.0264 - mean_absolute_error: 0.1313
# Epoch 24/50
#  - 45s - loss: 0.0253 - mean_absolute_error: 0.1280
# Epoch 25/50
#  - 45s - loss: 0.0253 - mean_absolute_error: 0.1260
# Epoch 26/50
#  - 45s - loss: 0.0227 - mean_absolute_error: 0.1191
# Epoch 27/50
#  - 45s - loss: 0.0219 - mean_absolute_error: 0.1174
# Epoch 28/50
#  - 46s - loss: 0.0211 - mean_absolute_error: 0.1131
# Epoch 29/50
#  - 45s - loss: 0.0218 - mean_absolute_error: 0.1163
# Epoch 30/50
#  - 45s - loss: 0.0236 - mean_absolute_error: 0.1212
# Epoch 31/50
#  - 45s - loss: 0.0200 - mean_absolute_error: 0.1108
# Epoch 32/50
#  - 46s - loss: 0.0186 - mean_absolute_error: 0.1065
# Epoch 33/50
#  - 45s - loss: 0.0184 - mean_absolute_error: 0.1035
# Epoch 34/50
#  - 46s - loss: 0.0176 - mean_absolute_error: 0.1015
# Epoch 35/50
#  - 46s - loss: 0.0174 - mean_absolute_error: 0.1007
# Epoch 36/50
#  - 45s - loss: 0.0166 - mean_absolute_error: 0.0953
# Epoch 37/50
#  - 46s - loss: 0.0162 - mean_absolute_error: 0.0957
# Epoch 38/50
#  - 46s - loss: 0.0158 - mean_absolute_error: 0.0947
# Epoch 39/50
#  - 46s - loss: 0.0151 - mean_absolute_error: 0.0893
# Epoch 40/50
#  - 46s - loss: 0.0149 - mean_absolute_error: 0.0891
# Epoch 41/50
#  - 46s - loss: 0.0148 - mean_absolute_error: 0.0892
# Epoch 42/50
#  - 46s - loss: 0.0132 - mean_absolute_error: 0.0839
# Epoch 43/50
#  - 46s - loss: 0.0135 - mean_absolute_error: 0.0845
# Epoch 44/50
#  - 45s - loss: 0.0132 - mean_absolute_error: 0.0814
# Epoch 45/50
#  - 46s - loss: 0.0139 - mean_absolute_error: 0.0847
# Epoch 46/50
#  - 45s - loss: 0.0123 - mean_absolute_error: 0.0786
# Epoch 47/50
#  - 46s - loss: 0.0114 - mean_absolute_error: 0.0745
# Epoch 48/50
#  - 46s - loss: 0.0117 - mean_absolute_error: 0.0760
# Epoch 49/50
#  - 45s - loss: 0.0106 - mean_absolute_error: 0.0720
# Epoch 50/50
#  - 46s - loss: 0.0098 - mean_absolute_error: 0.0698
# Kappa Score: 0.8010725549128664
# Build model ...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 200)               0
# _________________________________________________________________
# embedding_4 (Embedding)      (None, 200, 50)           247500
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 300)               421200
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 669,001
# Trainable params: 669,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 47s - loss: 0.1038 - mean_absolute_error: 0.2692
# Epoch 2/50
#  - 46s - loss: 0.0968 - mean_absolute_error: 0.2597
# Epoch 3/50
#  - 46s - loss: 0.0871 - mean_absolute_error: 0.2401
# Epoch 4/50
#  - 46s - loss: 0.0924 - mean_absolute_error: 0.2511
# Epoch 5/50
#  - 46s - loss: 0.0797 - mean_absolute_error: 0.2284
# Epoch 6/50
#  - 46s - loss: 0.0818 - mean_absolute_error: 0.2319
# Epoch 7/50
#  - 46s - loss: 0.0708 - mean_absolute_error: 0.2102
# Epoch 8/50
#  - 46s - loss: 0.0719 - mean_absolute_error: 0.2150
# Epoch 9/50
#  - 46s - loss: 0.0660 - mean_absolute_error: 0.2055
# Epoch 10/50
#  - 46s - loss: 0.0671 - mean_absolute_error: 0.2075
# Epoch 11/50
#  - 46s - loss: 0.0591 - mean_absolute_error: 0.1947
# Epoch 12/50
#  - 46s - loss: 0.0703 - mean_absolute_error: 0.2117
# Epoch 13/50
#  - 46s - loss: 0.0582 - mean_absolute_error: 0.1920
# Epoch 14/50
#  - 46s - loss: 0.0515 - mean_absolute_error: 0.1810
# Epoch 15/50
#  - 46s - loss: 0.0480 - mean_absolute_error: 0.1744
# Epoch 16/50
#  - 47s - loss: 0.0396 - mean_absolute_error: 0.1635
# Epoch 17/50
#  - 47s - loss: 0.0674 - mean_absolute_error: 0.2089
# Epoch 18/50
#  - 47s - loss: 0.0585 - mean_absolute_error: 0.1936
# Epoch 19/50
#  - 46s - loss: 0.0483 - mean_absolute_error: 0.1752
# Epoch 20/50
#  - 46s - loss: 0.0414 - mean_absolute_error: 0.1643
# Epoch 21/50
#  - 46s - loss: 0.0399 - mean_absolute_error: 0.1633
# Epoch 22/50
#  - 46s - loss: 0.0354 - mean_absolute_error: 0.1553
# Epoch 23/50
#  - 46s - loss: 0.0312 - mean_absolute_error: 0.1460
# Epoch 24/50
#  - 45s - loss: 0.0290 - mean_absolute_error: 0.1404
# Epoch 25/50
#  - 46s - loss: 0.0302 - mean_absolute_error: 0.1419
# Epoch 26/50
#  - 46s - loss: 0.0289 - mean_absolute_error: 0.1398
# Epoch 27/50
#  - 46s - loss: 0.0278 - mean_absolute_error: 0.1369
# Epoch 28/50
#  - 46s - loss: 0.0261 - mean_absolute_error: 0.1339
# Epoch 29/50
#  - 46s - loss: 0.0241 - mean_absolute_error: 0.1274
# Epoch 30/50
#  - 46s - loss: 0.0240 - mean_absolute_error: 0.1248
# Epoch 31/50
#  - 47s - loss: 0.0260 - mean_absolute_error: 0.1293
# Epoch 32/50
#  - 46s - loss: 0.0229 - mean_absolute_error: 0.1226
# Epoch 33/50
#  - 45s - loss: 0.0231 - mean_absolute_error: 0.1211
# Epoch 34/50
#  - 46s - loss: 0.0227 - mean_absolute_error: 0.1214
# Epoch 35/50
#  - 46s - loss: 0.0201 - mean_absolute_error: 0.1144
# Epoch 36/50
#  - 46s - loss: 0.0197 - mean_absolute_error: 0.1109
# Epoch 37/50
#  - 46s - loss: 0.0178 - mean_absolute_error: 0.1044
# Epoch 38/50
#  - 47s - loss: 0.0181 - mean_absolute_error: 0.1053
# Epoch 39/50
#  - 47s - loss: 0.0185 - mean_absolute_error: 0.1051
# Epoch 40/50
#  - 46s - loss: 0.0172 - mean_absolute_error: 0.1000
# Epoch 41/50
#  - 46s - loss: 0.0173 - mean_absolute_error: 0.1004
# Epoch 42/50
#  - 46s - loss: 0.0152 - mean_absolute_error: 0.0941
# Epoch 43/50
#  - 45s - loss: 0.0154 - mean_absolute_error: 0.0935
# Epoch 44/50
#  - 46s - loss: 0.0142 - mean_absolute_error: 0.0885
# Epoch 45/50
#  - 46s - loss: 0.0147 - mean_absolute_error: 0.0921
# Epoch 46/50
#  - 47s - loss: 0.0154 - mean_absolute_error: 0.0942
# Epoch 47/50
#  - 46s - loss: 0.0142 - mean_absolute_error: 0.0901
# Epoch 48/50
#  - 46s - loss: 0.0131 - mean_absolute_error: 0.0857
# Epoch 49/50
#  - 46s - loss: 0.0124 - mean_absolute_error: 0.0816
# Epoch 50/50
#  - 47s - loss: 0.0118 - mean_absolute_error: 0.0791
# Kappa Score: 0.776902758275317
# Build model ...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 200)               0
# _________________________________________________________________
# embedding_5 (Embedding)      (None, 200, 50)           247500
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 300)               421200
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 669,001
# Trainable params: 669,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 48s - loss: 0.1022 - mean_absolute_error: 0.2661
# Epoch 2/50
#  - 46s - loss: 0.0955 - mean_absolute_error: 0.2549
# Epoch 3/50
#  - 46s - loss: 0.0888 - mean_absolute_error: 0.2438
# Epoch 4/50
#  - 46s - loss: 0.0830 - mean_absolute_error: 0.2352
# Epoch 5/50
#  - 46s - loss: 0.0777 - mean_absolute_error: 0.2232
# Epoch 6/50
#  - 46s - loss: 0.0755 - mean_absolute_error: 0.2227
# Epoch 7/50
#  - 46s - loss: 0.0668 - mean_absolute_error: 0.2053
# Epoch 8/50
#  - 46s - loss: 0.0617 - mean_absolute_error: 0.1978
# Epoch 9/50
#  - 46s - loss: 0.0535 - mean_absolute_error: 0.1843
# Epoch 10/50
#  - 46s - loss: 0.0554 - mean_absolute_error: 0.1866
# Epoch 11/50
#  - 45s - loss: 0.0494 - mean_absolute_error: 0.1783
# Epoch 12/50
#  - 46s - loss: 0.0458 - mean_absolute_error: 0.1719
# Epoch 13/50
#  - 46s - loss: 0.0395 - mean_absolute_error: 0.1627
# Epoch 14/50
#  - 45s - loss: 0.0379 - mean_absolute_error: 0.1608
# Epoch 15/50
#  - 45s - loss: 0.0354 - mean_absolute_error: 0.1543
# Epoch 16/50
#  - 45s - loss: 0.0352 - mean_absolute_error: 0.1522
# Epoch 17/50
#  - 45s - loss: 0.0316 - mean_absolute_error: 0.1472
# Epoch 18/50
#  - 44s - loss: 0.0313 - mean_absolute_error: 0.1457
# Epoch 19/50
#  - 45s - loss: 0.0308 - mean_absolute_error: 0.1436
# Epoch 20/50
#  - 45s - loss: 0.0279 - mean_absolute_error: 0.1360
# Epoch 21/50
#  - 45s - loss: 0.0279 - mean_absolute_error: 0.1373
# Epoch 22/50
#  - 46s - loss: 0.0258 - mean_absolute_error: 0.1325
# Epoch 23/50
#  - 46s - loss: 0.0268 - mean_absolute_error: 0.1336
# Epoch 24/50
#  - 45s - loss: 0.0249 - mean_absolute_error: 0.1279
# Epoch 25/50
#  - 45s - loss: 0.0247 - mean_absolute_error: 0.1274
# Epoch 26/50
#  - 45s - loss: 0.0230 - mean_absolute_error: 0.1205
# Epoch 27/50
#  - 45s - loss: 0.0227 - mean_absolute_error: 0.1211
# Epoch 28/50
#  - 46s - loss: 0.0215 - mean_absolute_error: 0.1174
# Epoch 29/50
#  - 45s - loss: 0.0213 - mean_absolute_error: 0.1165
# Epoch 30/50
#  - 45s - loss: 0.0198 - mean_absolute_error: 0.1117
# Epoch 31/50
#  - 45s - loss: 0.0198 - mean_absolute_error: 0.1107
# Epoch 32/50
#  - 45s - loss: 0.0192 - mean_absolute_error: 0.1069
# Epoch 33/50
#  - 46s - loss: 0.0219 - mean_absolute_error: 0.1145
# Epoch 34/50
#  - 45s - loss: 0.0199 - mean_absolute_error: 0.1155
# Epoch 35/50
#  - 46s - loss: 0.0199 - mean_absolute_error: 0.1127
# Epoch 36/50
#  - 46s - loss: 0.0173 - mean_absolute_error: 0.1031
# Epoch 37/50
#  - 45s - loss: 0.0173 - mean_absolute_error: 0.1034
# Epoch 38/50
#  - 45s - loss: 0.0160 - mean_absolute_error: 0.0979
# Epoch 39/50
#  - 45s - loss: 0.0162 - mean_absolute_error: 0.0975
# Epoch 40/50
#  - 46s - loss: 0.0154 - mean_absolute_error: 0.0948
# Epoch 41/50
#  - 45s - loss: 0.0144 - mean_absolute_error: 0.0919
# Epoch 42/50
#  - 45s - loss: 0.0144 - mean_absolute_error: 0.0893
# Epoch 43/50
#  - 45s - loss: 0.0145 - mean_absolute_error: 0.0914
# Epoch 44/50
#  - 45s - loss: 0.0127 - mean_absolute_error: 0.0831
# Epoch 45/50
#  - 45s - loss: 0.0127 - mean_absolute_error: 0.0827
# Epoch 46/50
#  - 46s - loss: 0.0124 - mean_absolute_error: 0.0813
# Epoch 47/50
#  - 45s - loss: 0.0124 - mean_absolute_error: 0.0813
# Epoch 48/50
#  - 46s - loss: 0.0115 - mean_absolute_error: 0.0768
# Epoch 49/50
#  - 45s - loss: 0.0109 - mean_absolute_error: 0.0747
# Epoch 50/50
#  - 45s - loss: 0.0122 - mean_absolute_error: 0.0805
# Kappa Score: 0.7594684592163818
# Build model ...
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 200)               0
# _________________________________________________________________
# embedding_6 (Embedding)      (None, 200, 50)           247500
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 300)               421200
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 669,001
# Trainable params: 669,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 48s - loss: 0.1030 - mean_absolute_error: 0.2680
# Epoch 2/50
#  - 45s - loss: 0.0946 - mean_absolute_error: 0.2564
# Epoch 3/50
#  - 45s - loss: 0.0920 - mean_absolute_error: 0.2505
# Epoch 4/50
#  - 45s - loss: 0.0877 - mean_absolute_error: 0.2419
# Epoch 5/50
#  - 45s - loss: 0.0826 - mean_absolute_error: 0.2337
# Epoch 6/50
#  - 46s - loss: 0.0805 - mean_absolute_error: 0.2308
# Epoch 7/50
#  - 45s - loss: 0.0596 - mean_absolute_error: 0.1922
# Epoch 8/50
#  - 45s - loss: 0.0654 - mean_absolute_error: 0.2041
# Epoch 9/50
#  - 46s - loss: 0.0535 - mean_absolute_error: 0.1846
# Epoch 10/50
#  - 46s - loss: 0.0484 - mean_absolute_error: 0.1774
# Epoch 11/50
#  - 45s - loss: 0.0459 - mean_absolute_error: 0.1720
# Epoch 12/50
#  - 45s - loss: 0.0431 - mean_absolute_error: 0.1668
# Epoch 13/50
#  - 45s - loss: 0.0423 - mean_absolute_error: 0.1654
# Epoch 14/50
#  - 45s - loss: 0.0378 - mean_absolute_error: 0.1591
# Epoch 15/50
#  - 45s - loss: 0.0325 - mean_absolute_error: 0.1469
# Epoch 16/50
#  - 45s - loss: 0.0333 - mean_absolute_error: 0.1507
# Epoch 17/50
#  - 44s - loss: 0.0308 - mean_absolute_error: 0.1430
# Epoch 18/50
#  - 45s - loss: 0.0301 - mean_absolute_error: 0.1425
# Epoch 19/50
#  - 45s - loss: 0.0274 - mean_absolute_error: 0.1375
# Epoch 20/50
#  - 45s - loss: 0.0281 - mean_absolute_error: 0.1363
# Epoch 21/50
#  - 46s - loss: 0.0273 - mean_absolute_error: 0.1338
# Epoch 22/50
#  - 46s - loss: 0.0256 - mean_absolute_error: 0.1276
# Epoch 23/50
#  - 46s - loss: 0.0269 - mean_absolute_error: 0.1315
# Epoch 24/50
#  - 46s - loss: 0.0247 - mean_absolute_error: 0.1266
# Epoch 25/50
#  - 45s - loss: 0.0235 - mean_absolute_error: 0.1232
# Epoch 26/50
#  - 46s - loss: 0.0228 - mean_absolute_error: 0.1211
# Epoch 27/50
#  - 46s - loss: 0.0225 - mean_absolute_error: 0.1195
# Epoch 28/50
#  - 46s - loss: 0.0215 - mean_absolute_error: 0.1175
# Epoch 29/50
#  - 45s - loss: 0.0221 - mean_absolute_error: 0.1166
# Epoch 30/50
#  - 45s - loss: 0.0217 - mean_absolute_error: 0.1148
# Epoch 31/50
#  - 45s - loss: 0.0199 - mean_absolute_error: 0.1098
# Epoch 32/50
#  - 46s - loss: 0.0200 - mean_absolute_error: 0.1104
# Epoch 33/50
#  - 46s - loss: 0.0189 - mean_absolute_error: 0.1066
# Epoch 34/50
#  - 46s - loss: 0.0173 - mean_absolute_error: 0.1012
# Epoch 35/50
#  - 45s - loss: 0.0180 - mean_absolute_error: 0.1006
# Epoch 36/50
#  - 46s - loss: 0.0177 - mean_absolute_error: 0.1014
# Epoch 37/50
#  - 46s - loss: 0.0163 - mean_absolute_error: 0.0957
# Epoch 38/50
#  - 46s - loss: 0.0170 - mean_absolute_error: 0.0980
# Epoch 39/50
#  - 46s - loss: 0.0159 - mean_absolute_error: 0.0937
# Epoch 40/50
#  - 46s - loss: 0.0151 - mean_absolute_error: 0.0925
# Epoch 41/50
#  - 45s - loss: 0.0145 - mean_absolute_error: 0.0865
# Epoch 42/50
#  - 46s - loss: 0.0140 - mean_absolute_error: 0.0862
# Epoch 43/50
#  - 46s - loss: 0.0128 - mean_absolute_error: 0.0814
# Epoch 44/50
#  - 46s - loss: 0.0133 - mean_absolute_error: 0.0819
# Epoch 45/50
#  - 46s - loss: 0.0140 - mean_absolute_error: 0.0849
# Epoch 46/50
#  - 46s - loss: 0.0125 - mean_absolute_error: 0.0800
# Epoch 47/50
#  - 46s - loss: 0.0112 - mean_absolute_error: 0.0753
# Epoch 48/50
#  - 46s - loss: 0.0112 - mean_absolute_error: 0.0732
# Epoch 49/50
#  - 46s - loss: 0.0115 - mean_absolute_error: 0.0729
# Epoch 50/50
#  - 46s - loss: 0.0119 - mean_absolute_error: 0.0773
# Kappa Score: 0.7670687764374118
# Build model ...
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 200)               0
# _________________________________________________________________
# embedding_7 (Embedding)      (None, 200, 50)           247500
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 300)               421200
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 669,001
# Trainable params: 669,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 48s - loss: 0.1014 - mean_absolute_error: 0.2644
# Epoch 2/50
#  - 45s - loss: 0.0957 - mean_absolute_error: 0.2564
# Epoch 3/50
#  - 45s - loss: 0.0935 - mean_absolute_error: 0.2508
# Epoch 4/50
#  - 45s - loss: 0.0858 - mean_absolute_error: 0.2379
# Epoch 5/50
#  - 46s - loss: 0.0900 - mean_absolute_error: 0.2466
# Epoch 6/50
#  - 46s - loss: 0.0837 - mean_absolute_error: 0.2362
# Epoch 7/50
#  - 46s - loss: 0.0730 - mean_absolute_error: 0.2139
# Epoch 8/50
#  - 45s - loss: 0.0849 - mean_absolute_error: 0.2401
# Epoch 9/50
#  - 45s - loss: 0.0666 - mean_absolute_error: 0.2045
# Epoch 10/50
#  - 45s - loss: 0.0564 - mean_absolute_error: 0.1894
# Epoch 11/50
#  - 46s - loss: 0.0585 - mean_absolute_error: 0.1940
# Epoch 12/50
#  - 45s - loss: 0.0481 - mean_absolute_error: 0.1773
# Epoch 13/50
#  - 46s - loss: 0.0430 - mean_absolute_error: 0.1680
# Epoch 14/50
#  - 46s - loss: 0.0364 - mean_absolute_error: 0.1578
# Epoch 15/50
#  - 46s - loss: 0.0375 - mean_absolute_error: 0.1594
# Epoch 16/50
#  - 46s - loss: 0.0343 - mean_absolute_error: 0.1533
# Epoch 17/50
#  - 45s - loss: 0.0325 - mean_absolute_error: 0.1479
# Epoch 18/50
#  - 46s - loss: 0.0305 - mean_absolute_error: 0.1417
# Epoch 19/50
#  - 46s - loss: 0.0295 - mean_absolute_error: 0.1407
# Epoch 20/50
#  - 46s - loss: 0.0290 - mean_absolute_error: 0.1387
# Epoch 21/50
#  - 46s - loss: 0.0262 - mean_absolute_error: 0.1308
# Epoch 22/50
#  - 46s - loss: 0.0269 - mean_absolute_error: 0.1339
# Epoch 23/50
#  - 46s - loss: 0.0243 - mean_absolute_error: 0.1268
# Epoch 24/50
#  - 46s - loss: 0.0248 - mean_absolute_error: 0.1281
# Epoch 25/50
#  - 46s - loss: 0.0243 - mean_absolute_error: 0.1254
# Epoch 26/50
#  - 46s - loss: 0.0219 - mean_absolute_error: 0.1186
# Epoch 27/50
#  - 46s - loss: 0.0224 - mean_absolute_error: 0.1185
# Epoch 28/50
#  - 46s - loss: 0.0219 - mean_absolute_error: 0.1166
# Epoch 29/50
#  - 47s - loss: 0.0221 - mean_absolute_error: 0.1165
# Epoch 30/50
#  - 46s - loss: 0.0205 - mean_absolute_error: 0.1106
# Epoch 31/50
#  - 47s - loss: 0.0204 - mean_absolute_error: 0.1114
# Epoch 32/50
#  - 46s - loss: 0.0178 - mean_absolute_error: 0.1034
# Epoch 33/50
#  - 46s - loss: 0.0180 - mean_absolute_error: 0.1051
# Epoch 34/50
#  - 47s - loss: 0.0173 - mean_absolute_error: 0.1018
# Epoch 35/50
#  - 47s - loss: 0.0176 - mean_absolute_error: 0.1011
# Epoch 36/50
#  - 47s - loss: 0.0158 - mean_absolute_error: 0.0946
# Epoch 37/50
#  - 47s - loss: 0.0147 - mean_absolute_error: 0.0911
# Epoch 38/50
#  - 47s - loss: 0.0146 - mean_absolute_error: 0.0886
# Epoch 39/50
#  - 47s - loss: 0.0139 - mean_absolute_error: 0.0870
# Epoch 40/50
#  - 46s - loss: 0.0171 - mean_absolute_error: 0.1002
# Epoch 41/50
#  - 47s - loss: 0.0144 - mean_absolute_error: 0.0911
# Epoch 42/50
#  - 47s - loss: 0.0131 - mean_absolute_error: 0.0839
# Epoch 43/50
#  - 46s - loss: 0.0126 - mean_absolute_error: 0.0818
# Epoch 44/50
#  - 47s - loss: 0.0137 - mean_absolute_error: 0.0856
# Epoch 45/50
#  - 46s - loss: 0.0118 - mean_absolute_error: 0.0783
# Epoch 46/50
#  - 45s - loss: 0.0108 - mean_absolute_error: 0.0722
# Epoch 47/50
#  - 46s - loss: 0.0105 - mean_absolute_error: 0.0726
# Epoch 48/50
#  - 46s - loss: 0.0111 - mean_absolute_error: 0.0730
# Epoch 49/50
#  - 46s - loss: 0.0100 - mean_absolute_error: 0.0684
# Epoch 50/50
#  - 46s - loss: 0.0096 - mean_absolute_error: 0.0691
# Kappa Score: 0.755877034358047
# Average Kappa score after a 5-fold cross validation:  0.77876
# Kappa score after a 5-fold cross validation:  0.7734301008606789
