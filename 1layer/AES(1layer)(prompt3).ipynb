# %%
prompt_id = 3
model_name = "1layer"  # 1layer, 1layer_MoT, 2layer, 2layer_MoT

# %%
import os
import pprint
import tensorflow as tf

if 'COLAB_TPU_ADDR' not in os.environ:
  print('ERROR: Not connected to a TPU runtime')
else:
  tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
  print ('TPU address is', tpu_address)

  with tf.Session(tpu_address) as session:
    devices = session.list_devices()

  print('TPU devices:')
  pprint.pprint(devices)
# Out:
# TPU address is grpc://10.4.90.50:8470
# TPU devices:
# [_DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:CPU:0, CPU, -1, 12065611628621048075),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 15969716781496918986),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 13713054317794903973),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 11248115130083586351),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 14042830133640035490),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 5254950815307049882),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 2597292791885097574),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 6889709608022076416),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 15084755291260677060),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 17816652064503281588),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 8589934592, 3452588043078486714)]

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/My Drive/AES謝"
os.chdir(path)
os.listdir(path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['1layer',
#  '実験結果.gsheet',
#  '1layerMoT+Overall',
#  '1layer+Overall',
#  'data_feature',
#  'glove.6B.50d.txt',
#  '2layer+Overall',
#  '2layer',
#  '1layerMoT',
#  'AES(1layer)(prompt1).ipynb のコピー',
#  'fine_tuning_out',
#  'sent_feature']

# %%
import argparse
import nltk
import tensorflow as tf
from keras.models import Model
from keras import layers
from keras.layers import Input, Embedding, LSTM, Dense
from keras.engine.topology import Layer
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
import keras.backend as K
from sklearn.model_selection import KFold
from sklearn.metrics import cohen_kappa_score
from keras.preprocessing.sequence import pad_sequences
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')

nltk.download('stopwords')
nltk.download('punkt')

# stopwords, punkt,
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Mean Over Time
class TemporalMean(Layer):
  def __init__(self, **kwargs):
      self.supports_masking = True
      super(TemporalMean, self).__init__(**kwargs)

  def compute_mask(self, input, input_mask=None):
      # do not pass the mask to the next layers
      return None

  def call(self, x, mask=None):
      if mask is not None:
          # mask (batch, time)
          mask = K.cast(mask, K.floatx())
          # mask (batch, x_dim, time)
          mask = K.repeat(mask, x.shape[-1])
          # mask (batch, time, x_dim)
          mask = tf.transpose(mask, [0,2,1])
          x = x * mask
      return K.sum(x, axis=1) / K.sum(mask, axis=1)

  def compute_output_shape(self, input_shape):
      # remove temporal dimension
      return (input_shape[0], input_shape[2])

def essay_to_wordlist(essay_v, remove_stopwords):
    """Remove the tagged labels and word tokenize the sentence."""
    essay_v = re.sub("[^a-zA-Z]", " ", essay_v)
    words = essay_v.lower().split()
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    return (words)

def get_clean_essays(Text):
    clean_essays = []
    for essay in Text:
        clean_essays.append(essay_to_wordlist(essay, remove_stopwords=False))
    return clean_essays

def create_dict(text):
    print("create_dict")
    word_index = {}
    word_index['xieyikuan'] = 0
    for sentence in text:
        for word in sentence:
            if word not in word_index:
                word_index[word] = len(word_index)
    word_index['unk'] = len(word_index)
    return word_index

def essay_to_index(essays, word_index):
    Essays = []
    for essay in essays:
        sentence = []
        for sent in essay:
            words = []
            for word in sent:
                words.append(word_index[word])
            sentence.append(words)
        Essays.append(sentence)
    return Essays

def essay_to_index2(essays, word_index):
    Essays = []
    for essay in essays:
        words = []
        for word in essay:
            words.append(word_index[word])
        Essays.append(words)
    return Essays

def get_embeddings_index():
    embeddings_index = {}
    f = open('glove.6B.50d.txt', 'r', encoding='UTF-8')
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.array(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    f.close()
    return embeddings_index

def embeddings_matrix(embeddings_index, word_index, embedding_dim):
    nb_words = len(word_index)
    embedding_matrix = np.zeros((nb_words + 1, embedding_dim))
    for word, i in word_index.items():
        if i > nb_words:
            continue
        embeddings_vector = embeddings_index.get(word)
        if embeddings_vector is not None:
            embedding_matrix[i] = embeddings_vector
        if embeddings_vector is None:
            embedding_matrix[i] = embeddings_index.get('unk')
    return embedding_matrix

# %%
csv_input = pd.read_csv(filepath_or_buffer="data_feature/set"+str(prompt_id)+"_feature(26).tsv", delimiter="\t", engine="python", error_bad_lines=False)

Text = csv_input['essay']
Score = csv_input['domain1_score']
Label = Score

# --------
if prompt_id == 1:
    Score = (Score - 2) / 10      # set_1     范围 2-12
elif prompt_id == 2:
    Score = (Score - 1) / 5       # set_2     范围 1-6
elif prompt_id == 3 or prompt_id == 4:
    Score = Score / 3           # set_3,4   范围 0-3
elif prompt_id == 5 or prompt_id == 6:
    Score = Score / 4           # set_5,6   范围 0-4
elif prompt_id == 7:
    Score = Score / 30          # set_7     范围 0-30
elif prompt_id == 8:
    Score = Score / 60          # set_8     范围 0-60
#print(Score)

# 做字典
clean_essays = get_clean_essays(Text)
word_index = create_dict(clean_essays)

# 做分句
text = np.array(Text)
# print(text)
a = []
for essay in text:
    a.append(sent_tokenize(essay))
texts = np.array(a)

# 做分词
essays = []
for essay in Text:
  essay_idx = essay_to_wordlist(essay, remove_stopwords=False)
  # sent = np.array(sent)
  essays.append(essay_idx)
essays = np.array(essays)

Essays = essay_to_index2(clean_essays, word_index)
Essays = np.array(Essays)

if prompt_id == 1:
    max_essay_length = 600
elif prompt_id == 2:
    max_essay_length = 700
elif prompt_id == 3:
    max_essay_length = 256
elif prompt_id == 4:
    max_essay_length = 200
elif prompt_id == 5:
    max_essay_length = 256
elif prompt_id == 6:
    max_essay_length = 256
elif prompt_id == 7:
    max_essay_length = 350
elif prompt_id == 8:
    max_essay_length = 870

essay_pad = pad_sequences(Essays, maxlen=max_essay_length)

embeddings_index = get_embeddings_index()
embeddings_matrix = embeddings_matrix(embeddings_index, word_index, embedding_dim=50)

# 记录成绩
results = []
score_predict_list = []
sssscore = []
llllabel = []
newresults = []
cv = KFold(n_splits=5, shuffle=True, random_state=10)

for train, test in cv.split(essay_pad):
    text_train, text_test = essay_pad[train], essay_pad[test]
    label_train, label_test = Score.iloc[train], Score.iloc[test]
    score_train, score_test = Label.iloc[train], Label.iloc[test]

    # -------
    print('Build model ...')
    text_input = Input(shape=(max_essay_length, ), name='text_input')

    embedding_layer = Embedding(input_dim=len(word_index) + 1,
                                output_dim=50,
                                weights=[embeddings_matrix],
                                input_length=max_essay_length,
                                trainable=True,
                                mask_zero=True)
    x = embedding_layer(text_input)  
    if model_name == "2layer_MoT":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)  
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)  
      x = TemporalMean()(x)
    elif model_name == "2layer":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)  
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)  
    elif model_name == "1layer_MoT":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)  
      x = TemporalMean()(x)
    elif model_name == "1layer":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)  
    x = layers.Dropout(0.5)(x)
    output = Dense(1, activation='sigmoid')(x)

    model = Model(inputs=text_input, outputs=output)
    # -------

    model.summary()
    model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001, decay=1e-6), metrics=['mean_absolute_error'])
    model.fit(text_train, label_train, batch_size=32, epochs=50, verbose=2)

    score_predict = model.predict(text_test)
    if prompt_id == 1:
        score_predict = score_predict*10+2
    elif prompt_id == 2:
        score_predict = score_predict*5+1
    elif prompt_id == 3:
        score_predict = score_predict*3
    elif prompt_id == 4:
        score_predict = score_predict*3
    elif prompt_id == 5:
        score_predict = score_predict*4
    elif prompt_id == 6:
        score_predict = score_predict*4
    elif prompt_id == 7:
        score_predict = score_predict*30
    elif prompt_id == 8:
        score_predict = score_predict*60

    score_predict = np.around(score_predict)

    sssscore.append(score_predict)
    llllabel.append(score_test)

    result = cohen_kappa_score(score_test.values, score_predict, weights='quadratic')
    print("Kappa Score: {}".format(result))
    results.append(result)
    for i in results:
      if i != 0:
        newresults.append(i)

print("Average Kappa score after a 5-fold cross validation: ", np.around(np.array(newresults).mean(), decimals=5))

sssscore = np.array(sssscore)
res = []
for scores in sssscore:
  for score in scores:
    res.append(score)

ll = np.array(llllabel)
res_label = []
for labels in ll:
  for label in labels:
    res_label.append(label)
res_label = np.array(res_label)

QWK = cohen_kappa_score(res_label, res, weights='quadratic')
print("Kappa score after a 5-fold cross validation: ", QWK)
# Out:
# create_dict
# Build model ...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3239: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 256)               0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 256, 50)           317500
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 300)               421200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 739,001
# Trainable params: 739,001
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/50
#  - 56s - loss: 0.0797 - mean_absolute_error: 0.2353
# Epoch 2/50
#  - 55s - loss: 0.0741 - mean_absolute_error: 0.2266
# Epoch 3/50
#  - 55s - loss: 0.0731 - mean_absolute_error: 0.2234
# Epoch 4/50
#  - 54s - loss: 0.0710 - mean_absolute_error: 0.2217
# Epoch 5/50
#  - 59s - loss: 0.0672 - mean_absolute_error: 0.2151
# Epoch 6/50
#  - 59s - loss: 0.0660 - mean_absolute_error: 0.2127
# Epoch 7/50
#  - 57s - loss: 0.0646 - mean_absolute_error: 0.2107
# Epoch 8/50
#  - 54s - loss: 0.0650 - mean_absolute_error: 0.2107
# Epoch 9/50
#  - 55s - loss: 0.0657 - mean_absolute_error: 0.2137
# Epoch 10/50
#  - 55s - loss: 0.0627 - mean_absolute_error: 0.2082
# Epoch 11/50
#  - 55s - loss: 0.0592 - mean_absolute_error: 0.2016
# Epoch 12/50
#  - 56s - loss: 0.0551 - mean_absolute_error: 0.1928
# Epoch 13/50
#  - 56s - loss: 0.0550 - mean_absolute_error: 0.1943
# Epoch 14/50
#  - 57s - loss: 0.0519 - mean_absolute_error: 0.1877
# Epoch 15/50
#  - 57s - loss: 0.0510 - mean_absolute_error: 0.1839
# Epoch 16/50
#  - 58s - loss: 0.0473 - mean_absolute_error: 0.1778
# Epoch 17/50
#  - 57s - loss: 0.0439 - mean_absolute_error: 0.1704
# Epoch 18/50
#  - 57s - loss: 0.0443 - mean_absolute_error: 0.1721
# Epoch 19/50
#  - 57s - loss: 0.0443 - mean_absolute_error: 0.1705
# Epoch 20/50
#  - 57s - loss: 0.0363 - mean_absolute_error: 0.1534
# Epoch 21/50
#  - 56s - loss: 0.0353 - mean_absolute_error: 0.1504
# Epoch 22/50
#  - 56s - loss: 0.0338 - mean_absolute_error: 0.1470
# Epoch 23/50
#  - 55s - loss: 0.0318 - mean_absolute_error: 0.1425
# Epoch 24/50
#  - 55s - loss: 0.0298 - mean_absolute_error: 0.1371
# Epoch 25/50
#  - 55s - loss: 0.0260 - mean_absolute_error: 0.1276
# Epoch 26/50
#  - 56s - loss: 0.0254 - mean_absolute_error: 0.1256
# Epoch 27/50
#  - 55s - loss: 0.0224 - mean_absolute_error: 0.1152
# Epoch 28/50
#  - 57s - loss: 0.0224 - mean_absolute_error: 0.1150
# Epoch 29/50
#  - 58s - loss: 0.0218 - mean_absolute_error: 0.1145
# Epoch 30/50
#  - 58s - loss: 0.0236 - mean_absolute_error: 0.1190
# Epoch 31/50
#  - 58s - loss: 0.0207 - mean_absolute_error: 0.1112
# Epoch 32/50
#  - 57s - loss: 0.0178 - mean_absolute_error: 0.1014
# Epoch 33/50
#  - 57s - loss: 0.0173 - mean_absolute_error: 0.1001
# Epoch 34/50
#  - 58s - loss: 0.0161 - mean_absolute_error: 0.0971
# Epoch 35/50
#  - 58s - loss: 0.0155 - mean_absolute_error: 0.0931
# Epoch 36/50
#  - 58s - loss: 0.0154 - mean_absolute_error: 0.0938
# Epoch 37/50
#  - 58s - loss: 0.0149 - mean_absolute_error: 0.0922
# Epoch 38/50
#  - 57s - loss: 0.0141 - mean_absolute_error: 0.0894
# Epoch 39/50
#  - 56s - loss: 0.0128 - mean_absolute_error: 0.0822
# Epoch 40/50
#  - 56s - loss: 0.0137 - mean_absolute_error: 0.0874
# Epoch 41/50
#  - 57s - loss: 0.0130 - mean_absolute_error: 0.0854
# Epoch 42/50
#  - 60s - loss: 0.0127 - mean_absolute_error: 0.0849
# Epoch 43/50
#  - 58s - loss: 0.0124 - mean_absolute_error: 0.0824
# Epoch 44/50
#  - 57s - loss: 0.0120 - mean_absolute_error: 0.0824
# Epoch 45/50
#  - 58s - loss: 0.0113 - mean_absolute_error: 0.0774
# Epoch 46/50
#  - 57s - loss: 0.0106 - mean_absolute_error: 0.0764
# Epoch 47/50
#  - 56s - loss: 0.0107 - mean_absolute_error: 0.0761
# Epoch 48/50
#  - 56s - loss: 0.0100 - mean_absolute_error: 0.0738
# Epoch 49/50
#  - 56s - loss: 0.0091 - mean_absolute_error: 0.0692
# Epoch 50/50
#  - 57s - loss: 0.0097 - mean_absolute_error: 0.0722
# Kappa Score: 0.5338947482433218
# Build model ...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 256)               0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 256, 50)           317500
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 300)               421200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 739,001
# Trainable params: 739,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 57s - loss: 0.0787 - mean_absolute_error: 0.2338
# Epoch 2/50
#  - 56s - loss: 0.0743 - mean_absolute_error: 0.2268
# Epoch 3/50
#  - 55s - loss: 0.0704 - mean_absolute_error: 0.2196
# Epoch 4/50
#  - 56s - loss: 0.0709 - mean_absolute_error: 0.2208
# Epoch 5/50
#  - 56s - loss: 0.0701 - mean_absolute_error: 0.2198
# Epoch 6/50
#  - 56s - loss: 0.0687 - mean_absolute_error: 0.2186
# Epoch 7/50
#  - 56s - loss: 0.0646 - mean_absolute_error: 0.2102
# Epoch 8/50
#  - 56s - loss: 0.0638 - mean_absolute_error: 0.2104
# Epoch 9/50
#  - 56s - loss: 0.0600 - mean_absolute_error: 0.2035
# Epoch 10/50
#  - 56s - loss: 0.0612 - mean_absolute_error: 0.2043
# Epoch 11/50
#  - 56s - loss: 0.0556 - mean_absolute_error: 0.1951
# Epoch 12/50
#  - 56s - loss: 0.0590 - mean_absolute_error: 0.2010
# Epoch 13/50
#  - 57s - loss: 0.0546 - mean_absolute_error: 0.1919
# Epoch 14/50
#  - 58s - loss: 0.0540 - mean_absolute_error: 0.1910
# Epoch 15/50
#  - 58s - loss: 0.0512 - mean_absolute_error: 0.1858
# Epoch 16/50
#  - 57s - loss: 0.0497 - mean_absolute_error: 0.1816
# Epoch 17/50
#  - 58s - loss: 0.0449 - mean_absolute_error: 0.1718
# Epoch 18/50
#  - 58s - loss: 0.0455 - mean_absolute_error: 0.1739
# Epoch 19/50
#  - 57s - loss: 0.0433 - mean_absolute_error: 0.1667
# Epoch 20/50
#  - 57s - loss: 0.0430 - mean_absolute_error: 0.1670
# Epoch 21/50
#  - 58s - loss: 0.0401 - mean_absolute_error: 0.1602
# Epoch 22/50
#  - 57s - loss: 0.0381 - mean_absolute_error: 0.1580
# Epoch 23/50
#  - 57s - loss: 0.0372 - mean_absolute_error: 0.1538
# Epoch 24/50
#  - 58s - loss: 0.0353 - mean_absolute_error: 0.1498
# Epoch 25/50
#  - 56s - loss: 0.0349 - mean_absolute_error: 0.1481
# Epoch 26/50
#  - 56s - loss: 0.0313 - mean_absolute_error: 0.1381
# Epoch 27/50
#  - 57s - loss: 0.0292 - mean_absolute_error: 0.1332
# Epoch 28/50
#  - 58s - loss: 0.0271 - mean_absolute_error: 0.1288
# Epoch 29/50
#  - 58s - loss: 0.0288 - mean_absolute_error: 0.1336
# Epoch 30/50
#  - 58s - loss: 0.0236 - mean_absolute_error: 0.1203
# Epoch 31/50
#  - 59s - loss: 0.0216 - mean_absolute_error: 0.1155
# Epoch 32/50
#  - 58s - loss: 0.0206 - mean_absolute_error: 0.1115
# Epoch 33/50
#  - 59s - loss: 0.0202 - mean_absolute_error: 0.1106
# Epoch 34/50
#  - 59s - loss: 0.0170 - mean_absolute_error: 0.1005
# Epoch 35/50
#  - 57s - loss: 0.0171 - mean_absolute_error: 0.1007
# Epoch 36/50
#  - 57s - loss: 0.0169 - mean_absolute_error: 0.0976
# Epoch 37/50
#  - 57s - loss: 0.0156 - mean_absolute_error: 0.0960
# Epoch 38/50
#  - 57s - loss: 0.0153 - mean_absolute_error: 0.0951
# Epoch 39/50
#  - 57s - loss: 0.0145 - mean_absolute_error: 0.0924
# Epoch 40/50
#  - 58s - loss: 0.0143 - mean_absolute_error: 0.0903
# Epoch 41/50
#  - 57s - loss: 0.0134 - mean_absolute_error: 0.0865
# Epoch 42/50
#  - 57s - loss: 0.0123 - mean_absolute_error: 0.0841
# Epoch 43/50
#  - 57s - loss: 0.0125 - mean_absolute_error: 0.0842
# Epoch 44/50
#  - 55s - loss: 0.0117 - mean_absolute_error: 0.0809
# Epoch 45/50
#  - 56s - loss: 0.0118 - mean_absolute_error: 0.0842
# Epoch 46/50
#  - 57s - loss: 0.0121 - mean_absolute_error: 0.0822
# Epoch 47/50
#  - 55s - loss: 0.0115 - mean_absolute_error: 0.0808
# Epoch 48/50
#  - 54s - loss: 0.0109 - mean_absolute_error: 0.0777
# Epoch 49/50
#  - 55s - loss: 0.0108 - mean_absolute_error: 0.0782
# Epoch 50/50
#  - 54s - loss: 0.0104 - mean_absolute_error: 0.0752
# Kappa Score: 0.39305433913407717
# Build model ...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 256)               0
# _________________________________________________________________
# embedding_3 (Embedding)      (None, 256, 50)           317500
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 300)               421200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 739,001
# Trainable params: 739,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 57s - loss: 0.0796 - mean_absolute_error: 0.2365
# Epoch 2/50
#  - 55s - loss: 0.0746 - mean_absolute_error: 0.2281
# Epoch 3/50
#  - 55s - loss: 0.0740 - mean_absolute_error: 0.2267
# Epoch 4/50
#  - 55s - loss: 0.0712 - mean_absolute_error: 0.2231
# Epoch 5/50
#  - 55s - loss: 0.0698 - mean_absolute_error: 0.2211
# Epoch 6/50
#  - 55s - loss: 0.0680 - mean_absolute_error: 0.2164
# Epoch 7/50
#  - 56s - loss: 0.0641 - mean_absolute_error: 0.2106
# Epoch 8/50
#  - 55s - loss: 0.0643 - mean_absolute_error: 0.2096
# Epoch 9/50
#  - 55s - loss: 0.0641 - mean_absolute_error: 0.2106
# Epoch 10/50
#  - 55s - loss: 0.0597 - mean_absolute_error: 0.2017
# Epoch 11/50
#  - 54s - loss: 0.0578 - mean_absolute_error: 0.2005
# Epoch 12/50
#  - 55s - loss: 0.0556 - mean_absolute_error: 0.1948
# Epoch 13/50
#  - 54s - loss: 0.0527 - mean_absolute_error: 0.1888
# Epoch 14/50
#  - 54s - loss: 0.0506 - mean_absolute_error: 0.1857
# Epoch 15/50
#  - 54s - loss: 0.0511 - mean_absolute_error: 0.1845
# Epoch 16/50
#  - 54s - loss: 0.0508 - mean_absolute_error: 0.1854
# Epoch 17/50
#  - 54s - loss: 0.0513 - mean_absolute_error: 0.1845
# Epoch 18/50
#  - 54s - loss: 0.0438 - mean_absolute_error: 0.1707
# Epoch 19/50
#  - 54s - loss: 0.0392 - mean_absolute_error: 0.1608
# Epoch 20/50
#  - 55s - loss: 0.0332 - mean_absolute_error: 0.1445
# Epoch 21/50
#  - 54s - loss: 0.0323 - mean_absolute_error: 0.1415
# Epoch 22/50
#  - 54s - loss: 0.0323 - mean_absolute_error: 0.1415
# Epoch 23/50
#  - 54s - loss: 0.0290 - mean_absolute_error: 0.1331
# Epoch 24/50
#  - 56s - loss: 0.0282 - mean_absolute_error: 0.1314
# Epoch 25/50
#  - 55s - loss: 0.0273 - mean_absolute_error: 0.1288
# Epoch 26/50
#  - 56s - loss: 0.0256 - mean_absolute_error: 0.1231
# Epoch 27/50
#  - 56s - loss: 0.0226 - mean_absolute_error: 0.1179
# Epoch 28/50
#  - 55s - loss: 0.0229 - mean_absolute_error: 0.1169
# Epoch 29/50
#  - 56s - loss: 0.0228 - mean_absolute_error: 0.1170
# Epoch 30/50
#  - 57s - loss: 0.0197 - mean_absolute_error: 0.1096
# Epoch 31/50
#  - 56s - loss: 0.0199 - mean_absolute_error: 0.1077
# Epoch 32/50
#  - 55s - loss: 0.0186 - mean_absolute_error: 0.1033
# Epoch 33/50
#  - 55s - loss: 0.0184 - mean_absolute_error: 0.1039
# Epoch 34/50
#  - 55s - loss: 0.0166 - mean_absolute_error: 0.0980
# Epoch 35/50
#  - 55s - loss: 0.0160 - mean_absolute_error: 0.0951
# Epoch 36/50
#  - 55s - loss: 0.0159 - mean_absolute_error: 0.0949
# Epoch 37/50
#  - 54s - loss: 0.0151 - mean_absolute_error: 0.0912
# Epoch 38/50
#  - 54s - loss: 0.0152 - mean_absolute_error: 0.0934
# Epoch 39/50
#  - 54s - loss: 0.0132 - mean_absolute_error: 0.0848
# Epoch 40/50
#  - 54s - loss: 0.0132 - mean_absolute_error: 0.0862
# Epoch 41/50
#  - 54s - loss: 0.0124 - mean_absolute_error: 0.0817
# Epoch 42/50
#  - 54s - loss: 0.0121 - mean_absolute_error: 0.0814
# Epoch 43/50
#  - 54s - loss: 0.0114 - mean_absolute_error: 0.0777
# Epoch 44/50
#  - 54s - loss: 0.0112 - mean_absolute_error: 0.0783
# Epoch 45/50
#  - 54s - loss: 0.0112 - mean_absolute_error: 0.0779
# Epoch 46/50
#  - 54s - loss: 0.0108 - mean_absolute_error: 0.0754
# Epoch 47/50
#  - 54s - loss: 0.0101 - mean_absolute_error: 0.0730
# Epoch 48/50
#  - 55s - loss: 0.0102 - mean_absolute_error: 0.0740
# Epoch 49/50
#  - 55s - loss: 0.0105 - mean_absolute_error: 0.0736
# Epoch 50/50
#  - 54s - loss: 0.0103 - mean_absolute_error: 0.0738
# Kappa Score: 0.5314109969713054
# Build model ...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 256)               0
# _________________________________________________________________
# embedding_4 (Embedding)      (None, 256, 50)           317500
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 300)               421200
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 739,001
# Trainable params: 739,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 56s - loss: 0.0786 - mean_absolute_error: 0.2334
# Epoch 2/50
#  - 55s - loss: 0.0741 - mean_absolute_error: 0.2253
# Epoch 3/50
#  - 54s - loss: 0.0723 - mean_absolute_error: 0.2246
# Epoch 4/50
#  - 59s - loss: 0.0708 - mean_absolute_error: 0.2220
# Epoch 5/50
#  - 59s - loss: 0.0686 - mean_absolute_error: 0.2194
# Epoch 6/50
#  - 58s - loss: 0.0666 - mean_absolute_error: 0.2143
# Epoch 7/50
#  - 59s - loss: 0.0666 - mean_absolute_error: 0.2134
# Epoch 8/50
#  - 59s - loss: 0.0636 - mean_absolute_error: 0.2092
# Epoch 9/50
#  - 59s - loss: 0.0628 - mean_absolute_error: 0.2072
# Epoch 10/50
#  - 59s - loss: 0.0627 - mean_absolute_error: 0.2096
# Epoch 11/50
#  - 58s - loss: 0.0594 - mean_absolute_error: 0.2031
# Epoch 12/50
#  - 58s - loss: 0.0541 - mean_absolute_error: 0.1921
# Epoch 13/50
#  - 59s - loss: 0.0547 - mean_absolute_error: 0.1946
# Epoch 14/50
#  - 58s - loss: 0.0523 - mean_absolute_error: 0.1898
# Epoch 15/50
#  - 55s - loss: 0.0477 - mean_absolute_error: 0.1797
# Epoch 16/50
#  - 55s - loss: 0.0460 - mean_absolute_error: 0.1766
# Epoch 17/50
#  - 55s - loss: 0.0438 - mean_absolute_error: 0.1716
# Epoch 18/50
#  - 58s - loss: 0.0401 - mean_absolute_error: 0.1614
# Epoch 19/50
#  - 59s - loss: 0.0435 - mean_absolute_error: 0.1664
# Epoch 20/50
#  - 59s - loss: 0.0384 - mean_absolute_error: 0.1582
# Epoch 21/50
#  - 59s - loss: 0.0350 - mean_absolute_error: 0.1501
# Epoch 22/50
#  - 59s - loss: 0.0331 - mean_absolute_error: 0.1448
# Epoch 23/50
#  - 60s - loss: 0.0292 - mean_absolute_error: 0.1356
# Epoch 24/50
#  - 59s - loss: 0.0293 - mean_absolute_error: 0.1356
# Epoch 25/50
#  - 57s - loss: 0.0283 - mean_absolute_error: 0.1330
# Epoch 26/50
#  - 56s - loss: 0.0277 - mean_absolute_error: 0.1319
# Epoch 27/50
#  - 54s - loss: 0.0264 - mean_absolute_error: 0.1234
# Epoch 28/50
#  - 56s - loss: 0.0230 - mean_absolute_error: 0.1175
# Epoch 29/50
#  - 56s - loss: 0.0219 - mean_absolute_error: 0.1140
# Epoch 30/50
#  - 54s - loss: 0.0218 - mean_absolute_error: 0.1136
# Epoch 31/50
#  - 58s - loss: 0.0196 - mean_absolute_error: 0.1054
# Epoch 32/50
#  - 56s - loss: 0.0198 - mean_absolute_error: 0.1061
# Epoch 33/50
#  - 56s - loss: 0.0184 - mean_absolute_error: 0.1012
# Epoch 34/50
#  - 58s - loss: 0.0187 - mean_absolute_error: 0.1032
# Epoch 35/50
#  - 55s - loss: 0.0173 - mean_absolute_error: 0.0971
# Epoch 36/50
#  - 55s - loss: 0.0172 - mean_absolute_error: 0.0975
# Epoch 37/50
#  - 54s - loss: 0.0159 - mean_absolute_error: 0.0921
# Epoch 38/50
#  - 56s - loss: 0.0155 - mean_absolute_error: 0.0910
# Epoch 39/50
#  - 57s - loss: 0.0144 - mean_absolute_error: 0.0896
# Epoch 40/50
#  - 57s - loss: 0.0146 - mean_absolute_error: 0.0890
# Epoch 41/50
#  - 55s - loss: 0.0134 - mean_absolute_error: 0.0842
# Epoch 42/50
#  - 54s - loss: 0.0125 - mean_absolute_error: 0.0808
# Epoch 43/50
#  - 54s - loss: 0.0155 - mean_absolute_error: 0.0908
# Epoch 44/50
#  - 55s - loss: 0.0121 - mean_absolute_error: 0.0788
# Epoch 45/50
#  - 55s - loss: 0.0117 - mean_absolute_error: 0.0790
# Epoch 46/50
#  - 55s - loss: 0.0115 - mean_absolute_error: 0.0771
# Epoch 47/50
#  - 54s - loss: 0.0116 - mean_absolute_error: 0.0783
# Epoch 48/50
#  - 55s - loss: 0.0108 - mean_absolute_error: 0.0742
# Epoch 49/50
#  - 54s - loss: 0.0129 - mean_absolute_error: 0.0830
# Epoch 50/50
#  - 54s - loss: 0.0101 - mean_absolute_error: 0.0731
# Kappa Score: 0.5710059171597632
# Build model ...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 256)               0
# _________________________________________________________________
# embedding_5 (Embedding)      (None, 256, 50)           317500
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 300)               421200
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 739,001
# Trainable params: 739,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 55s - loss: 0.0790 - mean_absolute_error: 0.2348
# Epoch 2/50
#  - 54s - loss: 0.0755 - mean_absolute_error: 0.2294
# Epoch 3/50
#  - 54s - loss: 0.0736 - mean_absolute_error: 0.2250
# Epoch 4/50
#  - 55s - loss: 0.0714 - mean_absolute_error: 0.2218
# Epoch 5/50
#  - 54s - loss: 0.0694 - mean_absolute_error: 0.2185
# Epoch 6/50
#  - 54s - loss: 0.0659 - mean_absolute_error: 0.2140
# Epoch 7/50
#  - 55s - loss: 0.0642 - mean_absolute_error: 0.2129
# Epoch 8/50
#  - 56s - loss: 0.0636 - mean_absolute_error: 0.2083
# Epoch 9/50
#  - 56s - loss: 0.0614 - mean_absolute_error: 0.2053
# Epoch 10/50
#  - 55s - loss: 0.0604 - mean_absolute_error: 0.2037
# Epoch 11/50
#  - 55s - loss: 0.0579 - mean_absolute_error: 0.1964
# Epoch 12/50
#  - 56s - loss: 0.0583 - mean_absolute_error: 0.1982
# Epoch 13/50
#  - 56s - loss: 0.0543 - mean_absolute_error: 0.1907
# Epoch 14/50
#  - 57s - loss: 0.0542 - mean_absolute_error: 0.1903
# Epoch 15/50
#  - 56s - loss: 0.0505 - mean_absolute_error: 0.1814
# Epoch 16/50
#  - 57s - loss: 0.0492 - mean_absolute_error: 0.1786
# Epoch 17/50
#  - 55s - loss: 0.0460 - mean_absolute_error: 0.1738
# Epoch 18/50
#  - 57s - loss: 0.0459 - mean_absolute_error: 0.1738
# Epoch 19/50
#  - 57s - loss: 0.0409 - mean_absolute_error: 0.1643
# Epoch 20/50
#  - 54s - loss: 0.0386 - mean_absolute_error: 0.1580
# Epoch 21/50
#  - 54s - loss: 0.0390 - mean_absolute_error: 0.1577
# Epoch 22/50
#  - 55s - loss: 0.0331 - mean_absolute_error: 0.1470
# Epoch 23/50
#  - 54s - loss: 0.0302 - mean_absolute_error: 0.1393
# Epoch 24/50
#  - 55s - loss: 0.0295 - mean_absolute_error: 0.1343
# Epoch 25/50
#  - 54s - loss: 0.0261 - mean_absolute_error: 0.1256
# Epoch 26/50
#  - 54s - loss: 0.0252 - mean_absolute_error: 0.1245
# Epoch 27/50
#  - 54s - loss: 0.0234 - mean_absolute_error: 0.1193
# Epoch 28/50
#  - 54s - loss: 0.0235 - mean_absolute_error: 0.1182
# Epoch 29/50
#  - 54s - loss: 0.0213 - mean_absolute_error: 0.1149
# Epoch 30/50
#  - 54s - loss: 0.0204 - mean_absolute_error: 0.1116
# Epoch 31/50
#  - 54s - loss: 0.0219 - mean_absolute_error: 0.1149
# Epoch 32/50
#  - 54s - loss: 0.0180 - mean_absolute_error: 0.1033
# Epoch 33/50
#  - 54s - loss: 0.0183 - mean_absolute_error: 0.1039
# Epoch 34/50
#  - 54s - loss: 0.0161 - mean_absolute_error: 0.0960
# Epoch 35/50
#  - 54s - loss: 0.0153 - mean_absolute_error: 0.0945
# Epoch 36/50
#  - 54s - loss: 0.0150 - mean_absolute_error: 0.0920
# Epoch 37/50
#  - 54s - loss: 0.0139 - mean_absolute_error: 0.0895
# Epoch 38/50
#  - 54s - loss: 0.0135 - mean_absolute_error: 0.0882
# Epoch 39/50
#  - 54s - loss: 0.0129 - mean_absolute_error: 0.0860
# Epoch 40/50
#  - 54s - loss: 0.0124 - mean_absolute_error: 0.0832
# Epoch 41/50
#  - 54s - loss: 0.0116 - mean_absolute_error: 0.0800
# Epoch 42/50
#  - 54s - loss: 0.0126 - mean_absolute_error: 0.0840
# Epoch 43/50
#  - 55s - loss: 0.0120 - mean_absolute_error: 0.0817
# Epoch 44/50
#  - 54s - loss: 0.0106 - mean_absolute_error: 0.0762
# Epoch 45/50
#  - 54s - loss: 0.0106 - mean_absolute_error: 0.0760
# Epoch 46/50
#  - 55s - loss: 0.0110 - mean_absolute_error: 0.0789
# Epoch 47/50
#  - 55s - loss: 0.0104 - mean_absolute_error: 0.0752
# Epoch 48/50
#  - 55s - loss: 0.0099 - mean_absolute_error: 0.0721
# Epoch 49/50
#  - 55s - loss: 0.0089 - mean_absolute_error: 0.0707
# Epoch 50/50
#  - 54s - loss: 0.0087 - mean_absolute_error: 0.0690
# Kappa Score: 0.547665262772386
# Average Kappa score after a 5-fold cross validation:  0.50171
# Kappa score after a 5-fold cross validation:  0.5161289188623897
