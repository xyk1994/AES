# %%
prompt_id = 1
model_name = "1LayerOverall"  # 1LayerOverall, 1LayerMoTOverall, 2LayerOverall

# %%
import os
import pprint
import tensorflow as tf

if 'COLAB_TPU_ADDR' not in os.environ:
  print('ERROR: Not connected to a TPU runtime')
else:
  tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
  print ('TPU address is', tpu_address)

  with tf.Session(tpu_address) as session:
    devices = session.list_devices()

  print('TPU devices:')
  pprint.pprint(devices)
# Out:
# TPU address is grpc://10.108.35.114:8470
# TPU devices:
# [_DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:CPU:0, CPU, -1, 5984757971621565538),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 490460265567459375),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 11891024191234132860),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 8710278087382089222),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 9670583753303074861),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 2736910108731536225),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 13433791941365238587),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 6290652168368094206),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 12921414486498046979),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 7654705508240167164),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 8589934592, 15767400709781034208)]

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/My Drive/AES謝"
os.chdir(path)
# os.listdir(path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import argparse
import nltk
import tensorflow as tf
from keras.models import Model
from keras import layers
from keras.layers import Input, concatenate, Embedding, LSTM, Dense, Lambda
from keras.engine.topology import Layer
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
import re
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
import keras.backend as K
from sklearn.model_selection import KFold
from sklearn.metrics import cohen_kappa_score
from sklearn.preprocessing import StandardScaler
from keras.preprocessing.sequence import pad_sequences
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')

nltk.download('stopwords')
nltk.download('punkt')
# stopwords, punkt,
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Mean Over Time
class TemporalMean(Layer):
  def __init__(self, **kwargs):
      self.supports_masking = True
      super(TemporalMean, self).__init__(**kwargs)

  def compute_mask(self, input, input_mask=None):
      # do not pass the mask to the next layers
      return None

  def call(self, x, mask=None):
      if mask is not None:
          # mask (batch, time)
          mask = K.cast(mask, K.floatx())
          # mask (batch, x_dim, time)
          mask = K.repeat(mask, x.shape[-1])
          # mask (batch, time, x_dim)
          mask = tf.transpose(mask, [0,2,1])
          x = x * mask
      return K.sum(x, axis=1) / K.sum(mask, axis=1)

  def compute_output_shape(self, input_shape):
      # remove temporal dimension
      return (input_shape[0], input_shape[2])

def essay_to_wordlist(essay_v, remove_stopwords):
    """Remove the tagged labels and word tokenize the sentence."""
    essay_v = re.sub("[^a-zA-Z]", " ", essay_v)
    words = essay_v.lower().split()
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    return (words)

def get_clean_essays(Text):
    clean_essays = []
    for essay in Text:
        clean_essays.append(essay_to_wordlist(essay, remove_stopwords=False))
    return clean_essays

def create_dict(text):
    print("create_dict")
    word_index = {}
    word_index['xieyikuan'] = 0
    for sentence in text:
        for word in sentence:
            if word not in word_index:
                word_index[word] = len(word_index)
    word_index['unk'] = len(word_index)
    return word_index

def essay_to_index(essays, word_index):
    Essays = []
    for essay in essays:
        sentence = []
        for sent in essay:
            words = []
            for word in sent:
                words.append(word_index[word])
            sentence.append(words)
        Essays.append(sentence)
    return Essays

def essay_to_index2(essays, word_index):
    Essays = []
    for essay in essays:
        words = []
        for word in essay:
            words.append(word_index[word])
        Essays.append(words)
    return Essays

def get_embeddings_index():
    embeddings_index = {}
    f = open('glove.6B.50d.txt', 'r', encoding='UTF-8')
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.array(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    f.close()
    return embeddings_index

def embeddings_matrix(embeddings_index, word_index, embedding_dim):
    nb_words = len(word_index)
    embedding_matrix = np.zeros((nb_words + 1, embedding_dim))
    for word, i in word_index.items():
        if i > nb_words:
            continue
        embeddings_vector = embeddings_index.get(word)
        if embeddings_vector is not None:
            embedding_matrix[i] = embeddings_vector
        if embeddings_vector is None:
            embedding_matrix[i] = embeddings_index.get('unk')
    return embedding_matrix

# %%
csv_input = pd.read_csv(filepath_or_buffer="data_feature/set"+str(prompt_id)+"_feature(26).tsv", delimiter="\t", engine="python", error_bad_lines=False)

Text = csv_input['essay']
Score = csv_input['domain1_score']
Label = Score

# --------
if prompt_id == 1:
    Score = (Score - 2) / 10      # set_1     范围 2-12
elif prompt_id == 2:
    Score = (Score - 1) / 5       # set_2     范围 1-6
elif prompt_id == 3 or prompt_id == 4:
    Score = Score / 3           # set_3,4   范围 0-3
elif prompt_id == 5 or prompt_id == 6:
    Score = Score / 4           # set_5,6   范围 0-4
elif prompt_id == 7:
    Score = Score / 30          # set_7     范围 0-30
elif prompt_id == 8:
    Score = Score / 60          # set_8     范围 0-60

# get Overall Feature
overall_feature = csv_input[['word_count', 'avg_word_len', 'sentence_count', 'avg_sentence_len', 'lemma_count', 'noun_count', 'adj_count', 'adv_count', 'verb_count', 'cc_count',
                             'syllable_count', 'flesch_reading_ease', 'smog_index', 'flesch_kincaid_grade', 'coleman_liau_index', 'automated_readability_index',
                             'dale_chall_readability_score', 'difficult_words', 'linsear_write_formula',
                             'gunning_fog', 'spelling_errors', 'exc_count', 'que_count', 'comma_count', 'stopwords_num']]
# overall_feature = np.array(np.sqrt(overall_feature))
overall_feature = np.array(overall_feature)
num_feature = 25
where_are_nan = np.isnan(overall_feature)
where_are_inf = np.isinf(overall_feature)
overall_feature[where_are_nan] = 0
overall_feature[where_are_inf] = 0
# standardized
stdsc = StandardScaler()
overall_feature = stdsc.fit_transform(overall_feature)

# 做字典
clean_essays = get_clean_essays(Text)
word_index = create_dict(clean_essays)

# 做分句
text = np.array(Text)
# print(text)
a = []
for essay in text:
    a.append(sent_tokenize(essay))
texts = np.array(a)

# 做分词
essays = []
for essay in Text:
  essay_idx = essay_to_wordlist(essay, remove_stopwords=False)
  essays.append(essay_idx)
essays = np.array(essays)

Essays = essay_to_index2(clean_essays, word_index)
Essays = np.array(Essays)

if prompt_id == 1:
    max_essay_length = 600
elif prompt_id == 2:
    max_essay_length = 700
elif prompt_id == 3:
    max_essay_length = 256
elif prompt_id == 4:
    max_essay_length = 200
elif prompt_id == 5:
    max_essay_length = 256
elif prompt_id == 6:
    max_essay_length = 256
elif prompt_id == 7:
    max_essay_length = 350
elif prompt_id == 8:
    max_essay_length = 870

essay_pad = pad_sequences(Essays, maxlen=max_essay_length)

embeddings_index = get_embeddings_index()
embeddings_matrix = embeddings_matrix(embeddings_index, word_index, embedding_dim=50)

# 记录成绩
results = []
score_predict_list = []
sssscore = []
llllabel = []
newresults = []
cv = KFold(n_splits=5, shuffle=True, random_state=10)
count = 0
for train, test in cv.split(essay_pad):
    text_train, text_test = essay_pad[train], essay_pad[test]
    label_train, label_test = Score.iloc[train], Score.iloc[test]
    score_train, score_test = Label.iloc[train], Label.iloc[test]
    overall_train, overall_test = overall_feature[train], overall_feature[test]

    print('Build model '+str(count)+'...')
    count += 1

    # -------
    text_input = Input(shape=(max_essay_length, ), name='text_input')
    overall_feature_input = Input(shape=(num_feature,), name='overall_feature_input')

    embedding_layer = Embedding(input_dim=len(word_index) + 1,
                                output_dim=50,
                                weights=[embeddings_matrix],
                                input_length=max_essay_length,
                                trainable=True,
                                mask_zero=True)
    x = embedding_layer(text_input)  
    if model_name == "2LayerOverall":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)
    elif model_name == "1LayerMoTOverall":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)
      x = TemporalMean()(x)
    elif model_name == "1LayerOverall":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)
    x = layers.Dropout(0.5)(x)
    concat_layer = Lambda(concatenate)([x, overall_feature_input])
    output = Dense(1, activation='sigmoid')(concat_layer)

    model = Model(inputs=[text_input, overall_feature_input], outputs=output)
    # -------

    model.summary()
    model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001, decay=1e-6), metrics=['mean_absolute_error'])
    model.fit([text_train, overall_train], label_train, batch_size=32, epochs=50, verbose=2)

    score_predict = model.predict([text_test, overall_test])
    if prompt_id == 1:
        score_predict = score_predict*10+2
    elif prompt_id == 2:
        score_predict = score_predict*5+1
    elif prompt_id == 3:
        score_predict = score_predict*3
    elif prompt_id == 4:
        score_predict = score_predict*3
    elif prompt_id == 5:
        score_predict = score_predict*4
    elif prompt_id == 6:
        score_predict = score_predict*4
    elif prompt_id == 7:
        score_predict = score_predict*30
    elif prompt_id == 8:
        score_predict = score_predict*60

    score_predict = np.around(score_predict)

    sssscore.append(score_predict)
    llllabel.append(score_test)

    result = cohen_kappa_score(score_test.values, score_predict, weights='quadratic')
    print("Kappa Score: {}".format(result))
    results.append(result)
    for i in results:
      if i != 0:
        newresults.append(i)

print("Average Kappa score after a 5-fold cross validation: ", np.around(np.array(newresults).mean(), decimals=5))

sssscore = np.array(sssscore)
res = []
for scores in sssscore:
  for score in scores:
    res.append(score)

ll = np.array(llllabel)
res_label = []
for labels in ll:
  for label in labels:
    res_label.append(label)
res_label = np.array(res_label)

QWK = cohen_kappa_score(res_label, res, weights='quadratic')
print("Kappa score after a 5-fold cross validation: ", QWK)
# Out:
# create_dict
# Build model 0...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3239: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 600)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 600, 50)      783100      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 300)          421200      embedding_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 300)          0           lstm_1[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 325)          0           dropout_1[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            326         lambda_1[0][0]
# ==================================================================================================
# Total params: 1,204,626
# Trainable params: 1,204,626
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/50
#  - 135s - loss: 0.0263 - mean_absolute_error: 0.1242
# Epoch 2/50
#  - 134s - loss: 0.0117 - mean_absolute_error: 0.0848
# Epoch 3/50
#  - 133s - loss: 0.0097 - mean_absolute_error: 0.0777
# Epoch 4/50
#  - 135s - loss: 0.0090 - mean_absolute_error: 0.0756
# Epoch 5/50
#  - 134s - loss: 0.0084 - mean_absolute_error: 0.0727
# Epoch 6/50
#  - 133s - loss: 0.0079 - mean_absolute_error: 0.0700
# Epoch 7/50
#  - 133s - loss: 0.0076 - mean_absolute_error: 0.0688
# Epoch 8/50
#  - 134s - loss: 0.0076 - mean_absolute_error: 0.0690
# Epoch 9/50
#  - 135s - loss: 0.0073 - mean_absolute_error: 0.0678
# Epoch 10/50
#  - 135s - loss: 0.0071 - mean_absolute_error: 0.0667
# Epoch 11/50
#  - 135s - loss: 0.0070 - mean_absolute_error: 0.0659
# Epoch 12/50
#  - 135s - loss: 0.0068 - mean_absolute_error: 0.0658
# Epoch 13/50
#  - 135s - loss: 0.0068 - mean_absolute_error: 0.0651
# Epoch 14/50
#  - 132s - loss: 0.0067 - mean_absolute_error: 0.0639
# Epoch 15/50
#  - 132s - loss: 0.0065 - mean_absolute_error: 0.0639
# Epoch 16/50
#  - 131s - loss: 0.0065 - mean_absolute_error: 0.0633
# Epoch 17/50
#  - 132s - loss: 0.0064 - mean_absolute_error: 0.0625
# Epoch 18/50
#  - 132s - loss: 0.0065 - mean_absolute_error: 0.0636
# Epoch 19/50
#  - 132s - loss: 0.0062 - mean_absolute_error: 0.0619
# Epoch 20/50
#  - 132s - loss: 0.0061 - mean_absolute_error: 0.0617
# Epoch 21/50
#  - 134s - loss: 0.0061 - mean_absolute_error: 0.0613
# Epoch 22/50
#  - 134s - loss: 0.0060 - mean_absolute_error: 0.0611
# Epoch 23/50
#  - 134s - loss: 0.0060 - mean_absolute_error: 0.0607
# Epoch 24/50
#  - 135s - loss: 0.0057 - mean_absolute_error: 0.0593
# Epoch 25/50
#  - 133s - loss: 0.0059 - mean_absolute_error: 0.0603
# Epoch 26/50
#  - 133s - loss: 0.0056 - mean_absolute_error: 0.0581
# Epoch 27/50
#  - 134s - loss: 0.0056 - mean_absolute_error: 0.0583
# Epoch 28/50
#  - 135s - loss: 0.0055 - mean_absolute_error: 0.0574
# Epoch 29/50
#  - 133s - loss: 0.0051 - mean_absolute_error: 0.0555
# Epoch 30/50
#  - 133s - loss: 0.0050 - mean_absolute_error: 0.0547
# Epoch 31/50
#  - 134s - loss: 0.0052 - mean_absolute_error: 0.0561
# Epoch 32/50
#  - 135s - loss: 0.0050 - mean_absolute_error: 0.0543
# Epoch 33/50
#  - 136s - loss: 0.0047 - mean_absolute_error: 0.0527
# Epoch 34/50
#  - 135s - loss: 0.0048 - mean_absolute_error: 0.0531
# Epoch 35/50
#  - 134s - loss: 0.0048 - mean_absolute_error: 0.0530
# Epoch 36/50
#  - 133s - loss: 0.0045 - mean_absolute_error: 0.0516
# Epoch 37/50
#  - 133s - loss: 0.0043 - mean_absolute_error: 0.0505
# Epoch 38/50
#  - 134s - loss: 0.0043 - mean_absolute_error: 0.0502
# Epoch 39/50
#  - 133s - loss: 0.0042 - mean_absolute_error: 0.0494
# Epoch 40/50
#  - 133s - loss: 0.0041 - mean_absolute_error: 0.0488
# Epoch 41/50
#  - 132s - loss: 0.0040 - mean_absolute_error: 0.0479
# Epoch 42/50
#  - 132s - loss: 0.0039 - mean_absolute_error: 0.0468
# Epoch 43/50
#  - 132s - loss: 0.0038 - mean_absolute_error: 0.0472
# Epoch 44/50
#  - 134s - loss: 0.0037 - mean_absolute_error: 0.0462
# Epoch 45/50
#  - 133s - loss: 0.0036 - mean_absolute_error: 0.0456
# Epoch 46/50
#  - 133s - loss: 0.0035 - mean_absolute_error: 0.0448
# Epoch 47/50
#  - 133s - loss: 0.0033 - mean_absolute_error: 0.0431
# Epoch 48/50
#  - 134s - loss: 0.0032 - mean_absolute_error: 0.0429
# Epoch 49/50
#  - 135s - loss: 0.0031 - mean_absolute_error: 0.0418
# Epoch 50/50
#  - 135s - loss: 0.0031 - mean_absolute_error: 0.0415
# Kappa Score: 0.7570537976935244
# Build model 1...
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 600)          0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 600, 50)      783100      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 300)          421200      embedding_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 300)          0           lstm_2[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 325)          0           dropout_2[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            326         lambda_2[0][0]
# ==================================================================================================
# Total params: 1,204,626
# Trainable params: 1,204,626
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 137s - loss: 0.0125 - mean_absolute_error: 0.0879
# Epoch 2/50
#  - 134s - loss: 0.0089 - mean_absolute_error: 0.0742
# Epoch 3/50
#  - 135s - loss: 0.0083 - mean_absolute_error: 0.0718
# Epoch 4/50
#  - 133s - loss: 0.0080 - mean_absolute_error: 0.0704
# Epoch 5/50
#  - 133s - loss: 0.0073 - mean_absolute_error: 0.0667
# Epoch 6/50
#  - 134s - loss: 0.0068 - mean_absolute_error: 0.0649
# Epoch 7/50
#  - 133s - loss: 0.0067 - mean_absolute_error: 0.0646
# Epoch 8/50
#  - 136s - loss: 0.0068 - mean_absolute_error: 0.0646
# Epoch 9/50
#  - 135s - loss: 0.0064 - mean_absolute_error: 0.0627
# Epoch 10/50
#  - 135s - loss: 0.0066 - mean_absolute_error: 0.0634
# Epoch 11/50
#  - 134s - loss: 0.0066 - mean_absolute_error: 0.0639
# Epoch 12/50
#  - 135s - loss: 0.0064 - mean_absolute_error: 0.0629
# Epoch 13/50
#  - 137s - loss: 0.0062 - mean_absolute_error: 0.0617
# Epoch 14/50
#  - 136s - loss: 0.0061 - mean_absolute_error: 0.0610
# Epoch 15/50
#  - 136s - loss: 0.0061 - mean_absolute_error: 0.0607
# Epoch 16/50
#  - 137s - loss: 0.0060 - mean_absolute_error: 0.0601
# Epoch 17/50
#  - 134s - loss: 0.0059 - mean_absolute_error: 0.0603
# Epoch 18/50
#  - 135s - loss: 0.0058 - mean_absolute_error: 0.0592
# Epoch 19/50
#  - 136s - loss: 0.0058 - mean_absolute_error: 0.0594
# Epoch 20/50
#  - 137s - loss: 0.0058 - mean_absolute_error: 0.0590
# Epoch 21/50
#  - 136s - loss: 0.0057 - mean_absolute_error: 0.0586
# Epoch 22/50
#  - 139s - loss: 0.0055 - mean_absolute_error: 0.0573
# Epoch 23/50
#  - 135s - loss: 0.0054 - mean_absolute_error: 0.0569
# Epoch 24/50
#  - 133s - loss: 0.0053 - mean_absolute_error: 0.0568
# Epoch 25/50
#  - 133s - loss: 0.0052 - mean_absolute_error: 0.0558
# Epoch 26/50
#  - 133s - loss: 0.0051 - mean_absolute_error: 0.0546
# Epoch 27/50
#  - 133s - loss: 0.0050 - mean_absolute_error: 0.0547
# Epoch 28/50
#  - 133s - loss: 0.0052 - mean_absolute_error: 0.0553
# Epoch 29/50
#  - 134s - loss: 0.0048 - mean_absolute_error: 0.0533
# Epoch 30/50
#  - 133s - loss: 0.0047 - mean_absolute_error: 0.0527
# Epoch 31/50
#  - 135s - loss: 0.0045 - mean_absolute_error: 0.0518
# Epoch 32/50
#  - 133s - loss: 0.0045 - mean_absolute_error: 0.0515
# Epoch 33/50
#  - 134s - loss: 0.0044 - mean_absolute_error: 0.0505
# Epoch 34/50
#  - 136s - loss: 0.0042 - mean_absolute_error: 0.0498
# Epoch 35/50
#  - 136s - loss: 0.0040 - mean_absolute_error: 0.0484
# Epoch 36/50
#  - 134s - loss: 0.0039 - mean_absolute_error: 0.0478
# Epoch 37/50
#  - 134s - loss: 0.0038 - mean_absolute_error: 0.0467
# Epoch 38/50
#  - 135s - loss: 0.0036 - mean_absolute_error: 0.0459
# Epoch 39/50
#  - 135s - loss: 0.0037 - mean_absolute_error: 0.0466
# Epoch 40/50
#  - 135s - loss: 0.0036 - mean_absolute_error: 0.0451
# Epoch 41/50
#  - 135s - loss: 0.0035 - mean_absolute_error: 0.0444
# Epoch 42/50
#  - 136s - loss: 0.0035 - mean_absolute_error: 0.0443
# Epoch 43/50
#  - 135s - loss: 0.0031 - mean_absolute_error: 0.0425
# Epoch 44/50
#  - 136s - loss: 0.0030 - mean_absolute_error: 0.0420
# Epoch 45/50
#  - 136s - loss: 0.0029 - mean_absolute_error: 0.0411
# Epoch 46/50
#  - 136s - loss: 0.0029 - mean_absolute_error: 0.0405
# Epoch 47/50
#  - 137s - loss: 0.0028 - mean_absolute_error: 0.0399
# Epoch 48/50
#  - 137s - loss: 0.0028 - mean_absolute_error: 0.0405
# Epoch 49/50
#  - 138s - loss: 0.0027 - mean_absolute_error: 0.0384
# Epoch 50/50
#  - 137s - loss: 0.0026 - mean_absolute_error: 0.0387
# Kappa Score: 0.7786982937538101
# Build model 2...
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 600)          0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 600, 50)      783100      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 300)          421200      embedding_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 300)          0           lstm_3[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 325)          0           dropout_3[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            326         lambda_3[0][0]
# ==================================================================================================
# Total params: 1,204,626
# Trainable params: 1,204,626
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 138s - loss: 0.0223 - mean_absolute_error: 0.1131
# Epoch 2/50
#  - 135s - loss: 0.0104 - mean_absolute_error: 0.0811
# Epoch 3/50
#  - 136s - loss: 0.0089 - mean_absolute_error: 0.0742
# Epoch 4/50
#  - 135s - loss: 0.0082 - mean_absolute_error: 0.0716
# Epoch 5/50
#  - 135s - loss: 0.0076 - mean_absolute_error: 0.0690
# Epoch 6/50
#  - 137s - loss: 0.0076 - mean_absolute_error: 0.0695
# Epoch 7/50
#  - 135s - loss: 0.0073 - mean_absolute_error: 0.0679
# Epoch 8/50
#  - 136s - loss: 0.0071 - mean_absolute_error: 0.0666
# Epoch 9/50
#  - 135s - loss: 0.0072 - mean_absolute_error: 0.0670
# Epoch 10/50
#  - 136s - loss: 0.0068 - mean_absolute_error: 0.0646
# Epoch 11/50
#  - 135s - loss: 0.0069 - mean_absolute_error: 0.0657
# Epoch 12/50
#  - 135s - loss: 0.0067 - mean_absolute_error: 0.0645
# Epoch 13/50
#  - 134s - loss: 0.0066 - mean_absolute_error: 0.0643
# Epoch 14/50
#  - 134s - loss: 0.0068 - mean_absolute_error: 0.0648
# Epoch 15/50
#  - 135s - loss: 0.0063 - mean_absolute_error: 0.0627
# Epoch 16/50
#  - 135s - loss: 0.0064 - mean_absolute_error: 0.0630
# Epoch 17/50
#  - 135s - loss: 0.0063 - mean_absolute_error: 0.0621
# Epoch 18/50
#  - 135s - loss: 0.0061 - mean_absolute_error: 0.0610
# Epoch 19/50
#  - 135s - loss: 0.0061 - mean_absolute_error: 0.0616
# Epoch 20/50
#  - 135s - loss: 0.0061 - mean_absolute_error: 0.0607
# Epoch 21/50
#  - 135s - loss: 0.0060 - mean_absolute_error: 0.0602
# Epoch 22/50
#  - 137s - loss: 0.0059 - mean_absolute_error: 0.0600
# Epoch 23/50
#  - 135s - loss: 0.0057 - mean_absolute_error: 0.0586
# Epoch 24/50
#  - 136s - loss: 0.0057 - mean_absolute_error: 0.0583
# Epoch 25/50
#  - 134s - loss: 0.0055 - mean_absolute_error: 0.0572
# Epoch 26/50
#  - 134s - loss: 0.0053 - mean_absolute_error: 0.0568
# Epoch 27/50
#  - 133s - loss: 0.0054 - mean_absolute_error: 0.0560
# Epoch 28/50
#  - 133s - loss: 0.0053 - mean_absolute_error: 0.0566
# Epoch 29/50
#  - 133s - loss: 0.0052 - mean_absolute_error: 0.0555
# Epoch 30/50
#  - 132s - loss: 0.0052 - mean_absolute_error: 0.0549
# Epoch 31/50
#  - 132s - loss: 0.0049 - mean_absolute_error: 0.0539
# Epoch 32/50
#  - 133s - loss: 0.0049 - mean_absolute_error: 0.0532
# Epoch 33/50
#  - 133s - loss: 0.0047 - mean_absolute_error: 0.0520
# Epoch 34/50
#  - 132s - loss: 0.0047 - mean_absolute_error: 0.0526
# Epoch 35/50
#  - 134s - loss: 0.0045 - mean_absolute_error: 0.0514
# Epoch 36/50
#  - 131s - loss: 0.0044 - mean_absolute_error: 0.0499
# Epoch 37/50
#  - 132s - loss: 0.0044 - mean_absolute_error: 0.0504
# Epoch 38/50
#  - 132s - loss: 0.0042 - mean_absolute_error: 0.0488
# Epoch 39/50
#  - 132s - loss: 0.0040 - mean_absolute_error: 0.0486
# Epoch 40/50
#  - 133s - loss: 0.0040 - mean_absolute_error: 0.0476
# Epoch 41/50
#  - 131s - loss: 0.0039 - mean_absolute_error: 0.0464
# Epoch 42/50
#  - 132s - loss: 0.0038 - mean_absolute_error: 0.0461
# Epoch 43/50
#  - 131s - loss: 0.0036 - mean_absolute_error: 0.0449
# Epoch 44/50
#  - 131s - loss: 0.0036 - mean_absolute_error: 0.0450
# Epoch 45/50
#  - 133s - loss: 0.0035 - mean_absolute_error: 0.0446
# Epoch 46/50
#  - 134s - loss: 0.0033 - mean_absolute_error: 0.0429
# Epoch 47/50
#  - 133s - loss: 0.0032 - mean_absolute_error: 0.0422
# Epoch 48/50
#  - 133s - loss: 0.0031 - mean_absolute_error: 0.0411
# Epoch 49/50
#  - 133s - loss: 0.0030 - mean_absolute_error: 0.0415
# Epoch 50/50
#  - 132s - loss: 0.0030 - mean_absolute_error: 0.0412
# Kappa Score: 0.7627293349783102
# Build model 3...
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 600)          0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 600, 50)      783100      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 300)          421200      embedding_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 300)          0           lstm_4[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 325)          0           dropout_4[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            326         lambda_4[0][0]
# ==================================================================================================
# Total params: 1,204,626
# Trainable params: 1,204,626
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 133s - loss: 0.0271 - mean_absolute_error: 0.1275
# Epoch 2/50
#  - 131s - loss: 0.0129 - mean_absolute_error: 0.0888
# Epoch 3/50
#  - 133s - loss: 0.0101 - mean_absolute_error: 0.0786
# Epoch 4/50
#  - 133s - loss: 0.0090 - mean_absolute_error: 0.0751
# Epoch 5/50
#  - 131s - loss: 0.0086 - mean_absolute_error: 0.0732
# Epoch 6/50
#  - 132s - loss: 0.0081 - mean_absolute_error: 0.0704
# Epoch 7/50
#  - 130s - loss: 0.0077 - mean_absolute_error: 0.0693
# Epoch 8/50
#  - 131s - loss: 0.0076 - mean_absolute_error: 0.0686
# Epoch 9/50
#  - 131s - loss: 0.0072 - mean_absolute_error: 0.0662
# Epoch 10/50
#  - 131s - loss: 0.0071 - mean_absolute_error: 0.0659
# Epoch 11/50
#  - 131s - loss: 0.0071 - mean_absolute_error: 0.0656
# Epoch 12/50
#  - 133s - loss: 0.0069 - mean_absolute_error: 0.0650
# Epoch 13/50
#  - 132s - loss: 0.0068 - mean_absolute_error: 0.0648
# Epoch 14/50
#  - 134s - loss: 0.0068 - mean_absolute_error: 0.0645
# Epoch 15/50
#  - 135s - loss: 0.0066 - mean_absolute_error: 0.0631
# Epoch 16/50
#  - 134s - loss: 0.0064 - mean_absolute_error: 0.0625
# Epoch 17/50
#  - 135s - loss: 0.0063 - mean_absolute_error: 0.0616
# Epoch 18/50
#  - 134s - loss: 0.0065 - mean_absolute_error: 0.0626
# Epoch 19/50
#  - 133s - loss: 0.0062 - mean_absolute_error: 0.0610
# Epoch 20/50
#  - 132s - loss: 0.0062 - mean_absolute_error: 0.0612
# Epoch 21/50
#  - 133s - loss: 0.0061 - mean_absolute_error: 0.0601
# Epoch 22/50
#  - 133s - loss: 0.0059 - mean_absolute_error: 0.0597
# Epoch 23/50
#  - 132s - loss: 0.0059 - mean_absolute_error: 0.0598
# Epoch 24/50
#  - 134s - loss: 0.0058 - mean_absolute_error: 0.0588
# Epoch 25/50
#  - 134s - loss: 0.0058 - mean_absolute_error: 0.0588
# Epoch 26/50
#  - 135s - loss: 0.0057 - mean_absolute_error: 0.0578
# Epoch 27/50
#  - 135s - loss: 0.0055 - mean_absolute_error: 0.0575
# Epoch 28/50
#  - 137s - loss: 0.0052 - mean_absolute_error: 0.0554
# Epoch 29/50
#  - 137s - loss: 0.0052 - mean_absolute_error: 0.0550
# Epoch 30/50
#  - 135s - loss: 0.0050 - mean_absolute_error: 0.0537
# Epoch 31/50
#  - 134s - loss: 0.0050 - mean_absolute_error: 0.0541
# Epoch 32/50
#  - 135s - loss: 0.0047 - mean_absolute_error: 0.0520
# Epoch 33/50
#  - 132s - loss: 0.0047 - mean_absolute_error: 0.0527
# Epoch 34/50
#  - 132s - loss: 0.0044 - mean_absolute_error: 0.0499
# Epoch 35/50
#  - 134s - loss: 0.0044 - mean_absolute_error: 0.0501
# Epoch 36/50
#  - 134s - loss: 0.0041 - mean_absolute_error: 0.0485
# Epoch 37/50
#  - 133s - loss: 0.0040 - mean_absolute_error: 0.0482
# Epoch 38/50
#  - 133s - loss: 0.0040 - mean_absolute_error: 0.0483
# Epoch 39/50
#  - 133s - loss: 0.0037 - mean_absolute_error: 0.0460
# Epoch 40/50
#  - 133s - loss: 0.0036 - mean_absolute_error: 0.0456
# Epoch 41/50
#  - 133s - loss: 0.0034 - mean_absolute_error: 0.0432
# Epoch 42/50
#  - 133s - loss: 0.0034 - mean_absolute_error: 0.0441
# Epoch 43/50
#  - 133s - loss: 0.0033 - mean_absolute_error: 0.0425
# Epoch 44/50
#  - 133s - loss: 0.0031 - mean_absolute_error: 0.0416
# Epoch 45/50
#  - 134s - loss: 0.0031 - mean_absolute_error: 0.0412
# Epoch 46/50
#  - 134s - loss: 0.0030 - mean_absolute_error: 0.0418
# Epoch 47/50
#  - 134s - loss: 0.0029 - mean_absolute_error: 0.0402
# Epoch 48/50
#  - 133s - loss: 0.0028 - mean_absolute_error: 0.0401
# Epoch 49/50
#  - 132s - loss: 0.0025 - mean_absolute_error: 0.0377
# Epoch 50/50
#  - 134s - loss: 0.0026 - mean_absolute_error: 0.0385
# Kappa Score: 0.7708093202410307
# Build model 4...
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 600)          0
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 600, 50)      783100      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 300)          421200      embedding_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 300)          0           lstm_5[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 325)          0           dropout_5[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            326         lambda_5[0][0]
# ==================================================================================================
# Total params: 1,204,626
# Trainable params: 1,204,626
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 135s - loss: 0.0166 - mean_absolute_error: 0.0977
# Epoch 2/50
#  - 133s - loss: 0.0100 - mean_absolute_error: 0.0787
# Epoch 3/50
#  - 133s - loss: 0.0088 - mean_absolute_error: 0.0741
# Epoch 4/50
#  - 133s - loss: 0.0083 - mean_absolute_error: 0.0716
# Epoch 5/50
#  - 133s - loss: 0.0080 - mean_absolute_error: 0.0694
# Epoch 6/50
#  - 134s - loss: 0.0074 - mean_absolute_error: 0.0669
# Epoch 7/50
#  - 135s - loss: 0.0072 - mean_absolute_error: 0.0669
# Epoch 8/50
#  - 135s - loss: 0.0070 - mean_absolute_error: 0.0661
# Epoch 9/50
#  - 134s - loss: 0.0070 - mean_absolute_error: 0.0653
# Epoch 10/50
#  - 134s - loss: 0.0065 - mean_absolute_error: 0.0635
# Epoch 11/50
#  - 134s - loss: 0.0064 - mean_absolute_error: 0.0629
# Epoch 12/50
#  - 134s - loss: 0.0063 - mean_absolute_error: 0.0624
# Epoch 13/50
#  - 137s - loss: 0.0062 - mean_absolute_error: 0.0623
# Epoch 14/50
#  - 135s - loss: 0.0063 - mean_absolute_error: 0.0620
# Epoch 15/50
#  - 137s - loss: 0.0061 - mean_absolute_error: 0.0626
# Epoch 16/50
#  - 137s - loss: 0.0062 - mean_absolute_error: 0.0619
# Epoch 17/50
#  - 137s - loss: 0.0059 - mean_absolute_error: 0.0604
# Epoch 18/50
#  - 139s - loss: 0.0058 - mean_absolute_error: 0.0596
# Epoch 19/50
#  - 137s - loss: 0.0058 - mean_absolute_error: 0.0601
# Epoch 20/50
#  - 135s - loss: 0.0057 - mean_absolute_error: 0.0589
# Epoch 21/50
#  - 134s - loss: 0.0057 - mean_absolute_error: 0.0594
# Epoch 22/50
#  - 135s - loss: 0.0054 - mean_absolute_error: 0.0574
# Epoch 23/50
#  - 136s - loss: 0.0054 - mean_absolute_error: 0.0578
# Epoch 24/50
#  - 135s - loss: 0.0052 - mean_absolute_error: 0.0561
# Epoch 25/50
#  - 138s - loss: 0.0052 - mean_absolute_error: 0.0559
# Epoch 26/50
#  - 136s - loss: 0.0050 - mean_absolute_error: 0.0554
# Epoch 27/50
#  - 136s - loss: 0.0047 - mean_absolute_error: 0.0537
# Epoch 28/50
#  - 135s - loss: 0.0046 - mean_absolute_error: 0.0523
# Epoch 29/50
#  - 135s - loss: 0.0045 - mean_absolute_error: 0.0525
# Epoch 30/50
#  - 135s - loss: 0.0045 - mean_absolute_error: 0.0507
# Epoch 31/50
#  - 137s - loss: 0.0042 - mean_absolute_error: 0.0503
# Epoch 32/50
#  - 136s - loss: 0.0041 - mean_absolute_error: 0.0492
# Epoch 33/50
#  - 134s - loss: 0.0037 - mean_absolute_error: 0.0470
# Epoch 34/50
#  - 135s - loss: 0.0038 - mean_absolute_error: 0.0473
# Epoch 35/50
#  - 137s - loss: 0.0036 - mean_absolute_error: 0.0458
# Epoch 36/50
#  - 137s - loss: 0.0036 - mean_absolute_error: 0.0459
# Epoch 37/50
#  - 137s - loss: 0.0034 - mean_absolute_error: 0.0445
# Epoch 38/50
#  - 136s - loss: 0.0033 - mean_absolute_error: 0.0439
# Epoch 39/50
#  - 134s - loss: 0.0030 - mean_absolute_error: 0.0422
# Epoch 40/50
#  - 135s - loss: 0.0030 - mean_absolute_error: 0.0423
# Epoch 41/50
#  - 135s - loss: 0.0030 - mean_absolute_error: 0.0421
# Epoch 42/50
#  - 135s - loss: 0.0029 - mean_absolute_error: 0.0410
# Epoch 43/50
#  - 135s - loss: 0.0028 - mean_absolute_error: 0.0408
# Epoch 44/50
#  - 135s - loss: 0.0027 - mean_absolute_error: 0.0392
# Epoch 45/50
#  - 133s - loss: 0.0024 - mean_absolute_error: 0.0373
# Epoch 46/50
#  - 132s - loss: 0.0024 - mean_absolute_error: 0.0374
# Epoch 47/50
#  - 134s - loss: 0.0024 - mean_absolute_error: 0.0376
# Epoch 48/50
#  - 135s - loss: 0.0022 - mean_absolute_error: 0.0361
# Epoch 49/50
#  - 137s - loss: 0.0023 - mean_absolute_error: 0.0362
# Epoch 50/50
#  - 138s - loss: 0.0021 - mean_absolute_error: 0.0348
# Kappa Score: 0.7867514045231447
# Average Kappa score after a 5-fold cross validation:  0.76777
# Kappa score after a 5-fold cross validation:  0.7718710277270842
