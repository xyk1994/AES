# %%
prompt_id = 3
model_name = "1LayerOverall"  # 1LayerOverall, 1LayerMoTOverall, 2LayerOverall

# %%
import os
import pprint
import tensorflow as tf

if 'COLAB_TPU_ADDR' not in os.environ:
  print('ERROR: Not connected to a TPU runtime')
else:
  tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
  print ('TPU address is', tpu_address)

  with tf.Session(tpu_address) as session:
    devices = session.list_devices()

  print('TPU devices:')
  pprint.pprint(devices)
# Out:
# TPU address is grpc://10.31.236.138:8470
# TPU devices:
# [_DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:CPU:0, CPU, -1, 10486013659882129101),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 13267380751485239306),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 16437157151934229734),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 12006973421325791079),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 7282847736331497919),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 6556371063566467909),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 519690644636217582),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 5378729156969595899),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 8318848321446593743),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 12847022075525792096),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 8589934592, 1160810559463598674)]

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/My Drive/AES謝"
os.chdir(path)
# os.listdir(path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import argparse
import nltk
import tensorflow as tf
from keras.models import Model
from keras import layers
from keras.layers import Input, concatenate, Embedding, LSTM, Dense, Lambda
from keras.engine.topology import Layer
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
import re
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
import keras.backend as K
from sklearn.model_selection import KFold
from sklearn.metrics import cohen_kappa_score
from sklearn.preprocessing import StandardScaler
from keras.preprocessing.sequence import pad_sequences
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')

nltk.download('stopwords')
nltk.download('punkt')
# stopwords, punkt,
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Mean Over Time
class TemporalMean(Layer):
  def __init__(self, **kwargs):
      self.supports_masking = True
      super(TemporalMean, self).__init__(**kwargs)

  def compute_mask(self, input, input_mask=None):
      # do not pass the mask to the next layers
      return None

  def call(self, x, mask=None):
      if mask is not None:
          # mask (batch, time)
          mask = K.cast(mask, K.floatx())
          # mask (batch, x_dim, time)
          mask = K.repeat(mask, x.shape[-1])
          # mask (batch, time, x_dim)
          mask = tf.transpose(mask, [0,2,1])
          x = x * mask
      return K.sum(x, axis=1) / K.sum(mask, axis=1)

  def compute_output_shape(self, input_shape):
      # remove temporal dimension
      return (input_shape[0], input_shape[2])

def essay_to_wordlist(essay_v, remove_stopwords):
    """Remove the tagged labels and word tokenize the sentence."""
    essay_v = re.sub("[^a-zA-Z]", " ", essay_v)
    words = essay_v.lower().split()
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    return (words)

def get_clean_essays(Text):
    clean_essays = []
    for essay in Text:
        clean_essays.append(essay_to_wordlist(essay, remove_stopwords=False))
    return clean_essays

def create_dict(text):
    print("create_dict")
    word_index = {}
    word_index['xieyikuan'] = 0
    for sentence in text:
        for word in sentence:
            if word not in word_index:
                word_index[word] = len(word_index)
    word_index['unk'] = len(word_index)
    return word_index

def essay_to_index(essays, word_index):
    Essays = []
    for essay in essays:
        sentence = []
        for sent in essay:
            words = []
            for word in sent:
                words.append(word_index[word])
            sentence.append(words)
        Essays.append(sentence)
    return Essays

def essay_to_index2(essays, word_index):
    Essays = []
    for essay in essays:
        words = []
        for word in essay:
            words.append(word_index[word])
        Essays.append(words)
    return Essays

def get_embeddings_index():
    embeddings_index = {}
    f = open('glove.6B.50d.txt', 'r', encoding='UTF-8')
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.array(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    f.close()
    return embeddings_index

def embeddings_matrix(embeddings_index, word_index, embedding_dim):
    nb_words = len(word_index)
    embedding_matrix = np.zeros((nb_words + 1, embedding_dim))
    for word, i in word_index.items():
        if i > nb_words:
            continue
        embeddings_vector = embeddings_index.get(word)
        if embeddings_vector is not None:
            embedding_matrix[i] = embeddings_vector
        if embeddings_vector is None:
            embedding_matrix[i] = embeddings_index.get('unk')
    return embedding_matrix

# %%
csv_input = pd.read_csv(filepath_or_buffer="data_feature/set"+str(prompt_id)+"_feature(26).tsv", delimiter="\t", engine="python", error_bad_lines=False)

Text = csv_input['essay']
Score = csv_input['domain1_score']
Label = Score

# --------
if prompt_id == 1:
    Score = (Score - 2) / 10      # set_1     范围 2-12
elif prompt_id == 2:
    Score = (Score - 1) / 5       # set_2     范围 1-6
elif prompt_id == 3 or prompt_id == 4:
    Score = Score / 3           # set_3,4   范围 0-3
elif prompt_id == 5 or prompt_id == 6:
    Score = Score / 4           # set_5,6   范围 0-4
elif prompt_id == 7:
    Score = Score / 30          # set_7     范围 0-30
elif prompt_id == 8:
    Score = Score / 60          # set_8     范围 0-60

# get Overall Feature
overall_feature = csv_input[['word_count', 'avg_word_len', 'sentence_count', 'avg_sentence_len', 'lemma_count', 'noun_count', 'adj_count', 'adv_count', 'verb_count', 'cc_count',
                             'syllable_count', 'flesch_reading_ease', 'smog_index', 'flesch_kincaid_grade', 'coleman_liau_index', 'automated_readability_index',
                             'dale_chall_readability_score', 'difficult_words', 'linsear_write_formula',
                             'gunning_fog', 'spelling_errors', 'exc_count', 'que_count', 'comma_count', 'stopwords_num']]
# overall_feature = np.array(np.sqrt(overall_feature))
overall_feature = np.array(overall_feature)
num_feature = 25
where_are_nan = np.isnan(overall_feature)
where_are_inf = np.isinf(overall_feature)
overall_feature[where_are_nan] = 0
overall_feature[where_are_inf] = 0
# standardized
stdsc = StandardScaler()
overall_feature = stdsc.fit_transform(overall_feature)

# 做字典
clean_essays = get_clean_essays(Text)
word_index = create_dict(clean_essays)

# 做分句
text = np.array(Text)
# print(text)
a = []
for essay in text:
    a.append(sent_tokenize(essay))
texts = np.array(a)

# 做分词
essays = []
for essay in Text:
  essay_idx = essay_to_wordlist(essay, remove_stopwords=False)
  essays.append(essay_idx)
essays = np.array(essays)

Essays = essay_to_index2(clean_essays, word_index)
Essays = np.array(Essays)

if prompt_id == 1:
    max_essay_length = 600
elif prompt_id == 2:
    max_essay_length = 700
elif prompt_id == 3:
    max_essay_length = 256
elif prompt_id == 4:
    max_essay_length = 200
elif prompt_id == 5:
    max_essay_length = 256
elif prompt_id == 6:
    max_essay_length = 256
elif prompt_id == 7:
    max_essay_length = 350
elif prompt_id == 8:
    max_essay_length = 870

essay_pad = pad_sequences(Essays, maxlen=max_essay_length)

embeddings_index = get_embeddings_index()
embeddings_matrix = embeddings_matrix(embeddings_index, word_index, embedding_dim=50)

# 记录成绩
results = []
score_predict_list = []
sssscore = []
llllabel = []
newresults = []
cv = KFold(n_splits=5, shuffle=True, random_state=10)
count = 0
for train, test in cv.split(essay_pad):
    text_train, text_test = essay_pad[train], essay_pad[test]
    label_train, label_test = Score.iloc[train], Score.iloc[test]
    score_train, score_test = Label.iloc[train], Label.iloc[test]
    overall_train, overall_test = overall_feature[train], overall_feature[test]

    print('Build model '+str(count)+'...')
    count += 1

    # -------
    text_input = Input(shape=(max_essay_length, ), name='text_input')
    overall_feature_input = Input(shape=(num_feature,), name='overall_feature_input')

    embedding_layer = Embedding(input_dim=len(word_index) + 1,
                                output_dim=50,
                                weights=[embeddings_matrix],
                                input_length=max_essay_length,
                                trainable=True,
                                mask_zero=True)
    x = embedding_layer(text_input)  
    if model_name == "2LayerOverall":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)
    elif model_name == "1LayerMoTOverall":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)
      x = TemporalMean()(x)
    elif model_name == "1LayerOverall":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)
    x = layers.Dropout(0.5)(x)
    concat_layer = Lambda(concatenate)([x, overall_feature_input])
    output = Dense(1, activation='sigmoid')(concat_layer)

    model = Model(inputs=[text_input, overall_feature_input], outputs=output)
    # -------

    model.summary()
    model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001, decay=1e-6), metrics=['mean_absolute_error'])
    model.fit([text_train, overall_train], label_train, batch_size=32, epochs=50, verbose=2)

    score_predict = model.predict([text_test, overall_test])
    if prompt_id == 1:
        score_predict = score_predict*10+2
    elif prompt_id == 2:
        score_predict = score_predict*5+1
    elif prompt_id == 3:
        score_predict = score_predict*3
    elif prompt_id == 4:
        score_predict = score_predict*3
    elif prompt_id == 5:
        score_predict = score_predict*4
    elif prompt_id == 6:
        score_predict = score_predict*4
    elif prompt_id == 7:
        score_predict = score_predict*30
    elif prompt_id == 8:
        score_predict = score_predict*60

    score_predict = np.around(score_predict)

    sssscore.append(score_predict)
    llllabel.append(score_test)

    result = cohen_kappa_score(score_test.values, score_predict, weights='quadratic')
    print("Kappa Score: {}".format(result))
    results.append(result)
    for i in results:
      if i != 0:
        newresults.append(i)

print("Average Kappa score after a 5-fold cross validation: ", np.around(np.array(newresults).mean(), decimals=5))

sssscore = np.array(sssscore)
res = []
for scores in sssscore:
  for score in scores:
    res.append(score)

ll = np.array(llllabel)
res_label = []
for labels in ll:
  for label in labels:
    res_label.append(label)
res_label = np.array(res_label)

QWK = cohen_kappa_score(res_label, res, weights='quadratic')
print("Kappa score after a 5-fold cross validation: ", QWK)
# Out:
# create_dict
# Build model 0...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3239: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 256)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 256, 50)      317500      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 300)          421200      embedding_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 300)          0           lstm_1[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 325)          0           dropout_1[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            326         lambda_1[0][0]
# ==================================================================================================
# Total params: 739,026
# Trainable params: 739,026
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/50
#  - 59s - loss: 0.0829 - mean_absolute_error: 0.2390
# Epoch 2/50
#  - 63s - loss: 0.0521 - mean_absolute_error: 0.1872
# Epoch 3/50
#  - 63s - loss: 0.0412 - mean_absolute_error: 0.1628
# Epoch 4/50
#  - 62s - loss: 0.0396 - mean_absolute_error: 0.1579
# Epoch 5/50
#  - 60s - loss: 0.0373 - mean_absolute_error: 0.1519
# Epoch 6/50
#  - 63s - loss: 0.0364 - mean_absolute_error: 0.1500
# Epoch 7/50
#  - 63s - loss: 0.0362 - mean_absolute_error: 0.1497
# Epoch 8/50
#  - 61s - loss: 0.0351 - mean_absolute_error: 0.1454
# Epoch 9/50
#  - 58s - loss: 0.0350 - mean_absolute_error: 0.1455
# Epoch 10/50
#  - 59s - loss: 0.0348 - mean_absolute_error: 0.1450
# Epoch 11/50
#  - 58s - loss: 0.0341 - mean_absolute_error: 0.1434
# Epoch 12/50
#  - 58s - loss: 0.0334 - mean_absolute_error: 0.1411
# Epoch 13/50
#  - 59s - loss: 0.0328 - mean_absolute_error: 0.1423
# Epoch 14/50
#  - 59s - loss: 0.0318 - mean_absolute_error: 0.1391
# Epoch 15/50
#  - 59s - loss: 0.0318 - mean_absolute_error: 0.1394
# Epoch 16/50
#  - 60s - loss: 0.0315 - mean_absolute_error: 0.1376
# Epoch 17/50
#  - 61s - loss: 0.0305 - mean_absolute_error: 0.1343
# Epoch 18/50
#  - 59s - loss: 0.0297 - mean_absolute_error: 0.1359
# Epoch 19/50
#  - 59s - loss: 0.0283 - mean_absolute_error: 0.1307
# Epoch 20/50
#  - 61s - loss: 0.0277 - mean_absolute_error: 0.1292
# Epoch 21/50
#  - 61s - loss: 0.0264 - mean_absolute_error: 0.1260
# Epoch 22/50
#  - 59s - loss: 0.0261 - mean_absolute_error: 0.1263
# Epoch 23/50
#  - 59s - loss: 0.0252 - mean_absolute_error: 0.1237
# Epoch 24/50
#  - 58s - loss: 0.0251 - mean_absolute_error: 0.1225
# Epoch 25/50
#  - 61s - loss: 0.0234 - mean_absolute_error: 0.1180
# Epoch 26/50
#  - 60s - loss: 0.0239 - mean_absolute_error: 0.1200
# Epoch 27/50
#  - 60s - loss: 0.0217 - mean_absolute_error: 0.1145
# Epoch 28/50
#  - 63s - loss: 0.0210 - mean_absolute_error: 0.1122
# Epoch 29/50
#  - 57s - loss: 0.0203 - mean_absolute_error: 0.1103
# Epoch 30/50
#  - 56s - loss: 0.0194 - mean_absolute_error: 0.1079
# Epoch 31/50
#  - 56s - loss: 0.0189 - mean_absolute_error: 0.1067
# Epoch 32/50
#  - 55s - loss: 0.0174 - mean_absolute_error: 0.1029
# Epoch 33/50
#  - 56s - loss: 0.0167 - mean_absolute_error: 0.1004
# Epoch 34/50
#  - 57s - loss: 0.0159 - mean_absolute_error: 0.0964
# Epoch 35/50
#  - 57s - loss: 0.0167 - mean_absolute_error: 0.1001
# Epoch 36/50
#  - 57s - loss: 0.0148 - mean_absolute_error: 0.0935
# Epoch 37/50
#  - 56s - loss: 0.0137 - mean_absolute_error: 0.0895
# Epoch 38/50
#  - 57s - loss: 0.0137 - mean_absolute_error: 0.0921
# Epoch 39/50
#  - 57s - loss: 0.0129 - mean_absolute_error: 0.0871
# Epoch 40/50
#  - 58s - loss: 0.0121 - mean_absolute_error: 0.0846
# Epoch 41/50
#  - 57s - loss: 0.0122 - mean_absolute_error: 0.0844
# Epoch 42/50
#  - 57s - loss: 0.0122 - mean_absolute_error: 0.0845
# Epoch 43/50
#  - 57s - loss: 0.0113 - mean_absolute_error: 0.0808
# Epoch 44/50
#  - 57s - loss: 0.0108 - mean_absolute_error: 0.0795
# Epoch 45/50
#  - 57s - loss: 0.0109 - mean_absolute_error: 0.0797
# Epoch 46/50
#  - 57s - loss: 0.0098 - mean_absolute_error: 0.0765
# Epoch 47/50
#  - 57s - loss: 0.0103 - mean_absolute_error: 0.0786
# Epoch 48/50
#  - 57s - loss: 0.0095 - mean_absolute_error: 0.0751
# Epoch 49/50
#  - 58s - loss: 0.0096 - mean_absolute_error: 0.0760
# Epoch 50/50
#  - 58s - loss: 0.0096 - mean_absolute_error: 0.0765
# Kappa Score: 0.531918883441828
# Build model 1...
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 256)          0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 256, 50)      317500      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 300)          421200      embedding_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 300)          0           lstm_2[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 325)          0           dropout_2[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            326         lambda_2[0][0]
# ==================================================================================================
# Total params: 739,026
# Trainable params: 739,026
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 58s - loss: 0.0713 - mean_absolute_error: 0.2195
# Epoch 2/50
#  - 56s - loss: 0.0478 - mean_absolute_error: 0.1759
# Epoch 3/50
#  - 56s - loss: 0.0388 - mean_absolute_error: 0.1578
# Epoch 4/50
#  - 58s - loss: 0.0372 - mean_absolute_error: 0.1517
# Epoch 5/50
#  - 58s - loss: 0.0357 - mean_absolute_error: 0.1487
# Epoch 6/50
#  - 58s - loss: 0.0357 - mean_absolute_error: 0.1478
# Epoch 7/50
#  - 59s - loss: 0.0355 - mean_absolute_error: 0.1473
# Epoch 8/50
#  - 59s - loss: 0.0336 - mean_absolute_error: 0.1450
# Epoch 9/50
#  - 58s - loss: 0.0339 - mean_absolute_error: 0.1437
# Epoch 10/50
#  - 58s - loss: 0.0326 - mean_absolute_error: 0.1403
# Epoch 11/50
#  - 58s - loss: 0.0323 - mean_absolute_error: 0.1398
# Epoch 12/50
#  - 59s - loss: 0.0324 - mean_absolute_error: 0.1396
# Epoch 13/50
#  - 58s - loss: 0.0316 - mean_absolute_error: 0.1388
# Epoch 14/50
#  - 58s - loss: 0.0306 - mean_absolute_error: 0.1350
# Epoch 15/50
#  - 58s - loss: 0.0304 - mean_absolute_error: 0.1363
# Epoch 16/50
#  - 58s - loss: 0.0299 - mean_absolute_error: 0.1352
# Epoch 17/50
#  - 58s - loss: 0.0291 - mean_absolute_error: 0.1323
# Epoch 18/50
#  - 59s - loss: 0.0280 - mean_absolute_error: 0.1299
# Epoch 19/50
#  - 58s - loss: 0.0264 - mean_absolute_error: 0.1252
# Epoch 20/50
#  - 59s - loss: 0.0264 - mean_absolute_error: 0.1266
# Epoch 21/50
#  - 59s - loss: 0.0257 - mean_absolute_error: 0.1241
# Epoch 22/50
#  - 59s - loss: 0.0255 - mean_absolute_error: 0.1230
# Epoch 23/50
#  - 57s - loss: 0.0234 - mean_absolute_error: 0.1196
# Epoch 24/50
#  - 59s - loss: 0.0230 - mean_absolute_error: 0.1177
# Epoch 25/50
#  - 58s - loss: 0.0220 - mean_absolute_error: 0.1148
# Epoch 26/50
#  - 59s - loss: 0.0207 - mean_absolute_error: 0.1108
# Epoch 27/50
#  - 59s - loss: 0.0212 - mean_absolute_error: 0.1131
# Epoch 28/50
#  - 59s - loss: 0.0199 - mean_absolute_error: 0.1098
# Epoch 29/50
#  - 59s - loss: 0.0190 - mean_absolute_error: 0.1078
# Epoch 30/50
#  - 59s - loss: 0.0185 - mean_absolute_error: 0.1062
# Epoch 31/50
#  - 62s - loss: 0.0173 - mean_absolute_error: 0.1014
# Epoch 32/50
#  - 61s - loss: 0.0167 - mean_absolute_error: 0.1006
# Epoch 33/50
#  - 60s - loss: 0.0163 - mean_absolute_error: 0.0993
# Epoch 34/50
#  - 59s - loss: 0.0151 - mean_absolute_error: 0.0953
# Epoch 35/50
#  - 59s - loss: 0.0156 - mean_absolute_error: 0.0987
# Epoch 36/50
#  - 58s - loss: 0.0140 - mean_absolute_error: 0.0916
# Epoch 37/50
#  - 59s - loss: 0.0139 - mean_absolute_error: 0.0915
# Epoch 38/50
#  - 57s - loss: 0.0130 - mean_absolute_error: 0.0884
# Epoch 39/50
#  - 56s - loss: 0.0124 - mean_absolute_error: 0.0874
# Epoch 40/50
#  - 55s - loss: 0.0120 - mean_absolute_error: 0.0855
# Epoch 41/50
#  - 55s - loss: 0.0116 - mean_absolute_error: 0.0858
# Epoch 42/50
#  - 55s - loss: 0.0112 - mean_absolute_error: 0.0823
# Epoch 43/50
#  - 55s - loss: 0.0103 - mean_absolute_error: 0.0796
# Epoch 44/50
#  - 55s - loss: 0.0105 - mean_absolute_error: 0.0811
# Epoch 45/50
#  - 54s - loss: 0.0100 - mean_absolute_error: 0.0780
# Epoch 46/50
#  - 55s - loss: 0.0090 - mean_absolute_error: 0.0741
# Epoch 47/50
#  - 54s - loss: 0.0086 - mean_absolute_error: 0.0734
# Epoch 48/50
#  - 55s - loss: 0.0091 - mean_absolute_error: 0.0736
# Epoch 49/50
#  - 56s - loss: 0.0089 - mean_absolute_error: 0.0739
# Epoch 50/50
#  - 57s - loss: 0.0088 - mean_absolute_error: 0.0731
# Kappa Score: 0.5889401231866985
# Build model 2...
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 256)          0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 256, 50)      317500      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 300)          421200      embedding_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 300)          0           lstm_3[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 325)          0           dropout_3[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            326         lambda_3[0][0]
# ==================================================================================================
# Total params: 739,026
# Trainable params: 739,026
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 56s - loss: 0.0782 - mean_absolute_error: 0.2306
# Epoch 2/50
#  - 56s - loss: 0.0475 - mean_absolute_error: 0.1791
# Epoch 3/50
#  - 57s - loss: 0.0397 - mean_absolute_error: 0.1610
# Epoch 4/50
#  - 58s - loss: 0.0376 - mean_absolute_error: 0.1534
# Epoch 5/50
#  - 60s - loss: 0.0374 - mean_absolute_error: 0.1521
# Epoch 6/50
#  - 61s - loss: 0.0358 - mean_absolute_error: 0.1484
# Epoch 7/50
#  - 60s - loss: 0.0348 - mean_absolute_error: 0.1447
# Epoch 8/50
#  - 60s - loss: 0.0346 - mean_absolute_error: 0.1454
# Epoch 9/50
#  - 61s - loss: 0.0341 - mean_absolute_error: 0.1436
# Epoch 10/50
#  - 61s - loss: 0.0348 - mean_absolute_error: 0.1457
# Epoch 11/50
#  - 61s - loss: 0.0327 - mean_absolute_error: 0.1406
# Epoch 12/50
#  - 60s - loss: 0.0335 - mean_absolute_error: 0.1421
# Epoch 13/50
#  - 61s - loss: 0.0322 - mean_absolute_error: 0.1391
# Epoch 14/50
#  - 61s - loss: 0.0323 - mean_absolute_error: 0.1382
# Epoch 15/50
#  - 59s - loss: 0.0317 - mean_absolute_error: 0.1377
# Epoch 16/50
#  - 58s - loss: 0.0300 - mean_absolute_error: 0.1337
# Epoch 17/50
#  - 56s - loss: 0.0298 - mean_absolute_error: 0.1347
# Epoch 18/50
#  - 58s - loss: 0.0289 - mean_absolute_error: 0.1308
# Epoch 19/50
#  - 63s - loss: 0.0278 - mean_absolute_error: 0.1296
# Epoch 20/50
#  - 60s - loss: 0.0271 - mean_absolute_error: 0.1279
# Epoch 21/50
#  - 60s - loss: 0.0261 - mean_absolute_error: 0.1250
# Epoch 22/50
#  - 61s - loss: 0.0253 - mean_absolute_error: 0.1243
# Epoch 23/50
#  - 61s - loss: 0.0247 - mean_absolute_error: 0.1214
# Epoch 24/50
#  - 60s - loss: 0.0232 - mean_absolute_error: 0.1184
# Epoch 25/50
#  - 59s - loss: 0.0241 - mean_absolute_error: 0.1196
# Epoch 26/50
#  - 58s - loss: 0.0211 - mean_absolute_error: 0.1126
# Epoch 27/50
#  - 54s - loss: 0.0206 - mean_absolute_error: 0.1109
# Epoch 28/50
#  - 56s - loss: 0.0194 - mean_absolute_error: 0.1086
# Epoch 29/50
#  - 58s - loss: 0.0195 - mean_absolute_error: 0.1098
# Epoch 30/50
#  - 56s - loss: 0.0187 - mean_absolute_error: 0.1066
# Epoch 31/50
#  - 60s - loss: 0.0177 - mean_absolute_error: 0.1027
# Epoch 32/50
#  - 58s - loss: 0.0172 - mean_absolute_error: 0.1028
# Epoch 33/50
#  - 57s - loss: 0.0165 - mean_absolute_error: 0.0982
# Epoch 34/50
#  - 58s - loss: 0.0158 - mean_absolute_error: 0.0982
# Epoch 35/50
#  - 56s - loss: 0.0144 - mean_absolute_error: 0.0927
# Epoch 36/50
#  - 55s - loss: 0.0141 - mean_absolute_error: 0.0927
# Epoch 37/50
#  - 55s - loss: 0.0142 - mean_absolute_error: 0.0923
# Epoch 38/50
#  - 55s - loss: 0.0127 - mean_absolute_error: 0.0880
# Epoch 39/50
#  - 55s - loss: 0.0134 - mean_absolute_error: 0.0907
# Epoch 40/50
#  - 56s - loss: 0.0128 - mean_absolute_error: 0.0878
# Epoch 41/50
#  - 56s - loss: 0.0124 - mean_absolute_error: 0.0857
# Epoch 42/50
#  - 57s - loss: 0.0115 - mean_absolute_error: 0.0831
# Epoch 43/50
#  - 56s - loss: 0.0110 - mean_absolute_error: 0.0822
# Epoch 44/50
#  - 56s - loss: 0.0108 - mean_absolute_error: 0.0813
# Epoch 45/50
#  - 56s - loss: 0.0107 - mean_absolute_error: 0.0802
# Epoch 46/50
#  - 57s - loss: 0.0099 - mean_absolute_error: 0.0779
# Epoch 47/50
#  - 56s - loss: 0.0097 - mean_absolute_error: 0.0773
# Epoch 48/50
#  - 56s - loss: 0.0099 - mean_absolute_error: 0.0774
# Epoch 49/50
#  - 56s - loss: 0.0095 - mean_absolute_error: 0.0757
# Epoch 50/50
#  - 56s - loss: 0.0102 - mean_absolute_error: 0.0793
# Kappa Score: 0.5428225736755682
# Build model 3...
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 256)          0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 256, 50)      317500      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 300)          421200      embedding_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 300)          0           lstm_4[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 325)          0           dropout_4[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            326         lambda_4[0][0]
# ==================================================================================================
# Total params: 739,026
# Trainable params: 739,026
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 57s - loss: 0.0506 - mean_absolute_error: 0.1826
# Epoch 2/50
#  - 56s - loss: 0.0400 - mean_absolute_error: 0.1572
# Epoch 3/50
#  - 56s - loss: 0.0384 - mean_absolute_error: 0.1526
# Epoch 4/50
#  - 56s - loss: 0.0372 - mean_absolute_error: 0.1480
# Epoch 5/50
#  - 56s - loss: 0.0368 - mean_absolute_error: 0.1474
# Epoch 6/50
#  - 57s - loss: 0.0361 - mean_absolute_error: 0.1460
# Epoch 7/50
#  - 57s - loss: 0.0361 - mean_absolute_error: 0.1469
# Epoch 8/50
#  - 57s - loss: 0.0361 - mean_absolute_error: 0.1473
# Epoch 9/50
#  - 56s - loss: 0.0345 - mean_absolute_error: 0.1440
# Epoch 10/50
#  - 56s - loss: 0.0357 - mean_absolute_error: 0.1455
# Epoch 11/50
#  - 56s - loss: 0.0340 - mean_absolute_error: 0.1414
# Epoch 12/50
#  - 57s - loss: 0.0335 - mean_absolute_error: 0.1408
# Epoch 13/50
#  - 58s - loss: 0.0327 - mean_absolute_error: 0.1397
# Epoch 14/50
#  - 58s - loss: 0.0324 - mean_absolute_error: 0.1389
# Epoch 15/50
#  - 59s - loss: 0.0309 - mean_absolute_error: 0.1356
# Epoch 16/50
#  - 58s - loss: 0.0308 - mean_absolute_error: 0.1358
# Epoch 17/50
#  - 58s - loss: 0.0298 - mean_absolute_error: 0.1331
# Epoch 18/50
#  - 60s - loss: 0.0291 - mean_absolute_error: 0.1330
# Epoch 19/50
#  - 57s - loss: 0.0287 - mean_absolute_error: 0.1305
# Epoch 20/50
#  - 56s - loss: 0.0276 - mean_absolute_error: 0.1284
# Epoch 21/50
#  - 57s - loss: 0.0281 - mean_absolute_error: 0.1295
# Epoch 22/50
#  - 56s - loss: 0.0261 - mean_absolute_error: 0.1235
# Epoch 23/50
#  - 57s - loss: 0.0243 - mean_absolute_error: 0.1200
# Epoch 24/50
#  - 56s - loss: 0.0241 - mean_absolute_error: 0.1207
# Epoch 25/50
#  - 56s - loss: 0.0226 - mean_absolute_error: 0.1185
# Epoch 26/50
#  - 56s - loss: 0.0217 - mean_absolute_error: 0.1149
# Epoch 27/50
#  - 56s - loss: 0.0214 - mean_absolute_error: 0.1130
# Epoch 28/50
#  - 54s - loss: 0.0215 - mean_absolute_error: 0.1127
# Epoch 29/50
#  - 54s - loss: 0.0197 - mean_absolute_error: 0.1085
# Epoch 30/50
#  - 55s - loss: 0.0181 - mean_absolute_error: 0.1053
# Epoch 31/50
#  - 54s - loss: 0.0182 - mean_absolute_error: 0.1034
# Epoch 32/50
#  - 54s - loss: 0.0170 - mean_absolute_error: 0.1031
# Epoch 33/50
#  - 54s - loss: 0.0155 - mean_absolute_error: 0.0968
# Epoch 34/50
#  - 54s - loss: 0.0156 - mean_absolute_error: 0.0979
# Epoch 35/50
#  - 54s - loss: 0.0146 - mean_absolute_error: 0.0929
# Epoch 36/50
#  - 54s - loss: 0.0136 - mean_absolute_error: 0.0917
# Epoch 37/50
#  - 55s - loss: 0.0135 - mean_absolute_error: 0.0899
# Epoch 38/50
#  - 55s - loss: 0.0127 - mean_absolute_error: 0.0876
# Epoch 39/50
#  - 57s - loss: 0.0131 - mean_absolute_error: 0.0886
# Epoch 40/50
#  - 57s - loss: 0.0118 - mean_absolute_error: 0.0839
# Epoch 41/50
#  - 57s - loss: 0.0119 - mean_absolute_error: 0.0848
# Epoch 42/50
#  - 58s - loss: 0.0113 - mean_absolute_error: 0.0832
# Epoch 43/50
#  - 58s - loss: 0.0111 - mean_absolute_error: 0.0828
# Epoch 44/50
#  - 57s - loss: 0.0102 - mean_absolute_error: 0.0784
# Epoch 45/50
#  - 57s - loss: 0.0103 - mean_absolute_error: 0.0798
# Epoch 46/50
#  - 57s - loss: 0.0102 - mean_absolute_error: 0.0778
# Epoch 47/50
#  - 57s - loss: 0.0099 - mean_absolute_error: 0.0762
# Epoch 48/50
#  - 56s - loss: 0.0098 - mean_absolute_error: 0.0764
# Epoch 49/50
#  - 57s - loss: 0.0090 - mean_absolute_error: 0.0737
# Epoch 50/50
#  - 56s - loss: 0.0092 - mean_absolute_error: 0.0744
# Kappa Score: 0.5859441825306837
# Build model 4...
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 256)          0
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 256, 50)      317500      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 300)          421200      embedding_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 300)          0           lstm_5[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 325)          0           dropout_5[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            326         lambda_5[0][0]
# ==================================================================================================
# Total params: 739,026
# Trainable params: 739,026
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 59s - loss: 0.0640 - mean_absolute_error: 0.2088
# Epoch 2/50
#  - 60s - loss: 0.0419 - mean_absolute_error: 0.1664
# Epoch 3/50
#  - 61s - loss: 0.0389 - mean_absolute_error: 0.1571
# Epoch 4/50
#  - 60s - loss: 0.0379 - mean_absolute_error: 0.1550
# Epoch 5/50
#  - 61s - loss: 0.0363 - mean_absolute_error: 0.1514
# Epoch 6/50
#  - 61s - loss: 0.0362 - mean_absolute_error: 0.1502
# Epoch 7/50
#  - 61s - loss: 0.0354 - mean_absolute_error: 0.1480
# Epoch 8/50
#  - 60s - loss: 0.0361 - mean_absolute_error: 0.1505
# Epoch 9/50
#  - 59s - loss: 0.0351 - mean_absolute_error: 0.1464
# Epoch 10/50
#  - 59s - loss: 0.0333 - mean_absolute_error: 0.1430
# Epoch 11/50
#  - 59s - loss: 0.0327 - mean_absolute_error: 0.1426
# Epoch 12/50
#  - 59s - loss: 0.0327 - mean_absolute_error: 0.1401
# Epoch 13/50
#  - 59s - loss: 0.0322 - mean_absolute_error: 0.1398
# Epoch 14/50
#  - 59s - loss: 0.0310 - mean_absolute_error: 0.1382
# Epoch 15/50
#  - 60s - loss: 0.0308 - mean_absolute_error: 0.1376
# Epoch 16/50
#  - 60s - loss: 0.0296 - mean_absolute_error: 0.1345
# Epoch 17/50
#  - 60s - loss: 0.0288 - mean_absolute_error: 0.1321
# Epoch 18/50
#  - 64s - loss: 0.0290 - mean_absolute_error: 0.1336
# Epoch 19/50
#  - 62s - loss: 0.0279 - mean_absolute_error: 0.1296
# Epoch 20/50
#  - 65s - loss: 0.0265 - mean_absolute_error: 0.1270
# Epoch 21/50
#  - 62s - loss: 0.0252 - mean_absolute_error: 0.1236
# Epoch 22/50
#  - 67s - loss: 0.0251 - mean_absolute_error: 0.1233
# Epoch 23/50
#  - 67s - loss: 0.0241 - mean_absolute_error: 0.1213
# Epoch 24/50
#  - 64s - loss: 0.0232 - mean_absolute_error: 0.1168
# Epoch 25/50
#  - 60s - loss: 0.0224 - mean_absolute_error: 0.1178
# Epoch 26/50
#  - 60s - loss: 0.0221 - mean_absolute_error: 0.1164
# Epoch 27/50
#  - 59s - loss: 0.0206 - mean_absolute_error: 0.1109
# Epoch 28/50
#  - 59s - loss: 0.0192 - mean_absolute_error: 0.1080
# Epoch 29/50
#  - 58s - loss: 0.0185 - mean_absolute_error: 0.1069
# Epoch 30/50
#  - 59s - loss: 0.0184 - mean_absolute_error: 0.1064
# Epoch 31/50
#  - 58s - loss: 0.0171 - mean_absolute_error: 0.1018
# Epoch 32/50
#  - 56s - loss: 0.0158 - mean_absolute_error: 0.0976
# Epoch 33/50
#  - 57s - loss: 0.0161 - mean_absolute_error: 0.0976
# Epoch 34/50
#  - 58s - loss: 0.0141 - mean_absolute_error: 0.0940
# Epoch 35/50
#  - 58s - loss: 0.0139 - mean_absolute_error: 0.0917
# Epoch 36/50
#  - 58s - loss: 0.0140 - mean_absolute_error: 0.0918
# Epoch 37/50
#  - 58s - loss: 0.0132 - mean_absolute_error: 0.0897
# Epoch 38/50
#  - 59s - loss: 0.0127 - mean_absolute_error: 0.0875
# Epoch 39/50
#  - 56s - loss: 0.0114 - mean_absolute_error: 0.0840
# Epoch 40/50
#  - 56s - loss: 0.0116 - mean_absolute_error: 0.0824
# Epoch 41/50
#  - 56s - loss: 0.0112 - mean_absolute_error: 0.0823
# Epoch 42/50
#  - 56s - loss: 0.0106 - mean_absolute_error: 0.0806
# Epoch 43/50
#  - 56s - loss: 0.0102 - mean_absolute_error: 0.0780
# Epoch 44/50
#  - 56s - loss: 0.0094 - mean_absolute_error: 0.0758
# Epoch 45/50
#  - 56s - loss: 0.0096 - mean_absolute_error: 0.0775
# Epoch 46/50
#  - 56s - loss: 0.0109 - mean_absolute_error: 0.0820
# Epoch 47/50
#  - 55s - loss: 0.0096 - mean_absolute_error: 0.0777
# Epoch 48/50
#  - 56s - loss: 0.0092 - mean_absolute_error: 0.0754
# Epoch 49/50
#  - 56s - loss: 0.0091 - mean_absolute_error: 0.0746
# Epoch 50/50
#  - 57s - loss: 0.0087 - mean_absolute_error: 0.0715
# Kappa Score: 0.5455231560891939
# Average Kappa score after a 5-fold cross validation:  0.55742
# Kappa score after a 5-fold cross validation:  0.5587794782270513
