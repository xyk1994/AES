# %%
prompt_id = 4
model_name = "1LayerOverall"  # 1LayerOverall, 1LayerMoTOverall, 2LayerOverall

# %%
import os
import pprint
import tensorflow as tf

if 'COLAB_TPU_ADDR' not in os.environ:
  print('ERROR: Not connected to a TPU runtime')
else:
  tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
  print ('TPU address is', tpu_address)

  with tf.Session(tpu_address) as session:
    devices = session.list_devices()

  print('TPU devices:')
  pprint.pprint(devices)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# ERROR: Not connected to a TPU runtime

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/My Drive/AES謝"
os.chdir(path)
# os.listdir(path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import argparse
import nltk
import tensorflow as tf
from keras.models import Model
from keras import layers
from keras.layers import Input, concatenate, Embedding, LSTM, Dense, Lambda
from keras.engine.topology import Layer
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
import re
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
import keras.backend as K
from sklearn.model_selection import KFold
from sklearn.metrics import cohen_kappa_score
from sklearn.preprocessing import StandardScaler
from keras.preprocessing.sequence import pad_sequences
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')

nltk.download('stopwords')
nltk.download('punkt')
# stopwords, punkt,
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Mean Over Time
class TemporalMean(Layer):
  def __init__(self, **kwargs):
      self.supports_masking = True
      super(TemporalMean, self).__init__(**kwargs)

  def compute_mask(self, input, input_mask=None):
      # do not pass the mask to the next layers
      return None

  def call(self, x, mask=None):
      if mask is not None:
          # mask (batch, time)
          mask = K.cast(mask, K.floatx())
          # mask (batch, x_dim, time)
          mask = K.repeat(mask, x.shape[-1])
          # mask (batch, time, x_dim)
          mask = tf.transpose(mask, [0,2,1])
          x = x * mask
      return K.sum(x, axis=1) / K.sum(mask, axis=1)

  def compute_output_shape(self, input_shape):
      # remove temporal dimension
      return (input_shape[0], input_shape[2])

def essay_to_wordlist(essay_v, remove_stopwords):
    """Remove the tagged labels and word tokenize the sentence."""
    essay_v = re.sub("[^a-zA-Z]", " ", essay_v)
    words = essay_v.lower().split()
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    return (words)

def get_clean_essays(Text):
    clean_essays = []
    for essay in Text:
        clean_essays.append(essay_to_wordlist(essay, remove_stopwords=False))
    return clean_essays

def create_dict(text):
    print("create_dict")
    word_index = {}
    word_index['xieyikuan'] = 0
    for sentence in text:
        for word in sentence:
            if word not in word_index:
                word_index[word] = len(word_index)
    word_index['unk'] = len(word_index)
    return word_index

def essay_to_index(essays, word_index):
    Essays = []
    for essay in essays:
        sentence = []
        for sent in essay:
            words = []
            for word in sent:
                words.append(word_index[word])
            sentence.append(words)
        Essays.append(sentence)
    return Essays

def essay_to_index2(essays, word_index):
    Essays = []
    for essay in essays:
        words = []
        for word in essay:
            words.append(word_index[word])
        Essays.append(words)
    return Essays

def get_embeddings_index():
    embeddings_index = {}
    f = open('glove.6B.50d.txt', 'r', encoding='UTF-8')
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.array(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    f.close()
    return embeddings_index

def embeddings_matrix(embeddings_index, word_index, embedding_dim):
    nb_words = len(word_index)
    embedding_matrix = np.zeros((nb_words + 1, embedding_dim))
    for word, i in word_index.items():
        if i > nb_words:
            continue
        embeddings_vector = embeddings_index.get(word)
        if embeddings_vector is not None:
            embedding_matrix[i] = embeddings_vector
        if embeddings_vector is None:
            embedding_matrix[i] = embeddings_index.get('unk')
    return embedding_matrix

# %%
csv_input = pd.read_csv(filepath_or_buffer="data_feature/set"+str(prompt_id)+"_feature(26).tsv", delimiter="\t", engine="python", error_bad_lines=False)

Text = csv_input['essay']
Score = csv_input['domain1_score']
Label = Score

# --------
if prompt_id == 1:
    Score = (Score - 2) / 10      # set_1     范围 2-12
elif prompt_id == 2:
    Score = (Score - 1) / 5       # set_2     范围 1-6
elif prompt_id == 3 or prompt_id == 4:
    Score = Score / 3           # set_3,4   范围 0-3
elif prompt_id == 5 or prompt_id == 6:
    Score = Score / 4           # set_5,6   范围 0-4
elif prompt_id == 7:
    Score = Score / 30          # set_7     范围 0-30
elif prompt_id == 8:
    Score = Score / 60          # set_8     范围 0-60

# get Overall Feature
overall_feature = csv_input[['word_count', 'avg_word_len', 'sentence_count', 'avg_sentence_len', 'lemma_count', 'noun_count', 'adj_count', 'adv_count', 'verb_count', 'cc_count',
                             'syllable_count', 'flesch_reading_ease', 'smog_index', 'flesch_kincaid_grade', 'coleman_liau_index', 'automated_readability_index',
                             'dale_chall_readability_score', 'difficult_words', 'linsear_write_formula',
                             'gunning_fog', 'spelling_errors', 'exc_count', 'que_count', 'comma_count', 'stopwords_num']]
# overall_feature = np.array(np.sqrt(overall_feature))
overall_feature = np.array(overall_feature)
num_feature = 25
where_are_nan = np.isnan(overall_feature)
where_are_inf = np.isinf(overall_feature)
overall_feature[where_are_nan] = 0
overall_feature[where_are_inf] = 0
# standardized
stdsc = StandardScaler()
overall_feature = stdsc.fit_transform(overall_feature)

# 做字典
clean_essays = get_clean_essays(Text)
word_index = create_dict(clean_essays)

# 做分句
text = np.array(Text)
# print(text)
a = []
for essay in text:
    a.append(sent_tokenize(essay))
texts = np.array(a)

# 做分词
essays = []
for essay in Text:
  essay_idx = essay_to_wordlist(essay, remove_stopwords=False)
  essays.append(essay_idx)
essays = np.array(essays)

Essays = essay_to_index2(clean_essays, word_index)
Essays = np.array(Essays)

if prompt_id == 1:
    max_essay_length = 600
elif prompt_id == 2:
    max_essay_length = 700
elif prompt_id == 3:
    max_essay_length = 256
elif prompt_id == 4:
    max_essay_length = 200
elif prompt_id == 5:
    max_essay_length = 256
elif prompt_id == 6:
    max_essay_length = 256
elif prompt_id == 7:
    max_essay_length = 350
elif prompt_id == 8:
    max_essay_length = 870

essay_pad = pad_sequences(Essays, maxlen=max_essay_length)

embeddings_index = get_embeddings_index()
embeddings_matrix = embeddings_matrix(embeddings_index, word_index, embedding_dim=50)

# 记录成绩
results = []
score_predict_list = []
sssscore = []
llllabel = []
newresults = []
cv = KFold(n_splits=5, shuffle=True, random_state=10)
count = 0
for train, test in cv.split(essay_pad):
    text_train, text_test = essay_pad[train], essay_pad[test]
    label_train, label_test = Score.iloc[train], Score.iloc[test]
    score_train, score_test = Label.iloc[train], Label.iloc[test]
    overall_train, overall_test = overall_feature[train], overall_feature[test]

    print('Build model '+str(count)+'...')
    count += 1

    # -------
    text_input = Input(shape=(max_essay_length, ), name='text_input')
    overall_feature_input = Input(shape=(num_feature,), name='overall_feature_input')

    embedding_layer = Embedding(input_dim=len(word_index) + 1,
                                output_dim=50,
                                weights=[embeddings_matrix],
                                input_length=max_essay_length,
                                trainable=True,
                                mask_zero=True)
    x = embedding_layer(text_input)  
    if model_name == "2LayerOverall":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)
    elif model_name == "1LayerMoTOverall":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)
      x = TemporalMean()(x)
    elif model_name == "1LayerOverall":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)
    x = layers.Dropout(0.5)(x)
    concat_layer = Lambda(concatenate)([x, overall_feature_input])
    output = Dense(1, activation='sigmoid')(concat_layer)

    model = Model(inputs=[text_input, overall_feature_input], outputs=output)
    # -------

    model.summary()
    model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001, decay=1e-6), metrics=['mean_absolute_error'])
    model.fit([text_train, overall_train], label_train, batch_size=32, epochs=50, verbose=2)

    score_predict = model.predict([text_test, overall_test])
    if prompt_id == 1:
        score_predict = score_predict*10+2
    elif prompt_id == 2:
        score_predict = score_predict*5+1
    elif prompt_id == 3:
        score_predict = score_predict*3
    elif prompt_id == 4:
        score_predict = score_predict*3
    elif prompt_id == 5:
        score_predict = score_predict*4
    elif prompt_id == 6:
        score_predict = score_predict*4
    elif prompt_id == 7:
        score_predict = score_predict*30
    elif prompt_id == 8:
        score_predict = score_predict*60

    score_predict = np.around(score_predict)

    sssscore.append(score_predict)
    llllabel.append(score_test)

    result = cohen_kappa_score(score_test.values, score_predict, weights='quadratic')
    print("Kappa Score: {}".format(result))
    results.append(result)
    for i in results:
      if i != 0:
        newresults.append(i)

print("Average Kappa score after a 5-fold cross validation: ", np.around(np.array(newresults).mean(), decimals=5))

sssscore = np.array(sssscore)
res = []
for scores in sssscore:
  for score in scores:
    res.append(score)

ll = np.array(llllabel)
res_label = []
for labels in ll:
  for label in labels:
    res_label.append(label)
res_label = np.array(res_label)

QWK = cohen_kappa_score(res_label, res, weights='quadratic')
print("Kappa score after a 5-fold cross validation: ", QWK)
# Out:
# create_dict
# Build model 0...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3239: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 200)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 200, 50)      247500      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 300)          421200      embedding_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 300)          0           lstm_1[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 325)          0           dropout_1[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            326         lambda_1[0][0]
# ==================================================================================================
# Total params: 669,026
# Trainable params: 669,026
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/50
#  - 23s - loss: 0.1052 - mean_absolute_error: 0.2645
# Epoch 2/50
#  - 20s - loss: 0.0640 - mean_absolute_error: 0.2005
# Epoch 3/50
#  - 20s - loss: 0.0476 - mean_absolute_error: 0.1712
# Epoch 4/50
#  - 21s - loss: 0.0425 - mean_absolute_error: 0.1631
# Epoch 5/50
#  - 21s - loss: 0.0393 - mean_absolute_error: 0.1573
# Epoch 6/50
#  - 22s - loss: 0.0386 - mean_absolute_error: 0.1558
# Epoch 7/50
#  - 23s - loss: 0.0377 - mean_absolute_error: 0.1541
# Epoch 8/50
#  - 23s - loss: 0.0373 - mean_absolute_error: 0.1530
# Epoch 9/50
#  - 23s - loss: 0.0364 - mean_absolute_error: 0.1504
# Epoch 10/50
#  - 23s - loss: 0.0353 - mean_absolute_error: 0.1499
# Epoch 11/50
#  - 23s - loss: 0.0345 - mean_absolute_error: 0.1459
# Epoch 12/50
#  - 23s - loss: 0.0341 - mean_absolute_error: 0.1453
# Epoch 13/50
#  - 23s - loss: 0.0330 - mean_absolute_error: 0.1411
# Epoch 14/50
#  - 23s - loss: 0.0314 - mean_absolute_error: 0.1395
# Epoch 15/50
#  - 23s - loss: 0.0316 - mean_absolute_error: 0.1386
# Epoch 16/50
#  - 23s - loss: 0.0306 - mean_absolute_error: 0.1372
# Epoch 17/50
#  - 22s - loss: 0.0297 - mean_absolute_error: 0.1357
# Epoch 18/50
#  - 23s - loss: 0.0290 - mean_absolute_error: 0.1331
# Epoch 19/50
#  - 22s - loss: 0.0280 - mean_absolute_error: 0.1292
# Epoch 20/50
#  - 20s - loss: 0.0269 - mean_absolute_error: 0.1298
# Epoch 21/50
#  - 21s - loss: 0.0265 - mean_absolute_error: 0.1271
# Epoch 22/50
#  - 21s - loss: 0.0247 - mean_absolute_error: 0.1230
# Epoch 23/50
#  - 21s - loss: 0.0254 - mean_absolute_error: 0.1244
# Epoch 24/50
#  - 21s - loss: 0.0232 - mean_absolute_error: 0.1194
# Epoch 25/50
#  - 21s - loss: 0.0223 - mean_absolute_error: 0.1159
# Epoch 26/50
#  - 21s - loss: 0.0222 - mean_absolute_error: 0.1164
# Epoch 27/50
#  - 21s - loss: 0.0211 - mean_absolute_error: 0.1132
# Epoch 28/50
#  - 21s - loss: 0.0193 - mean_absolute_error: 0.1083
# Epoch 29/50
#  - 21s - loss: 0.0192 - mean_absolute_error: 0.1088
# Epoch 30/50
#  - 21s - loss: 0.0183 - mean_absolute_error: 0.1053
# Epoch 31/50
#  - 21s - loss: 0.0183 - mean_absolute_error: 0.1046
# Epoch 32/50
#  - 20s - loss: 0.0173 - mean_absolute_error: 0.1023
# Epoch 33/50
#  - 21s - loss: 0.0170 - mean_absolute_error: 0.1010
# Epoch 34/50
#  - 21s - loss: 0.0166 - mean_absolute_error: 0.0997
# Epoch 35/50
#  - 21s - loss: 0.0163 - mean_absolute_error: 0.0993
# Epoch 36/50
#  - 21s - loss: 0.0148 - mean_absolute_error: 0.0938
# Epoch 37/50
#  - 21s - loss: 0.0154 - mean_absolute_error: 0.0966
# Epoch 38/50
#  - 21s - loss: 0.0145 - mean_absolute_error: 0.0939
# Epoch 39/50
#  - 20s - loss: 0.0136 - mean_absolute_error: 0.0903
# Epoch 40/50
#  - 20s - loss: 0.0132 - mean_absolute_error: 0.0890
# Epoch 41/50
#  - 21s - loss: 0.0131 - mean_absolute_error: 0.0886
# Epoch 42/50
#  - 21s - loss: 0.0127 - mean_absolute_error: 0.0885
# Epoch 43/50
#  - 21s - loss: 0.0137 - mean_absolute_error: 0.0900
# Epoch 44/50
#  - 21s - loss: 0.0119 - mean_absolute_error: 0.0854
# Epoch 45/50
#  - 21s - loss: 0.0117 - mean_absolute_error: 0.0842
# Epoch 46/50
#  - 20s - loss: 0.0102 - mean_absolute_error: 0.0779
# Epoch 47/50
#  - 20s - loss: 0.0103 - mean_absolute_error: 0.0791
# Epoch 48/50
#  - 21s - loss: 0.0108 - mean_absolute_error: 0.0804
# Epoch 49/50
#  - 20s - loss: 0.0102 - mean_absolute_error: 0.0785
# Epoch 50/50
#  - 21s - loss: 0.0099 - mean_absolute_error: 0.0770
# Kappa Score: 0.7915352660997412
# Build model 1...
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 200)          0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 200, 50)      247500      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 300)          421200      embedding_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 300)          0           lstm_2[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 325)          0           dropout_2[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            326         lambda_2[0][0]
# ==================================================================================================
# Total params: 669,026
# Trainable params: 669,026
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 22s - loss: 0.0880 - mean_absolute_error: 0.2424
# Epoch 2/50
#  - 20s - loss: 0.0530 - mean_absolute_error: 0.1834
# Epoch 3/50
#  - 21s - loss: 0.0431 - mean_absolute_error: 0.1651
# Epoch 4/50
#  - 21s - loss: 0.0389 - mean_absolute_error: 0.1568
# Epoch 5/50
#  - 21s - loss: 0.0381 - mean_absolute_error: 0.1567
# Epoch 6/50
#  - 21s - loss: 0.0373 - mean_absolute_error: 0.1530
# Epoch 7/50
#  - 21s - loss: 0.0369 - mean_absolute_error: 0.1534
# Epoch 8/50
#  - 21s - loss: 0.0354 - mean_absolute_error: 0.1501
# Epoch 9/50
#  - 21s - loss: 0.0349 - mean_absolute_error: 0.1475
# Epoch 10/50
#  - 21s - loss: 0.0342 - mean_absolute_error: 0.1471
# Epoch 11/50
#  - 21s - loss: 0.0328 - mean_absolute_error: 0.1443
# Epoch 12/50
#  - 20s - loss: 0.0328 - mean_absolute_error: 0.1439
# Epoch 13/50
#  - 21s - loss: 0.0323 - mean_absolute_error: 0.1442
# Epoch 14/50
#  - 21s - loss: 0.0319 - mean_absolute_error: 0.1411
# Epoch 15/50
#  - 21s - loss: 0.0303 - mean_absolute_error: 0.1378
# Epoch 16/50
#  - 21s - loss: 0.0297 - mean_absolute_error: 0.1353
# Epoch 17/50
#  - 20s - loss: 0.0289 - mean_absolute_error: 0.1333
# Epoch 18/50
#  - 21s - loss: 0.0277 - mean_absolute_error: 0.1307
# Epoch 19/50
#  - 21s - loss: 0.0271 - mean_absolute_error: 0.1283
# Epoch 20/50
#  - 20s - loss: 0.0265 - mean_absolute_error: 0.1288
# Epoch 21/50
#  - 20s - loss: 0.0253 - mean_absolute_error: 0.1250
# Epoch 22/50
#  - 21s - loss: 0.0246 - mean_absolute_error: 0.1228
# Epoch 23/50
#  - 21s - loss: 0.0243 - mean_absolute_error: 0.1231
# Epoch 24/50
#  - 21s - loss: 0.0226 - mean_absolute_error: 0.1178
# Epoch 25/50
#  - 21s - loss: 0.0222 - mean_absolute_error: 0.1163
# Epoch 26/50
#  - 21s - loss: 0.0202 - mean_absolute_error: 0.1112
# Epoch 27/50
#  - 21s - loss: 0.0190 - mean_absolute_error: 0.1082
# Epoch 28/50
#  - 20s - loss: 0.0187 - mean_absolute_error: 0.1072
# Epoch 29/50
#  - 21s - loss: 0.0178 - mean_absolute_error: 0.1050
# Epoch 30/50
#  - 21s - loss: 0.0173 - mean_absolute_error: 0.1032
# Epoch 31/50
#  - 20s - loss: 0.0176 - mean_absolute_error: 0.1038
# Epoch 32/50
#  - 20s - loss: 0.0158 - mean_absolute_error: 0.0973
# Epoch 33/50
#  - 20s - loss: 0.0160 - mean_absolute_error: 0.0994
# Epoch 34/50
#  - 20s - loss: 0.0151 - mean_absolute_error: 0.0950
# Epoch 35/50
#  - 20s - loss: 0.0147 - mean_absolute_error: 0.0940
# Epoch 36/50
#  - 20s - loss: 0.0139 - mean_absolute_error: 0.0905
# Epoch 37/50
#  - 21s - loss: 0.0140 - mean_absolute_error: 0.0920
# Epoch 38/50
#  - 21s - loss: 0.0131 - mean_absolute_error: 0.0877
# Epoch 39/50
#  - 20s - loss: 0.0125 - mean_absolute_error: 0.0874
# Epoch 40/50
#  - 21s - loss: 0.0120 - mean_absolute_error: 0.0853
# Epoch 41/50
#  - 21s - loss: 0.0122 - mean_absolute_error: 0.0848
# Epoch 42/50
#  - 20s - loss: 0.0113 - mean_absolute_error: 0.0830
# Epoch 43/50
#  - 20s - loss: 0.0112 - mean_absolute_error: 0.0822
# Epoch 44/50
#  - 21s - loss: 0.0104 - mean_absolute_error: 0.0795
# Epoch 45/50
#  - 21s - loss: 0.0106 - mean_absolute_error: 0.0791
# Epoch 46/50
#  - 21s - loss: 0.0106 - mean_absolute_error: 0.0794
# Epoch 47/50
#  - 21s - loss: 0.0105 - mean_absolute_error: 0.0799
# Epoch 48/50
#  - 21s - loss: 0.0095 - mean_absolute_error: 0.0759
# Epoch 49/50
#  - 21s - loss: 0.0100 - mean_absolute_error: 0.0778
# Epoch 50/50
#  - 21s - loss: 0.0090 - mean_absolute_error: 0.0731
# Kappa Score: 0.7434877254600666
# Build model 2...
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 200)          0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 200, 50)      247500      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 300)          421200      embedding_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 300)          0           lstm_3[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 325)          0           dropout_3[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            326         lambda_3[0][0]
# ==================================================================================================
# Total params: 669,026
# Trainable params: 669,026
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 21s - loss: 0.1170 - mean_absolute_error: 0.2857
# Epoch 2/50
#  - 21s - loss: 0.0663 - mean_absolute_error: 0.2077
# Epoch 3/50
#  - 21s - loss: 0.0484 - mean_absolute_error: 0.1731
# Epoch 4/50
#  - 21s - loss: 0.0419 - mean_absolute_error: 0.1618
# Epoch 5/50
#  - 21s - loss: 0.0389 - mean_absolute_error: 0.1564
# Epoch 6/50
#  - 21s - loss: 0.0382 - mean_absolute_error: 0.1544
# Epoch 7/50
#  - 21s - loss: 0.0374 - mean_absolute_error: 0.1542
# Epoch 8/50
#  - 21s - loss: 0.0363 - mean_absolute_error: 0.1509
# Epoch 9/50
#  - 21s - loss: 0.0358 - mean_absolute_error: 0.1511
# Epoch 10/50
#  - 21s - loss: 0.0346 - mean_absolute_error: 0.1469
# Epoch 11/50
#  - 21s - loss: 0.0349 - mean_absolute_error: 0.1468
# Epoch 12/50
#  - 21s - loss: 0.0342 - mean_absolute_error: 0.1469
# Epoch 13/50
#  - 21s - loss: 0.0330 - mean_absolute_error: 0.1446
# Epoch 14/50
#  - 21s - loss: 0.0306 - mean_absolute_error: 0.1382
# Epoch 15/50
#  - 21s - loss: 0.0313 - mean_absolute_error: 0.1408
# Epoch 16/50
#  - 21s - loss: 0.0302 - mean_absolute_error: 0.1383
# Epoch 17/50
#  - 21s - loss: 0.0296 - mean_absolute_error: 0.1349
# Epoch 18/50
#  - 21s - loss: 0.0281 - mean_absolute_error: 0.1320
# Epoch 19/50
#  - 21s - loss: 0.0274 - mean_absolute_error: 0.1303
# Epoch 20/50
#  - 21s - loss: 0.0265 - mean_absolute_error: 0.1288
# Epoch 21/50
#  - 21s - loss: 0.0246 - mean_absolute_error: 0.1241
# Epoch 22/50
#  - 21s - loss: 0.0251 - mean_absolute_error: 0.1247
# Epoch 23/50
#  - 21s - loss: 0.0242 - mean_absolute_error: 0.1211
# Epoch 24/50
#  - 21s - loss: 0.0228 - mean_absolute_error: 0.1192
# Epoch 25/50
#  - 21s - loss: 0.0232 - mean_absolute_error: 0.1192
# Epoch 26/50
#  - 21s - loss: 0.0225 - mean_absolute_error: 0.1168
# Epoch 27/50
#  - 21s - loss: 0.0217 - mean_absolute_error: 0.1153
# Epoch 28/50
#  - 21s - loss: 0.0207 - mean_absolute_error: 0.1126
# Epoch 29/50
#  - 21s - loss: 0.0194 - mean_absolute_error: 0.1090
# Epoch 30/50
#  - 21s - loss: 0.0186 - mean_absolute_error: 0.1072
# Epoch 31/50
#  - 21s - loss: 0.0187 - mean_absolute_error: 0.1061
# Epoch 32/50
#  - 22s - loss: 0.0169 - mean_absolute_error: 0.1028
# Epoch 33/50
#  - 21s - loss: 0.0167 - mean_absolute_error: 0.0992
# Epoch 34/50
#  - 21s - loss: 0.0170 - mean_absolute_error: 0.1012
# Epoch 35/50
#  - 21s - loss: 0.0152 - mean_absolute_error: 0.0959
# Epoch 36/50
#  - 21s - loss: 0.0156 - mean_absolute_error: 0.0957
# Epoch 37/50
#  - 21s - loss: 0.0151 - mean_absolute_error: 0.0955
# Epoch 38/50
#  - 21s - loss: 0.0130 - mean_absolute_error: 0.0889
# Epoch 39/50
#  - 21s - loss: 0.0137 - mean_absolute_error: 0.0900
# Epoch 40/50
#  - 21s - loss: 0.0137 - mean_absolute_error: 0.0907
# Epoch 41/50
#  - 20s - loss: 0.0133 - mean_absolute_error: 0.0888
# Epoch 42/50
#  - 21s - loss: 0.0128 - mean_absolute_error: 0.0886
# Epoch 43/50
#  - 20s - loss: 0.0123 - mean_absolute_error: 0.0847
# Epoch 44/50
#  - 20s - loss: 0.0119 - mean_absolute_error: 0.0832
# Epoch 45/50
#  - 20s - loss: 0.0112 - mean_absolute_error: 0.0812
# Epoch 46/50
#  - 21s - loss: 0.0111 - mean_absolute_error: 0.0806
# Epoch 47/50
#  - 21s - loss: 0.0105 - mean_absolute_error: 0.0779
# Epoch 48/50
#  - 20s - loss: 0.0104 - mean_absolute_error: 0.0781
# Epoch 49/50
#  - 21s - loss: 0.0100 - mean_absolute_error: 0.0769
# Epoch 50/50
#  - 21s - loss: 0.0093 - mean_absolute_error: 0.0745
# Kappa Score: 0.7510411208251744
# Build model 3...
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 200)          0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 200, 50)      247500      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 300)          421200      embedding_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 300)          0           lstm_4[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 325)          0           dropout_4[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            326         lambda_4[0][0]
# ==================================================================================================
# Total params: 669,026
# Trainable params: 669,026
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 22s - loss: 0.1388 - mean_absolute_error: 0.3106
# Epoch 2/50
#  - 21s - loss: 0.0765 - mean_absolute_error: 0.2227
# Epoch 3/50
#  - 21s - loss: 0.0504 - mean_absolute_error: 0.1781
# Epoch 4/50
#  - 21s - loss: 0.0442 - mean_absolute_error: 0.1682
# Epoch 5/50
#  - 21s - loss: 0.0406 - mean_absolute_error: 0.1615
# Epoch 6/50
#  - 21s - loss: 0.0395 - mean_absolute_error: 0.1596
# Epoch 7/50
#  - 21s - loss: 0.0368 - mean_absolute_error: 0.1536
# Epoch 8/50
#  - 21s - loss: 0.0361 - mean_absolute_error: 0.1526
# Epoch 9/50
#  - 21s - loss: 0.0351 - mean_absolute_error: 0.1490
# Epoch 10/50
#  - 21s - loss: 0.0349 - mean_absolute_error: 0.1489
# Epoch 11/50
#  - 21s - loss: 0.0343 - mean_absolute_error: 0.1490
# Epoch 12/50
#  - 22s - loss: 0.0326 - mean_absolute_error: 0.1418
# Epoch 13/50
#  - 21s - loss: 0.0312 - mean_absolute_error: 0.1420
# Epoch 14/50
#  - 21s - loss: 0.0321 - mean_absolute_error: 0.1429
# Epoch 15/50
#  - 21s - loss: 0.0296 - mean_absolute_error: 0.1381
# Epoch 16/50
#  - 21s - loss: 0.0299 - mean_absolute_error: 0.1376
# Epoch 17/50
#  - 21s - loss: 0.0276 - mean_absolute_error: 0.1321
# Epoch 18/50
#  - 21s - loss: 0.0270 - mean_absolute_error: 0.1309
# Epoch 19/50
#  - 21s - loss: 0.0275 - mean_absolute_error: 0.1337
# Epoch 20/50
#  - 21s - loss: 0.0256 - mean_absolute_error: 0.1266
# Epoch 21/50
#  - 21s - loss: 0.0237 - mean_absolute_error: 0.1242
# Epoch 22/50
#  - 22s - loss: 0.0225 - mean_absolute_error: 0.1198
# Epoch 23/50
#  - 22s - loss: 0.0240 - mean_absolute_error: 0.1216
# Epoch 24/50
#  - 21s - loss: 0.0223 - mean_absolute_error: 0.1193
# Epoch 25/50
#  - 21s - loss: 0.0207 - mean_absolute_error: 0.1145
# Epoch 26/50
#  - 22s - loss: 0.0213 - mean_absolute_error: 0.1147
# Epoch 27/50
#  - 22s - loss: 0.0186 - mean_absolute_error: 0.1085
# Epoch 28/50
#  - 21s - loss: 0.0197 - mean_absolute_error: 0.1119
# Epoch 29/50
#  - 21s - loss: 0.0188 - mean_absolute_error: 0.1111
# Epoch 30/50
#  - 22s - loss: 0.0182 - mean_absolute_error: 0.1077
# Epoch 31/50
#  - 21s - loss: 0.0175 - mean_absolute_error: 0.1053
# Epoch 32/50
#  - 22s - loss: 0.0165 - mean_absolute_error: 0.1015
# Epoch 33/50
#  - 22s - loss: 0.0169 - mean_absolute_error: 0.1017
# Epoch 34/50
#  - 21s - loss: 0.0148 - mean_absolute_error: 0.0957
# Epoch 35/50
#  - 21s - loss: 0.0161 - mean_absolute_error: 0.0994
# Epoch 36/50
#  - 22s - loss: 0.0143 - mean_absolute_error: 0.0940
# Epoch 37/50
#  - 22s - loss: 0.0139 - mean_absolute_error: 0.0933
# Epoch 38/50
#  - 22s - loss: 0.0131 - mean_absolute_error: 0.0886
# Epoch 39/50
#  - 22s - loss: 0.0139 - mean_absolute_error: 0.0925
# Epoch 40/50
#  - 22s - loss: 0.0129 - mean_absolute_error: 0.0881
# Epoch 41/50
#  - 22s - loss: 0.0127 - mean_absolute_error: 0.0870
# Epoch 42/50
#  - 21s - loss: 0.0120 - mean_absolute_error: 0.0856
# Epoch 43/50
#  - 21s - loss: 0.0119 - mean_absolute_error: 0.0847
# Epoch 44/50
#  - 21s - loss: 0.0117 - mean_absolute_error: 0.0844
# Epoch 45/50
#  - 21s - loss: 0.0117 - mean_absolute_error: 0.0843
# Epoch 46/50
#  - 21s - loss: 0.0110 - mean_absolute_error: 0.0798
# Epoch 47/50
#  - 21s - loss: 0.0103 - mean_absolute_error: 0.0793
# Epoch 48/50
#  - 21s - loss: 0.0100 - mean_absolute_error: 0.0780
# Epoch 49/50
#  - 21s - loss: 0.0096 - mean_absolute_error: 0.0769
# Epoch 50/50
#  - 21s - loss: 0.0092 - mean_absolute_error: 0.0755
# Kappa Score: 0.7750515020139593
# Build model 4...
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 200)          0
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 200, 50)      247500      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 300)          421200      embedding_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 300)          0           lstm_5[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 325)          0           dropout_5[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            326         lambda_5[0][0]
# ==================================================================================================
# Total params: 669,026
# Trainable params: 669,026
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 22s - loss: 0.0587 - mean_absolute_error: 0.1932
# Epoch 2/50
#  - 21s - loss: 0.0440 - mean_absolute_error: 0.1665
# Epoch 3/50
#  - 21s - loss: 0.0422 - mean_absolute_error: 0.1620
# Epoch 4/50
#  - 21s - loss: 0.0402 - mean_absolute_error: 0.1587
# Epoch 5/50
#  - 21s - loss: 0.0389 - mean_absolute_error: 0.1566
# Epoch 6/50
#  - 21s - loss: 0.0375 - mean_absolute_error: 0.1520
# Epoch 7/50
#  - 21s - loss: 0.0374 - mean_absolute_error: 0.1527
# Epoch 8/50
#  - 21s - loss: 0.0372 - mean_absolute_error: 0.1517
# Epoch 9/50
#  - 21s - loss: 0.0357 - mean_absolute_error: 0.1487
# Epoch 10/50
#  - 21s - loss: 0.0354 - mean_absolute_error: 0.1505
# Epoch 11/50
#  - 21s - loss: 0.0338 - mean_absolute_error: 0.1444
# Epoch 12/50
#  - 21s - loss: 0.0334 - mean_absolute_error: 0.1442
# Epoch 13/50
#  - 21s - loss: 0.0322 - mean_absolute_error: 0.1414
# Epoch 14/50
#  - 21s - loss: 0.0331 - mean_absolute_error: 0.1430
# Epoch 15/50
#  - 21s - loss: 0.0312 - mean_absolute_error: 0.1393
# Epoch 16/50
#  - 21s - loss: 0.0295 - mean_absolute_error: 0.1352
# Epoch 17/50
#  - 21s - loss: 0.0295 - mean_absolute_error: 0.1354
# Epoch 18/50
#  - 21s - loss: 0.0279 - mean_absolute_error: 0.1308
# Epoch 19/50
#  - 21s - loss: 0.0274 - mean_absolute_error: 0.1287
# Epoch 20/50
#  - 21s - loss: 0.0268 - mean_absolute_error: 0.1283
# Epoch 21/50
#  - 21s - loss: 0.0254 - mean_absolute_error: 0.1253
# Epoch 22/50
#  - 20s - loss: 0.0252 - mean_absolute_error: 0.1241
# Epoch 23/50
#  - 20s - loss: 0.0221 - mean_absolute_error: 0.1174
# Epoch 24/50
#  - 21s - loss: 0.0223 - mean_absolute_error: 0.1163
# Epoch 25/50
#  - 21s - loss: 0.0228 - mean_absolute_error: 0.1183
# Epoch 26/50
#  - 20s - loss: 0.0206 - mean_absolute_error: 0.1114
# Epoch 27/50
#  - 20s - loss: 0.0201 - mean_absolute_error: 0.1101
# Epoch 28/50
#  - 20s - loss: 0.0187 - mean_absolute_error: 0.1082
# Epoch 29/50
#  - 21s - loss: 0.0182 - mean_absolute_error: 0.1043
# Epoch 30/50
#  - 20s - loss: 0.0175 - mean_absolute_error: 0.1035
# Epoch 31/50
#  - 20s - loss: 0.0164 - mean_absolute_error: 0.0997
# Epoch 32/50
#  - 20s - loss: 0.0159 - mean_absolute_error: 0.0980
# Epoch 33/50
#  - 21s - loss: 0.0159 - mean_absolute_error: 0.0998
# Epoch 34/50
#  - 20s - loss: 0.0148 - mean_absolute_error: 0.0961
# Epoch 35/50
#  - 21s - loss: 0.0141 - mean_absolute_error: 0.0924
# Epoch 36/50
#  - 20s - loss: 0.0145 - mean_absolute_error: 0.0924
# Epoch 37/50
#  - 21s - loss: 0.0136 - mean_absolute_error: 0.0902
# Epoch 38/50
#  - 20s - loss: 0.0127 - mean_absolute_error: 0.0873
# Epoch 39/50
#  - 21s - loss: 0.0122 - mean_absolute_error: 0.0863
# Epoch 40/50
#  - 20s - loss: 0.0116 - mean_absolute_error: 0.0833
# Epoch 41/50
#  - 21s - loss: 0.0117 - mean_absolute_error: 0.0832
# Epoch 42/50
#  - 20s - loss: 0.0105 - mean_absolute_error: 0.0803
# Epoch 43/50
#  - 20s - loss: 0.0107 - mean_absolute_error: 0.0793
# Epoch 44/50
#  - 20s - loss: 0.0104 - mean_absolute_error: 0.0795
# Epoch 45/50
#  - 21s - loss: 0.0104 - mean_absolute_error: 0.0782
# Epoch 46/50
#  - 20s - loss: 0.0096 - mean_absolute_error: 0.0773
# Epoch 47/50
#  - 20s - loss: 0.0102 - mean_absolute_error: 0.0782
# Epoch 48/50
#  - 20s - loss: 0.0092 - mean_absolute_error: 0.0743
# Epoch 49/50
#  - 21s - loss: 0.0093 - mean_absolute_error: 0.0755
# Epoch 50/50
#  - 21s - loss: 0.0087 - mean_absolute_error: 0.0715
# Kappa Score: 0.7407396974733107
# Average Kappa score after a 5-fold cross validation:  0.76504
# Kappa score after a 5-fold cross validation:  0.7609914731643226
