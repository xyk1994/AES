# %%
prompt_id = 3
model_name = '1layer+BERT+Overall'
# '1layer+BERT+Overall', '1layerMoT+BERT+Overall'

# %%
import os
import pprint
import tensorflow as tf

if 'COLAB_TPU_ADDR' not in os.environ:
  print('ERROR: Not connected to a TPU runtime')
else:
  tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
  print ('TPU address is', tpu_address)

  with tf.Session(tpu_address) as session:
    devices = session.list_devices()

  print('TPU devices:')
  pprint.pprint(devices)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# ERROR: Not connected to a TPU runtime

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/My Drive/AES謝"
os.chdir(path)
# os.listdir(path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import argparse
import nltk
import tensorflow as tf
from keras.models import Model
from keras import layers
from keras.layers import Input, concatenate, Embedding, LSTM, Dense, Lambda
from keras.engine.topology import Layer
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
import re
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
import keras.backend as K
from sklearn.model_selection import KFold
from sklearn.metrics import cohen_kappa_score
from sklearn.preprocessing import StandardScaler
from keras.preprocessing.sequence import pad_sequences
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')

nltk.download('stopwords')
nltk.download('punkt')
# stopwords, punkt,
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Mean Over Time
class TemporalMean(Layer):
  def __init__(self, **kwargs):
      self.supports_masking = True
      super(TemporalMean, self).__init__(**kwargs)

  def compute_mask(self, input, input_mask=None):
      # do not pass the mask to the next layers
      return None

  def call(self, x, mask=None):
      if mask is not None:
          # mask (batch, time)
          mask = K.cast(mask, K.floatx())
          # mask (batch, x_dim, time)
          mask = K.repeat(mask, x.shape[-1])
          # mask (batch, time, x_dim)
          mask = tf.transpose(mask, [0,2,1])
          x = x * mask
      return K.sum(x, axis=1) / K.sum(mask, axis=1)

  def compute_output_shape(self, input_shape):
      # remove temporal dimension
      return (input_shape[0], input_shape[2])

def essay_to_wordlist(essay_v, remove_stopwords):
    """Remove the tagged labels and word tokenize the sentence."""
    essay_v = re.sub("[^a-zA-Z]", " ", essay_v)
    words = essay_v.lower().split()
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    return (words)

def get_clean_essays(Text):
    clean_essays = []
    for essay in Text:
        clean_essays.append(essay_to_wordlist(essay, remove_stopwords=False))
    return clean_essays

def create_dict(text):
    print("create_dict")
    word_index = {}
    word_index['xieyikuan'] = 0
    for sentence in text:
        for word in sentence:
            if word not in word_index:
                word_index[word] = len(word_index)
    word_index['unk'] = len(word_index)
    return word_index

def essay_to_index(essays, word_index):
    Essays = []
    for essay in essays:
        sentence = []
        for sent in essay:
            words = []
            for word in sent:
                words.append(word_index[word])
            sentence.append(words)
        Essays.append(sentence)
    return Essays

def essay_to_index2(essays, word_index):
    Essays = []
    for essay in essays:
        words = []
        for word in essay:
            words.append(word_index[word])
        Essays.append(words)
    return Essays

def get_embeddings_index():
    embeddings_index = {}
    f = open('glove.6B.50d.txt', 'r', encoding='UTF-8')
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.array(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    f.close()
    return embeddings_index

def embeddings_matrix(embeddings_index, word_index, embedding_dim):
    nb_words = len(word_index)
    embedding_matrix = np.zeros((nb_words + 1, embedding_dim))
    for word, i in word_index.items():
        if i > nb_words:
            continue
        embeddings_vector = embeddings_index.get(word)
        if embeddings_vector is not None:
            embedding_matrix[i] = embeddings_vector
        if embeddings_vector is None:
            embedding_matrix[i] = embeddings_index.get('unk')
    return embedding_matrix

# %%
csv_input = pd.read_csv(filepath_or_buffer="data_feature/set"+str(prompt_id)+"_feature(26).tsv", delimiter="\t", engine="python", error_bad_lines=False)

Text = csv_input['essay']
Score = csv_input['domain1_score']
Label = csv_input['domain1_score']

# --------
if prompt_id == 1:
    Score = (Score - 2) / 10      # set_1     范围 2-12
elif prompt_id == 2:
    Score = (Score - 1) / 5       # set_2     范围 1-6
elif prompt_id == 3 or prompt_id == 4:
    Score = Score / 3           # set_3,4   范围 0-3
elif prompt_id == 5 or prompt_id == 6:
    Score = Score / 4           # set_5,6   范围 0-4
elif prompt_id == 7:
    Score = Score / 30          # set_7     范围 0-30
elif prompt_id == 8:
    Score = Score / 60          # set_8     范围 0-60

# get Overall Feature
overall_feature = csv_input[['word_count', 'avg_word_len', 'sentence_count', 'avg_sentence_len', 'lemma_count', 'noun_count', 'adj_count', 'adv_count', 'verb_count', 'cc_count',
                             'syllable_count', 'flesch_reading_ease', 'smog_index', 'flesch_kincaid_grade', 'coleman_liau_index', 'automated_readability_index',
                             'dale_chall_readability_score', 'difficult_words', 'linsear_write_formula',
                             'gunning_fog', 'spelling_errors', 'exc_count', 'que_count', 'comma_count', 'stopwords_num']]
# overall_feature = np.array(np.sqrt(overall_feature))
overall_feature = np.array(overall_feature)
num_feature = 25
where_are_nan = np.isnan(overall_feature)
where_are_inf = np.isinf(overall_feature)
overall_feature[where_are_nan] = 0
overall_feature[where_are_inf] = 0
# standardized
stdsc = StandardScaler()
overall_feature = stdsc.fit_transform(overall_feature)
 
# Get the Second Last Layer of BERT
bert = pd.read_csv(filepath_or_buffer="fine_tuning_out/essay_set_"+str(prompt_id)+"_output.tsv", delimiter="\t", engine="python", error_bad_lines=False)
bert = np.array(bert)
max_seq_length = len(bert[0])

# 做字典
clean_essays = get_clean_essays(Text)
word_index = create_dict(clean_essays)

# 做分句
text = np.array(Text)
# print(text)
a = []
for essay in text:
    a.append(sent_tokenize(essay))
texts = np.array(a)

# 做分词
essays = []
for essay in Text:
  essay_idx = essay_to_wordlist(essay, remove_stopwords=False)
  essays.append(essay_idx)
essays = np.array(essays)

Essays = essay_to_index2(clean_essays, word_index)
Essays = np.array(Essays)

if prompt_id == 1:
    max_essay_length = 600
elif prompt_id == 2:
    max_essay_length = 700
elif prompt_id == 3:
    max_essay_length = 256
elif prompt_id == 4:
    max_essay_length = 200
elif prompt_id == 5:
    max_essay_length = 256
elif prompt_id == 6:
    max_essay_length = 256
elif prompt_id == 7:
    max_essay_length = 350
elif prompt_id == 8:
    max_essay_length = 870

essay_pad = pad_sequences(Essays, maxlen=max_essay_length)

embeddings_index = get_embeddings_index()
embeddings_matrix = embeddings_matrix(embeddings_index, word_index, embedding_dim=50)

# 记录成绩
results = []
score_predict_list = []
sssscore = []
llllabel = []
newresults = []
cv = KFold(n_splits=5, shuffle=True, random_state=10)
count = 0
for train, test in cv.split(essay_pad):
    text_train, text_test = essay_pad[train], essay_pad[test]
    label_train, label_test = Score.iloc[train], Score.iloc[test]
    score_train, score_test = Label.iloc[train], Label.iloc[test]
    overall_train, overall_test = overall_feature[train], overall_feature[test]
    bert_train, bert_test = bert[train], bert[test]

    # print('Build model '+str(count)+'...')
    # count += 1

    # -------
    text_input = Input(shape=(max_essay_length, ), name='text_input')
    overall_feature_input = Input(shape=(num_feature,), name='overall_feature_input')
    bert_input = Input(shape=(max_seq_length,), name='bert_input')

    embedding_layer = Embedding(input_dim=len(word_index) + 1,
                                output_dim=50,
                                weights=[embeddings_matrix],
                                input_length=max_essay_length,
                                trainable=True,
                                mask_zero=True)
    x = embedding_layer(text_input)  
    if model_name == "1layer+BERT+Overall":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)
    elif model_name == "1layerMoT+BERT+Overall":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)
      x = TemporalMean()(x)
    x = layers.Dropout(0.5)(x)
    concat_layer = Lambda(concatenate)([x, overall_feature_input, bert_input])
    output = Dense(1, activation='sigmoid')(concat_layer)

    model = Model(inputs=[text_input, overall_feature_input, bert_input], outputs=output)
    # -------

    model.summary()
    model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001, decay=1e-6), metrics=['mean_absolute_error'])
    model.fit([text_train, overall_train, bert_train], label_train, batch_size=32, epochs=50, verbose=2)

    score_predict = model.predict([text_test, overall_test, bert_test])
    if prompt_id == 1:
        score_predict = score_predict*10+2
    elif prompt_id == 2:
        score_predict = score_predict*5+1
    elif prompt_id == 3:
        score_predict = score_predict*3
    elif prompt_id == 4:
        score_predict = score_predict*3
    elif prompt_id == 5:
        score_predict = score_predict*4
    elif prompt_id == 6:
        score_predict = score_predict*4
    elif prompt_id == 7:
        score_predict = score_predict*30
    elif prompt_id == 8:
        score_predict = score_predict*60

    score_predict = np.around(score_predict)

    sssscore.append(score_predict)
    llllabel.append(score_test)

    result = cohen_kappa_score(score_test.values, score_predict, weights='quadratic')
    print("Kappa Score: {}".format(result))
    results.append(result)
    for i in results:
      if i != 0:
        newresults.append(i)

print("Average Kappa score after a 5-fold cross validation: ", np.around(np.array(newresults).mean(), decimals=5))

sssscore = np.array(sssscore)
res = []
for scores in sssscore:
  for score in scores:
    res.append(score)

ll = np.array(llllabel)
res_label = []
for labels in ll:
  for label in labels:
    res_label.append(label)
res_label = np.array(res_label)

QWK = cohen_kappa_score(res_label, res, weights='quadratic')
print("Kappa score after a 5-fold cross validation: ", QWK)
# Out:
# create_dict
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3239: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 256)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 256, 50)      317500      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 300)          421200      embedding_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 300)          0           lstm_1[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# bert_input (InputLayer)         (None, 768)          0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1093)         0           dropout_1[0][0]
#                                                                  overall_feature_input[0][0]
#                                                                  bert_input[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            1094        lambda_1[0][0]
# ==================================================================================================
# Total params: 739,794
# Trainable params: 739,794
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/50
#  - 30s - loss: 0.0397 - mean_absolute_error: 0.1549
# Epoch 2/50
#  - 28s - loss: 0.0263 - mean_absolute_error: 0.1249
# Epoch 3/50
#  - 27s - loss: 0.0250 - mean_absolute_error: 0.1233
# Epoch 4/50
#  - 28s - loss: 0.0242 - mean_absolute_error: 0.1209
# Epoch 5/50
#  - 28s - loss: 0.0230 - mean_absolute_error: 0.1168
# Epoch 6/50
#  - 28s - loss: 0.0213 - mean_absolute_error: 0.1117
# Epoch 7/50
#  - 28s - loss: 0.0202 - mean_absolute_error: 0.1069
# Epoch 8/50
#  - 27s - loss: 0.0232 - mean_absolute_error: 0.1197
# Epoch 9/50
#  - 25s - loss: 0.0196 - mean_absolute_error: 0.1073
# Epoch 10/50
#  - 25s - loss: 0.0188 - mean_absolute_error: 0.1039
# Epoch 11/50
#  - 25s - loss: 0.0182 - mean_absolute_error: 0.1016
# Epoch 12/50
#  - 25s - loss: 0.0180 - mean_absolute_error: 0.1014
# Epoch 13/50
#  - 26s - loss: 0.0172 - mean_absolute_error: 0.0992
# Epoch 14/50
#  - 25s - loss: 0.0173 - mean_absolute_error: 0.0989
# Epoch 15/50
#  - 25s - loss: 0.0165 - mean_absolute_error: 0.0968
# Epoch 16/50
#  - 25s - loss: 0.0166 - mean_absolute_error: 0.0980
# Epoch 17/50
#  - 25s - loss: 0.0156 - mean_absolute_error: 0.0943
# Epoch 18/50
#  - 25s - loss: 0.0157 - mean_absolute_error: 0.0939
# Epoch 19/50
#  - 25s - loss: 0.0153 - mean_absolute_error: 0.0945
# Epoch 20/50
#  - 25s - loss: 0.0142 - mean_absolute_error: 0.0915
# Epoch 21/50
#  - 25s - loss: 0.0142 - mean_absolute_error: 0.0919
# Epoch 22/50
#  - 25s - loss: 0.0131 - mean_absolute_error: 0.0882
# Epoch 23/50
#  - 25s - loss: 0.0128 - mean_absolute_error: 0.0865
# Epoch 24/50
#  - 25s - loss: 0.0127 - mean_absolute_error: 0.0862
# Epoch 25/50
#  - 25s - loss: 0.0124 - mean_absolute_error: 0.0858
# Epoch 26/50
#  - 26s - loss: 0.0124 - mean_absolute_error: 0.0856
# Epoch 27/50
#  - 25s - loss: 0.0125 - mean_absolute_error: 0.0869
# Epoch 28/50
#  - 25s - loss: 0.0108 - mean_absolute_error: 0.0804
# Epoch 29/50
#  - 25s - loss: 0.0110 - mean_absolute_error: 0.0816
# Epoch 30/50
#  - 25s - loss: 0.0101 - mean_absolute_error: 0.0773
# Epoch 31/50
#  - 25s - loss: 0.0100 - mean_absolute_error: 0.0771
# Epoch 32/50
#  - 25s - loss: 0.0093 - mean_absolute_error: 0.0740
# Epoch 33/50
#  - 25s - loss: 0.0093 - mean_absolute_error: 0.0758
# Epoch 34/50
#  - 25s - loss: 0.0084 - mean_absolute_error: 0.0724
# Epoch 35/50
#  - 25s - loss: 0.0090 - mean_absolute_error: 0.0739
# Epoch 36/50
#  - 25s - loss: 0.0082 - mean_absolute_error: 0.0713
# Epoch 37/50
#  - 25s - loss: 0.0076 - mean_absolute_error: 0.0679
# Epoch 38/50
#  - 26s - loss: 0.0071 - mean_absolute_error: 0.0659
# Epoch 39/50
#  - 25s - loss: 0.0068 - mean_absolute_error: 0.0651
# Epoch 40/50
#  - 25s - loss: 0.0069 - mean_absolute_error: 0.0654
# Epoch 41/50
#  - 25s - loss: 0.0067 - mean_absolute_error: 0.0651
# Epoch 42/50
#  - 25s - loss: 0.0061 - mean_absolute_error: 0.0608
# Epoch 43/50
#  - 25s - loss: 0.0059 - mean_absolute_error: 0.0602
# Epoch 44/50
#  - 25s - loss: 0.0059 - mean_absolute_error: 0.0607
# Epoch 45/50
#  - 25s - loss: 0.0054 - mean_absolute_error: 0.0596
# Epoch 46/50
#  - 25s - loss: 0.0053 - mean_absolute_error: 0.0576
# Epoch 47/50
#  - 25s - loss: 0.0051 - mean_absolute_error: 0.0563
# Epoch 48/50
#  - 25s - loss: 0.0053 - mean_absolute_error: 0.0569
# Epoch 49/50
#  - 25s - loss: 0.0050 - mean_absolute_error: 0.0560
# Epoch 50/50
#  - 26s - loss: 0.0046 - mean_absolute_error: 0.0545
# Kappa Score: 0.7601275622212464
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 256)          0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 256, 50)      317500      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 300)          421200      embedding_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 300)          0           lstm_2[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# bert_input (InputLayer)         (None, 768)          0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 1093)         0           dropout_2[0][0]
#                                                                  overall_feature_input[0][0]
#                                                                  bert_input[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            1094        lambda_2[0][0]
# ==================================================================================================
# Total params: 739,794
# Trainable params: 739,794
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 26s - loss: 0.0441 - mean_absolute_error: 0.1646
# Epoch 2/50
#  - 25s - loss: 0.0287 - mean_absolute_error: 0.1307
# Epoch 3/50
#  - 26s - loss: 0.0268 - mean_absolute_error: 0.1271
# Epoch 4/50
#  - 25s - loss: 0.0243 - mean_absolute_error: 0.1202
# Epoch 5/50
#  - 25s - loss: 0.0231 - mean_absolute_error: 0.1159
# Epoch 6/50
#  - 25s - loss: 0.0226 - mean_absolute_error: 0.1140
# Epoch 7/50
#  - 25s - loss: 0.0219 - mean_absolute_error: 0.1121
# Epoch 8/50
#  - 25s - loss: 0.0218 - mean_absolute_error: 0.1125
# Epoch 9/50
#  - 25s - loss: 0.0206 - mean_absolute_error: 0.1094
# Epoch 10/50
#  - 25s - loss: 0.0203 - mean_absolute_error: 0.1077
# Epoch 11/50
#  - 25s - loss: 0.0195 - mean_absolute_error: 0.1042
# Epoch 12/50
#  - 26s - loss: 0.0190 - mean_absolute_error: 0.1030
# Epoch 13/50
#  - 25s - loss: 0.0180 - mean_absolute_error: 0.1003
# Epoch 14/50
#  - 25s - loss: 0.0178 - mean_absolute_error: 0.0992
# Epoch 15/50
#  - 25s - loss: 0.0181 - mean_absolute_error: 0.1019
# Epoch 16/50
#  - 26s - loss: 0.0173 - mean_absolute_error: 0.1008
# Epoch 17/50
#  - 25s - loss: 0.0164 - mean_absolute_error: 0.0966
# Epoch 18/50
#  - 25s - loss: 0.0162 - mean_absolute_error: 0.0953
# Epoch 19/50
#  - 25s - loss: 0.0157 - mean_absolute_error: 0.0966
# Epoch 20/50
#  - 25s - loss: 0.0151 - mean_absolute_error: 0.0933
# Epoch 21/50
#  - 25s - loss: 0.0152 - mean_absolute_error: 0.0940
# Epoch 22/50
#  - 25s - loss: 0.0148 - mean_absolute_error: 0.0928
# Epoch 23/50
#  - 25s - loss: 0.0132 - mean_absolute_error: 0.0870
# Epoch 24/50
#  - 25s - loss: 0.0129 - mean_absolute_error: 0.0874
# Epoch 25/50
#  - 26s - loss: 0.0145 - mean_absolute_error: 0.0936
# Epoch 26/50
#  - 25s - loss: 0.0122 - mean_absolute_error: 0.0845
# Epoch 27/50
#  - 25s - loss: 0.0122 - mean_absolute_error: 0.0850
# Epoch 28/50
#  - 25s - loss: 0.0109 - mean_absolute_error: 0.0802
# Epoch 29/50
#  - 25s - loss: 0.0111 - mean_absolute_error: 0.0824
# Epoch 30/50
#  - 25s - loss: 0.0104 - mean_absolute_error: 0.0797
# Epoch 31/50
#  - 25s - loss: 0.0106 - mean_absolute_error: 0.0812
# Epoch 32/50
#  - 25s - loss: 0.0097 - mean_absolute_error: 0.0768
# Epoch 33/50
#  - 25s - loss: 0.0105 - mean_absolute_error: 0.0802
# Epoch 34/50
#  - 25s - loss: 0.0095 - mean_absolute_error: 0.0767
# Epoch 35/50
#  - 25s - loss: 0.0088 - mean_absolute_error: 0.0738
# Epoch 36/50
#  - 25s - loss: 0.0079 - mean_absolute_error: 0.0697
# Epoch 37/50
#  - 26s - loss: 0.0081 - mean_absolute_error: 0.0722
# Epoch 38/50
#  - 25s - loss: 0.0091 - mean_absolute_error: 0.0747
# Epoch 39/50
#  - 25s - loss: 0.0078 - mean_absolute_error: 0.0701
# Epoch 40/50
#  - 25s - loss: 0.0072 - mean_absolute_error: 0.0671
# Epoch 41/50
#  - 25s - loss: 0.0067 - mean_absolute_error: 0.0640
# Epoch 42/50
#  - 25s - loss: 0.0069 - mean_absolute_error: 0.0654
# Epoch 43/50
#  - 25s - loss: 0.0064 - mean_absolute_error: 0.0628
# Epoch 44/50
#  - 25s - loss: 0.0067 - mean_absolute_error: 0.0645
# Epoch 45/50
#  - 25s - loss: 0.0059 - mean_absolute_error: 0.0601
# Epoch 46/50
#  - 25s - loss: 0.0060 - mean_absolute_error: 0.0611
# Epoch 47/50
#  - 25s - loss: 0.0057 - mean_absolute_error: 0.0588
# Epoch 48/50
#  - 25s - loss: 0.0063 - mean_absolute_error: 0.0626
# Epoch 49/50
#  - 26s - loss: 0.0071 - mean_absolute_error: 0.0663
# Epoch 50/50
#  - 25s - loss: 0.0053 - mean_absolute_error: 0.0576
# Kappa Score: 0.7354447917002287
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 256)          0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 256, 50)      317500      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 300)          421200      embedding_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 300)          0           lstm_3[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# bert_input (InputLayer)         (None, 768)          0
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 1093)         0           dropout_3[0][0]
#                                                                  overall_feature_input[0][0]
#                                                                  bert_input[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            1094        lambda_3[0][0]
# ==================================================================================================
# Total params: 739,794
# Trainable params: 739,794
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 26s - loss: 0.0615 - mean_absolute_error: 0.1979
# Epoch 2/50
#  - 25s - loss: 0.0283 - mean_absolute_error: 0.1298
# Epoch 3/50
#  - 25s - loss: 0.0251 - mean_absolute_error: 0.1208
# Epoch 4/50
#  - 25s - loss: 0.0238 - mean_absolute_error: 0.1166
# Epoch 5/50
#  - 25s - loss: 0.0237 - mean_absolute_error: 0.1184
# Epoch 6/50
#  - 25s - loss: 0.0223 - mean_absolute_error: 0.1135
# Epoch 7/50
#  - 25s - loss: 0.0220 - mean_absolute_error: 0.1125
# Epoch 8/50
#  - 25s - loss: 0.0211 - mean_absolute_error: 0.1099
# Epoch 9/50
#  - 25s - loss: 0.0201 - mean_absolute_error: 0.1069
# Epoch 10/50
#  - 25s - loss: 0.0205 - mean_absolute_error: 0.1085
# Epoch 11/50
#  - 25s - loss: 0.0192 - mean_absolute_error: 0.1058
# Epoch 12/50
#  - 25s - loss: 0.0192 - mean_absolute_error: 0.1050
# Epoch 13/50
#  - 25s - loss: 0.0195 - mean_absolute_error: 0.1068
# Epoch 14/50
#  - 25s - loss: 0.0183 - mean_absolute_error: 0.1035
# Epoch 15/50
#  - 25s - loss: 0.0175 - mean_absolute_error: 0.1020
# Epoch 16/50
#  - 25s - loss: 0.0168 - mean_absolute_error: 0.0999
# Epoch 17/50
#  - 25s - loss: 0.0162 - mean_absolute_error: 0.0968
# Epoch 18/50
#  - 25s - loss: 0.0162 - mean_absolute_error: 0.0982
# Epoch 19/50
#  - 25s - loss: 0.0153 - mean_absolute_error: 0.0957
# Epoch 20/50
#  - 25s - loss: 0.0149 - mean_absolute_error: 0.0929
# Epoch 21/50
#  - 25s - loss: 0.0143 - mean_absolute_error: 0.0927
# Epoch 22/50
#  - 25s - loss: 0.0140 - mean_absolute_error: 0.0915
# Epoch 23/50
#  - 25s - loss: 0.0134 - mean_absolute_error: 0.0905
# Epoch 24/50
#  - 25s - loss: 0.0129 - mean_absolute_error: 0.0882
# Epoch 25/50
#  - 25s - loss: 0.0123 - mean_absolute_error: 0.0857
# Epoch 26/50
#  - 25s - loss: 0.0117 - mean_absolute_error: 0.0841
# Epoch 27/50
#  - 25s - loss: 0.0115 - mean_absolute_error: 0.0845
# Epoch 28/50
#  - 25s - loss: 0.0108 - mean_absolute_error: 0.0802
# Epoch 29/50
#  - 25s - loss: 0.0111 - mean_absolute_error: 0.0821
# Epoch 30/50
#  - 25s - loss: 0.0106 - mean_absolute_error: 0.0796
# Epoch 31/50
#  - 25s - loss: 0.0098 - mean_absolute_error: 0.0785
# Epoch 32/50
#  - 25s - loss: 0.0099 - mean_absolute_error: 0.0780
# Epoch 33/50
#  - 25s - loss: 0.0097 - mean_absolute_error: 0.0771
# Epoch 34/50
#  - 25s - loss: 0.0090 - mean_absolute_error: 0.0740
# Epoch 35/50
#  - 25s - loss: 0.0080 - mean_absolute_error: 0.0710
# Epoch 36/50
#  - 25s - loss: 0.0085 - mean_absolute_error: 0.0724
# Epoch 37/50
#  - 25s - loss: 0.0083 - mean_absolute_error: 0.0723
# Epoch 38/50
#  - 25s - loss: 0.0084 - mean_absolute_error: 0.0724
# Epoch 39/50
#  - 25s - loss: 0.0078 - mean_absolute_error: 0.0701
# Epoch 40/50
#  - 25s - loss: 0.0078 - mean_absolute_error: 0.0708
# Epoch 41/50
#  - 25s - loss: 0.0071 - mean_absolute_error: 0.0667
# Epoch 42/50
#  - 25s - loss: 0.0069 - mean_absolute_error: 0.0660
# Epoch 43/50
#  - 25s - loss: 0.0061 - mean_absolute_error: 0.0618
# Epoch 44/50
#  - 25s - loss: 0.0063 - mean_absolute_error: 0.0629
# Epoch 45/50
#  - 25s - loss: 0.0060 - mean_absolute_error: 0.0617
# Epoch 46/50
#  - 25s - loss: 0.0058 - mean_absolute_error: 0.0596
# Epoch 47/50
#  - 25s - loss: 0.0056 - mean_absolute_error: 0.0585
# Epoch 48/50
#  - 25s - loss: 0.0057 - mean_absolute_error: 0.0597
# Epoch 49/50
#  - 25s - loss: 0.0055 - mean_absolute_error: 0.0594
# Epoch 50/50
#  - 25s - loss: 0.0053 - mean_absolute_error: 0.0577
# Kappa Score: 0.7634384025598936
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 256)          0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 256, 50)      317500      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 300)          421200      embedding_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 300)          0           lstm_4[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# bert_input (InputLayer)         (None, 768)          0
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 1093)         0           dropout_4[0][0]
#                                                                  overall_feature_input[0][0]
#                                                                  bert_input[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            1094        lambda_4[0][0]
# ==================================================================================================
# Total params: 739,794
# Trainable params: 739,794
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 26s - loss: 0.0577 - mean_absolute_error: 0.1859
# Epoch 2/50
#  - 25s - loss: 0.0297 - mean_absolute_error: 0.1291
# Epoch 3/50
#  - 25s - loss: 0.0269 - mean_absolute_error: 0.1230
# Epoch 4/50
#  - 25s - loss: 0.0256 - mean_absolute_error: 0.1196
# Epoch 5/50
#  - 25s - loss: 0.0239 - mean_absolute_error: 0.1158
# Epoch 6/50
#  - 25s - loss: 0.0233 - mean_absolute_error: 0.1144
# Epoch 7/50
#  - 25s - loss: 0.0231 - mean_absolute_error: 0.1133
# Epoch 8/50
#  - 25s - loss: 0.0222 - mean_absolute_error: 0.1111
# Epoch 9/50
#  - 25s - loss: 0.0214 - mean_absolute_error: 0.1092
# Epoch 10/50
#  - 25s - loss: 0.0205 - mean_absolute_error: 0.1068
# Epoch 11/50
#  - 25s - loss: 0.0195 - mean_absolute_error: 0.1031
# Epoch 12/50
#  - 25s - loss: 0.0203 - mean_absolute_error: 0.1082
# Epoch 13/50
#  - 25s - loss: 0.0192 - mean_absolute_error: 0.1036
# Epoch 14/50
#  - 25s - loss: 0.0187 - mean_absolute_error: 0.1041
# Epoch 15/50
#  - 25s - loss: 0.0177 - mean_absolute_error: 0.1005
# Epoch 16/50
#  - 25s - loss: 0.0178 - mean_absolute_error: 0.1011
# Epoch 17/50
#  - 25s - loss: 0.0170 - mean_absolute_error: 0.0995
# Epoch 18/50
#  - 25s - loss: 0.0163 - mean_absolute_error: 0.0974
# Epoch 19/50
#  - 25s - loss: 0.0165 - mean_absolute_error: 0.0994
# Epoch 20/50
#  - 25s - loss: 0.0154 - mean_absolute_error: 0.0948
# Epoch 21/50
#  - 25s - loss: 0.0144 - mean_absolute_error: 0.0921
# Epoch 22/50
#  - 25s - loss: 0.0150 - mean_absolute_error: 0.0946
# Epoch 23/50
#  - 26s - loss: 0.0133 - mean_absolute_error: 0.0883
# Epoch 24/50
#  - 25s - loss: 0.0132 - mean_absolute_error: 0.0887
# Epoch 25/50
#  - 25s - loss: 0.0125 - mean_absolute_error: 0.0865
# Epoch 26/50
#  - 25s - loss: 0.0123 - mean_absolute_error: 0.0858
# Epoch 27/50
#  - 25s - loss: 0.0122 - mean_absolute_error: 0.0855
# Epoch 28/50
#  - 25s - loss: 0.0117 - mean_absolute_error: 0.0837
# Epoch 29/50
#  - 25s - loss: 0.0113 - mean_absolute_error: 0.0838
# Epoch 30/50
#  - 25s - loss: 0.0113 - mean_absolute_error: 0.0834
# Epoch 31/50
#  - 25s - loss: 0.0102 - mean_absolute_error: 0.0788
# Epoch 32/50
#  - 25s - loss: 0.0093 - mean_absolute_error: 0.0750
# Epoch 33/50
#  - 25s - loss: 0.0091 - mean_absolute_error: 0.0737
# Epoch 34/50
#  - 25s - loss: 0.0091 - mean_absolute_error: 0.0746
# Epoch 35/50
#  - 25s - loss: 0.0086 - mean_absolute_error: 0.0714
# Epoch 36/50
#  - 25s - loss: 0.0079 - mean_absolute_error: 0.0698
# Epoch 37/50
#  - 25s - loss: 0.0080 - mean_absolute_error: 0.0702
# Epoch 38/50
#  - 25s - loss: 0.0075 - mean_absolute_error: 0.0676
# Epoch 39/50
#  - 25s - loss: 0.0078 - mean_absolute_error: 0.0695
# Epoch 40/50
#  - 25s - loss: 0.0071 - mean_absolute_error: 0.0667
# Epoch 41/50
#  - 25s - loss: 0.0065 - mean_absolute_error: 0.0631
# Epoch 42/50
#  - 25s - loss: 0.0065 - mean_absolute_error: 0.0628
# Epoch 43/50
#  - 25s - loss: 0.0060 - mean_absolute_error: 0.0608
# Epoch 44/50
#  - 25s - loss: 0.0063 - mean_absolute_error: 0.0624
# Epoch 45/50
#  - 25s - loss: 0.0058 - mean_absolute_error: 0.0602
# Epoch 46/50
#  - 25s - loss: 0.0063 - mean_absolute_error: 0.0628
# Epoch 47/50
#  - 25s - loss: 0.0053 - mean_absolute_error: 0.0578
# Epoch 48/50
#  - 26s - loss: 0.0057 - mean_absolute_error: 0.0591
# Epoch 49/50
#  - 25s - loss: 0.0053 - mean_absolute_error: 0.0564
# Epoch 50/50
#  - 25s - loss: 0.0051 - mean_absolute_error: 0.0550
# Kappa Score: 0.7783185418455959
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 256)          0
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 256, 50)      317500      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 300)          421200      embedding_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 300)          0           lstm_5[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# bert_input (InputLayer)         (None, 768)          0
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 1093)         0           dropout_5[0][0]
#                                                                  overall_feature_input[0][0]
#                                                                  bert_input[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            1094        lambda_5[0][0]
# ==================================================================================================
# Total params: 739,794
# Trainable params: 739,794
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 26s - loss: 0.0718 - mean_absolute_error: 0.2128
# Epoch 2/50
#  - 25s - loss: 0.0298 - mean_absolute_error: 0.1342
# Epoch 3/50
#  - 25s - loss: 0.0266 - mean_absolute_error: 0.1263
# Epoch 4/50
#  - 24s - loss: 0.0250 - mean_absolute_error: 0.1208
# Epoch 5/50
#  - 25s - loss: 0.0240 - mean_absolute_error: 0.1181
# Epoch 6/50
#  - 25s - loss: 0.0232 - mean_absolute_error: 0.1159
# Epoch 7/50
#  - 24s - loss: 0.0219 - mean_absolute_error: 0.1117
# Epoch 8/50
#  - 25s - loss: 0.0213 - mean_absolute_error: 0.1105
# Epoch 9/50
#  - 25s - loss: 0.0206 - mean_absolute_error: 0.1076
# Epoch 10/50
#  - 25s - loss: 0.0193 - mean_absolute_error: 0.1044
# Epoch 11/50
#  - 25s - loss: 0.0194 - mean_absolute_error: 0.1056
# Epoch 12/50
#  - 25s - loss: 0.0192 - mean_absolute_error: 0.1053
# Epoch 13/50
#  - 25s - loss: 0.0186 - mean_absolute_error: 0.1029
# Epoch 14/50
#  - 24s - loss: 0.0185 - mean_absolute_error: 0.1027
# Epoch 15/50
#  - 25s - loss: 0.0173 - mean_absolute_error: 0.1000
# Epoch 16/50
#  - 24s - loss: 0.0167 - mean_absolute_error: 0.0980
# Epoch 17/50
#  - 24s - loss: 0.0159 - mean_absolute_error: 0.0956
# Epoch 18/50
#  - 25s - loss: 0.0162 - mean_absolute_error: 0.0971
# Epoch 19/50
#  - 25s - loss: 0.0157 - mean_absolute_error: 0.0960
# Epoch 20/50
#  - 24s - loss: 0.0151 - mean_absolute_error: 0.0937
# Epoch 21/50
#  - 25s - loss: 0.0145 - mean_absolute_error: 0.0929
# Epoch 22/50
#  - 24s - loss: 0.0134 - mean_absolute_error: 0.0885
# Epoch 23/50
#  - 25s - loss: 0.0135 - mean_absolute_error: 0.0895
# Epoch 24/50
#  - 25s - loss: 0.0134 - mean_absolute_error: 0.0890
# Epoch 25/50
#  - 25s - loss: 0.0129 - mean_absolute_error: 0.0880
# Epoch 26/50
#  - 25s - loss: 0.0127 - mean_absolute_error: 0.0879
# Epoch 27/50
#  - 25s - loss: 0.0128 - mean_absolute_error: 0.0881
# Epoch 28/50
#  - 25s - loss: 0.0114 - mean_absolute_error: 0.0828
# Epoch 29/50
#  - 25s - loss: 0.0116 - mean_absolute_error: 0.0838
# Epoch 30/50
#  - 25s - loss: 0.0102 - mean_absolute_error: 0.0784
# Epoch 31/50
#  - 25s - loss: 0.0101 - mean_absolute_error: 0.0781
# Epoch 32/50
#  - 25s - loss: 0.0099 - mean_absolute_error: 0.0759
# Epoch 33/50
#  - 25s - loss: 0.0097 - mean_absolute_error: 0.0772
# Epoch 34/50
#  - 24s - loss: 0.0093 - mean_absolute_error: 0.0746
# Epoch 35/50
#  - 25s - loss: 0.0092 - mean_absolute_error: 0.0761
# Epoch 36/50
#  - 25s - loss: 0.0091 - mean_absolute_error: 0.0742
# Epoch 37/50
#  - 25s - loss: 0.0081 - mean_absolute_error: 0.0707
# Epoch 38/50
#  - 25s - loss: 0.0083 - mean_absolute_error: 0.0721
# Epoch 39/50
#  - 24s - loss: 0.0074 - mean_absolute_error: 0.0675
# Epoch 40/50
#  - 24s - loss: 0.0069 - mean_absolute_error: 0.0645
# Epoch 41/50
#  - 25s - loss: 0.0074 - mean_absolute_error: 0.0660
# Epoch 42/50
#  - 24s - loss: 0.0067 - mean_absolute_error: 0.0642
# Epoch 43/50
#  - 25s - loss: 0.0063 - mean_absolute_error: 0.0621
# Epoch 44/50
#  - 24s - loss: 0.0066 - mean_absolute_error: 0.0630
# Epoch 45/50
#  - 24s - loss: 0.0063 - mean_absolute_error: 0.0616
# Epoch 46/50
#  - 24s - loss: 0.0062 - mean_absolute_error: 0.0614
# Epoch 47/50
#  - 25s - loss: 0.0056 - mean_absolute_error: 0.0584
# Epoch 48/50
#  - 25s - loss: 0.0057 - mean_absolute_error: 0.0591
# Epoch 49/50
#  - 25s - loss: 0.0061 - mean_absolute_error: 0.0610
# Epoch 50/50
#  - 25s - loss: 0.0060 - mean_absolute_error: 0.0618
# Kappa Score: 0.7435278774046299
# Average Kappa score after a 5-fold cross validation:  0.75553
# Kappa score after a 5-fold cross validation:  0.7573625450650039

# %% [markdown]
# 最後に、Mean over Time Layerの出力を以下の式のように線形変換
