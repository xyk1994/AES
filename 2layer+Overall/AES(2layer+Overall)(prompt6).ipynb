# %%
prompt_id = 6
model_name = "2LayerOverall"  # 1LayerOverall, 1LayerMoTOverall, 2LayerOverall

# %%
import os
import pprint
import tensorflow as tf

if 'COLAB_TPU_ADDR' not in os.environ:
  print('ERROR: Not connected to a TPU runtime')
else:
  tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
  print ('TPU address is', tpu_address)

  with tf.Session(tpu_address) as session:
    devices = session.list_devices()

  print('TPU devices:')
  pprint.pprint(devices)
# Out:
# TPU address is grpc://10.52.236.66:8470
# TPU devices:
# [_DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:CPU:0, CPU, -1, 5411037004004875443),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 12227427790018925541),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 14668385240954076252),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 12490427264308496499),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 14505509791850503435),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 8860062359152135169),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 8272679944356376722),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 6477886526500442960),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 13519625617522582120),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 17254951796161683830),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 8589934592, 8127338510043523668)]

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/My Drive/AES謝"
os.chdir(path)
# os.listdir(path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import argparse
import nltk
import tensorflow as tf
from keras.models import Model
from keras import layers
from keras.layers import Input, concatenate, Embedding, LSTM, Dense, Lambda
from keras.engine.topology import Layer
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
import re
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
import keras.backend as K
from sklearn.model_selection import KFold
from sklearn.metrics import cohen_kappa_score
from sklearn.preprocessing import StandardScaler
from keras.preprocessing.sequence import pad_sequences
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')

nltk.download('stopwords')
nltk.download('punkt')
# stopwords, punkt,
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Mean Over Time
class TemporalMean(Layer):
  def __init__(self, **kwargs):
      self.supports_masking = True
      super(TemporalMean, self).__init__(**kwargs)

  def compute_mask(self, input, input_mask=None):
      # do not pass the mask to the next layers
      return None

  def call(self, x, mask=None):
      if mask is not None:
          # mask (batch, time)
          mask = K.cast(mask, K.floatx())
          # mask (batch, x_dim, time)
          mask = K.repeat(mask, x.shape[-1])
          # mask (batch, time, x_dim)
          mask = tf.transpose(mask, [0,2,1])
          x = x * mask
      return K.sum(x, axis=1) / K.sum(mask, axis=1)

  def compute_output_shape(self, input_shape):
      # remove temporal dimension
      return (input_shape[0], input_shape[2])

def essay_to_wordlist(essay_v, remove_stopwords):
    """Remove the tagged labels and word tokenize the sentence."""
    essay_v = re.sub("[^a-zA-Z]", " ", essay_v)
    words = essay_v.lower().split()
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    return (words)

def get_clean_essays(Text):
    clean_essays = []
    for essay in Text:
        clean_essays.append(essay_to_wordlist(essay, remove_stopwords=False))
    return clean_essays

def create_dict(text):
    print("create_dict")
    word_index = {}
    word_index['xieyikuan'] = 0
    for sentence in text:
        for word in sentence:
            if word not in word_index:
                word_index[word] = len(word_index)
    word_index['unk'] = len(word_index)
    return word_index

def essay_to_index(essays, word_index):
    Essays = []
    for essay in essays:
        sentence = []
        for sent in essay:
            words = []
            for word in sent:
                words.append(word_index[word])
            sentence.append(words)
        Essays.append(sentence)
    return Essays

def essay_to_index2(essays, word_index):
    Essays = []
    for essay in essays:
        words = []
        for word in essay:
            words.append(word_index[word])
        Essays.append(words)
    return Essays

def get_embeddings_index():
    embeddings_index = {}
    f = open('glove.6B.50d.txt', 'r', encoding='UTF-8')
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.array(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    f.close()
    return embeddings_index

def embeddings_matrix(embeddings_index, word_index, embedding_dim):
    nb_words = len(word_index)
    embedding_matrix = np.zeros((nb_words + 1, embedding_dim))
    for word, i in word_index.items():
        if i > nb_words:
            continue
        embeddings_vector = embeddings_index.get(word)
        if embeddings_vector is not None:
            embedding_matrix[i] = embeddings_vector
        if embeddings_vector is None:
            embedding_matrix[i] = embeddings_index.get('unk')
    return embedding_matrix

# %%
csv_input = pd.read_csv(filepath_or_buffer="data_feature/set"+str(prompt_id)+"_feature(26).tsv", delimiter="\t", engine="python", error_bad_lines=False)

Text = csv_input['essay']
Score = csv_input['domain1_score']
Label = Score

# --------
if prompt_id == 1:
    Score = (Score - 2) / 10      # set_1     范围 2-12
elif prompt_id == 2:
    Score = (Score - 1) / 5       # set_2     范围 1-6
elif prompt_id == 3 or prompt_id == 4:
    Score = Score / 3           # set_3,4   范围 0-3
elif prompt_id == 5 or prompt_id == 6:
    Score = Score / 4           # set_5,6   范围 0-4
elif prompt_id == 7:
    Score = Score / 30          # set_7     范围 0-30
elif prompt_id == 8:
    Score = Score / 60          # set_8     范围 0-60

# get Overall Feature
overall_feature = csv_input[['word_count', 'avg_word_len', 'sentence_count', 'avg_sentence_len', 'lemma_count', 'noun_count', 'adj_count', 'adv_count', 'verb_count', 'cc_count',
                             'syllable_count', 'flesch_reading_ease', 'smog_index', 'flesch_kincaid_grade', 'coleman_liau_index', 'automated_readability_index',
                             'dale_chall_readability_score', 'difficult_words', 'linsear_write_formula',
                             'gunning_fog', 'spelling_errors', 'exc_count', 'que_count', 'comma_count', 'stopwords_num']]
# overall_feature = np.array(np.sqrt(overall_feature))
overall_feature = np.array(overall_feature)
num_feature = 25
where_are_nan = np.isnan(overall_feature)
where_are_inf = np.isinf(overall_feature)
overall_feature[where_are_nan] = 0
overall_feature[where_are_inf] = 0
# standardized
stdsc = StandardScaler()
overall_feature = stdsc.fit_transform(overall_feature)

# 做字典
clean_essays = get_clean_essays(Text)
word_index = create_dict(clean_essays)

# 做分句
text = np.array(Text)
# print(text)
a = []
for essay in text:
    a.append(sent_tokenize(essay))
texts = np.array(a)

# 做分词
essays = []
for essay in Text:
  essay_idx = essay_to_wordlist(essay, remove_stopwords=False)
  essays.append(essay_idx)
essays = np.array(essays)

Essays = essay_to_index2(clean_essays, word_index)
Essays = np.array(Essays)

if prompt_id == 1:
    max_essay_length = 600
elif prompt_id == 2:
    max_essay_length = 700
elif prompt_id == 3:
    max_essay_length = 256
elif prompt_id == 4:
    max_essay_length = 200
elif prompt_id == 5:
    max_essay_length = 256
elif prompt_id == 6:
    max_essay_length = 256
elif prompt_id == 7:
    max_essay_length = 350
elif prompt_id == 8:
    max_essay_length = 870

essay_pad = pad_sequences(Essays, maxlen=max_essay_length)

embeddings_index = get_embeddings_index()
embeddings_matrix = embeddings_matrix(embeddings_index, word_index, embedding_dim=50)

# 记录成绩
results = []
score_predict_list = []
sssscore = []
llllabel = []
newresults = []
cv = KFold(n_splits=5, shuffle=True, random_state=10)
count = 0
for train, test in cv.split(essay_pad):
    text_train, text_test = essay_pad[train], essay_pad[test]
    label_train, label_test = Score.iloc[train], Score.iloc[test]
    score_train, score_test = Label.iloc[train], Label.iloc[test]
    overall_train, overall_test = overall_feature[train], overall_feature[test]

    print('Build model '+str(count)+'...')
    count += 1

    # -------
    text_input = Input(shape=(max_essay_length, ), name='text_input')
    overall_feature_input = Input(shape=(num_feature,), name='overall_feature_input')

    embedding_layer = Embedding(input_dim=len(word_index) + 1,
                                output_dim=50,
                                weights=[embeddings_matrix],
                                input_length=max_essay_length,
                                trainable=True,
                                mask_zero=True)
    x = embedding_layer(text_input)  
    if model_name == "2LayerOverall":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)
    elif model_name == "1LayerMoTOverall":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)
      x = TemporalMean()(x)
    elif model_name == "1LayerOverall":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)
    x = layers.Dropout(0.5)(x)
    concat_layer = Lambda(concatenate)([x, overall_feature_input])
    output = Dense(1, activation='sigmoid')(concat_layer)

    model = Model(inputs=[text_input, overall_feature_input], outputs=output)
    # -------

    model.summary()
    model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001, decay=1e-6), metrics=['mean_absolute_error'])
    model.fit([text_train, overall_train], label_train, batch_size=32, epochs=50, verbose=2)

    score_predict = model.predict([text_test, overall_test])
    if prompt_id == 1:
        score_predict = score_predict*10+2
    elif prompt_id == 2:
        score_predict = score_predict*5+1
    elif prompt_id == 3:
        score_predict = score_predict*3
    elif prompt_id == 4:
        score_predict = score_predict*3
    elif prompt_id == 5:
        score_predict = score_predict*4
    elif prompt_id == 6:
        score_predict = score_predict*4
    elif prompt_id == 7:
        score_predict = score_predict*30
    elif prompt_id == 8:
        score_predict = score_predict*60

    score_predict = np.around(score_predict)

    sssscore.append(score_predict)
    llllabel.append(score_test)

    result = cohen_kappa_score(score_test.values, score_predict, weights='quadratic')
    print("Kappa Score: {}".format(result))
    results.append(result)
    for i in results:
      if i != 0:
        newresults.append(i)

print("Average Kappa score after a 5-fold cross validation: ", np.around(np.array(newresults).mean(), decimals=5))

sssscore = np.array(sssscore)
res = []
for scores in sssscore:
  for score in scores:
    res.append(score)

ll = np.array(llllabel)
res_label = []
for labels in ll:
  for label in labels:
    res_label.append(label)
res_label = np.array(res_label)

QWK = cohen_kappa_score(res_label, res, weights='quadratic')
print("Kappa score after a 5-fold cross validation: ", QWK)
# Out:
# create_dict
# Build model 0...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3239: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 256)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 256, 50)      263350      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 256, 300)     421200      embedding_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 300)          721200      lstm_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 300)          0           lstm_2[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 325)          0           dropout_1[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            326         lambda_1[0][0]
# ==================================================================================================
# Total params: 1,406,076
# Trainable params: 1,406,076
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/50
#  - 147s - loss: 0.0464 - mean_absolute_error: 0.1664
# Epoch 2/50
#  - 145s - loss: 0.0334 - mean_absolute_error: 0.1431
# Epoch 3/50
#  - 147s - loss: 0.0309 - mean_absolute_error: 0.1376
# Epoch 4/50
#  - 147s - loss: 0.0285 - mean_absolute_error: 0.1322
# Epoch 5/50
#  - 145s - loss: 0.0277 - mean_absolute_error: 0.1315
# Epoch 6/50
#  - 146s - loss: 0.0264 - mean_absolute_error: 0.1276
# Epoch 7/50
#  - 145s - loss: 0.0257 - mean_absolute_error: 0.1243
# Epoch 8/50
#  - 146s - loss: 0.0247 - mean_absolute_error: 0.1241
# Epoch 9/50
#  - 145s - loss: 0.0237 - mean_absolute_error: 0.1208
# Epoch 10/50
#  - 145s - loss: 0.0233 - mean_absolute_error: 0.1209
# Epoch 11/50
#  - 145s - loss: 0.0221 - mean_absolute_error: 0.1176
# Epoch 12/50
#  - 145s - loss: 0.0215 - mean_absolute_error: 0.1158
# Epoch 13/50
#  - 145s - loss: 0.0204 - mean_absolute_error: 0.1130
# Epoch 14/50
#  - 145s - loss: 0.0214 - mean_absolute_error: 0.1159
# Epoch 15/50
#  - 146s - loss: 0.0193 - mean_absolute_error: 0.1110
# Epoch 16/50
#  - 145s - loss: 0.0191 - mean_absolute_error: 0.1104
# Epoch 17/50
#  - 146s - loss: 0.0178 - mean_absolute_error: 0.1074
# Epoch 18/50
#  - 146s - loss: 0.0175 - mean_absolute_error: 0.1063
# Epoch 19/50
#  - 146s - loss: 0.0176 - mean_absolute_error: 0.1059
# Epoch 20/50
#  - 145s - loss: 0.0178 - mean_absolute_error: 0.1072
# Epoch 21/50
#  - 145s - loss: 0.0168 - mean_absolute_error: 0.1047
# Epoch 22/50
#  - 144s - loss: 0.0163 - mean_absolute_error: 0.1021
# Epoch 23/50
#  - 146s - loss: 0.0153 - mean_absolute_error: 0.0992
# Epoch 24/50
#  - 145s - loss: 0.0152 - mean_absolute_error: 0.0985
# Epoch 25/50
#  - 146s - loss: 0.0144 - mean_absolute_error: 0.0966
# Epoch 26/50
#  - 144s - loss: 0.0142 - mean_absolute_error: 0.0950
# Epoch 27/50
#  - 145s - loss: 0.0137 - mean_absolute_error: 0.0940
# Epoch 28/50
#  - 145s - loss: 0.0137 - mean_absolute_error: 0.0939
# Epoch 29/50
#  - 145s - loss: 0.0130 - mean_absolute_error: 0.0915
# Epoch 30/50
#  - 145s - loss: 0.0133 - mean_absolute_error: 0.0925
# Epoch 31/50
#  - 145s - loss: 0.0122 - mean_absolute_error: 0.0895
# Epoch 32/50
#  - 145s - loss: 0.0122 - mean_absolute_error: 0.0878
# Epoch 33/50
#  - 144s - loss: 0.0119 - mean_absolute_error: 0.0880
# Epoch 34/50
#  - 144s - loss: 0.0113 - mean_absolute_error: 0.0856
# Epoch 35/50
#  - 145s - loss: 0.0110 - mean_absolute_error: 0.0858
# Epoch 36/50
#  - 145s - loss: 0.0110 - mean_absolute_error: 0.0844
# Epoch 37/50
#  - 145s - loss: 0.0102 - mean_absolute_error: 0.0818
# Epoch 38/50
#  - 146s - loss: 0.0097 - mean_absolute_error: 0.0799
# Epoch 39/50
#  - 144s - loss: 0.0096 - mean_absolute_error: 0.0785
# Epoch 40/50
#  - 145s - loss: 0.0092 - mean_absolute_error: 0.0775
# Epoch 41/50
#  - 145s - loss: 0.0093 - mean_absolute_error: 0.0782
# Epoch 42/50
#  - 145s - loss: 0.0089 - mean_absolute_error: 0.0774
# Epoch 43/50
#  - 145s - loss: 0.0088 - mean_absolute_error: 0.0760
# Epoch 44/50
#  - 145s - loss: 0.0083 - mean_absolute_error: 0.0739
# Epoch 45/50
#  - 146s - loss: 0.0082 - mean_absolute_error: 0.0736
# Epoch 46/50
#  - 145s - loss: 0.0082 - mean_absolute_error: 0.0732
# Epoch 47/50
#  - 145s - loss: 0.0079 - mean_absolute_error: 0.0722
# Epoch 48/50
#  - 145s - loss: 0.0076 - mean_absolute_error: 0.0713
# Epoch 49/50
#  - 145s - loss: 0.0078 - mean_absolute_error: 0.0719
# Epoch 50/50
#  - 146s - loss: 0.0071 - mean_absolute_error: 0.0675
# Kappa Score: 0.7587049480757484
# Build model 1...
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 256)          0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 256, 50)      263350      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 256, 300)     421200      embedding_2[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 300)          721200      lstm_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 300)          0           lstm_4[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 325)          0           dropout_2[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            326         lambda_2[0][0]
# ==================================================================================================
# Total params: 1,406,076
# Trainable params: 1,406,076
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 150s - loss: 0.0512 - mean_absolute_error: 0.1781
# Epoch 2/50
#  - 147s - loss: 0.0340 - mean_absolute_error: 0.1440
# Epoch 3/50
#  - 147s - loss: 0.0311 - mean_absolute_error: 0.1395
# Epoch 4/50
#  - 148s - loss: 0.0293 - mean_absolute_error: 0.1349
# Epoch 5/50
#  - 148s - loss: 0.0278 - mean_absolute_error: 0.1320
# Epoch 6/50
#  - 151s - loss: 0.0268 - mean_absolute_error: 0.1285
# Epoch 7/50
#  - 148s - loss: 0.0253 - mean_absolute_error: 0.1253
# Epoch 8/50
#  - 153s - loss: 0.0244 - mean_absolute_error: 0.1233
# Epoch 9/50
#  - 148s - loss: 0.0249 - mean_absolute_error: 0.1240
# Epoch 10/50
#  - 146s - loss: 0.0244 - mean_absolute_error: 0.1235
# Epoch 11/50
#  - 147s - loss: 0.0234 - mean_absolute_error: 0.1207
# Epoch 12/50
#  - 149s - loss: 0.0228 - mean_absolute_error: 0.1202
# Epoch 13/50
#  - 147s - loss: 0.0218 - mean_absolute_error: 0.1172
# Epoch 14/50
#  - 147s - loss: 0.0217 - mean_absolute_error: 0.1165
# Epoch 15/50
#  - 146s - loss: 0.0214 - mean_absolute_error: 0.1165
# Epoch 16/50
#  - 147s - loss: 0.0195 - mean_absolute_error: 0.1122
# Epoch 17/50
#  - 147s - loss: 0.0188 - mean_absolute_error: 0.1094
# Epoch 18/50
#  - 148s - loss: 0.0186 - mean_absolute_error: 0.1086
# Epoch 19/50
#  - 147s - loss: 0.0184 - mean_absolute_error: 0.1091
# Epoch 20/50
#  - 147s - loss: 0.0177 - mean_absolute_error: 0.1067
# Epoch 21/50
#  - 146s - loss: 0.0171 - mean_absolute_error: 0.1055
# Epoch 22/50
#  - 148s - loss: 0.0164 - mean_absolute_error: 0.1029
# Epoch 23/50
#  - 149s - loss: 0.0162 - mean_absolute_error: 0.1031
# Epoch 24/50
#  - 148s - loss: 0.0150 - mean_absolute_error: 0.0984
# Epoch 25/50
#  - 146s - loss: 0.0149 - mean_absolute_error: 0.0981
# Epoch 26/50
#  - 147s - loss: 0.0143 - mean_absolute_error: 0.0961
# Epoch 27/50
#  - 147s - loss: 0.0139 - mean_absolute_error: 0.0961
# Epoch 28/50
#  - 148s - loss: 0.0136 - mean_absolute_error: 0.0941
# Epoch 29/50
#  - 147s - loss: 0.0134 - mean_absolute_error: 0.0932
# Epoch 30/50
#  - 148s - loss: 0.0128 - mean_absolute_error: 0.0921
# Epoch 31/50
#  - 148s - loss: 0.0120 - mean_absolute_error: 0.0888
# Epoch 32/50
#  - 147s - loss: 0.0121 - mean_absolute_error: 0.0893
# Epoch 33/50
#  - 148s - loss: 0.0113 - mean_absolute_error: 0.0856
# Epoch 34/50
#  - 148s - loss: 0.0113 - mean_absolute_error: 0.0864
# Epoch 35/50
#  - 151s - loss: 0.0108 - mean_absolute_error: 0.0846
# Epoch 36/50
#  - 147s - loss: 0.0104 - mean_absolute_error: 0.0821
# Epoch 37/50
#  - 149s - loss: 0.0102 - mean_absolute_error: 0.0820
# Epoch 38/50
#  - 149s - loss: 0.0094 - mean_absolute_error: 0.0781
# Epoch 39/50
#  - 149s - loss: 0.0093 - mean_absolute_error: 0.0779
# Epoch 40/50
#  - 148s - loss: 0.0093 - mean_absolute_error: 0.0777
# Epoch 41/50
#  - 148s - loss: 0.0089 - mean_absolute_error: 0.0766
# Epoch 42/50
#  - 147s - loss: 0.0089 - mean_absolute_error: 0.0761
# Epoch 43/50
#  - 147s - loss: 0.0087 - mean_absolute_error: 0.0756
# Epoch 44/50
#  - 146s - loss: 0.0081 - mean_absolute_error: 0.0733
# Epoch 45/50
#  - 146s - loss: 0.0081 - mean_absolute_error: 0.0723
# Epoch 46/50
#  - 146s - loss: 0.0082 - mean_absolute_error: 0.0734
# Epoch 47/50
#  - 147s - loss: 0.0076 - mean_absolute_error: 0.0713
# Epoch 48/50
#  - 147s - loss: 0.0072 - mean_absolute_error: 0.0688
# Epoch 49/50
#  - 147s - loss: 0.0071 - mean_absolute_error: 0.0673
# Epoch 50/50
#  - 146s - loss: 0.0075 - mean_absolute_error: 0.0701
# Kappa Score: 0.7797933517228481
# Build model 2...
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 256)          0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 256, 50)      263350      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 256, 300)     421200      embedding_3[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   (None, 300)          721200      lstm_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 300)          0           lstm_6[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 325)          0           dropout_3[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            326         lambda_3[0][0]
# ==================================================================================================
# Total params: 1,406,076
# Trainable params: 1,406,076
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 148s - loss: 0.0421 - mean_absolute_error: 0.1622
# Epoch 2/50
#  - 146s - loss: 0.0327 - mean_absolute_error: 0.1402
# Epoch 3/50
#  - 145s - loss: 0.0308 - mean_absolute_error: 0.1369
# Epoch 4/50
#  - 147s - loss: 0.0289 - mean_absolute_error: 0.1327
# Epoch 5/50
#  - 146s - loss: 0.0282 - mean_absolute_error: 0.1309
# Epoch 6/50
#  - 146s - loss: 0.0271 - mean_absolute_error: 0.1276
# Epoch 7/50
#  - 147s - loss: 0.0264 - mean_absolute_error: 0.1268
# Epoch 8/50
#  - 146s - loss: 0.0250 - mean_absolute_error: 0.1237
# Epoch 9/50
#  - 145s - loss: 0.0239 - mean_absolute_error: 0.1219
# Epoch 10/50
#  - 147s - loss: 0.0239 - mean_absolute_error: 0.1216
# Epoch 11/50
#  - 146s - loss: 0.0228 - mean_absolute_error: 0.1187
# Epoch 12/50
#  - 147s - loss: 0.0220 - mean_absolute_error: 0.1183
# Epoch 13/50
#  - 145s - loss: 0.0209 - mean_absolute_error: 0.1152
# Epoch 14/50
#  - 146s - loss: 0.0196 - mean_absolute_error: 0.1117
# Epoch 15/50
#  - 146s - loss: 0.0199 - mean_absolute_error: 0.1120
# Epoch 16/50
#  - 146s - loss: 0.0190 - mean_absolute_error: 0.1107
# Epoch 17/50
#  - 148s - loss: 0.0188 - mean_absolute_error: 0.1093
# Epoch 18/50
#  - 151s - loss: 0.0184 - mean_absolute_error: 0.1077
# Epoch 19/50
#  - 153s - loss: 0.0169 - mean_absolute_error: 0.1048
# Epoch 20/50
#  - 152s - loss: 0.0166 - mean_absolute_error: 0.1033
# Epoch 21/50
#  - 153s - loss: 0.0164 - mean_absolute_error: 0.1026
# Epoch 22/50
#  - 150s - loss: 0.0162 - mean_absolute_error: 0.1016
# Epoch 23/50
#  - 150s - loss: 0.0164 - mean_absolute_error: 0.1018
# Epoch 24/50
#  - 149s - loss: 0.0146 - mean_absolute_error: 0.0968
# Epoch 25/50
#  - 149s - loss: 0.0143 - mean_absolute_error: 0.0957
# Epoch 26/50
#  - 150s - loss: 0.0143 - mean_absolute_error: 0.0960
# Epoch 27/50
#  - 149s - loss: 0.0140 - mean_absolute_error: 0.0951
# Epoch 28/50
#  - 149s - loss: 0.0138 - mean_absolute_error: 0.0948
# Epoch 29/50
#  - 149s - loss: 0.0126 - mean_absolute_error: 0.0906
# Epoch 30/50
#  - 148s - loss: 0.0123 - mean_absolute_error: 0.0899
# Epoch 31/50
#  - 148s - loss: 0.0126 - mean_absolute_error: 0.0904
# Epoch 32/50
#  - 149s - loss: 0.0123 - mean_absolute_error: 0.0888
# Epoch 33/50
#  - 150s - loss: 0.0121 - mean_absolute_error: 0.0884
# Epoch 34/50
#  - 148s - loss: 0.0108 - mean_absolute_error: 0.0837
# Epoch 35/50
#  - 150s - loss: 0.0109 - mean_absolute_error: 0.0860
# Epoch 36/50
#  - 149s - loss: 0.0103 - mean_absolute_error: 0.0830
# Epoch 37/50
#  - 149s - loss: 0.0103 - mean_absolute_error: 0.0823
# Epoch 38/50
#  - 149s - loss: 0.0101 - mean_absolute_error: 0.0811
# Epoch 39/50
#  - 149s - loss: 0.0094 - mean_absolute_error: 0.0786
# Epoch 40/50
#  - 149s - loss: 0.0098 - mean_absolute_error: 0.0802
# Epoch 41/50
#  - 149s - loss: 0.0093 - mean_absolute_error: 0.0773
# Epoch 42/50
#  - 149s - loss: 0.0088 - mean_absolute_error: 0.0761
# Epoch 43/50
#  - 147s - loss: 0.0090 - mean_absolute_error: 0.0770
# Epoch 44/50
#  - 147s - loss: 0.0085 - mean_absolute_error: 0.0754
# Epoch 45/50
#  - 147s - loss: 0.0084 - mean_absolute_error: 0.0744
# Epoch 46/50
#  - 147s - loss: 0.0080 - mean_absolute_error: 0.0730
# Epoch 47/50
#  - 146s - loss: 0.0078 - mean_absolute_error: 0.0708
# Epoch 48/50
#  - 146s - loss: 0.0077 - mean_absolute_error: 0.0715
# Epoch 49/50
#  - 146s - loss: 0.0076 - mean_absolute_error: 0.0710
# Epoch 50/50
#  - 147s - loss: 0.0076 - mean_absolute_error: 0.0702
# Kappa Score: 0.7725237327601647
# Build model 3...
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 256)          0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 256, 50)      263350      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_7 (LSTM)                   (None, 256, 300)     421200      embedding_4[0][0]
# __________________________________________________________________________________________________
# lstm_8 (LSTM)                   (None, 300)          721200      lstm_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 300)          0           lstm_8[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 325)          0           dropout_4[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            326         lambda_4[0][0]
# ==================================================================================================
# Total params: 1,406,076
# Trainable params: 1,406,076
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 151s - loss: 0.0455 - mean_absolute_error: 0.1677
# Epoch 2/50
#  - 147s - loss: 0.0315 - mean_absolute_error: 0.1393
# Epoch 3/50
#  - 147s - loss: 0.0288 - mean_absolute_error: 0.1335
# Epoch 4/50
#  - 147s - loss: 0.0273 - mean_absolute_error: 0.1301
# Epoch 5/50
#  - 147s - loss: 0.0264 - mean_absolute_error: 0.1268
# Epoch 6/50
#  - 146s - loss: 0.0259 - mean_absolute_error: 0.1266
# Epoch 7/50
#  - 145s - loss: 0.0249 - mean_absolute_error: 0.1243
# Epoch 8/50
#  - 146s - loss: 0.0248 - mean_absolute_error: 0.1243
# Epoch 9/50
#  - 145s - loss: 0.0233 - mean_absolute_error: 0.1201
# Epoch 10/50
#  - 146s - loss: 0.0233 - mean_absolute_error: 0.1203
# Epoch 11/50
#  - 147s - loss: 0.0227 - mean_absolute_error: 0.1205
# Epoch 12/50
#  - 147s - loss: 0.0222 - mean_absolute_error: 0.1183
# Epoch 13/50
#  - 148s - loss: 0.0211 - mean_absolute_error: 0.1154
# Epoch 14/50
#  - 147s - loss: 0.0210 - mean_absolute_error: 0.1141
# Epoch 15/50
#  - 147s - loss: 0.0197 - mean_absolute_error: 0.1118
# Epoch 16/50
#  - 148s - loss: 0.0202 - mean_absolute_error: 0.1132
# Epoch 17/50
#  - 149s - loss: 0.0195 - mean_absolute_error: 0.1108
# Epoch 18/50
#  - 150s - loss: 0.0183 - mean_absolute_error: 0.1088
# Epoch 19/50
#  - 150s - loss: 0.0181 - mean_absolute_error: 0.1079
# Epoch 20/50
#  - 148s - loss: 0.0171 - mean_absolute_error: 0.1044
# Epoch 21/50
#  - 147s - loss: 0.0171 - mean_absolute_error: 0.1047
# Epoch 22/50
#  - 149s - loss: 0.0172 - mean_absolute_error: 0.1051
# Epoch 23/50
#  - 150s - loss: 0.0157 - mean_absolute_error: 0.1007
# Epoch 24/50
#  - 150s - loss: 0.0156 - mean_absolute_error: 0.1013
# Epoch 25/50
#  - 150s - loss: 0.0152 - mean_absolute_error: 0.0985
# Epoch 26/50
#  - 149s - loss: 0.0152 - mean_absolute_error: 0.0980
# Epoch 27/50
#  - 150s - loss: 0.0144 - mean_absolute_error: 0.0961
# Epoch 28/50
#  - 149s - loss: 0.0139 - mean_absolute_error: 0.0942
# Epoch 29/50
#  - 149s - loss: 0.0140 - mean_absolute_error: 0.0953
# Epoch 30/50
#  - 150s - loss: 0.0126 - mean_absolute_error: 0.0908
# Epoch 31/50
#  - 149s - loss: 0.0132 - mean_absolute_error: 0.0921
# Epoch 32/50
#  - 148s - loss: 0.0126 - mean_absolute_error: 0.0895
# Epoch 33/50
#  - 148s - loss: 0.0123 - mean_absolute_error: 0.0895
# Epoch 34/50
#  - 148s - loss: 0.0125 - mean_absolute_error: 0.0897
# Epoch 35/50
#  - 146s - loss: 0.0114 - mean_absolute_error: 0.0864
# Epoch 36/50
#  - 147s - loss: 0.0114 - mean_absolute_error: 0.0859
# Epoch 37/50
#  - 147s - loss: 0.0108 - mean_absolute_error: 0.0845
# Epoch 38/50
#  - 148s - loss: 0.0106 - mean_absolute_error: 0.0829
# Epoch 39/50
#  - 147s - loss: 0.0101 - mean_absolute_error: 0.0822
# Epoch 40/50
#  - 147s - loss: 0.0100 - mean_absolute_error: 0.0807
# Epoch 41/50
#  - 147s - loss: 0.0103 - mean_absolute_error: 0.0809
# Epoch 42/50
#  - 148s - loss: 0.0097 - mean_absolute_error: 0.0787
# Epoch 43/50
#  - 147s - loss: 0.0092 - mean_absolute_error: 0.0781
# Epoch 44/50
#  - 148s - loss: 0.0091 - mean_absolute_error: 0.0769
# Epoch 45/50
#  - 147s - loss: 0.0089 - mean_absolute_error: 0.0770
# Epoch 46/50
#  - 148s - loss: 0.0085 - mean_absolute_error: 0.0740
# Epoch 47/50
#  - 146s - loss: 0.0084 - mean_absolute_error: 0.0739
# Epoch 48/50
#  - 148s - loss: 0.0084 - mean_absolute_error: 0.0741
# Epoch 49/50
#  - 148s - loss: 0.0078 - mean_absolute_error: 0.0717
# Epoch 50/50
#  - 148s - loss: 0.0076 - mean_absolute_error: 0.0714
# Kappa Score: 0.768739962671991
# Build model 4...
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# text_input (InputLayer)         (None, 256)          0
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 256, 50)      263350      text_input[0][0]
# __________________________________________________________________________________________________
# lstm_9 (LSTM)                   (None, 256, 300)     421200      embedding_5[0][0]
# __________________________________________________________________________________________________
# lstm_10 (LSTM)                  (None, 300)          721200      lstm_9[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 300)          0           lstm_10[0][0]
# __________________________________________________________________________________________________
# overall_feature_input (InputLay (None, 25)           0
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 325)          0           dropout_5[0][0]
#                                                                  overall_feature_input[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            326         lambda_5[0][0]
# ==================================================================================================
# Total params: 1,406,076
# Trainable params: 1,406,076
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
#  - 151s - loss: 0.0659 - mean_absolute_error: 0.1998
# Epoch 2/50
#  - 147s - loss: 0.0384 - mean_absolute_error: 0.1554
# Epoch 3/50
#  - 148s - loss: 0.0300 - mean_absolute_error: 0.1355
# Epoch 4/50
#  - 147s - loss: 0.0281 - mean_absolute_error: 0.1311
# Epoch 5/50
#  - 147s - loss: 0.0268 - mean_absolute_error: 0.1285
# Epoch 6/50
#  - 147s - loss: 0.0262 - mean_absolute_error: 0.1271
# Epoch 7/50
#  - 149s - loss: 0.0257 - mean_absolute_error: 0.1254
# Epoch 8/50
#  - 148s - loss: 0.0241 - mean_absolute_error: 0.1221
# Epoch 9/50
#  - 148s - loss: 0.0238 - mean_absolute_error: 0.1217
# Epoch 10/50
#  - 149s - loss: 0.0233 - mean_absolute_error: 0.1204
# Epoch 11/50
#  - 149s - loss: 0.0256 - mean_absolute_error: 0.1267
# Epoch 12/50
#  - 149s - loss: 0.0230 - mean_absolute_error: 0.1196
# Epoch 13/50
#  - 150s - loss: 0.0222 - mean_absolute_error: 0.1178
# Epoch 14/50
#  - 148s - loss: 0.0209 - mean_absolute_error: 0.1156
# Epoch 15/50
#  - 148s - loss: 0.0206 - mean_absolute_error: 0.1140
# Epoch 16/50
#  - 147s - loss: 0.0196 - mean_absolute_error: 0.1119
# Epoch 17/50
#  - 149s - loss: 0.0193 - mean_absolute_error: 0.1109
# Epoch 18/50
#  - 148s - loss: 0.0186 - mean_absolute_error: 0.1087
# Epoch 19/50
#  - 148s - loss: 0.0178 - mean_absolute_error: 0.1073
# Epoch 20/50
#  - 148s - loss: 0.0169 - mean_absolute_error: 0.1043
# Epoch 21/50
#  - 148s - loss: 0.0173 - mean_absolute_error: 0.1053
# Epoch 22/50
#  - 149s - loss: 0.0163 - mean_absolute_error: 0.1016
# Epoch 23/50
#  - 148s - loss: 0.0155 - mean_absolute_error: 0.0991
# Epoch 24/50
#  - 148s - loss: 0.0154 - mean_absolute_error: 0.1003
# Epoch 25/50
#  - 149s - loss: 0.0149 - mean_absolute_error: 0.0989
# Epoch 26/50
#  - 148s - loss: 0.0140 - mean_absolute_error: 0.0961
# Epoch 27/50
#  - 147s - loss: 0.0139 - mean_absolute_error: 0.0950
# Epoch 28/50
#  - 148s - loss: 0.0142 - mean_absolute_error: 0.0964
# Epoch 29/50
#  - 148s - loss: 0.0133 - mean_absolute_error: 0.0941
# Epoch 30/50
#  - 148s - loss: 0.0125 - mean_absolute_error: 0.0901
# Epoch 31/50
#  - 147s - loss: 0.0124 - mean_absolute_error: 0.0904
# Epoch 32/50
#  - 148s - loss: 0.0124 - mean_absolute_error: 0.0905
# Epoch 33/50
#  - 147s - loss: 0.0121 - mean_absolute_error: 0.0887
# Epoch 34/50
#  - 148s - loss: 0.0118 - mean_absolute_error: 0.0879
# Epoch 35/50
#  - 147s - loss: 0.0113 - mean_absolute_error: 0.0875
# Epoch 36/50
#  - 147s - loss: 0.0111 - mean_absolute_error: 0.0850
# Epoch 37/50
#  - 147s - loss: 0.0110 - mean_absolute_error: 0.0843
# Epoch 38/50
#  - 149s - loss: 0.0101 - mean_absolute_error: 0.0810
# Epoch 39/50
#  - 147s - loss: 0.0100 - mean_absolute_error: 0.0809
# Epoch 40/50
#  - 147s - loss: 0.0099 - mean_absolute_error: 0.0807
# Epoch 41/50
#  - 146s - loss: 0.0099 - mean_absolute_error: 0.0797
# Epoch 42/50
#  - 147s - loss: 0.0100 - mean_absolute_error: 0.0810
# Epoch 43/50
#  - 147s - loss: 0.0092 - mean_absolute_error: 0.0783
# Epoch 44/50
#  - 148s - loss: 0.0087 - mean_absolute_error: 0.0763
# Epoch 45/50
#  - 148s - loss: 0.0090 - mean_absolute_error: 0.0776
# Epoch 46/50
#  - 148s - loss: 0.0090 - mean_absolute_error: 0.0767
# Epoch 47/50
#  - 149s - loss: 0.0085 - mean_absolute_error: 0.0750
# Epoch 48/50
#  - 148s - loss: 0.0079 - mean_absolute_error: 0.0722
# Epoch 49/50
#  - 148s - loss: 0.0075 - mean_absolute_error: 0.0702
# Epoch 50/50
#  - 147s - loss: 0.0078 - mean_absolute_error: 0.0714
# Kappa Score: 0.7636460341732597
# Average Kappa score after a 5-fold cross validation:  0.76876
# Kappa score after a 5-fold cross validation:  0.7692497532082923
