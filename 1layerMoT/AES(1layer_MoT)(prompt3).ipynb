# %%
prompt_id = 3
model_name = "1layer_MoT"  # 1layer, 1layer_MoT, 2layer, 2layer_MoT

# %%
import os
import pprint
import tensorflow as tf

if 'COLAB_TPU_ADDR' not in os.environ:
  print('ERROR: Not connected to a TPU runtime')
else:
  tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
  print ('TPU address is', tpu_address)

  with tf.Session(tpu_address) as session:
    devices = session.list_devices()

  print('TPU devices:')
  pprint.pprint(devices)
# Out:
# TPU address is grpc://10.115.74.50:8470
# TPU devices:
# [_DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:CPU:0, CPU, -1, 16604546837251509377),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 17201039598428006975),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 960332082392662625),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 10257879207949714),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 5279337906012781587),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 4035012169652398044),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 8495643395126578693),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 278965319041828310),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 8823855950749329086),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 10549679783619071713),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 8589934592, 7115967208516124272)]

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/My Drive/AES謝"
os.chdir(path)
os.listdir(path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# ['glove.6B.50d.txt',
#  'data_feature',
#  'sent_feature',
#  'fine_tuning_out',
#  '1layer',
#  'AES(1layer)(prompt1).ipynb のコピー',
#  '1layerMoT',
#  '2layer',
#  '1layer+Overall',
#  '1layerMoT+Overall',
#  '2layer+Overall',
#  '実験結果.gsheet']

# %%
import argparse
import nltk
import tensorflow as tf
from keras.models import Model
from keras import layers
from keras.layers import Input, Embedding, LSTM, Dense
from keras.engine.topology import Layer
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
import keras.backend as K
from sklearn.model_selection import KFold
from sklearn.metrics import cohen_kappa_score
from keras.preprocessing.sequence import pad_sequences
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')

nltk.download('stopwords')
nltk.download('punkt')

# stopwords, punkt,
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Mean Over Time
class TemporalMean(Layer):
  def __init__(self, **kwargs):
      self.supports_masking = True
      super(TemporalMean, self).__init__(**kwargs)

  def compute_mask(self, input, input_mask=None):
      # do not pass the mask to the next layers
      return None

  def call(self, x, mask=None):
      if mask is not None:
          # mask (batch, time)
          mask = K.cast(mask, K.floatx())
          # mask (batch, x_dim, time)
          mask = K.repeat(mask, x.shape[-1])
          # mask (batch, time, x_dim)
          mask = tf.transpose(mask, [0,2,1])
          x = x * mask
      return K.sum(x, axis=1) / K.sum(mask, axis=1)

  def compute_output_shape(self, input_shape):
      # remove temporal dimension
      return (input_shape[0], input_shape[2])

def essay_to_wordlist(essay_v, remove_stopwords):
    """Remove the tagged labels and word tokenize the sentence."""
    essay_v = re.sub("[^a-zA-Z]", " ", essay_v)
    words = essay_v.lower().split()
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    return (words)

def get_clean_essays(Text):
    clean_essays = []
    for essay in Text:
        clean_essays.append(essay_to_wordlist(essay, remove_stopwords=False))
    return clean_essays

def create_dict(text):
    print("create_dict")
    word_index = {}
    word_index['xieyikuan'] = 0
    for sentence in text:
        for word in sentence:
            if word not in word_index:
                word_index[word] = len(word_index)
    word_index['unk'] = len(word_index)
    return word_index

def essay_to_index(essays, word_index):
    Essays = []
    for essay in essays:
        sentence = []
        for sent in essay:
            words = []
            for word in sent:
                words.append(word_index[word])
            sentence.append(words)
        Essays.append(sentence)
    return Essays

def essay_to_index2(essays, word_index):
    Essays = []
    for essay in essays:
        words = []
        for word in essay:
            words.append(word_index[word])
        Essays.append(words)
    return Essays

def get_embeddings_index():
    embeddings_index = {}
    f = open('glove.6B.50d.txt', 'r', encoding='UTF-8')
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.array(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    f.close()
    return embeddings_index

def embeddings_matrix(embeddings_index, word_index, embedding_dim):
    nb_words = len(word_index)
    embedding_matrix = np.zeros((nb_words + 1, embedding_dim))
    for word, i in word_index.items():
        if i > nb_words:
            continue
        embeddings_vector = embeddings_index.get(word)
        if embeddings_vector is not None:
            embedding_matrix[i] = embeddings_vector
        if embeddings_vector is None:
            embedding_matrix[i] = embeddings_index.get('unk')
    return embedding_matrix

# %%
csv_input = pd.read_csv(filepath_or_buffer="data_feature/set"+str(prompt_id)+"_feature(26).tsv", delimiter="\t", engine="python", error_bad_lines=False)

Text = csv_input['essay']
Score = csv_input['domain1_score']
Label = Score

# --------
if prompt_id == 1:
    Score = (Score - 2) / 10      # set_1     范围 2-12
elif prompt_id == 2:
    Score = (Score - 1) / 5       # set_2     范围 1-6
elif prompt_id == 3 or prompt_id == 4:
    Score = Score / 3           # set_3,4   范围 0-3
elif prompt_id == 5 or prompt_id == 6:
    Score = Score / 4           # set_5,6   范围 0-4
elif prompt_id == 7:
    Score = Score / 30          # set_7     范围 0-30
elif prompt_id == 8:
    Score = Score / 60          # set_8     范围 0-60
#print(Score)

# 做字典
clean_essays = get_clean_essays(Text)
word_index = create_dict(clean_essays)

# 做分句
text = np.array(Text)
# print(text)
a = []
for essay in text:
    a.append(sent_tokenize(essay))
texts = np.array(a)

# 做分词
essays = []
for essay in Text:
  essay_idx = essay_to_wordlist(essay, remove_stopwords=False)
  # sent = np.array(sent)
  essays.append(essay_idx)
essays = np.array(essays)

Essays = essay_to_index2(clean_essays, word_index)
Essays = np.array(Essays)

if prompt_id == 1:
    max_essay_length = 600
elif prompt_id == 2:
    max_essay_length = 700
elif prompt_id == 3:
    max_essay_length = 256
elif prompt_id == 4:
    max_essay_length = 200
elif prompt_id == 5:
    max_essay_length = 256
elif prompt_id == 6:
    max_essay_length = 256
elif prompt_id == 7:
    max_essay_length = 350
elif prompt_id == 8:
    max_essay_length = 870

essay_pad = pad_sequences(Essays, maxlen=max_essay_length)

embeddings_index = get_embeddings_index()
embeddings_matrix = embeddings_matrix(embeddings_index, word_index, embedding_dim=50)

# 记录成绩
results = []
score_predict_list = []
sssscore = []
llllabel = []
newresults = []
cv = KFold(n_splits=5, shuffle=True, random_state=10)

for train, test in cv.split(essay_pad):
    text_train, text_test = essay_pad[train], essay_pad[test]
    label_train, label_test = Score.iloc[train], Score.iloc[test]
    score_train, score_test = Label.iloc[train], Label.iloc[test]

    # -------
    print('Build model ...')
    text_input = Input(shape=(max_essay_length, ), name='text_input')

    embedding_layer = Embedding(input_dim=len(word_index) + 1,
                                output_dim=50,
                                weights=[embeddings_matrix],
                                input_length=max_essay_length,
                                trainable=True,
                                mask_zero=True)
    x = embedding_layer(text_input)  
    if model_name == "2layer_MoT":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)  
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)  
      x = TemporalMean()(x)
    elif model_name == "2layer":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)  
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)  
    elif model_name == "1layer_MoT":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=True)(x)  
      x = TemporalMean()(x)
    elif model_name == "1layer":
      x = LSTM(300, dropout=0.5, recurrent_dropout=0.1, return_sequences=False)(x)  
    x = layers.Dropout(0.5)(x)
    output = Dense(1, activation='sigmoid')(x)

    model = Model(inputs=text_input, outputs=output)
    # -------

    model.summary()
    model.compile(loss='mean_squared_error', optimizer=Adam(lr=0.001, decay=1e-6), metrics=['mean_absolute_error'])
    model.fit(text_train, label_train, batch_size=32, epochs=50, verbose=2)

    score_predict = model.predict(text_test)
    if prompt_id == 1:
        score_predict = score_predict*10+2
    elif prompt_id == 2:
        score_predict = score_predict*5+1
    elif prompt_id == 3:
        score_predict = score_predict*3
    elif prompt_id == 4:
        score_predict = score_predict*3
    elif prompt_id == 5:
        score_predict = score_predict*4
    elif prompt_id == 6:
        score_predict = score_predict*4
    elif prompt_id == 7:
        score_predict = score_predict*30
    elif prompt_id == 8:
        score_predict = score_predict*60

    score_predict = np.around(score_predict)

    sssscore.append(score_predict)
    llllabel.append(score_test)

    result = cohen_kappa_score(score_test.values, score_predict, weights='quadratic')
    print("Kappa Score: {}".format(result))
    results.append(result)
    for i in results:
      if i != 0:
        newresults.append(i)

print("Average Kappa score after a 5-fold cross validation: ", np.around(np.array(newresults).mean(), decimals=5))

sssscore = np.array(sssscore)
res = []
for scores in sssscore:
  for score in scores:
    res.append(score)

ll = np.array(llllabel)
res_label = []
for labels in ll:
  for label in labels:
    res_label.append(label)
res_label = np.array(res_label)

QWK = cohen_kappa_score(res_label, res, weights='quadratic')
print("Kappa score after a 5-fold cross validation: ", QWK)
# Out:
# create_dict
# Build model ...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3239: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 256)               0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 256, 50)           317500
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 256, 300)          421200
# _________________________________________________________________
# temporal_mean_1 (TemporalMea (None, 300)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 739,001
# Trainable params: 739,001
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/50
#  - 60s - loss: 0.0768 - mean_absolute_error: 0.2322
# Epoch 2/50
#  - 59s - loss: 0.0687 - mean_absolute_error: 0.2166
# Epoch 3/50
#  - 60s - loss: 0.0589 - mean_absolute_error: 0.1982
# Epoch 4/50
#  - 60s - loss: 0.0580 - mean_absolute_error: 0.1989
# Epoch 5/50
#  - 62s - loss: 0.0508 - mean_absolute_error: 0.1829
# Epoch 6/50
#  - 61s - loss: 0.0408 - mean_absolute_error: 0.1604
# Epoch 7/50
#  - 61s - loss: 0.0375 - mean_absolute_error: 0.1529
# Epoch 8/50
#  - 60s - loss: 0.0409 - mean_absolute_error: 0.1620
# Epoch 9/50
#  - 60s - loss: 0.0357 - mean_absolute_error: 0.1505
# Epoch 10/50
#  - 60s - loss: 0.0374 - mean_absolute_error: 0.1517
# Epoch 11/50
#  - 60s - loss: 0.0349 - mean_absolute_error: 0.1482
# Epoch 12/50
#  - 60s - loss: 0.0333 - mean_absolute_error: 0.1435
# Epoch 13/50
#  - 60s - loss: 0.0326 - mean_absolute_error: 0.1408
# Epoch 14/50
#  - 60s - loss: 0.0322 - mean_absolute_error: 0.1387
# Epoch 15/50
#  - 60s - loss: 0.0323 - mean_absolute_error: 0.1407
# Epoch 16/50
#  - 60s - loss: 0.0297 - mean_absolute_error: 0.1343
# Epoch 17/50
#  - 60s - loss: 0.0292 - mean_absolute_error: 0.1301
# Epoch 18/50
#  - 61s - loss: 0.0286 - mean_absolute_error: 0.1306
# Epoch 19/50
#  - 60s - loss: 0.0281 - mean_absolute_error: 0.1268
# Epoch 20/50
#  - 60s - loss: 0.0275 - mean_absolute_error: 0.1274
# Epoch 21/50
#  - 60s - loss: 0.0255 - mean_absolute_error: 0.1206
# Epoch 22/50
#  - 60s - loss: 0.0259 - mean_absolute_error: 0.1217
# Epoch 23/50
#  - 61s - loss: 0.0236 - mean_absolute_error: 0.1133
# Epoch 24/50
#  - 60s - loss: 0.0305 - mean_absolute_error: 0.1275
# Epoch 25/50
#  - 60s - loss: 0.0286 - mean_absolute_error: 0.1271
# Epoch 26/50
#  - 60s - loss: 0.0228 - mean_absolute_error: 0.1096
# Epoch 27/50
#  - 60s - loss: 0.0223 - mean_absolute_error: 0.1078
# Epoch 28/50
#  - 61s - loss: 0.0214 - mean_absolute_error: 0.1065
# Epoch 29/50
#  - 60s - loss: 0.0199 - mean_absolute_error: 0.1006
# Epoch 30/50
#  - 60s - loss: 0.0204 - mean_absolute_error: 0.1021
# Epoch 31/50
#  - 61s - loss: 0.0207 - mean_absolute_error: 0.1038
# Epoch 32/50
#  - 61s - loss: 0.0182 - mean_absolute_error: 0.0937
# Epoch 33/50
#  - 61s - loss: 0.0177 - mean_absolute_error: 0.0923
# Epoch 34/50
#  - 61s - loss: 0.0176 - mean_absolute_error: 0.0923
# Epoch 35/50
#  - 61s - loss: 0.0169 - mean_absolute_error: 0.0904
# Epoch 36/50
#  - 61s - loss: 0.0163 - mean_absolute_error: 0.0874
# Epoch 37/50
#  - 60s - loss: 0.0156 - mean_absolute_error: 0.0868
# Epoch 38/50
#  - 60s - loss: 0.0145 - mean_absolute_error: 0.0830
# Epoch 39/50
#  - 60s - loss: 0.0144 - mean_absolute_error: 0.0813
# Epoch 40/50
#  - 60s - loss: 0.0136 - mean_absolute_error: 0.0785
# Epoch 41/50
#  - 60s - loss: 0.0140 - mean_absolute_error: 0.0803
# Epoch 42/50
#  - 60s - loss: 0.0129 - mean_absolute_error: 0.0772
# Epoch 43/50
#  - 60s - loss: 0.0120 - mean_absolute_error: 0.0743
# Epoch 44/50
#  - 60s - loss: 0.0118 - mean_absolute_error: 0.0732
# Epoch 45/50
#  - 60s - loss: 0.0110 - mean_absolute_error: 0.0700
# Epoch 46/50
#  - 61s - loss: 0.0118 - mean_absolute_error: 0.0731
# Epoch 47/50
#  - 61s - loss: 0.0119 - mean_absolute_error: 0.0737
# Epoch 48/50
#  - 61s - loss: 0.0104 - mean_absolute_error: 0.0674
# Epoch 49/50
#  - 60s - loss: 0.0111 - mean_absolute_error: 0.0709
# Epoch 50/50
#  - 60s - loss: 0.0100 - mean_absolute_error: 0.0661
# Kappa Score: 0.5589642233107043
# Build model ...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 256)               0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 256, 50)           317500
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 256, 300)          421200
# _________________________________________________________________
# temporal_mean_2 (TemporalMea (None, 300)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 739,001
# Trainable params: 739,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 61s - loss: 0.0765 - mean_absolute_error: 0.2313
# Epoch 2/50
#  - 59s - loss: 0.0671 - mean_absolute_error: 0.2155
# Epoch 3/50
#  - 60s - loss: 0.0580 - mean_absolute_error: 0.1949
# Epoch 4/50
#  - 61s - loss: 0.0551 - mean_absolute_error: 0.1893
# Epoch 5/50
#  - 61s - loss: 0.0460 - mean_absolute_error: 0.1708
# Epoch 6/50
#  - 61s - loss: 0.0413 - mean_absolute_error: 0.1602
# Epoch 7/50
#  - 60s - loss: 0.0386 - mean_absolute_error: 0.1575
# Epoch 8/50
#  - 60s - loss: 0.0382 - mean_absolute_error: 0.1522
# Epoch 9/50
#  - 61s - loss: 0.0383 - mean_absolute_error: 0.1533
# Epoch 10/50
#  - 60s - loss: 0.0356 - mean_absolute_error: 0.1471
# Epoch 11/50
#  - 60s - loss: 0.0369 - mean_absolute_error: 0.1533
# Epoch 12/50
#  - 61s - loss: 0.0368 - mean_absolute_error: 0.1501
# Epoch 13/50
#  - 61s - loss: 0.0348 - mean_absolute_error: 0.1464
# Epoch 14/50
#  - 61s - loss: 0.0343 - mean_absolute_error: 0.1466
# Epoch 15/50
#  - 61s - loss: 0.0330 - mean_absolute_error: 0.1407
# Epoch 16/50
#  - 61s - loss: 0.0325 - mean_absolute_error: 0.1415
# Epoch 17/50
#  - 61s - loss: 0.0293 - mean_absolute_error: 0.1342
# Epoch 18/50
#  - 61s - loss: 0.0309 - mean_absolute_error: 0.1352
# Epoch 19/50
#  - 61s - loss: 0.0284 - mean_absolute_error: 0.1283
# Epoch 20/50
#  - 60s - loss: 0.0287 - mean_absolute_error: 0.1316
# Epoch 21/50
#  - 60s - loss: 0.0260 - mean_absolute_error: 0.1224
# Epoch 22/50
#  - 60s - loss: 0.0268 - mean_absolute_error: 0.1234
# Epoch 23/50
#  - 60s - loss: 0.0246 - mean_absolute_error: 0.1173
# Epoch 24/50
#  - 61s - loss: 0.0230 - mean_absolute_error: 0.1137
# Epoch 25/50
#  - 60s - loss: 0.0232 - mean_absolute_error: 0.1126
# Epoch 26/50
#  - 60s - loss: 0.0234 - mean_absolute_error: 0.1135
# Epoch 27/50
#  - 60s - loss: 0.0205 - mean_absolute_error: 0.1045
# Epoch 28/50
#  - 59s - loss: 0.0196 - mean_absolute_error: 0.1011
# Epoch 29/50
#  - 59s - loss: 0.0202 - mean_absolute_error: 0.1033
# Epoch 30/50
#  - 59s - loss: 0.0183 - mean_absolute_error: 0.0960
# Epoch 31/50
#  - 59s - loss: 0.0172 - mean_absolute_error: 0.0930
# Epoch 32/50
#  - 59s - loss: 0.0171 - mean_absolute_error: 0.0931
# Epoch 33/50
#  - 59s - loss: 0.0158 - mean_absolute_error: 0.0876
# Epoch 34/50
#  - 59s - loss: 0.0167 - mean_absolute_error: 0.0917
# Epoch 35/50
#  - 59s - loss: 0.0149 - mean_absolute_error: 0.0850
# Epoch 36/50
#  - 59s - loss: 0.0144 - mean_absolute_error: 0.0841
# Epoch 37/50
#  - 59s - loss: 0.0146 - mean_absolute_error: 0.0837
# Epoch 38/50
#  - 58s - loss: 0.0142 - mean_absolute_error: 0.0825
# Epoch 39/50
#  - 58s - loss: 0.0136 - mean_absolute_error: 0.0796
# Epoch 40/50
#  - 59s - loss: 0.0132 - mean_absolute_error: 0.0777
# Epoch 41/50
#  - 59s - loss: 0.0132 - mean_absolute_error: 0.0782
# Epoch 42/50
#  - 59s - loss: 0.0120 - mean_absolute_error: 0.0743
# Epoch 43/50
#  - 59s - loss: 0.0114 - mean_absolute_error: 0.0706
# Epoch 44/50
#  - 58s - loss: 0.0119 - mean_absolute_error: 0.0731
# Epoch 45/50
#  - 59s - loss: 0.0110 - mean_absolute_error: 0.0697
# Epoch 46/50
#  - 57s - loss: 0.0115 - mean_absolute_error: 0.0724
# Epoch 47/50
#  - 58s - loss: 0.0113 - mean_absolute_error: 0.0708
# Epoch 48/50
#  - 58s - loss: 0.0102 - mean_absolute_error: 0.0681
# Epoch 49/50
#  - 58s - loss: 0.0105 - mean_absolute_error: 0.0702
# Epoch 50/50
#  - 58s - loss: 0.0102 - mean_absolute_error: 0.0672
# Kappa Score: 0.6641603168742238
# Build model ...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 256)               0
# _________________________________________________________________
# embedding_3 (Embedding)      (None, 256, 50)           317500
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 256, 300)          421200
# _________________________________________________________________
# temporal_mean_3 (TemporalMea (None, 300)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 739,001
# Trainable params: 739,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 58s - loss: 0.0796 - mean_absolute_error: 0.2345
# Epoch 2/50
#  - 57s - loss: 0.0716 - mean_absolute_error: 0.2223
# Epoch 3/50
#  - 58s - loss: 0.0638 - mean_absolute_error: 0.2085
# Epoch 4/50
#  - 59s - loss: 0.0569 - mean_absolute_error: 0.1954
# Epoch 5/50
#  - 59s - loss: 0.0479 - mean_absolute_error: 0.1763
# Epoch 6/50
#  - 58s - loss: 0.0415 - mean_absolute_error: 0.1622
# Epoch 7/50
#  - 58s - loss: 0.0392 - mean_absolute_error: 0.1571
# Epoch 8/50
#  - 59s - loss: 0.0406 - mean_absolute_error: 0.1598
# Epoch 9/50
#  - 59s - loss: 0.0381 - mean_absolute_error: 0.1554
# Epoch 10/50
#  - 58s - loss: 0.0361 - mean_absolute_error: 0.1501
# Epoch 11/50
#  - 59s - loss: 0.0360 - mean_absolute_error: 0.1513
# Epoch 12/50
#  - 58s - loss: 0.0363 - mean_absolute_error: 0.1501
# Epoch 13/50
#  - 58s - loss: 0.0337 - mean_absolute_error: 0.1456
# Epoch 14/50
#  - 59s - loss: 0.0343 - mean_absolute_error: 0.1460
# Epoch 15/50
#  - 59s - loss: 0.0329 - mean_absolute_error: 0.1430
# Epoch 16/50
#  - 58s - loss: 0.0324 - mean_absolute_error: 0.1401
# Epoch 17/50
#  - 59s - loss: 0.0310 - mean_absolute_error: 0.1366
# Epoch 18/50
#  - 59s - loss: 0.0299 - mean_absolute_error: 0.1335
# Epoch 19/50
#  - 59s - loss: 0.0293 - mean_absolute_error: 0.1317
# Epoch 20/50
#  - 59s - loss: 0.0282 - mean_absolute_error: 0.1277
# Epoch 21/50
#  - 59s - loss: 0.0271 - mean_absolute_error: 0.1264
# Epoch 22/50
#  - 59s - loss: 0.0262 - mean_absolute_error: 0.1221
# Epoch 23/50
#  - 59s - loss: 0.0245 - mean_absolute_error: 0.1181
# Epoch 24/50
#  - 58s - loss: 0.0223 - mean_absolute_error: 0.1105
# Epoch 25/50
#  - 59s - loss: 0.0225 - mean_absolute_error: 0.1100
# Epoch 26/50
#  - 58s - loss: 0.0202 - mean_absolute_error: 0.1042
# Epoch 27/50
#  - 58s - loss: 0.0199 - mean_absolute_error: 0.1021
# Epoch 28/50
#  - 58s - loss: 0.0207 - mean_absolute_error: 0.1041
# Epoch 29/50
#  - 58s - loss: 0.0187 - mean_absolute_error: 0.0987
# Epoch 30/50
#  - 59s - loss: 0.0180 - mean_absolute_error: 0.0967
# Epoch 31/50
#  - 58s - loss: 0.0165 - mean_absolute_error: 0.0910
# Epoch 32/50
#  - 58s - loss: 0.0172 - mean_absolute_error: 0.0922
# Epoch 33/50
#  - 58s - loss: 0.0150 - mean_absolute_error: 0.0865
# Epoch 34/50
#  - 58s - loss: 0.0152 - mean_absolute_error: 0.0862
# Epoch 35/50
#  - 58s - loss: 0.0158 - mean_absolute_error: 0.0886
# Epoch 36/50
#  - 59s - loss: 0.0213 - mean_absolute_error: 0.1055
# Epoch 37/50
#  - 58s - loss: 0.0146 - mean_absolute_error: 0.0832
# Epoch 38/50
#  - 58s - loss: 0.0150 - mean_absolute_error: 0.0852
# Epoch 39/50
#  - 59s - loss: 0.0141 - mean_absolute_error: 0.0831
# Epoch 40/50
#  - 58s - loss: 0.0133 - mean_absolute_error: 0.0792
# Epoch 41/50
#  - 59s - loss: 0.0120 - mean_absolute_error: 0.0779
# Epoch 42/50
#  - 58s - loss: 0.0124 - mean_absolute_error: 0.0774
# Epoch 43/50
#  - 58s - loss: 0.0122 - mean_absolute_error: 0.0740
# Epoch 44/50
#  - 59s - loss: 0.0117 - mean_absolute_error: 0.0730
# Epoch 45/50
#  - 59s - loss: 0.0112 - mean_absolute_error: 0.0712
# Epoch 46/50
#  - 59s - loss: 0.0101 - mean_absolute_error: 0.0681
# Epoch 47/50
#  - 58s - loss: 0.0109 - mean_absolute_error: 0.0716
# Epoch 48/50
#  - 59s - loss: 0.0103 - mean_absolute_error: 0.0676
# Epoch 49/50
#  - 59s - loss: 0.0096 - mean_absolute_error: 0.0674
# Epoch 50/50
#  - 58s - loss: 0.0091 - mean_absolute_error: 0.0651
# Kappa Score: 0.6015350877192982
# Build model ...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 256)               0
# _________________________________________________________________
# embedding_4 (Embedding)      (None, 256, 50)           317500
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 256, 300)          421200
# _________________________________________________________________
# temporal_mean_4 (TemporalMea (None, 300)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 739,001
# Trainable params: 739,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 60s - loss: 0.0753 - mean_absolute_error: 0.2296
# Epoch 2/50
#  - 58s - loss: 0.0689 - mean_absolute_error: 0.2195
# Epoch 3/50
#  - 59s - loss: 0.0612 - mean_absolute_error: 0.2023
# Epoch 4/50
#  - 58s - loss: 0.0553 - mean_absolute_error: 0.1919
# Epoch 5/50
#  - 59s - loss: 0.0467 - mean_absolute_error: 0.1734
# Epoch 6/50
#  - 59s - loss: 0.0413 - mean_absolute_error: 0.1613
# Epoch 7/50
#  - 59s - loss: 0.0409 - mean_absolute_error: 0.1601
# Epoch 8/50
#  - 59s - loss: 0.0383 - mean_absolute_error: 0.1555
# Epoch 9/50
#  - 58s - loss: 0.0376 - mean_absolute_error: 0.1520
# Epoch 10/50
#  - 59s - loss: 0.0359 - mean_absolute_error: 0.1485
# Epoch 11/50
#  - 59s - loss: 0.0361 - mean_absolute_error: 0.1491
# Epoch 12/50
#  - 59s - loss: 0.0371 - mean_absolute_error: 0.1520
# Epoch 13/50
#  - 59s - loss: 0.0397 - mean_absolute_error: 0.1584
# Epoch 14/50
#  - 59s - loss: 0.0366 - mean_absolute_error: 0.1489
# Epoch 15/50
#  - 58s - loss: 0.0350 - mean_absolute_error: 0.1484
# Epoch 16/50
#  - 59s - loss: 0.0318 - mean_absolute_error: 0.1406
# Epoch 17/50
#  - 59s - loss: 0.0324 - mean_absolute_error: 0.1410
# Epoch 18/50
#  - 59s - loss: 0.0292 - mean_absolute_error: 0.1310
# Epoch 19/50
#  - 59s - loss: 0.0312 - mean_absolute_error: 0.1362
# Epoch 20/50
#  - 59s - loss: 0.0283 - mean_absolute_error: 0.1273
# Epoch 21/50
#  - 59s - loss: 0.0281 - mean_absolute_error: 0.1278
# Epoch 22/50
#  - 58s - loss: 0.0270 - mean_absolute_error: 0.1239
# Epoch 23/50
#  - 59s - loss: 0.0271 - mean_absolute_error: 0.1216
# Epoch 24/50
#  - 59s - loss: 0.0270 - mean_absolute_error: 0.1232
# Epoch 25/50
#  - 59s - loss: 0.0240 - mean_absolute_error: 0.1132
# Epoch 26/50
#  - 58s - loss: 0.0229 - mean_absolute_error: 0.1090
# Epoch 27/50
#  - 59s - loss: 0.0220 - mean_absolute_error: 0.1066
# Epoch 28/50
#  - 59s - loss: 0.0213 - mean_absolute_error: 0.1031
# Epoch 29/50
#  - 59s - loss: 0.0203 - mean_absolute_error: 0.1015
# Epoch 30/50
#  - 58s - loss: 0.0193 - mean_absolute_error: 0.0992
# Epoch 31/50
#  - 59s - loss: 0.0190 - mean_absolute_error: 0.0974
# Epoch 32/50
#  - 59s - loss: 0.0189 - mean_absolute_error: 0.0966
# Epoch 33/50
#  - 59s - loss: 0.0173 - mean_absolute_error: 0.0910
# Epoch 34/50
#  - 60s - loss: 0.0169 - mean_absolute_error: 0.0889
# Epoch 35/50
#  - 59s - loss: 0.0165 - mean_absolute_error: 0.0892
# Epoch 36/50
#  - 60s - loss: 0.0166 - mean_absolute_error: 0.0882
# Epoch 37/50
#  - 59s - loss: 0.0158 - mean_absolute_error: 0.0860
# Epoch 38/50
#  - 59s - loss: 0.0159 - mean_absolute_error: 0.0851
# Epoch 39/50
#  - 59s - loss: 0.0149 - mean_absolute_error: 0.0831
# Epoch 40/50
#  - 59s - loss: 0.0144 - mean_absolute_error: 0.0801
# Epoch 41/50
#  - 58s - loss: 0.0142 - mean_absolute_error: 0.0806
# Epoch 42/50
#  - 59s - loss: 0.0133 - mean_absolute_error: 0.0775
# Epoch 43/50
#  - 59s - loss: 0.0141 - mean_absolute_error: 0.0816
# Epoch 44/50
#  - 60s - loss: 0.0125 - mean_absolute_error: 0.0748
# Epoch 45/50
#  - 59s - loss: 0.0117 - mean_absolute_error: 0.0734
# Epoch 46/50
#  - 58s - loss: 0.0124 - mean_absolute_error: 0.0749
# Epoch 47/50
#  - 59s - loss: 0.0114 - mean_absolute_error: 0.0719
# Epoch 48/50
#  - 60s - loss: 0.0112 - mean_absolute_error: 0.0695
# Epoch 49/50
#  - 61s - loss: 0.0114 - mean_absolute_error: 0.0713
# Epoch 50/50
#  - 59s - loss: 0.0107 - mean_absolute_error: 0.0689
# Kappa Score: 0.6585510688836105
# Build model ...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# text_input (InputLayer)      (None, 256)               0
# _________________________________________________________________
# embedding_5 (Embedding)      (None, 256, 50)           317500
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 256, 300)          421200
# _________________________________________________________________
# temporal_mean_5 (TemporalMea (None, 300)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 739,001
# Trainable params: 739,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  - 61s - loss: 0.0823 - mean_absolute_error: 0.2400
# Epoch 2/50
#  - 59s - loss: 0.0722 - mean_absolute_error: 0.2239
# Epoch 3/50
#  - 59s - loss: 0.0652 - mean_absolute_error: 0.2125
# Epoch 4/50
#  - 59s - loss: 0.0570 - mean_absolute_error: 0.1948
# Epoch 5/50
#  - 59s - loss: 0.0466 - mean_absolute_error: 0.1739
# Epoch 6/50
#  - 59s - loss: 0.0423 - mean_absolute_error: 0.1631
# Epoch 7/50
#  - 59s - loss: 0.0398 - mean_absolute_error: 0.1582
# Epoch 8/50
#  - 60s - loss: 0.0406 - mean_absolute_error: 0.1612
# Epoch 9/50
#  - 59s - loss: 0.0369 - mean_absolute_error: 0.1537
# Epoch 10/50
#  - 60s - loss: 0.0348 - mean_absolute_error: 0.1482
# Epoch 11/50
#  - 59s - loss: 0.0350 - mean_absolute_error: 0.1491
# Epoch 12/50
#  - 59s - loss: 0.0362 - mean_absolute_error: 0.1505
# Epoch 13/50
#  - 60s - loss: 0.0363 - mean_absolute_error: 0.1509
# Epoch 14/50
#  - 59s - loss: 0.0351 - mean_absolute_error: 0.1476
# Epoch 15/50
#  - 60s - loss: 0.0331 - mean_absolute_error: 0.1416
# Epoch 16/50
#  - 59s - loss: 0.0363 - mean_absolute_error: 0.1506
# Epoch 17/50
#  - 60s - loss: 0.0346 - mean_absolute_error: 0.1467
# Epoch 18/50
#  - 59s - loss: 0.0326 - mean_absolute_error: 0.1421
# Epoch 19/50
#  - 60s - loss: 0.0314 - mean_absolute_error: 0.1383
# Epoch 20/50
#  - 60s - loss: 0.0294 - mean_absolute_error: 0.1318
# Epoch 21/50
#  - 60s - loss: 0.0281 - mean_absolute_error: 0.1295
# Epoch 22/50
#  - 59s - loss: 0.0275 - mean_absolute_error: 0.1257
# Epoch 23/50
#  - 59s - loss: 0.0281 - mean_absolute_error: 0.1271
# Epoch 24/50
#  - 59s - loss: 0.0272 - mean_absolute_error: 0.1257
# Epoch 25/50
#  - 59s - loss: 0.0257 - mean_absolute_error: 0.1195
# Epoch 26/50
#  - 59s - loss: 0.0250 - mean_absolute_error: 0.1173
# Epoch 27/50
#  - 59s - loss: 0.0237 - mean_absolute_error: 0.1137
# Epoch 28/50
#  - 58s - loss: 0.0230 - mean_absolute_error: 0.1127
# Epoch 29/50
#  - 58s - loss: 0.0247 - mean_absolute_error: 0.1188
# Epoch 30/50
#  - 59s - loss: 0.0481 - mean_absolute_error: 0.1761
# Epoch 31/50
#  - 60s - loss: 0.0269 - mean_absolute_error: 0.1287
# Epoch 32/50
#  - 59s - loss: 0.0224 - mean_absolute_error: 0.1126
# Epoch 33/50
#  - 59s - loss: 0.0217 - mean_absolute_error: 0.1066
# Epoch 34/50
#  - 59s - loss: 0.0203 - mean_absolute_error: 0.1027
# Epoch 35/50
#  - 58s - loss: 0.0190 - mean_absolute_error: 0.1007
# Epoch 36/50
#  - 59s - loss: 0.0170 - mean_absolute_error: 0.0940
# Epoch 37/50
#  - 58s - loss: 0.0171 - mean_absolute_error: 0.0921
# Epoch 38/50
#  - 59s - loss: 0.0157 - mean_absolute_error: 0.0881
# Epoch 39/50
#  - 59s - loss: 0.0163 - mean_absolute_error: 0.0892
# Epoch 40/50
#  - 58s - loss: 0.0152 - mean_absolute_error: 0.0889
# Epoch 41/50
#  - 60s - loss: 0.0149 - mean_absolute_error: 0.0859
# Epoch 42/50
#  - 60s - loss: 0.0137 - mean_absolute_error: 0.0824
# Epoch 43/50
#  - 58s - loss: 0.0143 - mean_absolute_error: 0.0840
# Epoch 44/50
#  - 59s - loss: 0.0139 - mean_absolute_error: 0.0831
# Epoch 45/50
#  - 58s - loss: 0.0130 - mean_absolute_error: 0.0795
# Epoch 46/50
#  - 59s - loss: 0.0123 - mean_absolute_error: 0.0756
# Epoch 47/50
#  - 59s - loss: 0.0127 - mean_absolute_error: 0.0777
# Epoch 48/50
#  - 59s - loss: 0.0124 - mean_absolute_error: 0.0757
# Epoch 49/50
#  - 58s - loss: 0.0106 - mean_absolute_error: 0.0702
# Epoch 50/50
#  - 59s - loss: 0.0113 - mean_absolute_error: 0.0735
# Kappa Score: 0.583738761530378
# Average Kappa score after a 5-fold cross validation:  0.61046
# Kappa score after a 5-fold cross validation:  0.61562947325888
